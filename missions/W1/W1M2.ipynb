# %%
import sqlite3
import csv

conn = sqlite3.connect(":memory:")
cursor = conn.cursor()

cursor.execute("DROP TABLE IF EXISTS Customers")

# # 테이블 생성 (CustomerID 자동 증가)
# cursor.execute("""
# CREATE TABLE Customers (
#     CustomerID INTEGER PRIMARY KEY AUTOINCREMENT,
#     CustomerName TEXT,
#     ContactName TEXT,
#     Address TEXT,
#     City TEXT,
#     PostalCode TEXT,
#     Country TEXT
# );
# """)

# # CSV 불러오기 (customerID 무시)
# with open("customers.csv", encoding="utf-8") as f:
#     reader = csv.DictReader(f)
#     for row in reader:
#         cursor.execute("""
#             INSERT INTO Customers (CustomerName, ContactName, Address, City, PostalCode, Country)
#             VALUES (?, ?, ?, ?, ?, ?)
#         """, (
#             row['companyName'],
#             row['contactName'],
#             row['address'],
#             row['city'],
#             row['postalCode'],
#             row['country']
#         ))


# w3schools.com 예제 실습에서는 CustomerID가 정수형으로 나오지만, 가져온 데이터에서는 CustomerID가 문자형으로 되어있어서 정수형으로 바꿔 진행
# 하지만 나중에 Customers 테이블과 Orders 테이블에 존재하는 CustomerID가 달라져 잘못된 예측 결과를 가져옴.
# 데이터 타입 불일치는 버그의 은상이자 성능 저하의 주범! 쿼리를 작성하기 전에 항상 조인하거나 비교할 열의 데이터 타입이 동일한지 확인하는 습관을 갖자.
# 따라서 Customers 테이블의 CustomerID를 다시 문자열로 바꿔 진행.

cursor.execute("""
CREATE TABLE Customers (
    CustomerID TEXT PRIMARY KEY,
    CustomerName TEXT,
    ContactName TEXT,
    Address TEXT,
    City TEXT,
    PostalCode TEXT,
    Country TEXT
);
""")

with open("customers.csv", encoding="utf-8") as f:
    reader = csv.DictReader(f)
    for row in reader:
        cursor.execute("""
            INSERT INTO Customers (CustomerID, CustomerName, ContactName, Address, City, PostalCode, Country)
            VALUES (?, ?, ?, ?, ?, ?, ?)
        """, (
            row['customerID'],
            row['companyName'],
            row['contactName'],
            row['address'],
            row['city'],
            row['postalCode'],
            row['country']
        ))
conn.commit()

# %%
cursor.execute("DROP TABLE IF EXISTS Products;")

cursor.execute("""
CREATE TABLE Products (
    ProductID INTEGER PRIMARY KEY,
    ProductName TEXT,
    SupplierID INTEGER,
    CategoryID INTEGER,
    QuantityPerUnit TEXT,
    UnitPrice REAL,
    UnitsInStock INTEGER,
    UnitsOnOrder INTEGER,
    ReorderLevel INTEGER,
    Discontinued INTEGER
);
""")

with open("products.csv", encoding="utf-8") as f:
    reader = csv.DictReader(f)
    for row in reader:
        cursor.execute("""
            INSERT INTO Products (
                ProductID, ProductName, SupplierID, CategoryID,
                QuantityPerUnit, UnitPrice, UnitsInStock,
                UnitsOnOrder, ReorderLevel, Discontinued
            )
            VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
        """, (
            int(row['productID']),
            row['productName'],
            int(row['supplierID']),
            int(row['categoryID']),
            row['quantityPerUnit'],
            float(row['unitPrice']),
            int(row['unitsInStock']),
            int(row['unitsOnOrder']),
            int(row['reorderLevel']),
            int(row['discontinued'])
        ))
conn.commit()

# %%
cursor.execute("DROP TABLE IF EXISTS Order_details")

# 새 테이블 생성
cursor.execute("""
CREATE TABLE Order_details (
    orderID INTEGER,
    productID INTEGER,
    unitPrice REAL,
    quantity INTEGER,
    discount REAL
)
""")

with open('order_details.csv', newline='', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for row in reader:
        cursor.execute("""
            INSERT INTO Order_details (
                orderID, productID,
                unitPrice, quantity, discount
            )
            VALUES (?, ?, ?, ?, ?)
        """, (
            int(row['orderID']),
            int(row['productID']),
            float(row['unitPrice']),
            int(row['quantity']),
            float(row['discount'])
        ))

conn.commit()

# %%
cursor.execute("DROP TABLE IF EXISTS Orders")

cursor.execute("""
CREATE TABLE Orders (
    orderID INTEGER,
    customerID TEXT,
    employeeID INTEGER,
    orderDate TEXT,
    requiredDate TEXT,
    shippedDate TEXT,
    shipVia INTEGER,
    freight REAL,
    shipName TEXT,
    shipAddress TEXT,
    shipCity TEXT,
    shipRegion TEXT,
    shipPostalCode TEXT,
    shipCountry TEXT
)
""")

with open('orders.csv', newline='', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for row in reader:
        cursor.execute("""
            INSERT INTO Orders (
                orderID, customerID, employeeID,
                orderDate, requiredDate, shippedDate,
                shipVia, freight, shipName,
                shipAddress, shipCity, shipRegion,
                shipPostalCode, shipCountry
            ) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
        """, (
            int(row['orderID']),
            row['customerID'],
            int(row['employeeID']),
            row['orderDate'],
            row['requiredDate'],
            row['shippedDate'],
            int(row['shipVia']),
            float(row['freight']),
            row['shipName'],
            row['shipAddress'],
            row['shipCity'],
            row['shipRegion'] if row['shipRegion'] != 'NULL' else None,
            row['shipPostalCode'],
            row['shipCountry']
        ))

conn.commit()

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS Categories (
    CategoryID INTEGER PRIMARY KEY,
    CategoryName TEXT,
    Description TEXT,
    Picture BLOB
);
""")

with open("categories.csv", encoding="utf-8") as f:
    reader = csv.DictReader(f)
    for row in reader:
        cursor.execute("""
            INSERT INTO Categories (CategoryID, CategoryName, Description, Picture)
            VALUES (?, ?, ?, ?)
        """, (
            int(row['categoryID']),
            row['categoryName'],
            row['description'],
            bytes.fromhex(row['picture'][2:]) if row['picture'].startswith("0x") else row['picture']
        ))
conn.commit()

# %%
cursor.execute("DROP TABLE IF EXISTS Employees;")

cursor.execute("""
CREATE TABLE IF NOT EXISTS Employees (
    EmployeeID INTEGER PRIMARY KEY,
    LastName TEXT,
    FirstName TEXT,
    Title TEXT,
    TitleOfCourtesy TEXT,
    BirthDate TEXT,
    HireDate TEXT,
    Address TEXT,
    City TEXT,
    Region TEXT,
    PostalCode TEXT,
    Country TEXT,
    HomePhone TEXT,
    Extension TEXT,
    Photo BLOB,
    Notes TEXT,
    ReportsTo INTEGER,
    PhotoPath TEXT
);
""")

def parse_blob(value):
    if value.startswith("0x"):
        return bytes.fromhex(value[2:])
    return value

def parse_nullable_int(value):
    return int(value) if value and value.upper() != 'NULL' else None

with open("employees.csv", encoding="utf-8") as f:
    reader = csv.DictReader(f)
    for row in reader:
        cursor.execute("""
            INSERT INTO Employees (
                EmployeeID, LastName, FirstName, Title, TitleOfCourtesy,
                BirthDate, HireDate, Address, City, Region, PostalCode,
                Country, HomePhone, Extension, Photo, Notes, ReportsTo, PhotoPath
            ) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
        """, (
            int(row['employeeID']),
            row['lastName'],
            row['firstName'],
            row['title'],
            row['titleOfCourtesy'],
            row['birthDate'],
            row['hireDate'],
            row['address'],
            row['city'],
            row['region'],
            row['postalCode'],
            row['country'],
            row['homePhone'],
            row['extension'],
            parse_blob(row['photo']),
            row['notes'],
            parse_nullable_int(row['reportsTo']),
            row['photoPath']
        ))
conn.commit()

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS Suppliers (
    SupplierID INTEGER PRIMARY KEY,
    CompanyName TEXT,
    ContactName TEXT,
    ContactTitle TEXT,
    Address TEXT,
    City TEXT,
    Region TEXT,
    PostalCode TEXT,
    Country TEXT,
    Phone TEXT,
    Fax TEXT,
    HomePage TEXT
);
""")

def clean_nullable(val):
    return None if val.upper() == 'NULL' or val.strip() == '' else val

with open("suppliers.csv", encoding="utf-8") as f:
    reader = csv.DictReader(f)
    for row in reader:
        cursor.execute("""
            INSERT INTO Suppliers (
                SupplierID, CompanyName, ContactName, ContactTitle,
                Address, City, Region, PostalCode, Country,
                Phone, Fax, HomePage
            ) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
        """, (
            int(row['supplierID']),
            row['companyName'],
            row['contactName'],
            row['contactTitle'],
            row['address'],
            row['city'],
            clean_nullable(row['region']),
            row['postalCode'],
            row['country'],
            row['phone'],
            clean_nullable(row['fax']),
            clean_nullable(row['homePage'])
        ))
conn.commit()

# %%
cursor.execute("SELECT * FROM Customers;")
for row in cursor.fetchall():
    print(row)
# Out:
# ('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# ('ANTON', 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos  2312', 'México D.F.', '05023', 'Mexico')
# ('AROUT', 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen  8', 'Luleå', 'S-958 22', 'Sweden')
# ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany')
# ('BLONP', 'Blondesddsl père et fils', 'Frédérique Citeaux', '24 place Kléber', 'Strasbourg', '67000', 'France')
# ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', '67C Araquil', 'Madrid', '28023', 'Spain')
# ('BONAP', "Bon app'", 'Laurence Lebihan', '12 rue des Bouchers', 'Marseille', '13008', 'France')
# ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada')
# ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK')
# ('CACTU', 'Cactus Comidas para llevar', 'Patricio Simpson', 'Cerrito 333', 'Buenos Aires', '1010', 'Argentina')
# ('CENTC', 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '05022', 'Mexico')
# ('CHOPS', 'Chop-suey Chinese', 'Yang Wang', 'Hauptstr. 29', 'Bern', '3012', 'Switzerland')
# ('COMMI', 'Comércio Mineiro', 'Pedro Afonso', '23 Av. dos Lusíadas', 'Sao Paulo', '05432-043', 'Brazil')
# ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12  Brewery', 'London', 'WX1 6LT', 'UK')
# ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Walserweg 21', 'Aachen', '52066', 'Germany')
# ('DUMON', 'Du monde entier', 'Janine Labrune', '67 rue des Cinquante Otages', 'Nantes', '44000', 'France')
# ('EASTC', 'Eastern Connection', 'Ann Devon', '35 King George', 'London', 'WX3 6FW', 'UK')
# ('ERNSH', 'Ernst Handel', 'Roland Mendel', 'Kirchgasse 6', 'Graz', '8010', 'Austria')
# ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 'Rua Orós 92', 'Sao Paulo', '05442-030', 'Brazil')
# ('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'C/ Moralzarzal 86', 'Madrid', '28034', 'Spain')
# ('FOLIG', 'Folies gourmandes', 'Martine Rancé', '184 chaussée de Tournai', 'Lille', '59000', 'France')
# ('FOLKO', 'Folk och fä HB', 'Maria Larsson', 'Åkergatan 24', 'Bräcke', 'S-844 67', 'Sweden')
# ('FRANK', 'Frankenversand', 'Peter Franken', 'Berliner Platz 43', 'München', '80805', 'Germany')
# ('FRANR', 'France restauration', 'Carine Schmitt', '54 rue Royale', 'Nantes', '44000', 'France')
# ('FRANS', 'Franchi S.p.A.', 'Paolo Accorti', 'Via Monte Bianco 34', 'Torino', '10100', 'Italy')
# ('FURIB', 'Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez', 'Jardim das rosas n. 32', 'Lisboa', '1675', 'Portugal')
# ('GALED', 'Galería del gastrónomo', 'Eduardo Saavedra', 'Rambla de Cataluña 23', 'Barcelona', '08022', 'Spain')
# ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero 33', 'Sevilla', '41101', 'Spain')
# ('GOURL', 'Gourmet Lanchonetes', 'André Fonseca', 'Av. Brasil 442', 'Campinas', '04876-786', 'Brazil')
# ('GREAL', 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA')
# ('GROSR', 'GROSELLA-Restaurante', 'Manuel Pereira', '5ª Ave. Los Palos Grandes', 'Caracas', '1081', 'Venezuela')
# ('HANAR', 'Hanari Carnes', 'Mario Pontes', 'Rua do Paço 67', 'Rio de Janeiro', '05454-876', 'Brazil')
# ('HILAA', 'HILARION-Abastos', 'Carlos Hernández', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristóbal', '5022', 'Venezuela')
# ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA')
# ('HUNGO', 'Hungry Owl All-Night Grocers', 'Patricia McKenna', '8 Johnstown Road', 'Cork', 'NULL', 'Ireland')
# ('ISLAT', 'Island Trading', 'Helen Bennett', 'Garden House Crowther Way', 'Cowes', 'PO31 7PJ', 'UK')
# ('KOENE', 'Königlich Essen', 'Philip Cramer', 'Maubelstr. 90', 'Brandenburg', '14776', 'Germany')
# ('LACOR', "La corne d'abondance", 'Daniel Tonini', "67 avenue de l'Europe", 'Versailles', '78000', 'France')
# ('LAMAI', "La maison d'Asie", 'Annette Roulet', '1 rue Alsace-Lorraine', 'Toulouse', '31000', 'France')
# ('LAUGB', 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', '1900 Oak St.', 'Vancouver', 'V3F 2K1', 'Canada')
# ('LAZYK', 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA')
# ('LEHMS', 'Lehmanns Marktstand', 'Renate Messner', 'Magazinweg 7', 'Frankfurt a.M.', '60528', 'Germany')
# ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA')
# ('LILAS', 'LILA-Supermercado', 'Carlos González', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', '3508', 'Venezuela')
# ('LINOD', 'LINO-Delicateses', 'Felipe Izquierdo', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita', '4980', 'Venezuela')
# ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA')
# ('MAGAA', 'Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 'Via Ludovico il Moro 22', 'Bergamo', '24100', 'Italy')
# ('MAISD', 'Maison Dewey', 'Catherine Dewey', 'Rue Joseph-Bens 532', 'Bruxelles', 'B-1180', 'Belgium')
# ('MEREP', 'Mère Paillarde', 'Jean Fresnière', '43 rue St. Laurent', 'Montréal', 'H1J 1C3', 'Canada')
# ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '04179', 'Germany')
# ('NORTS', 'North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK')
# ('OCEAN', 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', '1010', 'Argentina')
# ('OLDWO', 'Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA')
# ('OTTIK', 'Ottilies Käseladen', 'Henriette Pfalzheim', 'Mehrheimerstr. 369', 'Köln', '50739', 'Germany')
# ('PARIS', 'Paris spécialités', 'Marie Bertrand', '265 boulevard Charonne', 'Paris', '75012', 'France')
# ('PERIC', 'Pericles Comidas clásicas', 'Guillermo Fernández', 'Calle Dr. Jorge Cash 321', 'México D.F.', '05033', 'Mexico')
# ('PICCO', 'Piccolo und mehr', 'Georg Pipps', 'Geislweg 14', 'Salzburg', '5020', 'Austria')
# ('PRINI', 'Princesa Isabel Vinhos', 'Isabel de Castro', 'Estrada da saúde n. 58', 'Lisboa', '1756', 'Portugal')
# ('QUEDE', 'Que Delícia', 'Bernardo Batista', 'Rua da Panificadora', ' 12Rio de Janeiro', '02389-673', 'Brazil')
# ('QUEEN', 'Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios 891', 'Sao Paulo', '05487-020', 'Brazil')
# ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Taucherstraße 10', 'Cunewalde', '01307', 'Germany')
# ('RANCH', 'Rancho grande', 'Sergio Gutiérrez', 'Av. del Libertador 900', 'Buenos Aires', '1010', 'Argentina')
# ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', '2817 Milton Dr.', 'Albuquerque', '87110', 'USA')
# ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Strada Provinciale 124', 'Reggio Emilia', '42100', 'Italy')
# ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Av. Copacabana 267', 'Rio de Janeiro', '02389-890', 'Brazil')
# ('RICSU', 'Richter Supermarkt', 'Michael Holz', 'Grenzacherweg 237', 'Genève', '1203', 'Switzerland')
# ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Gran Vía 1', 'Madrid', '28001', 'Spain')
# ('SANTG', 'Santé Gourmet', 'Jonas Bergulfsen', 'Erling Skakkes gate 78', 'Stavern', '4110', 'Norway')
# ('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', '187 Suffolk Ln.', 'Boise', '83720', 'USA')
# ('SEVES', 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK')
# ('SIMOB', 'Simons bistro', 'Jytte Petersen', 'Vinbæltet 34', 'Kobenhavn', '1734', 'Denmark')
# ('SPECD', 'Spécialités du monde', 'Dominique Perrier', '25 rue Lauriston', 'Paris', '75016', 'France')
# ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'P.O. Box 555', 'Lander', '82520', 'USA')
# ('SUPRD', 'Suprêmes délices', 'Pascale Cartrain', 'Boulevard Tirou 255', 'Charleroi', 'B-6000', 'Belgium')
# ('THEBI', 'The Big Cheese', 'Liz Nixon', '89 Jefferson Way Suite 2', 'Portland', '97201', 'USA')
# ('THECR', 'The Cracker Box', 'Liu Wong', '55 Grizzly Peak Rd.', 'Butte', '59801', 'USA')
# ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Luisenstr. 48', 'Münster', '44087', 'Germany')
# ('TORTU', 'Tortuga Restaurante', 'Miguel Angel Paolino', 'Avda. Azteca 123', 'México D.F.', '05033', 'Mexico')
# ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 'Av. Inês de Castro 414', 'Sao Paulo', '05634-030', 'Brazil')
# ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', '722 DaVinci Blvd.', 'Kirkland', '98034', 'USA')
# ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 'Smagsloget 45', 'Århus', '8200', 'Denmark')
# ('VICTE', 'Victuailles en stock', 'Mary Saveley', '2 rue du Commerce', 'Lyon', '69004', 'France')
# ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', "59 rue de l'Abbaye", 'Reims', '51100', 'France')
# ('WANDK', 'Die Wandernde Kuh', 'Rita Müller', 'Adenauerallee 900', 'Stuttgart', '70563', 'Germany')
# ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Torikatu 38', 'Oulu', '90110', 'Finland')
# ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Rua do Mercado 12', 'Resende', '08737-363', 'Brazil')
# ('WHITC', 'White Clover Markets', 'Karl Jablonski', '305 - 14th Ave. S. Suite 3B', 'Seattle', '98128', 'USA')
# ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Keskuskatu 45', 'Helsinki', '21240', 'Finland')
# ('WOLZA', 'Wolski  Zajazd', 'Zbyszek Piestrzeniewicz', 'ul. Filtrowa 68', 'Warszawa', '01-012', 'Poland')

# %%
# 예제 실행 함수
def run_query(title, query):
    print(f"\n {title}")
    print(f"SQL : {query}")
    cursor.execute(query)
    rows = cursor.fetchall()
    for row in rows:
        print(row)

# %%
run_query("SQL Syntax", "SELECT * FROM Customers;")
# Out:
#  SQL Syntax
# SQL : SELECT * FROM Customers;
# ('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# ('ANTON', 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos  2312', 'México D.F.', '05023', 'Mexico')
# ('AROUT', 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen  8', 'Luleå', 'S-958 22', 'Sweden')
# ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany')
# ('BLONP', 'Blondesddsl père et fils', 'Frédérique Citeaux', '24 place Kléber', 'Strasbourg', '67000', 'France')
# ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', '67C Araquil', 'Madrid', '28023', 'Spain')
# ('BONAP', "Bon app'", 'Laurence Lebihan', '12 rue des Bouchers', 'Marseille', '13008', 'France')
# ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada')
# ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK')
# ('CACTU', 'Cactus Comidas para llevar', 'Patricio Simpson', 'Cerrito 333', 'Buenos Aires', '1010', 'Argentina')
# ('CENTC', 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '05022', 'Mexico')
# ('CHOPS', 'Chop-suey Chinese', 'Yang Wang', 'Hauptstr. 29', 'Bern', '3012', 'Switzerland')
# ('COMMI', 'Comércio Mineiro', 'Pedro Afonso', '23 Av. dos Lusíadas', 'Sao Paulo', '05432-043', 'Brazil')
# ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12  Brewery', 'London', 'WX1 6LT', 'UK')
# ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Walserweg 21', 'Aachen', '52066', 'Germany')
# ('DUMON', 'Du monde entier', 'Janine Labrune', '67 rue des Cinquante Otages', 'Nantes', '44000', 'France')
# ('EASTC', 'Eastern Connection', 'Ann Devon', '35 King George', 'London', 'WX3 6FW', 'UK')
# ('ERNSH', 'Ernst Handel', 'Roland Mendel', 'Kirchgasse 6', 'Graz', '8010', 'Austria')
# ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 'Rua Orós 92', 'Sao Paulo', '05442-030', 'Brazil')
# ('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'C/ Moralzarzal 86', 'Madrid', '28034', 'Spain')
# ('FOLIG', 'Folies gourmandes', 'Martine Rancé', '184 chaussée de Tournai', 'Lille', '59000', 'France')
# ('FOLKO', 'Folk och fä HB', 'Maria Larsson', 'Åkergatan 24', 'Bräcke', 'S-844 67', 'Sweden')
# ('FRANK', 'Frankenversand', 'Peter Franken', 'Berliner Platz 43', 'München', '80805', 'Germany')
# ('FRANR', 'France restauration', 'Carine Schmitt', '54 rue Royale', 'Nantes', '44000', 'France')
# ('FRANS', 'Franchi S.p.A.', 'Paolo Accorti', 'Via Monte Bianco 34', 'Torino', '10100', 'Italy')
# ('FURIB', 'Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez', 'Jardim das rosas n. 32', 'Lisboa', '1675', 'Portugal')
# ('GALED', 'Galería del gastrónomo', 'Eduardo Saavedra', 'Rambla de Cataluña 23', 'Barcelona', '08022', 'Spain')
# ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero 33', 'Sevilla', '41101', 'Spain')
# ('GOURL', 'Gourmet Lanchonetes', 'André Fonseca', 'Av. Brasil 442', 'Campinas', '04876-786', 'Brazil')
# ('GREAL', 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA')
# ('GROSR', 'GROSELLA-Restaurante', 'Manuel Pereira', '5ª Ave. Los Palos Grandes', 'Caracas', '1081', 'Venezuela')
# ('HANAR', 'Hanari Carnes', 'Mario Pontes', 'Rua do Paço 67', 'Rio de Janeiro', '05454-876', 'Brazil')
# ('HILAA', 'HILARION-Abastos', 'Carlos Hernández', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristóbal', '5022', 'Venezuela')
# ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA')
# ('HUNGO', 'Hungry Owl All-Night Grocers', 'Patricia McKenna', '8 Johnstown Road', 'Cork', 'NULL', 'Ireland')
# ('ISLAT', 'Island Trading', 'Helen Bennett', 'Garden House Crowther Way', 'Cowes', 'PO31 7PJ', 'UK')
# ('KOENE', 'Königlich Essen', 'Philip Cramer', 'Maubelstr. 90', 'Brandenburg', '14776', 'Germany')
# ('LACOR', "La corne d'abondance", 'Daniel Tonini', "67 avenue de l'Europe", 'Versailles', '78000', 'France')
# ('LAMAI', "La maison d'Asie", 'Annette Roulet', '1 rue Alsace-Lorraine', 'Toulouse', '31000', 'France')
# ('LAUGB', 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', '1900 Oak St.', 'Vancouver', 'V3F 2K1', 'Canada')
# ('LAZYK', 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA')
# ('LEHMS', 'Lehmanns Marktstand', 'Renate Messner', 'Magazinweg 7', 'Frankfurt a.M.', '60528', 'Germany')
# ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA')
# ('LILAS', 'LILA-Supermercado', 'Carlos González', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', '3508', 'Venezuela')
# ('LINOD', 'LINO-Delicateses', 'Felipe Izquierdo', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita', '4980', 'Venezuela')
# ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA')
# ('MAGAA', 'Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 'Via Ludovico il Moro 22', 'Bergamo', '24100', 'Italy')
# ('MAISD', 'Maison Dewey', 'Catherine Dewey', 'Rue Joseph-Bens 532', 'Bruxelles', 'B-1180', 'Belgium')
# ('MEREP', 'Mère Paillarde', 'Jean Fresnière', '43 rue St. Laurent', 'Montréal', 'H1J 1C3', 'Canada')
# ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '04179', 'Germany')
# ('NORTS', 'North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK')
# ('OCEAN', 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', '1010', 'Argentina')
# ('OLDWO', 'Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA')
# ('OTTIK', 'Ottilies Käseladen', 'Henriette Pfalzheim', 'Mehrheimerstr. 369', 'Köln', '50739', 'Germany')
# ('PARIS', 'Paris spécialités', 'Marie Bertrand', '265 boulevard Charonne', 'Paris', '75012', 'France')
# ('PERIC', 'Pericles Comidas clásicas', 'Guillermo Fernández', 'Calle Dr. Jorge Cash 321', 'México D.F.', '05033', 'Mexico')
# ('PICCO', 'Piccolo und mehr', 'Georg Pipps', 'Geislweg 14', 'Salzburg', '5020', 'Austria')
# ('PRINI', 'Princesa Isabel Vinhos', 'Isabel de Castro', 'Estrada da saúde n. 58', 'Lisboa', '1756', 'Portugal')
# ('QUEDE', 'Que Delícia', 'Bernardo Batista', 'Rua da Panificadora', ' 12Rio de Janeiro', '02389-673', 'Brazil')
# ('QUEEN', 'Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios 891', 'Sao Paulo', '05487-020', 'Brazil')
# ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Taucherstraße 10', 'Cunewalde', '01307', 'Germany')
# ('RANCH', 'Rancho grande', 'Sergio Gutiérrez', 'Av. del Libertador 900', 'Buenos Aires', '1010', 'Argentina')
# ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', '2817 Milton Dr.', 'Albuquerque', '87110', 'USA')
# ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Strada Provinciale 124', 'Reggio Emilia', '42100', 'Italy')
# ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Av. Copacabana 267', 'Rio de Janeiro', '02389-890', 'Brazil')
# ('RICSU', 'Richter Supermarkt', 'Michael Holz', 'Grenzacherweg 237', 'Genève', '1203', 'Switzerland')
# ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Gran Vía 1', 'Madrid', '28001', 'Spain')
# ('SANTG', 'Santé Gourmet', 'Jonas Bergulfsen', 'Erling Skakkes gate 78', 'Stavern', '4110', 'Norway')
# ('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', '187 Suffolk Ln.', 'Boise', '83720', 'USA')
# ('SEVES', 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK')
# ('SIMOB', 'Simons bistro', 'Jytte Petersen', 'Vinbæltet 34', 'Kobenhavn', '1734', 'Denmark')
# ('SPECD', 'Spécialités du monde', 'Dominique Perrier', '25 rue Lauriston', 'Paris', '75016', 'France')
# ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'P.O. Box 555', 'Lander', '82520', 'USA')
# ('SUPRD', 'Suprêmes délices', 'Pascale Cartrain', 'Boulevard Tirou 255', 'Charleroi', 'B-6000', 'Belgium')
# ('THEBI', 'The Big Cheese', 'Liz Nixon', '89 Jefferson Way Suite 2', 'Portland', '97201', 'USA')
# ('THECR', 'The Cracker Box', 'Liu Wong', '55 Grizzly Peak Rd.', 'Butte', '59801', 'USA')
# ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Luisenstr. 48', 'Münster', '44087', 'Germany')
# ('TORTU', 'Tortuga Restaurante', 'Miguel Angel Paolino', 'Avda. Azteca 123', 'México D.F.', '05033', 'Mexico')
# ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 'Av. Inês de Castro 414', 'Sao Paulo', '05634-030', 'Brazil')
# ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', '722 DaVinci Blvd.', 'Kirkland', '98034', 'USA')
# ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 'Smagsloget 45', 'Århus', '8200', 'Denmark')
# ('VICTE', 'Victuailles en stock', 'Mary Saveley', '2 rue du Commerce', 'Lyon', '69004', 'France')
# ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', "59 rue de l'Abbaye", 'Reims', '51100', 'France')
# ('WANDK', 'Die Wandernde Kuh', 'Rita Müller', 'Adenauerallee 900', 'Stuttgart', '70563', 'Germany')
# ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Torikatu 38', 'Oulu', '90110', 'Finland')
# ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Rua do Mercado 12', 'Resende', '08737-363', 'Brazil')
# ('WHITC', 'White Clover Markets', 'Karl Jablonski', '305 - 14th Ave. S. Suite 3B', 'Seattle', '98128', 'USA')
# ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Keskuskatu 45', 'Helsinki', '21240', 'Finland')
# ('WOLZA', 'Wolski  Zajazd', 'Zbyszek Piestrzeniewicz', 'ul. Filtrowa 68', 'Warszawa', '01-012', 'Poland')

# %%
run_query("SQL SELECT", "SELECT CustomerName,City FROM Customers;")
# Out:
#  SQL SELECT
# SQL : SELECT CustomerName,City FROM Customers;
# ('Alfreds Futterkiste', 'Berlin')
# ('Ana Trujillo Emparedados y helados', 'México D.F.')
# ('Antonio Moreno Taquería', 'México D.F.')
# ('Around the Horn', 'London')
# ('Berglunds snabbköp', 'Luleå')
# ('Blauer See Delikatessen', 'Mannheim')
# ('Blondesddsl père et fils', 'Strasbourg')
# ('Bólido Comidas preparadas', 'Madrid')
# ("Bon app'", 'Marseille')
# ('Bottom-Dollar Markets', 'Tsawassen')
# ("B's Beverages", 'London')
# ('Cactus Comidas para llevar', 'Buenos Aires')
# ('Centro comercial Moctezuma', 'México D.F.')
# ('Chop-suey Chinese', 'Bern')
# ('Comércio Mineiro', 'Sao Paulo')
# ('Consolidated Holdings', 'London')
# ('Drachenblut Delikatessen', 'Aachen')
# ('Du monde entier', 'Nantes')
# ('Eastern Connection', 'London')
# ('Ernst Handel', 'Graz')
# ('Familia Arquibaldo', 'Sao Paulo')
# ('FISSA Fabrica Inter. Salchichas S.A.', 'Madrid')
# ('Folies gourmandes', 'Lille')
# ('Folk och fä HB', 'Bräcke')
# ('Frankenversand', 'München')
# ('France restauration', 'Nantes')
# ('Franchi S.p.A.', 'Torino')
# ('Furia Bacalhau e Frutos do Mar', 'Lisboa')
# ('Galería del gastrónomo', 'Barcelona')
# ('Godos Cocina Típica', 'Sevilla')
# ('Gourmet Lanchonetes', 'Campinas')
# ('Great Lakes Food Market', 'Eugene')
# ('GROSELLA-Restaurante', 'Caracas')
# ('Hanari Carnes', 'Rio de Janeiro')
# ('HILARION-Abastos', 'San Cristóbal')
# ('Hungry Coyote Import Store', 'Elgin')
# ('Hungry Owl All-Night Grocers', 'Cork')
# ('Island Trading', 'Cowes')
# ('Königlich Essen', 'Brandenburg')
# ("La corne d'abondance", 'Versailles')
# ("La maison d'Asie", 'Toulouse')
# ('Laughing Bacchus Wine Cellars', 'Vancouver')
# ('Lazy K Kountry Store', 'Walla Walla')
# ('Lehmanns Marktstand', 'Frankfurt a.M.')
# ("Let's Stop N Shop", 'San Francisco')
# ('LILA-Supermercado', 'Barquisimeto')
# ('LINO-Delicateses', 'I. de Margarita')
# ('Lonesome Pine Restaurant', 'Portland')
# ('Magazzini Alimentari Riuniti', 'Bergamo')
# ('Maison Dewey', 'Bruxelles')
# ('Mère Paillarde', 'Montréal')
# ('Morgenstern Gesundkost', 'Leipzig')
# ('North/South', 'London')
# ('Océano Atlántico Ltda.', 'Buenos Aires')
# ('Old World Delicatessen', 'Anchorage')
# ('Ottilies Käseladen', 'Köln')
# ('Paris spécialités', 'Paris')
# ('Pericles Comidas clásicas', 'México D.F.')
# ('Piccolo und mehr', 'Salzburg')
# ('Princesa Isabel Vinhos', 'Lisboa')
# ('Que Delícia', ' 12Rio de Janeiro')
# ('Queen Cozinha', 'Sao Paulo')
# ('QUICK-Stop', 'Cunewalde')
# ('Rancho grande', 'Buenos Aires')
# ('Rattlesnake Canyon Grocery', 'Albuquerque')
# ('Reggiani Caseifici', 'Reggio Emilia')
# ('Ricardo Adocicados', 'Rio de Janeiro')
# ('Richter Supermarkt', 'Genève')
# ('Romero y tomillo', 'Madrid')
# ('Santé Gourmet', 'Stavern')
# ('Save-a-lot Markets', 'Boise')
# ('Seven Seas Imports', 'London')
# ('Simons bistro', 'Kobenhavn')
# ('Spécialités du monde', 'Paris')
# ('Split Rail Beer & Ale', 'Lander')
# ('Suprêmes délices', 'Charleroi')
# ('The Big Cheese', 'Portland')
# ('The Cracker Box', 'Butte')
# ('Toms Spezialitäten', 'Münster')
# ('Tortuga Restaurante', 'México D.F.')
# ('Tradição Hipermercados', 'Sao Paulo')
# ("Trail's Head Gourmet Provisioners", 'Kirkland')
# ('Vaffeljernet', 'Århus')
# ('Victuailles en stock', 'Lyon')
# ('Vins et alcools Chevalier', 'Reims')
# ('Die Wandernde Kuh', 'Stuttgart')
# ('Wartian Herkku', 'Oulu')
# ('Wellington Importadora', 'Resende')
# ('White Clover Markets', 'Seattle')
# ('Wilman Kala', 'Helsinki')
# ('Wolski  Zajazd', 'Warszawa')

# %%
run_query("SQL Select Distinct", "SELECT DISTINCT Country FROM Customers;")

run_query("SQL Select Distinct / Count Distinct", "SELECT COUNT(DISTINCT Country) FROM Customers;")

run_query("SQL Select Distinct / Count Distinct 2", "SELECT Count(*) AS DistinctCountries FROM (SELECT DISTINCT Country FROM Customers);")
# Out:
#  SQL Select Distinct
# SQL : SELECT DISTINCT Country FROM Customers;
# ('Germany',)
# ('Mexico',)
# ('UK',)
# ('Sweden',)
# ('France',)
# ('Spain',)
# ('Canada',)
# ('Argentina',)
# ('Switzerland',)
# ('Brazil',)
# ('Austria',)
# ('Italy',)
# ('Portugal',)
# ('USA',)
# ('Venezuela',)
# ('Ireland',)
# ('Belgium',)
# ('Norway',)
# ('Denmark',)
# ('Finland',)
# ('Poland',)
#
#  SQL Select Distinct / Count Distinct
# SQL : SELECT COUNT(DISTINCT Country) FROM Customers;
# (21,)
#
#  SQL Select Distinct / Count Distinct 2
# SQL : SELECT Count(*) AS DistinctCountries FROM (SELECT DISTINCT Country FROM Customers);
# (21,)

# %%
run_query("SQL Where", "SELECT * FROM Customers WHERE Country='Mexico';")

run_query("Sql Where / Text Fields vs Numeric Fields", "SELECT * FROM Customers WHERE CustomerID=1;")

run_query("SQL Where / Operators in the WHERE Clause", "SELECT * FROM Customers WHERE CustomerID > 80;")
# Out:
#  SQL Where
# SQL : SELECT * FROM Customers WHERE Country='Mexico';
# ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# ('ANTON', 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos  2312', 'México D.F.', '05023', 'Mexico')
# ('CENTC', 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '05022', 'Mexico')
# ('PERIC', 'Pericles Comidas clásicas', 'Guillermo Fernández', 'Calle Dr. Jorge Cash 321', 'México D.F.', '05033', 'Mexico')
# ('TORTU', 'Tortuga Restaurante', 'Miguel Angel Paolino', 'Avda. Azteca 123', 'México D.F.', '05033', 'Mexico')
#
#  Sql Where / Text Fields vs Numeric Fields
# SQL : SELECT * FROM Customers WHERE CustomerID=1;
#
#  SQL Where / Operators in the WHERE Clause
# SQL : SELECT * FROM Customers WHERE CustomerID > 80;
# ('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# ('ANTON', 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos  2312', 'México D.F.', '05023', 'Mexico')
# ('AROUT', 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen  8', 'Luleå', 'S-958 22', 'Sweden')
# ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany')
# ('BLONP', 'Blondesddsl père et fils', 'Frédérique Citeaux', '24 place Kléber', 'Strasbourg', '67000', 'France')
# ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', '67C Araquil', 'Madrid', '28023', 'Spain')
# ('BONAP', "Bon app'", 'Laurence Lebihan', '12 rue des Bouchers', 'Marseille', '13008', 'France')
# ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada')
# ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK')
# ('CACTU', 'Cactus Comidas para llevar', 'Patricio Simpson', 'Cerrito 333', 'Buenos Aires', '1010', 'Argentina')
# ('CENTC', 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '05022', 'Mexico')
# ('CHOPS', 'Chop-suey Chinese', 'Yang Wang', 'Hauptstr. 29', 'Bern', '3012', 'Switzerland')
# ('COMMI', 'Comércio Mineiro', 'Pedro Afonso', '23 Av. dos Lusíadas', 'Sao Paulo', '05432-043', 'Brazil')
# ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12  Brewery', 'London', 'WX1 6LT', 'UK')
# ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Walserweg 21', 'Aachen', '52066', 'Germany')
# ('DUMON', 'Du monde entier', 'Janine Labrune', '67 rue des Cinquante Otages', 'Nantes', '44000', 'France')
# ('EASTC', 'Eastern Connection', 'Ann Devon', '35 King George', 'London', 'WX3 6FW', 'UK')
# ('ERNSH', 'Ernst Handel', 'Roland Mendel', 'Kirchgasse 6', 'Graz', '8010', 'Austria')
# ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 'Rua Orós 92', 'Sao Paulo', '05442-030', 'Brazil')
# ('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'C/ Moralzarzal 86', 'Madrid', '28034', 'Spain')
# ('FOLIG', 'Folies gourmandes', 'Martine Rancé', '184 chaussée de Tournai', 'Lille', '59000', 'France')
# ('FOLKO', 'Folk och fä HB', 'Maria Larsson', 'Åkergatan 24', 'Bräcke', 'S-844 67', 'Sweden')
# ('FRANK', 'Frankenversand', 'Peter Franken', 'Berliner Platz 43', 'München', '80805', 'Germany')
# ('FRANR', 'France restauration', 'Carine Schmitt', '54 rue Royale', 'Nantes', '44000', 'France')
# ('FRANS', 'Franchi S.p.A.', 'Paolo Accorti', 'Via Monte Bianco 34', 'Torino', '10100', 'Italy')
# ('FURIB', 'Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez', 'Jardim das rosas n. 32', 'Lisboa', '1675', 'Portugal')
# ('GALED', 'Galería del gastrónomo', 'Eduardo Saavedra', 'Rambla de Cataluña 23', 'Barcelona', '08022', 'Spain')
# ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero 33', 'Sevilla', '41101', 'Spain')
# ('GOURL', 'Gourmet Lanchonetes', 'André Fonseca', 'Av. Brasil 442', 'Campinas', '04876-786', 'Brazil')
# ('GREAL', 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA')
# ('GROSR', 'GROSELLA-Restaurante', 'Manuel Pereira', '5ª Ave. Los Palos Grandes', 'Caracas', '1081', 'Venezuela')
# ('HANAR', 'Hanari Carnes', 'Mario Pontes', 'Rua do Paço 67', 'Rio de Janeiro', '05454-876', 'Brazil')
# ('HILAA', 'HILARION-Abastos', 'Carlos Hernández', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristóbal', '5022', 'Venezuela')
# ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA')
# ('HUNGO', 'Hungry Owl All-Night Grocers', 'Patricia McKenna', '8 Johnstown Road', 'Cork', 'NULL', 'Ireland')
# ('ISLAT', 'Island Trading', 'Helen Bennett', 'Garden House Crowther Way', 'Cowes', 'PO31 7PJ', 'UK')
# ('KOENE', 'Königlich Essen', 'Philip Cramer', 'Maubelstr. 90', 'Brandenburg', '14776', 'Germany')
# ('LACOR', "La corne d'abondance", 'Daniel Tonini', "67 avenue de l'Europe", 'Versailles', '78000', 'France')
# ('LAMAI', "La maison d'Asie", 'Annette Roulet', '1 rue Alsace-Lorraine', 'Toulouse', '31000', 'France')
# ('LAUGB', 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', '1900 Oak St.', 'Vancouver', 'V3F 2K1', 'Canada')
# ('LAZYK', 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA')
# ('LEHMS', 'Lehmanns Marktstand', 'Renate Messner', 'Magazinweg 7', 'Frankfurt a.M.', '60528', 'Germany')
# ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA')
# ('LILAS', 'LILA-Supermercado', 'Carlos González', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', '3508', 'Venezuela')
# ('LINOD', 'LINO-Delicateses', 'Felipe Izquierdo', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita', '4980', 'Venezuela')
# ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA')
# ('MAGAA', 'Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 'Via Ludovico il Moro 22', 'Bergamo', '24100', 'Italy')
# ('MAISD', 'Maison Dewey', 'Catherine Dewey', 'Rue Joseph-Bens 532', 'Bruxelles', 'B-1180', 'Belgium')
# ('MEREP', 'Mère Paillarde', 'Jean Fresnière', '43 rue St. Laurent', 'Montréal', 'H1J 1C3', 'Canada')
# ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '04179', 'Germany')
# ('NORTS', 'North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK')
# ('OCEAN', 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', '1010', 'Argentina')
# ('OLDWO', 'Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA')
# ('OTTIK', 'Ottilies Käseladen', 'Henriette Pfalzheim', 'Mehrheimerstr. 369', 'Köln', '50739', 'Germany')
# ('PARIS', 'Paris spécialités', 'Marie Bertrand', '265 boulevard Charonne', 'Paris', '75012', 'France')
# ('PERIC', 'Pericles Comidas clásicas', 'Guillermo Fernández', 'Calle Dr. Jorge Cash 321', 'México D.F.', '05033', 'Mexico')
# ('PICCO', 'Piccolo und mehr', 'Georg Pipps', 'Geislweg 14', 'Salzburg', '5020', 'Austria')
# ('PRINI', 'Princesa Isabel Vinhos', 'Isabel de Castro', 'Estrada da saúde n. 58', 'Lisboa', '1756', 'Portugal')
# ('QUEDE', 'Que Delícia', 'Bernardo Batista', 'Rua da Panificadora', ' 12Rio de Janeiro', '02389-673', 'Brazil')
# ('QUEEN', 'Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios 891', 'Sao Paulo', '05487-020', 'Brazil')
# ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Taucherstraße 10', 'Cunewalde', '01307', 'Germany')
# ('RANCH', 'Rancho grande', 'Sergio Gutiérrez', 'Av. del Libertador 900', 'Buenos Aires', '1010', 'Argentina')
# ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', '2817 Milton Dr.', 'Albuquerque', '87110', 'USA')
# ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Strada Provinciale 124', 'Reggio Emilia', '42100', 'Italy')
# ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Av. Copacabana 267', 'Rio de Janeiro', '02389-890', 'Brazil')
# ('RICSU', 'Richter Supermarkt', 'Michael Holz', 'Grenzacherweg 237', 'Genève', '1203', 'Switzerland')
# ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Gran Vía 1', 'Madrid', '28001', 'Spain')
# ('SANTG', 'Santé Gourmet', 'Jonas Bergulfsen', 'Erling Skakkes gate 78', 'Stavern', '4110', 'Norway')
# ('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', '187 Suffolk Ln.', 'Boise', '83720', 'USA')
# ('SEVES', 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK')
# ('SIMOB', 'Simons bistro', 'Jytte Petersen', 'Vinbæltet 34', 'Kobenhavn', '1734', 'Denmark')
# ('SPECD', 'Spécialités du monde', 'Dominique Perrier', '25 rue Lauriston', 'Paris', '75016', 'France')
# ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'P.O. Box 555', 'Lander', '82520', 'USA')
# ('SUPRD', 'Suprêmes délices', 'Pascale Cartrain', 'Boulevard Tirou 255', 'Charleroi', 'B-6000', 'Belgium')
# ('THEBI', 'The Big Cheese', 'Liz Nixon', '89 Jefferson Way Suite 2', 'Portland', '97201', 'USA')
# ('THECR', 'The Cracker Box', 'Liu Wong', '55 Grizzly Peak Rd.', 'Butte', '59801', 'USA')
# ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Luisenstr. 48', 'Münster', '44087', 'Germany')
# ('TORTU', 'Tortuga Restaurante', 'Miguel Angel Paolino', 'Avda. Azteca 123', 'México D.F.', '05033', 'Mexico')
# ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 'Av. Inês de Castro 414', 'Sao Paulo', '05634-030', 'Brazil')
# ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', '722 DaVinci Blvd.', 'Kirkland', '98034', 'USA')
# ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 'Smagsloget 45', 'Århus', '8200', 'Denmark')
# ('VICTE', 'Victuailles en stock', 'Mary Saveley', '2 rue du Commerce', 'Lyon', '69004', 'France')
# ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', "59 rue de l'Abbaye", 'Reims', '51100', 'France')
# ('WANDK', 'Die Wandernde Kuh', 'Rita Müller', 'Adenauerallee 900', 'Stuttgart', '70563', 'Germany')
# ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Torikatu 38', 'Oulu', '90110', 'Finland')
# ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Rua do Mercado 12', 'Resende', '08737-363', 'Brazil')
# ('WHITC', 'White Clover Markets', 'Karl Jablonski', '305 - 14th Ave. S. Suite 3B', 'Seattle', '98128', 'USA')
# ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Keskuskatu 45', 'Helsinki', '21240', 'Finland')
# ('WOLZA', 'Wolski  Zajazd', 'Zbyszek Piestrzeniewicz', 'ul. Filtrowa 68', 'Warszawa', '01-012', 'Poland')

# %%
run_query("SQL Order By", "SELECT * FROM Products ORDER BY unitPrice;")

run_query("SQL Order By / DESC", "SELECT * FROM Products ORDER BY unitPrice DESC;")

run_query("SQL Order By / Order Alphabetically", "SELECT * FROM Products ORDER BY ProductName;")

run_query("SQL Order By / Alphabetically DESC", "SELECT * FROM Products ORDER BY ProductName DESC;")

run_query("SQL Order By / ORDER BY Several Columns", "SELECT * FROM Customers ORDER BY Country, CustomerName;")

run_query("SQL Order By / Using Both ASC and DESC", "SELECT * FROM Customers ORDER BY Country ASC, customerName DESC;")
# Out:
#  SQL Order By
# SQL : SELECT * FROM Products ORDER BY unitPrice;
# (33, 'Geitost', 15, 4, '500 g', 2.5, 112, 0, 20, 0)
# (24, 'Guaraná Fantástica', 10, 1, '12 - 355 ml cans', 4.5, 20, 0, 0, 1)
# (13, 'Konbu', 6, 8, '2 kg box', 6.0, 24, 0, 5, 0)
# (52, 'Filo Mix', 24, 5, '16 - 2 kg boxes', 7.0, 38, 0, 25, 0)
# (54, 'Tourtière', 25, 6, '16 pies', 7.45, 21, 0, 10, 0)
# (75, 'Rhönbräu Klosterbier', 12, 1, '24 - 0.5 l bottles', 7.75, 125, 0, 25, 0)
# (23, 'Tunnbröd', 9, 5, '12 - 250 g pkgs.', 9.0, 61, 0, 25, 0)
# (19, 'Teatime Chocolate Biscuits', 8, 3, '10 boxes x 12 pieces', 9.2, 25, 0, 5, 0)
# (45, 'Rogede sild', 21, 8, '1k pkg.', 9.5, 5, 70, 15, 0)
# (47, 'Zaanse koeken', 22, 3, '10 - 4 oz boxes', 9.5, 36, 0, 0, 0)
# (41, "Jack's New England Clam Chowder", 19, 8, '12 - 12 oz cans', 9.65, 85, 0, 10, 0)
# (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10.0, 13, 70, 25, 0)
# (21, "Sir Rodney's Scones", 8, 3, '24 pkgs. x 4 pieces', 10.0, 3, 40, 5, 0)
# (74, 'Longlife Tofu', 4, 7, '5 kg pkg.', 10.0, 4, 20, 5, 0)
# (46, 'Spegesild', 21, 8, '4 - 450 g glasses', 12.0, 95, 0, 0, 0)
# (31, 'Gorgonzola Telino', 14, 4, '12 - 100 g pkgs', 12.5, 0, 70, 20, 0)
# (68, 'Scottish Longbreads', 8, 3, '10 boxes x 8 pieces', 12.5, 6, 10, 15, 0)
# (48, 'Chocolade', 22, 3, '10 pkgs.', 12.75, 15, 70, 25, 0)
# (77, 'Original Frankfurter grüne Soße', 12, 2, '12 boxes', 13.0, 32, 0, 15, 0)
# (58, 'Escargots de Bourgogne', 27, 8, '24 pieces', 13.25, 62, 0, 20, 0)
# (25, 'NuNuCa Nuß-Nougat-Creme', 11, 3, '20 - 450 g glasses', 14.0, 76, 0, 30, 0)
# (34, 'Sasquatch Ale', 16, 1, '24 - 12 oz bottles', 14.0, 111, 0, 15, 0)
# (42, 'Singaporean Hokkien Fried Mee', 20, 5, '32 - 1 kg pkgs.', 14.0, 26, 0, 0, 1)
# (67, 'Laughing Lumberjack Lager', 16, 1, '24 - 12 oz bottles', 14.0, 52, 0, 10, 0)
# (70, 'Outback Lager', 7, 1, '24 - 355 ml bottles', 15.0, 15, 10, 30, 0)
# (73, 'Röd Kaviar', 17, 8, '24 - 150 g jars', 15.0, 101, 0, 5, 0)
# (15, 'Genen Shouyu', 6, 2, '24 - 250 ml bottles', 15.5, 39, 0, 5, 0)
# (50, 'Valkoinen suklaa', 23, 3, '12 - 100 g bars', 16.25, 65, 0, 30, 0)
# (66, 'Louisiana Hot Spiced Okra', 2, 2, '24 - 8 oz jars', 17.0, 4, 100, 20, 0)
# (16, 'Pavlova', 7, 3, '32 - 500 g boxes', 17.45, 29, 0, 10, 0)
# (1, 'Chai', 1, 1, '10 boxes x 20 bags', 18.0, 39, 0, 10, 0)
# (35, 'Steeleye Stout', 16, 1, '24 - 12 oz bottles', 18.0, 20, 0, 15, 0)
# (39, 'Chartreuse verte', 18, 1, '750 cc per bottle', 18.0, 69, 0, 5, 0)
# (76, 'Lakkalikööri', 23, 1, '500 ml', 18.0, 57, 0, 20, 0)
# (40, 'Boston Crab Meat', 19, 8, '24 - 4 oz tins', 18.4, 123, 0, 30, 0)
# (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19.0, 17, 40, 25, 0)
# (36, 'Inlagd Sill', 17, 8, '24 - 250 g  jars', 19.0, 112, 0, 20, 0)
# (44, 'Gula Malacca', 20, 2, '20 - 2 kg bags', 19.45, 27, 0, 15, 0)
# (57, 'Ravioli Angelo', 26, 5, '24 - 250 g pkgs.', 19.5, 36, 0, 20, 0)
# (49, 'Maxilaku', 23, 3, '24 - 50 g pkgs.', 20.0, 10, 60, 15, 0)
# (11, 'Queso Cabrales', 5, 4, '1 kg pkg.', 21.0, 22, 30, 30, 0)
# (22, "Gustaf's Knäckebröd", 9, 5, '24 - 500 g pkgs.', 21.0, 104, 0, 25, 0)
# (65, 'Louisiana Fiery Hot Pepper Sauce', 2, 2, '32 - 8 oz bottles', 21.05, 76, 0, 0, 0)
# (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21.35, 0, 0, 0, 1)
# (71, 'Flotemysost', 15, 4, '10 - 500 g pkgs.', 21.5, 26, 0, 0, 0)
# (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22.0, 53, 0, 0, 0)
# (14, 'Tofu', 6, 7, '40 - 100 g pkgs.', 23.25, 35, 0, 0, 0)
# (55, 'Pâté chinois', 25, 6, '24 boxes x 2 pies', 24.0, 115, 0, 20, 0)
# (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25.0, 120, 0, 25, 0)
# (30, 'Nord-Ost Matjeshering', 13, 8, '10 - 200 g glasses', 25.89, 10, 0, 15, 0)
# (37, 'Gravad lax', 17, 8, '12 - 500 g pkgs.', 26.0, 11, 50, 25, 0)
# (61, "Sirop d'érable", 29, 2, '24 - 500 ml bottles', 28.5, 113, 0, 25, 0)
# (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30.0, 15, 0, 10, 0)
# (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31.0, 31, 0, 0, 0)
# (26, 'Gumbär Gummibärchen', 11, 3, '100 - 250 g bags', 31.23, 15, 0, 0, 0)
# (32, 'Mascarpone Fabioli', 14, 4, '24 - 200 g pkgs.', 32.0, 9, 40, 25, 0)
# (53, 'Perth Pasties', 24, 6, '48 pieces', 32.8, 0, 0, 0, 1)
# (64, 'Wimmers gute Semmelknödel', 12, 5, '20 bags x 4 pieces', 33.25, 22, 80, 30, 0)
# (60, 'Camembert Pierrot', 28, 4, '15 - 300 g rounds', 34.0, 19, 0, 0, 0)
# (72, 'Mozzarella di Giovanni', 14, 4, '24 - 200 g pkgs.', 34.8, 14, 0, 0, 0)
# (69, 'Gudbrandsdalsost', 15, 4, '10 kg pkg.', 36.0, 26, 0, 15, 0)
# (12, 'Queso Manchego La Pastora', 5, 4, '10 - 500 g pkgs.', 38.0, 86, 0, 0, 0)
# (56, 'Gnocchi di nonna Alice', 26, 5, '24 - 250 g pkgs.', 38.0, 21, 10, 30, 0)
# (17, 'Alice Mutton', 7, 6, '20 - 1 kg tins', 39.0, 0, 0, 0, 1)
# (8, 'Northwoods Cranberry Sauce', 3, 2, '12 - 12 oz jars', 40.0, 6, 0, 0, 0)
# (27, 'Schoggi Schokolade', 11, 3, '100 - 100 g pieces', 43.9, 49, 0, 30, 0)
# (63, 'Vegie-spread', 7, 2, '15 - 625 g jars', 43.9, 24, 0, 5, 0)
# (28, 'Rössle Sauerkraut', 12, 7, '25 - 825 g cans', 45.6, 26, 0, 0, 1)
# (43, 'Ipoh Coffee', 20, 1, '16 - 500 g tins', 46.0, 17, 10, 25, 0)
# (62, 'Tarte au sucre', 29, 3, '48 pies', 49.3, 17, 0, 0, 0)
# (51, 'Manjimup Dried Apples', 24, 7, '50 - 300 g pkgs.', 53.0, 20, 0, 10, 0)
# (59, 'Raclette Courdavault', 28, 4, '5 kg pkg.', 55.0, 79, 0, 0, 0)
# (18, 'Carnarvon Tigers', 7, 8, '16 kg pkg.', 62.5, 42, 0, 0, 0)
# (20, "Sir Rodney's Marmalade", 8, 3, '30 gift boxes', 81.0, 40, 0, 0, 0)
# (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97.0, 29, 0, 0, 1)
# (29, 'Thüringer Rostbratwurst', 12, 6, '50 bags x 30 sausgs.', 123.79, 0, 0, 0, 1)
# (38, 'Côte de Blaye', 18, 1, '12 - 75 cl bottles', 263.5, 17, 0, 15, 0)
#
#  SQL Order By / DESC
# SQL : SELECT * FROM Products ORDER BY unitPrice DESC;
# (38, 'Côte de Blaye', 18, 1, '12 - 75 cl bottles', 263.5, 17, 0, 15, 0)
# (29, 'Thüringer Rostbratwurst', 12, 6, '50 bags x 30 sausgs.', 123.79, 0, 0, 0, 1)
# (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97.0, 29, 0, 0, 1)
# (20, "Sir Rodney's Marmalade", 8, 3, '30 gift boxes', 81.0, 40, 0, 0, 0)
# (18, 'Carnarvon Tigers', 7, 8, '16 kg pkg.', 62.5, 42, 0, 0, 0)
# (59, 'Raclette Courdavault', 28, 4, '5 kg pkg.', 55.0, 79, 0, 0, 0)
# (51, 'Manjimup Dried Apples', 24, 7, '50 - 300 g pkgs.', 53.0, 20, 0, 10, 0)
# (62, 'Tarte au sucre', 29, 3, '48 pies', 49.3, 17, 0, 0, 0)
# (43, 'Ipoh Coffee', 20, 1, '16 - 500 g tins', 46.0, 17, 10, 25, 0)
# (28, 'Rössle Sauerkraut', 12, 7, '25 - 825 g cans', 45.6, 26, 0, 0, 1)
# (27, 'Schoggi Schokolade', 11, 3, '100 - 100 g pieces', 43.9, 49, 0, 30, 0)
# (63, 'Vegie-spread', 7, 2, '15 - 625 g jars', 43.9, 24, 0, 5, 0)
# (8, 'Northwoods Cranberry Sauce', 3, 2, '12 - 12 oz jars', 40.0, 6, 0, 0, 0)
# (17, 'Alice Mutton', 7, 6, '20 - 1 kg tins', 39.0, 0, 0, 0, 1)
# (12, 'Queso Manchego La Pastora', 5, 4, '10 - 500 g pkgs.', 38.0, 86, 0, 0, 0)
# (56, 'Gnocchi di nonna Alice', 26, 5, '24 - 250 g pkgs.', 38.0, 21, 10, 30, 0)
# (69, 'Gudbrandsdalsost', 15, 4, '10 kg pkg.', 36.0, 26, 0, 15, 0)
# (72, 'Mozzarella di Giovanni', 14, 4, '24 - 200 g pkgs.', 34.8, 14, 0, 0, 0)
# (60, 'Camembert Pierrot', 28, 4, '15 - 300 g rounds', 34.0, 19, 0, 0, 0)
# (64, 'Wimmers gute Semmelknödel', 12, 5, '20 bags x 4 pieces', 33.25, 22, 80, 30, 0)
# (53, 'Perth Pasties', 24, 6, '48 pieces', 32.8, 0, 0, 0, 1)
# (32, 'Mascarpone Fabioli', 14, 4, '24 - 200 g pkgs.', 32.0, 9, 40, 25, 0)
# (26, 'Gumbär Gummibärchen', 11, 3, '100 - 250 g bags', 31.23, 15, 0, 0, 0)
# (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31.0, 31, 0, 0, 0)
# (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30.0, 15, 0, 10, 0)
# (61, "Sirop d'érable", 29, 2, '24 - 500 ml bottles', 28.5, 113, 0, 25, 0)
# (37, 'Gravad lax', 17, 8, '12 - 500 g pkgs.', 26.0, 11, 50, 25, 0)
# (30, 'Nord-Ost Matjeshering', 13, 8, '10 - 200 g glasses', 25.89, 10, 0, 15, 0)
# (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25.0, 120, 0, 25, 0)
# (55, 'Pâté chinois', 25, 6, '24 boxes x 2 pies', 24.0, 115, 0, 20, 0)
# (14, 'Tofu', 6, 7, '40 - 100 g pkgs.', 23.25, 35, 0, 0, 0)
# (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22.0, 53, 0, 0, 0)
# (71, 'Flotemysost', 15, 4, '10 - 500 g pkgs.', 21.5, 26, 0, 0, 0)
# (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21.35, 0, 0, 0, 1)
# (65, 'Louisiana Fiery Hot Pepper Sauce', 2, 2, '32 - 8 oz bottles', 21.05, 76, 0, 0, 0)
# (11, 'Queso Cabrales', 5, 4, '1 kg pkg.', 21.0, 22, 30, 30, 0)
# (22, "Gustaf's Knäckebröd", 9, 5, '24 - 500 g pkgs.', 21.0, 104, 0, 25, 0)
# (49, 'Maxilaku', 23, 3, '24 - 50 g pkgs.', 20.0, 10, 60, 15, 0)
# (57, 'Ravioli Angelo', 26, 5, '24 - 250 g pkgs.', 19.5, 36, 0, 20, 0)
# (44, 'Gula Malacca', 20, 2, '20 - 2 kg bags', 19.45, 27, 0, 15, 0)
# (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19.0, 17, 40, 25, 0)
# (36, 'Inlagd Sill', 17, 8, '24 - 250 g  jars', 19.0, 112, 0, 20, 0)
# (40, 'Boston Crab Meat', 19, 8, '24 - 4 oz tins', 18.4, 123, 0, 30, 0)
# (1, 'Chai', 1, 1, '10 boxes x 20 bags', 18.0, 39, 0, 10, 0)
# (35, 'Steeleye Stout', 16, 1, '24 - 12 oz bottles', 18.0, 20, 0, 15, 0)
# (39, 'Chartreuse verte', 18, 1, '750 cc per bottle', 18.0, 69, 0, 5, 0)
# (76, 'Lakkalikööri', 23, 1, '500 ml', 18.0, 57, 0, 20, 0)
# (16, 'Pavlova', 7, 3, '32 - 500 g boxes', 17.45, 29, 0, 10, 0)
# (66, 'Louisiana Hot Spiced Okra', 2, 2, '24 - 8 oz jars', 17.0, 4, 100, 20, 0)
# (50, 'Valkoinen suklaa', 23, 3, '12 - 100 g bars', 16.25, 65, 0, 30, 0)
# (15, 'Genen Shouyu', 6, 2, '24 - 250 ml bottles', 15.5, 39, 0, 5, 0)
# (70, 'Outback Lager', 7, 1, '24 - 355 ml bottles', 15.0, 15, 10, 30, 0)
# (73, 'Röd Kaviar', 17, 8, '24 - 150 g jars', 15.0, 101, 0, 5, 0)
# (25, 'NuNuCa Nuß-Nougat-Creme', 11, 3, '20 - 450 g glasses', 14.0, 76, 0, 30, 0)
# (34, 'Sasquatch Ale', 16, 1, '24 - 12 oz bottles', 14.0, 111, 0, 15, 0)
# (42, 'Singaporean Hokkien Fried Mee', 20, 5, '32 - 1 kg pkgs.', 14.0, 26, 0, 0, 1)
# (67, 'Laughing Lumberjack Lager', 16, 1, '24 - 12 oz bottles', 14.0, 52, 0, 10, 0)
# (58, 'Escargots de Bourgogne', 27, 8, '24 pieces', 13.25, 62, 0, 20, 0)
# (77, 'Original Frankfurter grüne Soße', 12, 2, '12 boxes', 13.0, 32, 0, 15, 0)
# (48, 'Chocolade', 22, 3, '10 pkgs.', 12.75, 15, 70, 25, 0)
# (31, 'Gorgonzola Telino', 14, 4, '12 - 100 g pkgs', 12.5, 0, 70, 20, 0)
# (68, 'Scottish Longbreads', 8, 3, '10 boxes x 8 pieces', 12.5, 6, 10, 15, 0)
# (46, 'Spegesild', 21, 8, '4 - 450 g glasses', 12.0, 95, 0, 0, 0)
# (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10.0, 13, 70, 25, 0)
# (21, "Sir Rodney's Scones", 8, 3, '24 pkgs. x 4 pieces', 10.0, 3, 40, 5, 0)
# (74, 'Longlife Tofu', 4, 7, '5 kg pkg.', 10.0, 4, 20, 5, 0)
# (41, "Jack's New England Clam Chowder", 19, 8, '12 - 12 oz cans', 9.65, 85, 0, 10, 0)
# (45, 'Rogede sild', 21, 8, '1k pkg.', 9.5, 5, 70, 15, 0)
# (47, 'Zaanse koeken', 22, 3, '10 - 4 oz boxes', 9.5, 36, 0, 0, 0)
# (19, 'Teatime Chocolate Biscuits', 8, 3, '10 boxes x 12 pieces', 9.2, 25, 0, 5, 0)
# (23, 'Tunnbröd', 9, 5, '12 - 250 g pkgs.', 9.0, 61, 0, 25, 0)
# (75, 'Rhönbräu Klosterbier', 12, 1, '24 - 0.5 l bottles', 7.75, 125, 0, 25, 0)
# (54, 'Tourtière', 25, 6, '16 pies', 7.45, 21, 0, 10, 0)
# (52, 'Filo Mix', 24, 5, '16 - 2 kg boxes', 7.0, 38, 0, 25, 0)
# (13, 'Konbu', 6, 8, '2 kg box', 6.0, 24, 0, 5, 0)
# (24, 'Guaraná Fantástica', 10, 1, '12 - 355 ml cans', 4.5, 20, 0, 0, 1)
# (33, 'Geitost', 15, 4, '500 g', 2.5, 112, 0, 20, 0)
#
#  SQL Order By / Order Alphabetically
# SQL : SELECT * FROM Products ORDER BY ProductName;
# (17, 'Alice Mutton', 7, 6, '20 - 1 kg tins', 39.0, 0, 0, 0, 1)
# (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10.0, 13, 70, 25, 0)
# (40, 'Boston Crab Meat', 19, 8, '24 - 4 oz tins', 18.4, 123, 0, 30, 0)
# (60, 'Camembert Pierrot', 28, 4, '15 - 300 g rounds', 34.0, 19, 0, 0, 0)
# (18, 'Carnarvon Tigers', 7, 8, '16 kg pkg.', 62.5, 42, 0, 0, 0)
# (1, 'Chai', 1, 1, '10 boxes x 20 bags', 18.0, 39, 0, 10, 0)
# (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19.0, 17, 40, 25, 0)
# (39, 'Chartreuse verte', 18, 1, '750 cc per bottle', 18.0, 69, 0, 5, 0)
# (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22.0, 53, 0, 0, 0)
# (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21.35, 0, 0, 0, 1)
# (48, 'Chocolade', 22, 3, '10 pkgs.', 12.75, 15, 70, 25, 0)
# (38, 'Côte de Blaye', 18, 1, '12 - 75 cl bottles', 263.5, 17, 0, 15, 0)
# (58, 'Escargots de Bourgogne', 27, 8, '24 pieces', 13.25, 62, 0, 20, 0)
# (52, 'Filo Mix', 24, 5, '16 - 2 kg boxes', 7.0, 38, 0, 25, 0)
# (71, 'Flotemysost', 15, 4, '10 - 500 g pkgs.', 21.5, 26, 0, 0, 0)
# (33, 'Geitost', 15, 4, '500 g', 2.5, 112, 0, 20, 0)
# (15, 'Genen Shouyu', 6, 2, '24 - 250 ml bottles', 15.5, 39, 0, 5, 0)
# (56, 'Gnocchi di nonna Alice', 26, 5, '24 - 250 g pkgs.', 38.0, 21, 10, 30, 0)
# (31, 'Gorgonzola Telino', 14, 4, '12 - 100 g pkgs', 12.5, 0, 70, 20, 0)
# (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25.0, 120, 0, 25, 0)
# (37, 'Gravad lax', 17, 8, '12 - 500 g pkgs.', 26.0, 11, 50, 25, 0)
# (24, 'Guaraná Fantástica', 10, 1, '12 - 355 ml cans', 4.5, 20, 0, 0, 1)
# (69, 'Gudbrandsdalsost', 15, 4, '10 kg pkg.', 36.0, 26, 0, 15, 0)
# (44, 'Gula Malacca', 20, 2, '20 - 2 kg bags', 19.45, 27, 0, 15, 0)
# (26, 'Gumbär Gummibärchen', 11, 3, '100 - 250 g bags', 31.23, 15, 0, 0, 0)
# (22, "Gustaf's Knäckebröd", 9, 5, '24 - 500 g pkgs.', 21.0, 104, 0, 25, 0)
# (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31.0, 31, 0, 0, 0)
# (36, 'Inlagd Sill', 17, 8, '24 - 250 g  jars', 19.0, 112, 0, 20, 0)
# (43, 'Ipoh Coffee', 20, 1, '16 - 500 g tins', 46.0, 17, 10, 25, 0)
# (41, "Jack's New England Clam Chowder", 19, 8, '12 - 12 oz cans', 9.65, 85, 0, 10, 0)
# (13, 'Konbu', 6, 8, '2 kg box', 6.0, 24, 0, 5, 0)
# (76, 'Lakkalikööri', 23, 1, '500 ml', 18.0, 57, 0, 20, 0)
# (67, 'Laughing Lumberjack Lager', 16, 1, '24 - 12 oz bottles', 14.0, 52, 0, 10, 0)
# (74, 'Longlife Tofu', 4, 7, '5 kg pkg.', 10.0, 4, 20, 5, 0)
# (65, 'Louisiana Fiery Hot Pepper Sauce', 2, 2, '32 - 8 oz bottles', 21.05, 76, 0, 0, 0)
# (66, 'Louisiana Hot Spiced Okra', 2, 2, '24 - 8 oz jars', 17.0, 4, 100, 20, 0)
# (51, 'Manjimup Dried Apples', 24, 7, '50 - 300 g pkgs.', 53.0, 20, 0, 10, 0)
# (32, 'Mascarpone Fabioli', 14, 4, '24 - 200 g pkgs.', 32.0, 9, 40, 25, 0)
# (49, 'Maxilaku', 23, 3, '24 - 50 g pkgs.', 20.0, 10, 60, 15, 0)
# (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97.0, 29, 0, 0, 1)
# (72, 'Mozzarella di Giovanni', 14, 4, '24 - 200 g pkgs.', 34.8, 14, 0, 0, 0)
# (30, 'Nord-Ost Matjeshering', 13, 8, '10 - 200 g glasses', 25.89, 10, 0, 15, 0)
# (8, 'Northwoods Cranberry Sauce', 3, 2, '12 - 12 oz jars', 40.0, 6, 0, 0, 0)
# (25, 'NuNuCa Nuß-Nougat-Creme', 11, 3, '20 - 450 g glasses', 14.0, 76, 0, 30, 0)
# (77, 'Original Frankfurter grüne Soße', 12, 2, '12 boxes', 13.0, 32, 0, 15, 0)
# (70, 'Outback Lager', 7, 1, '24 - 355 ml bottles', 15.0, 15, 10, 30, 0)
# (16, 'Pavlova', 7, 3, '32 - 500 g boxes', 17.45, 29, 0, 10, 0)
# (53, 'Perth Pasties', 24, 6, '48 pieces', 32.8, 0, 0, 0, 1)
# (55, 'Pâté chinois', 25, 6, '24 boxes x 2 pies', 24.0, 115, 0, 20, 0)
# (11, 'Queso Cabrales', 5, 4, '1 kg pkg.', 21.0, 22, 30, 30, 0)
# (12, 'Queso Manchego La Pastora', 5, 4, '10 - 500 g pkgs.', 38.0, 86, 0, 0, 0)
# (59, 'Raclette Courdavault', 28, 4, '5 kg pkg.', 55.0, 79, 0, 0, 0)
# (57, 'Ravioli Angelo', 26, 5, '24 - 250 g pkgs.', 19.5, 36, 0, 20, 0)
# (75, 'Rhönbräu Klosterbier', 12, 1, '24 - 0.5 l bottles', 7.75, 125, 0, 25, 0)
# (45, 'Rogede sild', 21, 8, '1k pkg.', 9.5, 5, 70, 15, 0)
# (73, 'Röd Kaviar', 17, 8, '24 - 150 g jars', 15.0, 101, 0, 5, 0)
# (28, 'Rössle Sauerkraut', 12, 7, '25 - 825 g cans', 45.6, 26, 0, 0, 1)
# (34, 'Sasquatch Ale', 16, 1, '24 - 12 oz bottles', 14.0, 111, 0, 15, 0)
# (27, 'Schoggi Schokolade', 11, 3, '100 - 100 g pieces', 43.9, 49, 0, 30, 0)
# (68, 'Scottish Longbreads', 8, 3, '10 boxes x 8 pieces', 12.5, 6, 10, 15, 0)
# (42, 'Singaporean Hokkien Fried Mee', 20, 5, '32 - 1 kg pkgs.', 14.0, 26, 0, 0, 1)
# (20, "Sir Rodney's Marmalade", 8, 3, '30 gift boxes', 81.0, 40, 0, 0, 0)
# (21, "Sir Rodney's Scones", 8, 3, '24 pkgs. x 4 pieces', 10.0, 3, 40, 5, 0)
# (61, "Sirop d'érable", 29, 2, '24 - 500 ml bottles', 28.5, 113, 0, 25, 0)
# (46, 'Spegesild', 21, 8, '4 - 450 g glasses', 12.0, 95, 0, 0, 0)
# (35, 'Steeleye Stout', 16, 1, '24 - 12 oz bottles', 18.0, 20, 0, 15, 0)
# (62, 'Tarte au sucre', 29, 3, '48 pies', 49.3, 17, 0, 0, 0)
# (19, 'Teatime Chocolate Biscuits', 8, 3, '10 boxes x 12 pieces', 9.2, 25, 0, 5, 0)
# (29, 'Thüringer Rostbratwurst', 12, 6, '50 bags x 30 sausgs.', 123.79, 0, 0, 0, 1)
# (14, 'Tofu', 6, 7, '40 - 100 g pkgs.', 23.25, 35, 0, 0, 0)
# (54, 'Tourtière', 25, 6, '16 pies', 7.45, 21, 0, 10, 0)
# (23, 'Tunnbröd', 9, 5, '12 - 250 g pkgs.', 9.0, 61, 0, 25, 0)
# (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30.0, 15, 0, 10, 0)
# (50, 'Valkoinen suklaa', 23, 3, '12 - 100 g bars', 16.25, 65, 0, 30, 0)
# (63, 'Vegie-spread', 7, 2, '15 - 625 g jars', 43.9, 24, 0, 5, 0)
# (64, 'Wimmers gute Semmelknödel', 12, 5, '20 bags x 4 pieces', 33.25, 22, 80, 30, 0)
# (47, 'Zaanse koeken', 22, 3, '10 - 4 oz boxes', 9.5, 36, 0, 0, 0)
#
#  SQL Order By / Alphabetically DESC
# SQL : SELECT * FROM Products ORDER BY ProductName DESC;
# (47, 'Zaanse koeken', 22, 3, '10 - 4 oz boxes', 9.5, 36, 0, 0, 0)
# (64, 'Wimmers gute Semmelknödel', 12, 5, '20 bags x 4 pieces', 33.25, 22, 80, 30, 0)
# (63, 'Vegie-spread', 7, 2, '15 - 625 g jars', 43.9, 24, 0, 5, 0)
# (50, 'Valkoinen suklaa', 23, 3, '12 - 100 g bars', 16.25, 65, 0, 30, 0)
# (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30.0, 15, 0, 10, 0)
# (23, 'Tunnbröd', 9, 5, '12 - 250 g pkgs.', 9.0, 61, 0, 25, 0)
# (54, 'Tourtière', 25, 6, '16 pies', 7.45, 21, 0, 10, 0)
# (14, 'Tofu', 6, 7, '40 - 100 g pkgs.', 23.25, 35, 0, 0, 0)
# (29, 'Thüringer Rostbratwurst', 12, 6, '50 bags x 30 sausgs.', 123.79, 0, 0, 0, 1)
# (19, 'Teatime Chocolate Biscuits', 8, 3, '10 boxes x 12 pieces', 9.2, 25, 0, 5, 0)
# (62, 'Tarte au sucre', 29, 3, '48 pies', 49.3, 17, 0, 0, 0)
# (35, 'Steeleye Stout', 16, 1, '24 - 12 oz bottles', 18.0, 20, 0, 15, 0)
# (46, 'Spegesild', 21, 8, '4 - 450 g glasses', 12.0, 95, 0, 0, 0)
# (61, "Sirop d'érable", 29, 2, '24 - 500 ml bottles', 28.5, 113, 0, 25, 0)
# (21, "Sir Rodney's Scones", 8, 3, '24 pkgs. x 4 pieces', 10.0, 3, 40, 5, 0)
# (20, "Sir Rodney's Marmalade", 8, 3, '30 gift boxes', 81.0, 40, 0, 0, 0)
# (42, 'Singaporean Hokkien Fried Mee', 20, 5, '32 - 1 kg pkgs.', 14.0, 26, 0, 0, 1)
# (68, 'Scottish Longbreads', 8, 3, '10 boxes x 8 pieces', 12.5, 6, 10, 15, 0)
# (27, 'Schoggi Schokolade', 11, 3, '100 - 100 g pieces', 43.9, 49, 0, 30, 0)
# (34, 'Sasquatch Ale', 16, 1, '24 - 12 oz bottles', 14.0, 111, 0, 15, 0)
# (28, 'Rössle Sauerkraut', 12, 7, '25 - 825 g cans', 45.6, 26, 0, 0, 1)
# (73, 'Röd Kaviar', 17, 8, '24 - 150 g jars', 15.0, 101, 0, 5, 0)
# (45, 'Rogede sild', 21, 8, '1k pkg.', 9.5, 5, 70, 15, 0)
# (75, 'Rhönbräu Klosterbier', 12, 1, '24 - 0.5 l bottles', 7.75, 125, 0, 25, 0)
# (57, 'Ravioli Angelo', 26, 5, '24 - 250 g pkgs.', 19.5, 36, 0, 20, 0)
# (59, 'Raclette Courdavault', 28, 4, '5 kg pkg.', 55.0, 79, 0, 0, 0)
# (12, 'Queso Manchego La Pastora', 5, 4, '10 - 500 g pkgs.', 38.0, 86, 0, 0, 0)
# (11, 'Queso Cabrales', 5, 4, '1 kg pkg.', 21.0, 22, 30, 30, 0)
# (55, 'Pâté chinois', 25, 6, '24 boxes x 2 pies', 24.0, 115, 0, 20, 0)
# (53, 'Perth Pasties', 24, 6, '48 pieces', 32.8, 0, 0, 0, 1)
# (16, 'Pavlova', 7, 3, '32 - 500 g boxes', 17.45, 29, 0, 10, 0)
# (70, 'Outback Lager', 7, 1, '24 - 355 ml bottles', 15.0, 15, 10, 30, 0)
# (77, 'Original Frankfurter grüne Soße', 12, 2, '12 boxes', 13.0, 32, 0, 15, 0)
# (25, 'NuNuCa Nuß-Nougat-Creme', 11, 3, '20 - 450 g glasses', 14.0, 76, 0, 30, 0)
# (8, 'Northwoods Cranberry Sauce', 3, 2, '12 - 12 oz jars', 40.0, 6, 0, 0, 0)
# (30, 'Nord-Ost Matjeshering', 13, 8, '10 - 200 g glasses', 25.89, 10, 0, 15, 0)
# (72, 'Mozzarella di Giovanni', 14, 4, '24 - 200 g pkgs.', 34.8, 14, 0, 0, 0)
# (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97.0, 29, 0, 0, 1)
# (49, 'Maxilaku', 23, 3, '24 - 50 g pkgs.', 20.0, 10, 60, 15, 0)
# (32, 'Mascarpone Fabioli', 14, 4, '24 - 200 g pkgs.', 32.0, 9, 40, 25, 0)
# (51, 'Manjimup Dried Apples', 24, 7, '50 - 300 g pkgs.', 53.0, 20, 0, 10, 0)
# (66, 'Louisiana Hot Spiced Okra', 2, 2, '24 - 8 oz jars', 17.0, 4, 100, 20, 0)
# (65, 'Louisiana Fiery Hot Pepper Sauce', 2, 2, '32 - 8 oz bottles', 21.05, 76, 0, 0, 0)
# (74, 'Longlife Tofu', 4, 7, '5 kg pkg.', 10.0, 4, 20, 5, 0)
# (67, 'Laughing Lumberjack Lager', 16, 1, '24 - 12 oz bottles', 14.0, 52, 0, 10, 0)
# (76, 'Lakkalikööri', 23, 1, '500 ml', 18.0, 57, 0, 20, 0)
# (13, 'Konbu', 6, 8, '2 kg box', 6.0, 24, 0, 5, 0)
# (41, "Jack's New England Clam Chowder", 19, 8, '12 - 12 oz cans', 9.65, 85, 0, 10, 0)
# (43, 'Ipoh Coffee', 20, 1, '16 - 500 g tins', 46.0, 17, 10, 25, 0)
# (36, 'Inlagd Sill', 17, 8, '24 - 250 g  jars', 19.0, 112, 0, 20, 0)
# (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31.0, 31, 0, 0, 0)
# (22, "Gustaf's Knäckebröd", 9, 5, '24 - 500 g pkgs.', 21.0, 104, 0, 25, 0)
# (26, 'Gumbär Gummibärchen', 11, 3, '100 - 250 g bags', 31.23, 15, 0, 0, 0)
# (44, 'Gula Malacca', 20, 2, '20 - 2 kg bags', 19.45, 27, 0, 15, 0)
# (69, 'Gudbrandsdalsost', 15, 4, '10 kg pkg.', 36.0, 26, 0, 15, 0)
# (24, 'Guaraná Fantástica', 10, 1, '12 - 355 ml cans', 4.5, 20, 0, 0, 1)
# (37, 'Gravad lax', 17, 8, '12 - 500 g pkgs.', 26.0, 11, 50, 25, 0)
# (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25.0, 120, 0, 25, 0)
# (31, 'Gorgonzola Telino', 14, 4, '12 - 100 g pkgs', 12.5, 0, 70, 20, 0)
# (56, 'Gnocchi di nonna Alice', 26, 5, '24 - 250 g pkgs.', 38.0, 21, 10, 30, 0)
# (15, 'Genen Shouyu', 6, 2, '24 - 250 ml bottles', 15.5, 39, 0, 5, 0)
# (33, 'Geitost', 15, 4, '500 g', 2.5, 112, 0, 20, 0)
# (71, 'Flotemysost', 15, 4, '10 - 500 g pkgs.', 21.5, 26, 0, 0, 0)
# (52, 'Filo Mix', 24, 5, '16 - 2 kg boxes', 7.0, 38, 0, 25, 0)
# (58, 'Escargots de Bourgogne', 27, 8, '24 pieces', 13.25, 62, 0, 20, 0)
# (38, 'Côte de Blaye', 18, 1, '12 - 75 cl bottles', 263.5, 17, 0, 15, 0)
# (48, 'Chocolade', 22, 3, '10 pkgs.', 12.75, 15, 70, 25, 0)
# (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21.35, 0, 0, 0, 1)
# (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22.0, 53, 0, 0, 0)
# (39, 'Chartreuse verte', 18, 1, '750 cc per bottle', 18.0, 69, 0, 5, 0)
# (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19.0, 17, 40, 25, 0)
# (1, 'Chai', 1, 1, '10 boxes x 20 bags', 18.0, 39, 0, 10, 0)
# (18, 'Carnarvon Tigers', 7, 8, '16 kg pkg.', 62.5, 42, 0, 0, 0)
# (60, 'Camembert Pierrot', 28, 4, '15 - 300 g rounds', 34.0, 19, 0, 0, 0)
# (40, 'Boston Crab Meat', 19, 8, '24 - 4 oz tins', 18.4, 123, 0, 30, 0)
# (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10.0, 13, 70, 25, 0)
# (17, 'Alice Mutton', 7, 6, '20 - 1 kg tins', 39.0, 0, 0, 0, 1)
#
#  SQL Order By / ORDER BY Several Columns
# SQL : SELECT * FROM Customers ORDER BY Country, CustomerName;
# ('CACTU', 'Cactus Comidas para llevar', 'Patricio Simpson', 'Cerrito 333', 'Buenos Aires', '1010', 'Argentina')
# ('OCEAN', 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', '1010', 'Argentina')
# ('RANCH', 'Rancho grande', 'Sergio Gutiérrez', 'Av. del Libertador 900', 'Buenos Aires', '1010', 'Argentina')
# ('ERNSH', 'Ernst Handel', 'Roland Mendel', 'Kirchgasse 6', 'Graz', '8010', 'Austria')
# ('PICCO', 'Piccolo und mehr', 'Georg Pipps', 'Geislweg 14', 'Salzburg', '5020', 'Austria')
# ('MAISD', 'Maison Dewey', 'Catherine Dewey', 'Rue Joseph-Bens 532', 'Bruxelles', 'B-1180', 'Belgium')
# ('SUPRD', 'Suprêmes délices', 'Pascale Cartrain', 'Boulevard Tirou 255', 'Charleroi', 'B-6000', 'Belgium')
# ('COMMI', 'Comércio Mineiro', 'Pedro Afonso', '23 Av. dos Lusíadas', 'Sao Paulo', '05432-043', 'Brazil')
# ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 'Rua Orós 92', 'Sao Paulo', '05442-030', 'Brazil')
# ('GOURL', 'Gourmet Lanchonetes', 'André Fonseca', 'Av. Brasil 442', 'Campinas', '04876-786', 'Brazil')
# ('HANAR', 'Hanari Carnes', 'Mario Pontes', 'Rua do Paço 67', 'Rio de Janeiro', '05454-876', 'Brazil')
# ('QUEDE', 'Que Delícia', 'Bernardo Batista', 'Rua da Panificadora', ' 12Rio de Janeiro', '02389-673', 'Brazil')
# ('QUEEN', 'Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios 891', 'Sao Paulo', '05487-020', 'Brazil')
# ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Av. Copacabana 267', 'Rio de Janeiro', '02389-890', 'Brazil')
# ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 'Av. Inês de Castro 414', 'Sao Paulo', '05634-030', 'Brazil')
# ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Rua do Mercado 12', 'Resende', '08737-363', 'Brazil')
# ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada')
# ('LAUGB', 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', '1900 Oak St.', 'Vancouver', 'V3F 2K1', 'Canada')
# ('MEREP', 'Mère Paillarde', 'Jean Fresnière', '43 rue St. Laurent', 'Montréal', 'H1J 1C3', 'Canada')
# ('SIMOB', 'Simons bistro', 'Jytte Petersen', 'Vinbæltet 34', 'Kobenhavn', '1734', 'Denmark')
# ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 'Smagsloget 45', 'Århus', '8200', 'Denmark')
# ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Torikatu 38', 'Oulu', '90110', 'Finland')
# ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Keskuskatu 45', 'Helsinki', '21240', 'Finland')
# ('BLONP', 'Blondesddsl père et fils', 'Frédérique Citeaux', '24 place Kléber', 'Strasbourg', '67000', 'France')
# ('BONAP', "Bon app'", 'Laurence Lebihan', '12 rue des Bouchers', 'Marseille', '13008', 'France')
# ('DUMON', 'Du monde entier', 'Janine Labrune', '67 rue des Cinquante Otages', 'Nantes', '44000', 'France')
# ('FOLIG', 'Folies gourmandes', 'Martine Rancé', '184 chaussée de Tournai', 'Lille', '59000', 'France')
# ('FRANR', 'France restauration', 'Carine Schmitt', '54 rue Royale', 'Nantes', '44000', 'France')
# ('LACOR', "La corne d'abondance", 'Daniel Tonini', "67 avenue de l'Europe", 'Versailles', '78000', 'France')
# ('LAMAI', "La maison d'Asie", 'Annette Roulet', '1 rue Alsace-Lorraine', 'Toulouse', '31000', 'France')
# ('PARIS', 'Paris spécialités', 'Marie Bertrand', '265 boulevard Charonne', 'Paris', '75012', 'France')
# ('SPECD', 'Spécialités du monde', 'Dominique Perrier', '25 rue Lauriston', 'Paris', '75016', 'France')
# ('VICTE', 'Victuailles en stock', 'Mary Saveley', '2 rue du Commerce', 'Lyon', '69004', 'France')
# ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', "59 rue de l'Abbaye", 'Reims', '51100', 'France')
# ('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany')
# ('WANDK', 'Die Wandernde Kuh', 'Rita Müller', 'Adenauerallee 900', 'Stuttgart', '70563', 'Germany')
# ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Walserweg 21', 'Aachen', '52066', 'Germany')
# ('FRANK', 'Frankenversand', 'Peter Franken', 'Berliner Platz 43', 'München', '80805', 'Germany')
# ('KOENE', 'Königlich Essen', 'Philip Cramer', 'Maubelstr. 90', 'Brandenburg', '14776', 'Germany')
# ('LEHMS', 'Lehmanns Marktstand', 'Renate Messner', 'Magazinweg 7', 'Frankfurt a.M.', '60528', 'Germany')
# ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '04179', 'Germany')
# ('OTTIK', 'Ottilies Käseladen', 'Henriette Pfalzheim', 'Mehrheimerstr. 369', 'Köln', '50739', 'Germany')
# ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Taucherstraße 10', 'Cunewalde', '01307', 'Germany')
# ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Luisenstr. 48', 'Münster', '44087', 'Germany')
# ('HUNGO', 'Hungry Owl All-Night Grocers', 'Patricia McKenna', '8 Johnstown Road', 'Cork', 'NULL', 'Ireland')
# ('FRANS', 'Franchi S.p.A.', 'Paolo Accorti', 'Via Monte Bianco 34', 'Torino', '10100', 'Italy')
# ('MAGAA', 'Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 'Via Ludovico il Moro 22', 'Bergamo', '24100', 'Italy')
# ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Strada Provinciale 124', 'Reggio Emilia', '42100', 'Italy')
# ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# ('ANTON', 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos  2312', 'México D.F.', '05023', 'Mexico')
# ('CENTC', 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '05022', 'Mexico')
# ('PERIC', 'Pericles Comidas clásicas', 'Guillermo Fernández', 'Calle Dr. Jorge Cash 321', 'México D.F.', '05033', 'Mexico')
# ('TORTU', 'Tortuga Restaurante', 'Miguel Angel Paolino', 'Avda. Azteca 123', 'México D.F.', '05033', 'Mexico')
# ('SANTG', 'Santé Gourmet', 'Jonas Bergulfsen', 'Erling Skakkes gate 78', 'Stavern', '4110', 'Norway')
# ('WOLZA', 'Wolski  Zajazd', 'Zbyszek Piestrzeniewicz', 'ul. Filtrowa 68', 'Warszawa', '01-012', 'Poland')
# ('FURIB', 'Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez', 'Jardim das rosas n. 32', 'Lisboa', '1675', 'Portugal')
# ('PRINI', 'Princesa Isabel Vinhos', 'Isabel de Castro', 'Estrada da saúde n. 58', 'Lisboa', '1756', 'Portugal')
# ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', '67C Araquil', 'Madrid', '28023', 'Spain')
# ('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'C/ Moralzarzal 86', 'Madrid', '28034', 'Spain')
# ('GALED', 'Galería del gastrónomo', 'Eduardo Saavedra', 'Rambla de Cataluña 23', 'Barcelona', '08022', 'Spain')
# ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero 33', 'Sevilla', '41101', 'Spain')
# ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Gran Vía 1', 'Madrid', '28001', 'Spain')
# ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen  8', 'Luleå', 'S-958 22', 'Sweden')
# ('FOLKO', 'Folk och fä HB', 'Maria Larsson', 'Åkergatan 24', 'Bräcke', 'S-844 67', 'Sweden')
# ('CHOPS', 'Chop-suey Chinese', 'Yang Wang', 'Hauptstr. 29', 'Bern', '3012', 'Switzerland')
# ('RICSU', 'Richter Supermarkt', 'Michael Holz', 'Grenzacherweg 237', 'Genève', '1203', 'Switzerland')
# ('AROUT', 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK')
# ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12  Brewery', 'London', 'WX1 6LT', 'UK')
# ('EASTC', 'Eastern Connection', 'Ann Devon', '35 King George', 'London', 'WX3 6FW', 'UK')
# ('ISLAT', 'Island Trading', 'Helen Bennett', 'Garden House Crowther Way', 'Cowes', 'PO31 7PJ', 'UK')
# ('NORTS', 'North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK')
# ('SEVES', 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK')
# ('GREAL', 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA')
# ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA')
# ('LAZYK', 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA')
# ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA')
# ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA')
# ('OLDWO', 'Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA')
# ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', '2817 Milton Dr.', 'Albuquerque', '87110', 'USA')
# ('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', '187 Suffolk Ln.', 'Boise', '83720', 'USA')
# ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'P.O. Box 555', 'Lander', '82520', 'USA')
# ('THEBI', 'The Big Cheese', 'Liz Nixon', '89 Jefferson Way Suite 2', 'Portland', '97201', 'USA')
# ('THECR', 'The Cracker Box', 'Liu Wong', '55 Grizzly Peak Rd.', 'Butte', '59801', 'USA')
# ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', '722 DaVinci Blvd.', 'Kirkland', '98034', 'USA')
# ('WHITC', 'White Clover Markets', 'Karl Jablonski', '305 - 14th Ave. S. Suite 3B', 'Seattle', '98128', 'USA')
# ('GROSR', 'GROSELLA-Restaurante', 'Manuel Pereira', '5ª Ave. Los Palos Grandes', 'Caracas', '1081', 'Venezuela')
# ('HILAA', 'HILARION-Abastos', 'Carlos Hernández', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristóbal', '5022', 'Venezuela')
# ('LILAS', 'LILA-Supermercado', 'Carlos González', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', '3508', 'Venezuela')
# ('LINOD', 'LINO-Delicateses', 'Felipe Izquierdo', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita', '4980', 'Venezuela')
#
#  SQL Order By / Using Both ASC and DESC
# SQL : SELECT * FROM Customers ORDER BY Country ASC, customerName DESC;
# ('RANCH', 'Rancho grande', 'Sergio Gutiérrez', 'Av. del Libertador 900', 'Buenos Aires', '1010', 'Argentina')
# ('OCEAN', 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', '1010', 'Argentina')
# ('CACTU', 'Cactus Comidas para llevar', 'Patricio Simpson', 'Cerrito 333', 'Buenos Aires', '1010', 'Argentina')
# ('PICCO', 'Piccolo und mehr', 'Georg Pipps', 'Geislweg 14', 'Salzburg', '5020', 'Austria')
# ('ERNSH', 'Ernst Handel', 'Roland Mendel', 'Kirchgasse 6', 'Graz', '8010', 'Austria')
# ('SUPRD', 'Suprêmes délices', 'Pascale Cartrain', 'Boulevard Tirou 255', 'Charleroi', 'B-6000', 'Belgium')
# ('MAISD', 'Maison Dewey', 'Catherine Dewey', 'Rue Joseph-Bens 532', 'Bruxelles', 'B-1180', 'Belgium')
# ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Rua do Mercado 12', 'Resende', '08737-363', 'Brazil')
# ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 'Av. Inês de Castro 414', 'Sao Paulo', '05634-030', 'Brazil')
# ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Av. Copacabana 267', 'Rio de Janeiro', '02389-890', 'Brazil')
# ('QUEEN', 'Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios 891', 'Sao Paulo', '05487-020', 'Brazil')
# ('QUEDE', 'Que Delícia', 'Bernardo Batista', 'Rua da Panificadora', ' 12Rio de Janeiro', '02389-673', 'Brazil')
# ('HANAR', 'Hanari Carnes', 'Mario Pontes', 'Rua do Paço 67', 'Rio de Janeiro', '05454-876', 'Brazil')
# ('GOURL', 'Gourmet Lanchonetes', 'André Fonseca', 'Av. Brasil 442', 'Campinas', '04876-786', 'Brazil')
# ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 'Rua Orós 92', 'Sao Paulo', '05442-030', 'Brazil')
# ('COMMI', 'Comércio Mineiro', 'Pedro Afonso', '23 Av. dos Lusíadas', 'Sao Paulo', '05432-043', 'Brazil')
# ('MEREP', 'Mère Paillarde', 'Jean Fresnière', '43 rue St. Laurent', 'Montréal', 'H1J 1C3', 'Canada')
# ('LAUGB', 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', '1900 Oak St.', 'Vancouver', 'V3F 2K1', 'Canada')
# ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada')
# ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 'Smagsloget 45', 'Århus', '8200', 'Denmark')
# ('SIMOB', 'Simons bistro', 'Jytte Petersen', 'Vinbæltet 34', 'Kobenhavn', '1734', 'Denmark')
# ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Keskuskatu 45', 'Helsinki', '21240', 'Finland')
# ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Torikatu 38', 'Oulu', '90110', 'Finland')
# ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', "59 rue de l'Abbaye", 'Reims', '51100', 'France')
# ('VICTE', 'Victuailles en stock', 'Mary Saveley', '2 rue du Commerce', 'Lyon', '69004', 'France')
# ('SPECD', 'Spécialités du monde', 'Dominique Perrier', '25 rue Lauriston', 'Paris', '75016', 'France')
# ('PARIS', 'Paris spécialités', 'Marie Bertrand', '265 boulevard Charonne', 'Paris', '75012', 'France')
# ('LAMAI', "La maison d'Asie", 'Annette Roulet', '1 rue Alsace-Lorraine', 'Toulouse', '31000', 'France')
# ('LACOR', "La corne d'abondance", 'Daniel Tonini', "67 avenue de l'Europe", 'Versailles', '78000', 'France')
# ('FRANR', 'France restauration', 'Carine Schmitt', '54 rue Royale', 'Nantes', '44000', 'France')
# ('FOLIG', 'Folies gourmandes', 'Martine Rancé', '184 chaussée de Tournai', 'Lille', '59000', 'France')
# ('DUMON', 'Du monde entier', 'Janine Labrune', '67 rue des Cinquante Otages', 'Nantes', '44000', 'France')
# ('BONAP', "Bon app'", 'Laurence Lebihan', '12 rue des Bouchers', 'Marseille', '13008', 'France')
# ('BLONP', 'Blondesddsl père et fils', 'Frédérique Citeaux', '24 place Kléber', 'Strasbourg', '67000', 'France')
# ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Luisenstr. 48', 'Münster', '44087', 'Germany')
# ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Taucherstraße 10', 'Cunewalde', '01307', 'Germany')
# ('OTTIK', 'Ottilies Käseladen', 'Henriette Pfalzheim', 'Mehrheimerstr. 369', 'Köln', '50739', 'Germany')
# ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '04179', 'Germany')
# ('LEHMS', 'Lehmanns Marktstand', 'Renate Messner', 'Magazinweg 7', 'Frankfurt a.M.', '60528', 'Germany')
# ('KOENE', 'Königlich Essen', 'Philip Cramer', 'Maubelstr. 90', 'Brandenburg', '14776', 'Germany')
# ('FRANK', 'Frankenversand', 'Peter Franken', 'Berliner Platz 43', 'München', '80805', 'Germany')
# ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Walserweg 21', 'Aachen', '52066', 'Germany')
# ('WANDK', 'Die Wandernde Kuh', 'Rita Müller', 'Adenauerallee 900', 'Stuttgart', '70563', 'Germany')
# ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany')
# ('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# ('HUNGO', 'Hungry Owl All-Night Grocers', 'Patricia McKenna', '8 Johnstown Road', 'Cork', 'NULL', 'Ireland')
# ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Strada Provinciale 124', 'Reggio Emilia', '42100', 'Italy')
# ('MAGAA', 'Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 'Via Ludovico il Moro 22', 'Bergamo', '24100', 'Italy')
# ('FRANS', 'Franchi S.p.A.', 'Paolo Accorti', 'Via Monte Bianco 34', 'Torino', '10100', 'Italy')
# ('TORTU', 'Tortuga Restaurante', 'Miguel Angel Paolino', 'Avda. Azteca 123', 'México D.F.', '05033', 'Mexico')
# ('PERIC', 'Pericles Comidas clásicas', 'Guillermo Fernández', 'Calle Dr. Jorge Cash 321', 'México D.F.', '05033', 'Mexico')
# ('CENTC', 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '05022', 'Mexico')
# ('ANTON', 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos  2312', 'México D.F.', '05023', 'Mexico')
# ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# ('SANTG', 'Santé Gourmet', 'Jonas Bergulfsen', 'Erling Skakkes gate 78', 'Stavern', '4110', 'Norway')
# ('WOLZA', 'Wolski  Zajazd', 'Zbyszek Piestrzeniewicz', 'ul. Filtrowa 68', 'Warszawa', '01-012', 'Poland')
# ('PRINI', 'Princesa Isabel Vinhos', 'Isabel de Castro', 'Estrada da saúde n. 58', 'Lisboa', '1756', 'Portugal')
# ('FURIB', 'Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez', 'Jardim das rosas n. 32', 'Lisboa', '1675', 'Portugal')
# ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Gran Vía 1', 'Madrid', '28001', 'Spain')
# ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero 33', 'Sevilla', '41101', 'Spain')
# ('GALED', 'Galería del gastrónomo', 'Eduardo Saavedra', 'Rambla de Cataluña 23', 'Barcelona', '08022', 'Spain')
# ('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'C/ Moralzarzal 86', 'Madrid', '28034', 'Spain')
# ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', '67C Araquil', 'Madrid', '28023', 'Spain')
# ('FOLKO', 'Folk och fä HB', 'Maria Larsson', 'Åkergatan 24', 'Bräcke', 'S-844 67', 'Sweden')
# ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen  8', 'Luleå', 'S-958 22', 'Sweden')
# ('RICSU', 'Richter Supermarkt', 'Michael Holz', 'Grenzacherweg 237', 'Genève', '1203', 'Switzerland')
# ('CHOPS', 'Chop-suey Chinese', 'Yang Wang', 'Hauptstr. 29', 'Bern', '3012', 'Switzerland')
# ('SEVES', 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK')
# ('NORTS', 'North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK')
# ('ISLAT', 'Island Trading', 'Helen Bennett', 'Garden House Crowther Way', 'Cowes', 'PO31 7PJ', 'UK')
# ('EASTC', 'Eastern Connection', 'Ann Devon', '35 King George', 'London', 'WX3 6FW', 'UK')
# ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12  Brewery', 'London', 'WX1 6LT', 'UK')
# ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK')
# ('AROUT', 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# ('WHITC', 'White Clover Markets', 'Karl Jablonski', '305 - 14th Ave. S. Suite 3B', 'Seattle', '98128', 'USA')
# ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', '722 DaVinci Blvd.', 'Kirkland', '98034', 'USA')
# ('THECR', 'The Cracker Box', 'Liu Wong', '55 Grizzly Peak Rd.', 'Butte', '59801', 'USA')
# ('THEBI', 'The Big Cheese', 'Liz Nixon', '89 Jefferson Way Suite 2', 'Portland', '97201', 'USA')
# ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'P.O. Box 555', 'Lander', '82520', 'USA')
# ('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', '187 Suffolk Ln.', 'Boise', '83720', 'USA')
# ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', '2817 Milton Dr.', 'Albuquerque', '87110', 'USA')
# ('OLDWO', 'Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA')
# ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA')
# ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA')
# ('LAZYK', 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA')
# ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA')
# ('GREAL', 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA')
# ('LINOD', 'LINO-Delicateses', 'Felipe Izquierdo', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita', '4980', 'Venezuela')
# ('LILAS', 'LILA-Supermercado', 'Carlos González', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', '3508', 'Venezuela')
# ('HILAA', 'HILARION-Abastos', 'Carlos Hernández', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristóbal', '5022', 'Venezuela')
# ('GROSR', 'GROSELLA-Restaurante', 'Manuel Pereira', '5ª Ave. Los Palos Grandes', 'Caracas', '1081', 'Venezuela')

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print("현재 테이블 목록:")
for row in cursor.fetchall():
    print(" -", row[0])
# Out:
# 현재 테이블 목록:
#  - Customers
#  - Products
#  - Order_details
#  - Orders

# %%
run_query("SQL And", "SELECT * FROM Customers WHERE Country = 'Spain' AND CustomerName LIKE 'G%';")

run_query("SQL And / All conditions Must Be True", "SELECT * FROM Customers WHERE Country = 'Brazil' AND City = 'Rio de Janeiro' AND CustomerID > 50;")

run_query("SQL And / Combining AND and OR", "SELECT * FROM Customers WHERE Country = 'Spain' AND (CustomerName LIKE 'G%' OR CustomerName LIKE 'R%');")

run_query("SQL And / Combining AND and OR 2", "SELECT * FROM Customers WHERE Country = 'Spain' AND CustomerName LIKE 'G%' OR CustomerName LIKE 'R%';")
# Out:
#  SQL And
# SQL : SELECT * FROM Customers WHERE Country = 'Spain' AND CustomerName LIKE 'G%';
# ('GALED', 'Galería del gastrónomo', 'Eduardo Saavedra', 'Rambla de Cataluña 23', 'Barcelona', '08022', 'Spain')
# ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero 33', 'Sevilla', '41101', 'Spain')
#
#  SQL And / All conditions Must Be True
# SQL : SELECT * FROM Customers WHERE Country = 'Brazil' AND City = 'Rio de Janeiro' AND CustomerID > 50;
# ('HANAR', 'Hanari Carnes', 'Mario Pontes', 'Rua do Paço 67', 'Rio de Janeiro', '05454-876', 'Brazil')
# ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Av. Copacabana 267', 'Rio de Janeiro', '02389-890', 'Brazil')
#
#  SQL And / Combining AND and OR
# SQL : SELECT * FROM Customers WHERE Country = 'Spain' AND (CustomerName LIKE 'G%' OR CustomerName LIKE 'R%');
# ('GALED', 'Galería del gastrónomo', 'Eduardo Saavedra', 'Rambla de Cataluña 23', 'Barcelona', '08022', 'Spain')
# ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero 33', 'Sevilla', '41101', 'Spain')
# ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Gran Vía 1', 'Madrid', '28001', 'Spain')
#
#  SQL And / Combining AND and OR 2
# SQL : SELECT * FROM Customers WHERE Country = 'Spain' AND CustomerName LIKE 'G%' OR CustomerName LIKE 'R%';
# ('GALED', 'Galería del gastrónomo', 'Eduardo Saavedra', 'Rambla de Cataluña 23', 'Barcelona', '08022', 'Spain')
# ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero 33', 'Sevilla', '41101', 'Spain')
# ('RANCH', 'Rancho grande', 'Sergio Gutiérrez', 'Av. del Libertador 900', 'Buenos Aires', '1010', 'Argentina')
# ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', '2817 Milton Dr.', 'Albuquerque', '87110', 'USA')
# ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Strada Provinciale 124', 'Reggio Emilia', '42100', 'Italy')
# ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Av. Copacabana 267', 'Rio de Janeiro', '02389-890', 'Brazil')
# ('RICSU', 'Richter Supermarkt', 'Michael Holz', 'Grenzacherweg 237', 'Genève', '1203', 'Switzerland')
# ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Gran Vía 1', 'Madrid', '28001', 'Spain')

# %%
run_query("SQL Or", "SELECT * FROM Customers WHERE Country = 'Germany' OR Country = 'Spain';")

run_query("SQL Or / Combining AND and OR", "SELECT * FROM Customers WHERE Country = 'Spain' AND (CustomerName LIKE 'G%' OR CustomerName LIKE 'R%');")

run_query("SQL Or / Combining AND and OR", "SELECT * FROM Customers WHERE Country = 'Spain' AND CustomerName LIKE 'G%' OR CustomerName LIKE 'R%';")
# Out:
#  SQL Or
# SQL : SELECT * FROM Customers WHERE Country = 'Germany' OR Country = 'Spain';
# ('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany')
# ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', '67C Araquil', 'Madrid', '28023', 'Spain')
# ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Walserweg 21', 'Aachen', '52066', 'Germany')
# ('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'C/ Moralzarzal 86', 'Madrid', '28034', 'Spain')
# ('FRANK', 'Frankenversand', 'Peter Franken', 'Berliner Platz 43', 'München', '80805', 'Germany')
# ('GALED', 'Galería del gastrónomo', 'Eduardo Saavedra', 'Rambla de Cataluña 23', 'Barcelona', '08022', 'Spain')
# ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero 33', 'Sevilla', '41101', 'Spain')
# ('KOENE', 'Königlich Essen', 'Philip Cramer', 'Maubelstr. 90', 'Brandenburg', '14776', 'Germany')
# ('LEHMS', 'Lehmanns Marktstand', 'Renate Messner', 'Magazinweg 7', 'Frankfurt a.M.', '60528', 'Germany')
# ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '04179', 'Germany')
# ('OTTIK', 'Ottilies Käseladen', 'Henriette Pfalzheim', 'Mehrheimerstr. 369', 'Köln', '50739', 'Germany')
# ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Taucherstraße 10', 'Cunewalde', '01307', 'Germany')
# ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Gran Vía 1', 'Madrid', '28001', 'Spain')
# ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Luisenstr. 48', 'Münster', '44087', 'Germany')
# ('WANDK', 'Die Wandernde Kuh', 'Rita Müller', 'Adenauerallee 900', 'Stuttgart', '70563', 'Germany')
#
#  SQL Or / Combining AND and OR
# SQL : SELECT * FROM Customers WHERE Country = 'Spain' AND (CustomerName LIKE 'G%' OR CustomerName LIKE 'R%');
# ('GALED', 'Galería del gastrónomo', 'Eduardo Saavedra', 'Rambla de Cataluña 23', 'Barcelona', '08022', 'Spain')
# ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero 33', 'Sevilla', '41101', 'Spain')
# ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Gran Vía 1', 'Madrid', '28001', 'Spain')
#
#  SQL Or / Combining AND and OR
# SQL : SELECT * FROM Customers WHERE Country = 'Spain' AND CustomerName LIKE 'G%' OR CustomerName LIKE 'R%';
# ('GALED', 'Galería del gastrónomo', 'Eduardo Saavedra', 'Rambla de Cataluña 23', 'Barcelona', '08022', 'Spain')
# ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero 33', 'Sevilla', '41101', 'Spain')
# ('RANCH', 'Rancho grande', 'Sergio Gutiérrez', 'Av. del Libertador 900', 'Buenos Aires', '1010', 'Argentina')
# ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', '2817 Milton Dr.', 'Albuquerque', '87110', 'USA')
# ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Strada Provinciale 124', 'Reggio Emilia', '42100', 'Italy')
# ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Av. Copacabana 267', 'Rio de Janeiro', '02389-890', 'Brazil')
# ('RICSU', 'Richter Supermarkt', 'Michael Holz', 'Grenzacherweg 237', 'Genève', '1203', 'Switzerland')
# ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Gran Vía 1', 'Madrid', '28001', 'Spain')

# %%
run_query("SQL Not", "SELECT * FROM Customers WHERE NOT Country = 'Spain';")

run_query("SQL Not / NOT LIKE", "SELECT * FROM Customers WHERE CustomerName NOT LIKE 'A%';")

run_query("SQL Not / NOT BETWEEN", "SELECT * FROM Customers WHERE CustomerID NOT BETWEEN 10 AND 60;")

run_query("SQL Not / NOT IN", "SELECT * FROM Customers WHERE City NOT IN ('Paris', 'London');")

run_query("SQL Not / NOT Greater Than", "SELECT * FROM Customers WHERE NOT CustomerID > 50;")

run_query("SQL Not / NOT Less Than", "SELECT * FROM Customers WHERE NOT CustomerID < 50;")
# Out:
#  SQL Not
# SQL : SELECT * FROM Customers WHERE NOT Country = 'Spain';
# ('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# ('ANTON', 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos  2312', 'México D.F.', '05023', 'Mexico')
# ('AROUT', 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen  8', 'Luleå', 'S-958 22', 'Sweden')
# ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany')
# ('BLONP', 'Blondesddsl père et fils', 'Frédérique Citeaux', '24 place Kléber', 'Strasbourg', '67000', 'France')
# ('BONAP', "Bon app'", 'Laurence Lebihan', '12 rue des Bouchers', 'Marseille', '13008', 'France')
# ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada')
# ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK')
# ('CACTU', 'Cactus Comidas para llevar', 'Patricio Simpson', 'Cerrito 333', 'Buenos Aires', '1010', 'Argentina')
# ('CENTC', 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '05022', 'Mexico')
# ('CHOPS', 'Chop-suey Chinese', 'Yang Wang', 'Hauptstr. 29', 'Bern', '3012', 'Switzerland')
# ('COMMI', 'Comércio Mineiro', 'Pedro Afonso', '23 Av. dos Lusíadas', 'Sao Paulo', '05432-043', 'Brazil')
# ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12  Brewery', 'London', 'WX1 6LT', 'UK')
# ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Walserweg 21', 'Aachen', '52066', 'Germany')
# ('DUMON', 'Du monde entier', 'Janine Labrune', '67 rue des Cinquante Otages', 'Nantes', '44000', 'France')
# ('EASTC', 'Eastern Connection', 'Ann Devon', '35 King George', 'London', 'WX3 6FW', 'UK')
# ('ERNSH', 'Ernst Handel', 'Roland Mendel', 'Kirchgasse 6', 'Graz', '8010', 'Austria')
# ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 'Rua Orós 92', 'Sao Paulo', '05442-030', 'Brazil')
# ('FOLIG', 'Folies gourmandes', 'Martine Rancé', '184 chaussée de Tournai', 'Lille', '59000', 'France')
# ('FOLKO', 'Folk och fä HB', 'Maria Larsson', 'Åkergatan 24', 'Bräcke', 'S-844 67', 'Sweden')
# ('FRANK', 'Frankenversand', 'Peter Franken', 'Berliner Platz 43', 'München', '80805', 'Germany')
# ('FRANR', 'France restauration', 'Carine Schmitt', '54 rue Royale', 'Nantes', '44000', 'France')
# ('FRANS', 'Franchi S.p.A.', 'Paolo Accorti', 'Via Monte Bianco 34', 'Torino', '10100', 'Italy')
# ('FURIB', 'Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez', 'Jardim das rosas n. 32', 'Lisboa', '1675', 'Portugal')
# ('GOURL', 'Gourmet Lanchonetes', 'André Fonseca', 'Av. Brasil 442', 'Campinas', '04876-786', 'Brazil')
# ('GREAL', 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA')
# ('GROSR', 'GROSELLA-Restaurante', 'Manuel Pereira', '5ª Ave. Los Palos Grandes', 'Caracas', '1081', 'Venezuela')
# ('HANAR', 'Hanari Carnes', 'Mario Pontes', 'Rua do Paço 67', 'Rio de Janeiro', '05454-876', 'Brazil')
# ('HILAA', 'HILARION-Abastos', 'Carlos Hernández', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristóbal', '5022', 'Venezuela')
# ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA')
# ('HUNGO', 'Hungry Owl All-Night Grocers', 'Patricia McKenna', '8 Johnstown Road', 'Cork', 'NULL', 'Ireland')
# ('ISLAT', 'Island Trading', 'Helen Bennett', 'Garden House Crowther Way', 'Cowes', 'PO31 7PJ', 'UK')
# ('KOENE', 'Königlich Essen', 'Philip Cramer', 'Maubelstr. 90', 'Brandenburg', '14776', 'Germany')
# ('LACOR', "La corne d'abondance", 'Daniel Tonini', "67 avenue de l'Europe", 'Versailles', '78000', 'France')
# ('LAMAI', "La maison d'Asie", 'Annette Roulet', '1 rue Alsace-Lorraine', 'Toulouse', '31000', 'France')
# ('LAUGB', 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', '1900 Oak St.', 'Vancouver', 'V3F 2K1', 'Canada')
# ('LAZYK', 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA')
# ('LEHMS', 'Lehmanns Marktstand', 'Renate Messner', 'Magazinweg 7', 'Frankfurt a.M.', '60528', 'Germany')
# ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA')
# ('LILAS', 'LILA-Supermercado', 'Carlos González', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', '3508', 'Venezuela')
# ('LINOD', 'LINO-Delicateses', 'Felipe Izquierdo', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita', '4980', 'Venezuela')
# ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA')
# ('MAGAA', 'Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 'Via Ludovico il Moro 22', 'Bergamo', '24100', 'Italy')
# ('MAISD', 'Maison Dewey', 'Catherine Dewey', 'Rue Joseph-Bens 532', 'Bruxelles', 'B-1180', 'Belgium')
# ('MEREP', 'Mère Paillarde', 'Jean Fresnière', '43 rue St. Laurent', 'Montréal', 'H1J 1C3', 'Canada')
# ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '04179', 'Germany')
# ('NORTS', 'North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK')
# ('OCEAN', 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', '1010', 'Argentina')
# ('OLDWO', 'Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA')
# ('OTTIK', 'Ottilies Käseladen', 'Henriette Pfalzheim', 'Mehrheimerstr. 369', 'Köln', '50739', 'Germany')
# ('PARIS', 'Paris spécialités', 'Marie Bertrand', '265 boulevard Charonne', 'Paris', '75012', 'France')
# ('PERIC', 'Pericles Comidas clásicas', 'Guillermo Fernández', 'Calle Dr. Jorge Cash 321', 'México D.F.', '05033', 'Mexico')
# ('PICCO', 'Piccolo und mehr', 'Georg Pipps', 'Geislweg 14', 'Salzburg', '5020', 'Austria')
# ('PRINI', 'Princesa Isabel Vinhos', 'Isabel de Castro', 'Estrada da saúde n. 58', 'Lisboa', '1756', 'Portugal')
# ('QUEDE', 'Que Delícia', 'Bernardo Batista', 'Rua da Panificadora', ' 12Rio de Janeiro', '02389-673', 'Brazil')
# ('QUEEN', 'Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios 891', 'Sao Paulo', '05487-020', 'Brazil')
# ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Taucherstraße 10', 'Cunewalde', '01307', 'Germany')
# ('RANCH', 'Rancho grande', 'Sergio Gutiérrez', 'Av. del Libertador 900', 'Buenos Aires', '1010', 'Argentina')
# ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', '2817 Milton Dr.', 'Albuquerque', '87110', 'USA')
# ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Strada Provinciale 124', 'Reggio Emilia', '42100', 'Italy')
# ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Av. Copacabana 267', 'Rio de Janeiro', '02389-890', 'Brazil')
# ('RICSU', 'Richter Supermarkt', 'Michael Holz', 'Grenzacherweg 237', 'Genève', '1203', 'Switzerland')
# ('SANTG', 'Santé Gourmet', 'Jonas Bergulfsen', 'Erling Skakkes gate 78', 'Stavern', '4110', 'Norway')
# ('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', '187 Suffolk Ln.', 'Boise', '83720', 'USA')
# ('SEVES', 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK')
# ('SIMOB', 'Simons bistro', 'Jytte Petersen', 'Vinbæltet 34', 'Kobenhavn', '1734', 'Denmark')
# ('SPECD', 'Spécialités du monde', 'Dominique Perrier', '25 rue Lauriston', 'Paris', '75016', 'France')
# ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'P.O. Box 555', 'Lander', '82520', 'USA')
# ('SUPRD', 'Suprêmes délices', 'Pascale Cartrain', 'Boulevard Tirou 255', 'Charleroi', 'B-6000', 'Belgium')
# ('THEBI', 'The Big Cheese', 'Liz Nixon', '89 Jefferson Way Suite 2', 'Portland', '97201', 'USA')
# ('THECR', 'The Cracker Box', 'Liu Wong', '55 Grizzly Peak Rd.', 'Butte', '59801', 'USA')
# ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Luisenstr. 48', 'Münster', '44087', 'Germany')
# ('TORTU', 'Tortuga Restaurante', 'Miguel Angel Paolino', 'Avda. Azteca 123', 'México D.F.', '05033', 'Mexico')
# ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 'Av. Inês de Castro 414', 'Sao Paulo', '05634-030', 'Brazil')
# ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', '722 DaVinci Blvd.', 'Kirkland', '98034', 'USA')
# ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 'Smagsloget 45', 'Århus', '8200', 'Denmark')
# ('VICTE', 'Victuailles en stock', 'Mary Saveley', '2 rue du Commerce', 'Lyon', '69004', 'France')
# ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', "59 rue de l'Abbaye", 'Reims', '51100', 'France')
# ('WANDK', 'Die Wandernde Kuh', 'Rita Müller', 'Adenauerallee 900', 'Stuttgart', '70563', 'Germany')
# ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Torikatu 38', 'Oulu', '90110', 'Finland')
# ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Rua do Mercado 12', 'Resende', '08737-363', 'Brazil')
# ('WHITC', 'White Clover Markets', 'Karl Jablonski', '305 - 14th Ave. S. Suite 3B', 'Seattle', '98128', 'USA')
# ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Keskuskatu 45', 'Helsinki', '21240', 'Finland')
# ('WOLZA', 'Wolski  Zajazd', 'Zbyszek Piestrzeniewicz', 'ul. Filtrowa 68', 'Warszawa', '01-012', 'Poland')
#
#  SQL Not / NOT LIKE
# SQL : SELECT * FROM Customers WHERE CustomerName NOT LIKE 'A%';
# ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen  8', 'Luleå', 'S-958 22', 'Sweden')
# ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany')
# ('BLONP', 'Blondesddsl père et fils', 'Frédérique Citeaux', '24 place Kléber', 'Strasbourg', '67000', 'France')
# ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', '67C Araquil', 'Madrid', '28023', 'Spain')
# ('BONAP', "Bon app'", 'Laurence Lebihan', '12 rue des Bouchers', 'Marseille', '13008', 'France')
# ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada')
# ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK')
# ('CACTU', 'Cactus Comidas para llevar', 'Patricio Simpson', 'Cerrito 333', 'Buenos Aires', '1010', 'Argentina')
# ('CENTC', 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '05022', 'Mexico')
# ('CHOPS', 'Chop-suey Chinese', 'Yang Wang', 'Hauptstr. 29', 'Bern', '3012', 'Switzerland')
# ('COMMI', 'Comércio Mineiro', 'Pedro Afonso', '23 Av. dos Lusíadas', 'Sao Paulo', '05432-043', 'Brazil')
# ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12  Brewery', 'London', 'WX1 6LT', 'UK')
# ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Walserweg 21', 'Aachen', '52066', 'Germany')
# ('DUMON', 'Du monde entier', 'Janine Labrune', '67 rue des Cinquante Otages', 'Nantes', '44000', 'France')
# ('EASTC', 'Eastern Connection', 'Ann Devon', '35 King George', 'London', 'WX3 6FW', 'UK')
# ('ERNSH', 'Ernst Handel', 'Roland Mendel', 'Kirchgasse 6', 'Graz', '8010', 'Austria')
# ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 'Rua Orós 92', 'Sao Paulo', '05442-030', 'Brazil')
# ('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'C/ Moralzarzal 86', 'Madrid', '28034', 'Spain')
# ('FOLIG', 'Folies gourmandes', 'Martine Rancé', '184 chaussée de Tournai', 'Lille', '59000', 'France')
# ('FOLKO', 'Folk och fä HB', 'Maria Larsson', 'Åkergatan 24', 'Bräcke', 'S-844 67', 'Sweden')
# ('FRANK', 'Frankenversand', 'Peter Franken', 'Berliner Platz 43', 'München', '80805', 'Germany')
# ('FRANR', 'France restauration', 'Carine Schmitt', '54 rue Royale', 'Nantes', '44000', 'France')
# ('FRANS', 'Franchi S.p.A.', 'Paolo Accorti', 'Via Monte Bianco 34', 'Torino', '10100', 'Italy')
# ('FURIB', 'Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez', 'Jardim das rosas n. 32', 'Lisboa', '1675', 'Portugal')
# ('GALED', 'Galería del gastrónomo', 'Eduardo Saavedra', 'Rambla de Cataluña 23', 'Barcelona', '08022', 'Spain')
# ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero 33', 'Sevilla', '41101', 'Spain')
# ('GOURL', 'Gourmet Lanchonetes', 'André Fonseca', 'Av. Brasil 442', 'Campinas', '04876-786', 'Brazil')
# ('GREAL', 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA')
# ('GROSR', 'GROSELLA-Restaurante', 'Manuel Pereira', '5ª Ave. Los Palos Grandes', 'Caracas', '1081', 'Venezuela')
# ('HANAR', 'Hanari Carnes', 'Mario Pontes', 'Rua do Paço 67', 'Rio de Janeiro', '05454-876', 'Brazil')
# ('HILAA', 'HILARION-Abastos', 'Carlos Hernández', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristóbal', '5022', 'Venezuela')
# ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA')
# ('HUNGO', 'Hungry Owl All-Night Grocers', 'Patricia McKenna', '8 Johnstown Road', 'Cork', 'NULL', 'Ireland')
# ('ISLAT', 'Island Trading', 'Helen Bennett', 'Garden House Crowther Way', 'Cowes', 'PO31 7PJ', 'UK')
# ('KOENE', 'Königlich Essen', 'Philip Cramer', 'Maubelstr. 90', 'Brandenburg', '14776', 'Germany')
# ('LACOR', "La corne d'abondance", 'Daniel Tonini', "67 avenue de l'Europe", 'Versailles', '78000', 'France')
# ('LAMAI', "La maison d'Asie", 'Annette Roulet', '1 rue Alsace-Lorraine', 'Toulouse', '31000', 'France')
# ('LAUGB', 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', '1900 Oak St.', 'Vancouver', 'V3F 2K1', 'Canada')
# ('LAZYK', 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA')
# ('LEHMS', 'Lehmanns Marktstand', 'Renate Messner', 'Magazinweg 7', 'Frankfurt a.M.', '60528', 'Germany')
# ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA')
# ('LILAS', 'LILA-Supermercado', 'Carlos González', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', '3508', 'Venezuela')
# ('LINOD', 'LINO-Delicateses', 'Felipe Izquierdo', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita', '4980', 'Venezuela')
# ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA')
# ('MAGAA', 'Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 'Via Ludovico il Moro 22', 'Bergamo', '24100', 'Italy')
# ('MAISD', 'Maison Dewey', 'Catherine Dewey', 'Rue Joseph-Bens 532', 'Bruxelles', 'B-1180', 'Belgium')
# ('MEREP', 'Mère Paillarde', 'Jean Fresnière', '43 rue St. Laurent', 'Montréal', 'H1J 1C3', 'Canada')
# ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '04179', 'Germany')
# ('NORTS', 'North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK')
# ('OCEAN', 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', '1010', 'Argentina')
# ('OLDWO', 'Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA')
# ('OTTIK', 'Ottilies Käseladen', 'Henriette Pfalzheim', 'Mehrheimerstr. 369', 'Köln', '50739', 'Germany')
# ('PARIS', 'Paris spécialités', 'Marie Bertrand', '265 boulevard Charonne', 'Paris', '75012', 'France')
# ('PERIC', 'Pericles Comidas clásicas', 'Guillermo Fernández', 'Calle Dr. Jorge Cash 321', 'México D.F.', '05033', 'Mexico')
# ('PICCO', 'Piccolo und mehr', 'Georg Pipps', 'Geislweg 14', 'Salzburg', '5020', 'Austria')
# ('PRINI', 'Princesa Isabel Vinhos', 'Isabel de Castro', 'Estrada da saúde n. 58', 'Lisboa', '1756', 'Portugal')
# ('QUEDE', 'Que Delícia', 'Bernardo Batista', 'Rua da Panificadora', ' 12Rio de Janeiro', '02389-673', 'Brazil')
# ('QUEEN', 'Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios 891', 'Sao Paulo', '05487-020', 'Brazil')
# ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Taucherstraße 10', 'Cunewalde', '01307', 'Germany')
# ('RANCH', 'Rancho grande', 'Sergio Gutiérrez', 'Av. del Libertador 900', 'Buenos Aires', '1010', 'Argentina')
# ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', '2817 Milton Dr.', 'Albuquerque', '87110', 'USA')
# ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Strada Provinciale 124', 'Reggio Emilia', '42100', 'Italy')
# ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Av. Copacabana 267', 'Rio de Janeiro', '02389-890', 'Brazil')
# ('RICSU', 'Richter Supermarkt', 'Michael Holz', 'Grenzacherweg 237', 'Genève', '1203', 'Switzerland')
# ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Gran Vía 1', 'Madrid', '28001', 'Spain')
# ('SANTG', 'Santé Gourmet', 'Jonas Bergulfsen', 'Erling Skakkes gate 78', 'Stavern', '4110', 'Norway')
# ('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', '187 Suffolk Ln.', 'Boise', '83720', 'USA')
# ('SEVES', 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK')
# ('SIMOB', 'Simons bistro', 'Jytte Petersen', 'Vinbæltet 34', 'Kobenhavn', '1734', 'Denmark')
# ('SPECD', 'Spécialités du monde', 'Dominique Perrier', '25 rue Lauriston', 'Paris', '75016', 'France')
# ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'P.O. Box 555', 'Lander', '82520', 'USA')
# ('SUPRD', 'Suprêmes délices', 'Pascale Cartrain', 'Boulevard Tirou 255', 'Charleroi', 'B-6000', 'Belgium')
# ('THEBI', 'The Big Cheese', 'Liz Nixon', '89 Jefferson Way Suite 2', 'Portland', '97201', 'USA')
# ('THECR', 'The Cracker Box', 'Liu Wong', '55 Grizzly Peak Rd.', 'Butte', '59801', 'USA')
# ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Luisenstr. 48', 'Münster', '44087', 'Germany')
# ('TORTU', 'Tortuga Restaurante', 'Miguel Angel Paolino', 'Avda. Azteca 123', 'México D.F.', '05033', 'Mexico')
# ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 'Av. Inês de Castro 414', 'Sao Paulo', '05634-030', 'Brazil')
# ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', '722 DaVinci Blvd.', 'Kirkland', '98034', 'USA')
# ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 'Smagsloget 45', 'Århus', '8200', 'Denmark')
# ('VICTE', 'Victuailles en stock', 'Mary Saveley', '2 rue du Commerce', 'Lyon', '69004', 'France')
# ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', "59 rue de l'Abbaye", 'Reims', '51100', 'France')
# ('WANDK', 'Die Wandernde Kuh', 'Rita Müller', 'Adenauerallee 900', 'Stuttgart', '70563', 'Germany')
# ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Torikatu 38', 'Oulu', '90110', 'Finland')
# ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Rua do Mercado 12', 'Resende', '08737-363', 'Brazil')
# ('WHITC', 'White Clover Markets', 'Karl Jablonski', '305 - 14th Ave. S. Suite 3B', 'Seattle', '98128', 'USA')
# ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Keskuskatu 45', 'Helsinki', '21240', 'Finland')
# ('WOLZA', 'Wolski  Zajazd', 'Zbyszek Piestrzeniewicz', 'ul. Filtrowa 68', 'Warszawa', '01-012', 'Poland')
#
#  SQL Not / NOT BETWEEN
# SQL : SELECT * FROM Customers WHERE CustomerID NOT BETWEEN 10 AND 60;
# ('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# ('ANTON', 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos  2312', 'México D.F.', '05023', 'Mexico')
# ('AROUT', 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen  8', 'Luleå', 'S-958 22', 'Sweden')
# ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany')
# ('BLONP', 'Blondesddsl père et fils', 'Frédérique Citeaux', '24 place Kléber', 'Strasbourg', '67000', 'France')
# ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', '67C Araquil', 'Madrid', '28023', 'Spain')
# ('BONAP', "Bon app'", 'Laurence Lebihan', '12 rue des Bouchers', 'Marseille', '13008', 'France')
# ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada')
# ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK')
# ('CACTU', 'Cactus Comidas para llevar', 'Patricio Simpson', 'Cerrito 333', 'Buenos Aires', '1010', 'Argentina')
# ('CENTC', 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '05022', 'Mexico')
# ('CHOPS', 'Chop-suey Chinese', 'Yang Wang', 'Hauptstr. 29', 'Bern', '3012', 'Switzerland')
# ('COMMI', 'Comércio Mineiro', 'Pedro Afonso', '23 Av. dos Lusíadas', 'Sao Paulo', '05432-043', 'Brazil')
# ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12  Brewery', 'London', 'WX1 6LT', 'UK')
# ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Walserweg 21', 'Aachen', '52066', 'Germany')
# ('DUMON', 'Du monde entier', 'Janine Labrune', '67 rue des Cinquante Otages', 'Nantes', '44000', 'France')
# ('EASTC', 'Eastern Connection', 'Ann Devon', '35 King George', 'London', 'WX3 6FW', 'UK')
# ('ERNSH', 'Ernst Handel', 'Roland Mendel', 'Kirchgasse 6', 'Graz', '8010', 'Austria')
# ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 'Rua Orós 92', 'Sao Paulo', '05442-030', 'Brazil')
# ('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'C/ Moralzarzal 86', 'Madrid', '28034', 'Spain')
# ('FOLIG', 'Folies gourmandes', 'Martine Rancé', '184 chaussée de Tournai', 'Lille', '59000', 'France')
# ('FOLKO', 'Folk och fä HB', 'Maria Larsson', 'Åkergatan 24', 'Bräcke', 'S-844 67', 'Sweden')
# ('FRANK', 'Frankenversand', 'Peter Franken', 'Berliner Platz 43', 'München', '80805', 'Germany')
# ('FRANR', 'France restauration', 'Carine Schmitt', '54 rue Royale', 'Nantes', '44000', 'France')
# ('FRANS', 'Franchi S.p.A.', 'Paolo Accorti', 'Via Monte Bianco 34', 'Torino', '10100', 'Italy')
# ('FURIB', 'Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez', 'Jardim das rosas n. 32', 'Lisboa', '1675', 'Portugal')
# ('GALED', 'Galería del gastrónomo', 'Eduardo Saavedra', 'Rambla de Cataluña 23', 'Barcelona', '08022', 'Spain')
# ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero 33', 'Sevilla', '41101', 'Spain')
# ('GOURL', 'Gourmet Lanchonetes', 'André Fonseca', 'Av. Brasil 442', 'Campinas', '04876-786', 'Brazil')
# ('GREAL', 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA')
# ('GROSR', 'GROSELLA-Restaurante', 'Manuel Pereira', '5ª Ave. Los Palos Grandes', 'Caracas', '1081', 'Venezuela')
# ('HANAR', 'Hanari Carnes', 'Mario Pontes', 'Rua do Paço 67', 'Rio de Janeiro', '05454-876', 'Brazil')
# ('HILAA', 'HILARION-Abastos', 'Carlos Hernández', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristóbal', '5022', 'Venezuela')
# ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA')
# ('HUNGO', 'Hungry Owl All-Night Grocers', 'Patricia McKenna', '8 Johnstown Road', 'Cork', 'NULL', 'Ireland')
# ('ISLAT', 'Island Trading', 'Helen Bennett', 'Garden House Crowther Way', 'Cowes', 'PO31 7PJ', 'UK')
# ('KOENE', 'Königlich Essen', 'Philip Cramer', 'Maubelstr. 90', 'Brandenburg', '14776', 'Germany')
# ('LACOR', "La corne d'abondance", 'Daniel Tonini', "67 avenue de l'Europe", 'Versailles', '78000', 'France')
# ('LAMAI', "La maison d'Asie", 'Annette Roulet', '1 rue Alsace-Lorraine', 'Toulouse', '31000', 'France')
# ('LAUGB', 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', '1900 Oak St.', 'Vancouver', 'V3F 2K1', 'Canada')
# ('LAZYK', 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA')
# ('LEHMS', 'Lehmanns Marktstand', 'Renate Messner', 'Magazinweg 7', 'Frankfurt a.M.', '60528', 'Germany')
# ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA')
# ('LILAS', 'LILA-Supermercado', 'Carlos González', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', '3508', 'Venezuela')
# ('LINOD', 'LINO-Delicateses', 'Felipe Izquierdo', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita', '4980', 'Venezuela')
# ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA')
# ('MAGAA', 'Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 'Via Ludovico il Moro 22', 'Bergamo', '24100', 'Italy')
# ('MAISD', 'Maison Dewey', 'Catherine Dewey', 'Rue Joseph-Bens 532', 'Bruxelles', 'B-1180', 'Belgium')
# ('MEREP', 'Mère Paillarde', 'Jean Fresnière', '43 rue St. Laurent', 'Montréal', 'H1J 1C3', 'Canada')
# ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '04179', 'Germany')
# ('NORTS', 'North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK')
# ('OCEAN', 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', '1010', 'Argentina')
# ('OLDWO', 'Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA')
# ('OTTIK', 'Ottilies Käseladen', 'Henriette Pfalzheim', 'Mehrheimerstr. 369', 'Köln', '50739', 'Germany')
# ('PARIS', 'Paris spécialités', 'Marie Bertrand', '265 boulevard Charonne', 'Paris', '75012', 'France')
# ('PERIC', 'Pericles Comidas clásicas', 'Guillermo Fernández', 'Calle Dr. Jorge Cash 321', 'México D.F.', '05033', 'Mexico')
# ('PICCO', 'Piccolo und mehr', 'Georg Pipps', 'Geislweg 14', 'Salzburg', '5020', 'Austria')
# ('PRINI', 'Princesa Isabel Vinhos', 'Isabel de Castro', 'Estrada da saúde n. 58', 'Lisboa', '1756', 'Portugal')
# ('QUEDE', 'Que Delícia', 'Bernardo Batista', 'Rua da Panificadora', ' 12Rio de Janeiro', '02389-673', 'Brazil')
# ('QUEEN', 'Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios 891', 'Sao Paulo', '05487-020', 'Brazil')
# ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Taucherstraße 10', 'Cunewalde', '01307', 'Germany')
# ('RANCH', 'Rancho grande', 'Sergio Gutiérrez', 'Av. del Libertador 900', 'Buenos Aires', '1010', 'Argentina')
# ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', '2817 Milton Dr.', 'Albuquerque', '87110', 'USA')
# ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Strada Provinciale 124', 'Reggio Emilia', '42100', 'Italy')
# ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Av. Copacabana 267', 'Rio de Janeiro', '02389-890', 'Brazil')
# ('RICSU', 'Richter Supermarkt', 'Michael Holz', 'Grenzacherweg 237', 'Genève', '1203', 'Switzerland')
# ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Gran Vía 1', 'Madrid', '28001', 'Spain')
# ('SANTG', 'Santé Gourmet', 'Jonas Bergulfsen', 'Erling Skakkes gate 78', 'Stavern', '4110', 'Norway')
# ('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', '187 Suffolk Ln.', 'Boise', '83720', 'USA')
# ('SEVES', 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK')
# ('SIMOB', 'Simons bistro', 'Jytte Petersen', 'Vinbæltet 34', 'Kobenhavn', '1734', 'Denmark')
# ('SPECD', 'Spécialités du monde', 'Dominique Perrier', '25 rue Lauriston', 'Paris', '75016', 'France')
# ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'P.O. Box 555', 'Lander', '82520', 'USA')
# ('SUPRD', 'Suprêmes délices', 'Pascale Cartrain', 'Boulevard Tirou 255', 'Charleroi', 'B-6000', 'Belgium')
# ('THEBI', 'The Big Cheese', 'Liz Nixon', '89 Jefferson Way Suite 2', 'Portland', '97201', 'USA')
# ('THECR', 'The Cracker Box', 'Liu Wong', '55 Grizzly Peak Rd.', 'Butte', '59801', 'USA')
# ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Luisenstr. 48', 'Münster', '44087', 'Germany')
# ('TORTU', 'Tortuga Restaurante', 'Miguel Angel Paolino', 'Avda. Azteca 123', 'México D.F.', '05033', 'Mexico')
# ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 'Av. Inês de Castro 414', 'Sao Paulo', '05634-030', 'Brazil')
# ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', '722 DaVinci Blvd.', 'Kirkland', '98034', 'USA')
# ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 'Smagsloget 45', 'Århus', '8200', 'Denmark')
# ('VICTE', 'Victuailles en stock', 'Mary Saveley', '2 rue du Commerce', 'Lyon', '69004', 'France')
# ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', "59 rue de l'Abbaye", 'Reims', '51100', 'France')
# ('WANDK', 'Die Wandernde Kuh', 'Rita Müller', 'Adenauerallee 900', 'Stuttgart', '70563', 'Germany')
# ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Torikatu 38', 'Oulu', '90110', 'Finland')
# ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Rua do Mercado 12', 'Resende', '08737-363', 'Brazil')
# ('WHITC', 'White Clover Markets', 'Karl Jablonski', '305 - 14th Ave. S. Suite 3B', 'Seattle', '98128', 'USA')
# ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Keskuskatu 45', 'Helsinki', '21240', 'Finland')
# ('WOLZA', 'Wolski  Zajazd', 'Zbyszek Piestrzeniewicz', 'ul. Filtrowa 68', 'Warszawa', '01-012', 'Poland')
#
#  SQL Not / NOT IN
# SQL : SELECT * FROM Customers WHERE City NOT IN ('Paris', 'London');
# ('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# ('ANTON', 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos  2312', 'México D.F.', '05023', 'Mexico')
# ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen  8', 'Luleå', 'S-958 22', 'Sweden')
# ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany')
# ('BLONP', 'Blondesddsl père et fils', 'Frédérique Citeaux', '24 place Kléber', 'Strasbourg', '67000', 'France')
# ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', '67C Araquil', 'Madrid', '28023', 'Spain')
# ('BONAP', "Bon app'", 'Laurence Lebihan', '12 rue des Bouchers', 'Marseille', '13008', 'France')
# ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada')
# ('CACTU', 'Cactus Comidas para llevar', 'Patricio Simpson', 'Cerrito 333', 'Buenos Aires', '1010', 'Argentina')
# ('CENTC', 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '05022', 'Mexico')
# ('CHOPS', 'Chop-suey Chinese', 'Yang Wang', 'Hauptstr. 29', 'Bern', '3012', 'Switzerland')
# ('COMMI', 'Comércio Mineiro', 'Pedro Afonso', '23 Av. dos Lusíadas', 'Sao Paulo', '05432-043', 'Brazil')
# ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Walserweg 21', 'Aachen', '52066', 'Germany')
# ('DUMON', 'Du monde entier', 'Janine Labrune', '67 rue des Cinquante Otages', 'Nantes', '44000', 'France')
# ('ERNSH', 'Ernst Handel', 'Roland Mendel', 'Kirchgasse 6', 'Graz', '8010', 'Austria')
# ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 'Rua Orós 92', 'Sao Paulo', '05442-030', 'Brazil')
# ('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'C/ Moralzarzal 86', 'Madrid', '28034', 'Spain')
# ('FOLIG', 'Folies gourmandes', 'Martine Rancé', '184 chaussée de Tournai', 'Lille', '59000', 'France')
# ('FOLKO', 'Folk och fä HB', 'Maria Larsson', 'Åkergatan 24', 'Bräcke', 'S-844 67', 'Sweden')
# ('FRANK', 'Frankenversand', 'Peter Franken', 'Berliner Platz 43', 'München', '80805', 'Germany')
# ('FRANR', 'France restauration', 'Carine Schmitt', '54 rue Royale', 'Nantes', '44000', 'France')
# ('FRANS', 'Franchi S.p.A.', 'Paolo Accorti', 'Via Monte Bianco 34', 'Torino', '10100', 'Italy')
# ('FURIB', 'Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez', 'Jardim das rosas n. 32', 'Lisboa', '1675', 'Portugal')
# ('GALED', 'Galería del gastrónomo', 'Eduardo Saavedra', 'Rambla de Cataluña 23', 'Barcelona', '08022', 'Spain')
# ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero 33', 'Sevilla', '41101', 'Spain')
# ('GOURL', 'Gourmet Lanchonetes', 'André Fonseca', 'Av. Brasil 442', 'Campinas', '04876-786', 'Brazil')
# ('GREAL', 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA')
# ('GROSR', 'GROSELLA-Restaurante', 'Manuel Pereira', '5ª Ave. Los Palos Grandes', 'Caracas', '1081', 'Venezuela')
# ('HANAR', 'Hanari Carnes', 'Mario Pontes', 'Rua do Paço 67', 'Rio de Janeiro', '05454-876', 'Brazil')
# ('HILAA', 'HILARION-Abastos', 'Carlos Hernández', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristóbal', '5022', 'Venezuela')
# ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA')
# ('HUNGO', 'Hungry Owl All-Night Grocers', 'Patricia McKenna', '8 Johnstown Road', 'Cork', 'NULL', 'Ireland')
# ('ISLAT', 'Island Trading', 'Helen Bennett', 'Garden House Crowther Way', 'Cowes', 'PO31 7PJ', 'UK')
# ('KOENE', 'Königlich Essen', 'Philip Cramer', 'Maubelstr. 90', 'Brandenburg', '14776', 'Germany')
# ('LACOR', "La corne d'abondance", 'Daniel Tonini', "67 avenue de l'Europe", 'Versailles', '78000', 'France')
# ('LAMAI', "La maison d'Asie", 'Annette Roulet', '1 rue Alsace-Lorraine', 'Toulouse', '31000', 'France')
# ('LAUGB', 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', '1900 Oak St.', 'Vancouver', 'V3F 2K1', 'Canada')
# ('LAZYK', 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA')
# ('LEHMS', 'Lehmanns Marktstand', 'Renate Messner', 'Magazinweg 7', 'Frankfurt a.M.', '60528', 'Germany')
# ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA')
# ('LILAS', 'LILA-Supermercado', 'Carlos González', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', '3508', 'Venezuela')
# ('LINOD', 'LINO-Delicateses', 'Felipe Izquierdo', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita', '4980', 'Venezuela')
# ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA')
# ('MAGAA', 'Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 'Via Ludovico il Moro 22', 'Bergamo', '24100', 'Italy')
# ('MAISD', 'Maison Dewey', 'Catherine Dewey', 'Rue Joseph-Bens 532', 'Bruxelles', 'B-1180', 'Belgium')
# ('MEREP', 'Mère Paillarde', 'Jean Fresnière', '43 rue St. Laurent', 'Montréal', 'H1J 1C3', 'Canada')
# ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '04179', 'Germany')
# ('OCEAN', 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', '1010', 'Argentina')
# ('OLDWO', 'Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA')
# ('OTTIK', 'Ottilies Käseladen', 'Henriette Pfalzheim', 'Mehrheimerstr. 369', 'Köln', '50739', 'Germany')
# ('PERIC', 'Pericles Comidas clásicas', 'Guillermo Fernández', 'Calle Dr. Jorge Cash 321', 'México D.F.', '05033', 'Mexico')
# ('PICCO', 'Piccolo und mehr', 'Georg Pipps', 'Geislweg 14', 'Salzburg', '5020', 'Austria')
# ('PRINI', 'Princesa Isabel Vinhos', 'Isabel de Castro', 'Estrada da saúde n. 58', 'Lisboa', '1756', 'Portugal')
# ('QUEDE', 'Que Delícia', 'Bernardo Batista', 'Rua da Panificadora', ' 12Rio de Janeiro', '02389-673', 'Brazil')
# ('QUEEN', 'Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios 891', 'Sao Paulo', '05487-020', 'Brazil')
# ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Taucherstraße 10', 'Cunewalde', '01307', 'Germany')
# ('RANCH', 'Rancho grande', 'Sergio Gutiérrez', 'Av. del Libertador 900', 'Buenos Aires', '1010', 'Argentina')
# ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', '2817 Milton Dr.', 'Albuquerque', '87110', 'USA')
# ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Strada Provinciale 124', 'Reggio Emilia', '42100', 'Italy')
# ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Av. Copacabana 267', 'Rio de Janeiro', '02389-890', 'Brazil')
# ('RICSU', 'Richter Supermarkt', 'Michael Holz', 'Grenzacherweg 237', 'Genève', '1203', 'Switzerland')
# ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Gran Vía 1', 'Madrid', '28001', 'Spain')
# ('SANTG', 'Santé Gourmet', 'Jonas Bergulfsen', 'Erling Skakkes gate 78', 'Stavern', '4110', 'Norway')
# ('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', '187 Suffolk Ln.', 'Boise', '83720', 'USA')
# ('SIMOB', 'Simons bistro', 'Jytte Petersen', 'Vinbæltet 34', 'Kobenhavn', '1734', 'Denmark')
# ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'P.O. Box 555', 'Lander', '82520', 'USA')
# ('SUPRD', 'Suprêmes délices', 'Pascale Cartrain', 'Boulevard Tirou 255', 'Charleroi', 'B-6000', 'Belgium')
# ('THEBI', 'The Big Cheese', 'Liz Nixon', '89 Jefferson Way Suite 2', 'Portland', '97201', 'USA')
# ('THECR', 'The Cracker Box', 'Liu Wong', '55 Grizzly Peak Rd.', 'Butte', '59801', 'USA')
# ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Luisenstr. 48', 'Münster', '44087', 'Germany')
# ('TORTU', 'Tortuga Restaurante', 'Miguel Angel Paolino', 'Avda. Azteca 123', 'México D.F.', '05033', 'Mexico')
# ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 'Av. Inês de Castro 414', 'Sao Paulo', '05634-030', 'Brazil')
# ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', '722 DaVinci Blvd.', 'Kirkland', '98034', 'USA')
# ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 'Smagsloget 45', 'Århus', '8200', 'Denmark')
# ('VICTE', 'Victuailles en stock', 'Mary Saveley', '2 rue du Commerce', 'Lyon', '69004', 'France')
# ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', "59 rue de l'Abbaye", 'Reims', '51100', 'France')
# ('WANDK', 'Die Wandernde Kuh', 'Rita Müller', 'Adenauerallee 900', 'Stuttgart', '70563', 'Germany')
# ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Torikatu 38', 'Oulu', '90110', 'Finland')
# ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Rua do Mercado 12', 'Resende', '08737-363', 'Brazil')
# ('WHITC', 'White Clover Markets', 'Karl Jablonski', '305 - 14th Ave. S. Suite 3B', 'Seattle', '98128', 'USA')
# ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Keskuskatu 45', 'Helsinki', '21240', 'Finland')
# ('WOLZA', 'Wolski  Zajazd', 'Zbyszek Piestrzeniewicz', 'ul. Filtrowa 68', 'Warszawa', '01-012', 'Poland')
#
#  SQL Not / NOT Greater Than
# SQL : SELECT * FROM Customers WHERE NOT CustomerID > 50;
#
#  SQL Not / NOT Less Than
# SQL : SELECT * FROM Customers WHERE NOT CustomerID < 50;
# ('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# ('ANTON', 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos  2312', 'México D.F.', '05023', 'Mexico')
# ('AROUT', 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen  8', 'Luleå', 'S-958 22', 'Sweden')
# ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany')
# ('BLONP', 'Blondesddsl père et fils', 'Frédérique Citeaux', '24 place Kléber', 'Strasbourg', '67000', 'France')
# ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', '67C Araquil', 'Madrid', '28023', 'Spain')
# ('BONAP', "Bon app'", 'Laurence Lebihan', '12 rue des Bouchers', 'Marseille', '13008', 'France')
# ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada')
# ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK')
# ('CACTU', 'Cactus Comidas para llevar', 'Patricio Simpson', 'Cerrito 333', 'Buenos Aires', '1010', 'Argentina')
# ('CENTC', 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '05022', 'Mexico')
# ('CHOPS', 'Chop-suey Chinese', 'Yang Wang', 'Hauptstr. 29', 'Bern', '3012', 'Switzerland')
# ('COMMI', 'Comércio Mineiro', 'Pedro Afonso', '23 Av. dos Lusíadas', 'Sao Paulo', '05432-043', 'Brazil')
# ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12  Brewery', 'London', 'WX1 6LT', 'UK')
# ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Walserweg 21', 'Aachen', '52066', 'Germany')
# ('DUMON', 'Du monde entier', 'Janine Labrune', '67 rue des Cinquante Otages', 'Nantes', '44000', 'France')
# ('EASTC', 'Eastern Connection', 'Ann Devon', '35 King George', 'London', 'WX3 6FW', 'UK')
# ('ERNSH', 'Ernst Handel', 'Roland Mendel', 'Kirchgasse 6', 'Graz', '8010', 'Austria')
# ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 'Rua Orós 92', 'Sao Paulo', '05442-030', 'Brazil')
# ('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'C/ Moralzarzal 86', 'Madrid', '28034', 'Spain')
# ('FOLIG', 'Folies gourmandes', 'Martine Rancé', '184 chaussée de Tournai', 'Lille', '59000', 'France')
# ('FOLKO', 'Folk och fä HB', 'Maria Larsson', 'Åkergatan 24', 'Bräcke', 'S-844 67', 'Sweden')
# ('FRANK', 'Frankenversand', 'Peter Franken', 'Berliner Platz 43', 'München', '80805', 'Germany')
# ('FRANR', 'France restauration', 'Carine Schmitt', '54 rue Royale', 'Nantes', '44000', 'France')
# ('FRANS', 'Franchi S.p.A.', 'Paolo Accorti', 'Via Monte Bianco 34', 'Torino', '10100', 'Italy')
# ('FURIB', 'Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez', 'Jardim das rosas n. 32', 'Lisboa', '1675', 'Portugal')
# ('GALED', 'Galería del gastrónomo', 'Eduardo Saavedra', 'Rambla de Cataluña 23', 'Barcelona', '08022', 'Spain')
# ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero 33', 'Sevilla', '41101', 'Spain')
# ('GOURL', 'Gourmet Lanchonetes', 'André Fonseca', 'Av. Brasil 442', 'Campinas', '04876-786', 'Brazil')
# ('GREAL', 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA')
# ('GROSR', 'GROSELLA-Restaurante', 'Manuel Pereira', '5ª Ave. Los Palos Grandes', 'Caracas', '1081', 'Venezuela')
# ('HANAR', 'Hanari Carnes', 'Mario Pontes', 'Rua do Paço 67', 'Rio de Janeiro', '05454-876', 'Brazil')
# ('HILAA', 'HILARION-Abastos', 'Carlos Hernández', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristóbal', '5022', 'Venezuela')
# ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA')
# ('HUNGO', 'Hungry Owl All-Night Grocers', 'Patricia McKenna', '8 Johnstown Road', 'Cork', 'NULL', 'Ireland')
# ('ISLAT', 'Island Trading', 'Helen Bennett', 'Garden House Crowther Way', 'Cowes', 'PO31 7PJ', 'UK')
# ('KOENE', 'Königlich Essen', 'Philip Cramer', 'Maubelstr. 90', 'Brandenburg', '14776', 'Germany')
# ('LACOR', "La corne d'abondance", 'Daniel Tonini', "67 avenue de l'Europe", 'Versailles', '78000', 'France')
# ('LAMAI', "La maison d'Asie", 'Annette Roulet', '1 rue Alsace-Lorraine', 'Toulouse', '31000', 'France')
# ('LAUGB', 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', '1900 Oak St.', 'Vancouver', 'V3F 2K1', 'Canada')
# ('LAZYK', 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA')
# ('LEHMS', 'Lehmanns Marktstand', 'Renate Messner', 'Magazinweg 7', 'Frankfurt a.M.', '60528', 'Germany')
# ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA')
# ('LILAS', 'LILA-Supermercado', 'Carlos González', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', '3508', 'Venezuela')
# ('LINOD', 'LINO-Delicateses', 'Felipe Izquierdo', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita', '4980', 'Venezuela')
# ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA')
# ('MAGAA', 'Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 'Via Ludovico il Moro 22', 'Bergamo', '24100', 'Italy')
# ('MAISD', 'Maison Dewey', 'Catherine Dewey', 'Rue Joseph-Bens 532', 'Bruxelles', 'B-1180', 'Belgium')
# ('MEREP', 'Mère Paillarde', 'Jean Fresnière', '43 rue St. Laurent', 'Montréal', 'H1J 1C3', 'Canada')
# ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '04179', 'Germany')
# ('NORTS', 'North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK')
# ('OCEAN', 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', '1010', 'Argentina')
# ('OLDWO', 'Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA')
# ('OTTIK', 'Ottilies Käseladen', 'Henriette Pfalzheim', 'Mehrheimerstr. 369', 'Köln', '50739', 'Germany')
# ('PARIS', 'Paris spécialités', 'Marie Bertrand', '265 boulevard Charonne', 'Paris', '75012', 'France')
# ('PERIC', 'Pericles Comidas clásicas', 'Guillermo Fernández', 'Calle Dr. Jorge Cash 321', 'México D.F.', '05033', 'Mexico')
# ('PICCO', 'Piccolo und mehr', 'Georg Pipps', 'Geislweg 14', 'Salzburg', '5020', 'Austria')
# ('PRINI', 'Princesa Isabel Vinhos', 'Isabel de Castro', 'Estrada da saúde n. 58', 'Lisboa', '1756', 'Portugal')
# ('QUEDE', 'Que Delícia', 'Bernardo Batista', 'Rua da Panificadora', ' 12Rio de Janeiro', '02389-673', 'Brazil')
# ('QUEEN', 'Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios 891', 'Sao Paulo', '05487-020', 'Brazil')
# ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Taucherstraße 10', 'Cunewalde', '01307', 'Germany')
# ('RANCH', 'Rancho grande', 'Sergio Gutiérrez', 'Av. del Libertador 900', 'Buenos Aires', '1010', 'Argentina')
# ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', '2817 Milton Dr.', 'Albuquerque', '87110', 'USA')
# ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Strada Provinciale 124', 'Reggio Emilia', '42100', 'Italy')
# ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Av. Copacabana 267', 'Rio de Janeiro', '02389-890', 'Brazil')
# ('RICSU', 'Richter Supermarkt', 'Michael Holz', 'Grenzacherweg 237', 'Genève', '1203', 'Switzerland')
# ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Gran Vía 1', 'Madrid', '28001', 'Spain')
# ('SANTG', 'Santé Gourmet', 'Jonas Bergulfsen', 'Erling Skakkes gate 78', 'Stavern', '4110', 'Norway')
# ('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', '187 Suffolk Ln.', 'Boise', '83720', 'USA')
# ('SEVES', 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK')
# ('SIMOB', 'Simons bistro', 'Jytte Petersen', 'Vinbæltet 34', 'Kobenhavn', '1734', 'Denmark')
# ('SPECD', 'Spécialités du monde', 'Dominique Perrier', '25 rue Lauriston', 'Paris', '75016', 'France')
# ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'P.O. Box 555', 'Lander', '82520', 'USA')
# ('SUPRD', 'Suprêmes délices', 'Pascale Cartrain', 'Boulevard Tirou 255', 'Charleroi', 'B-6000', 'Belgium')
# ('THEBI', 'The Big Cheese', 'Liz Nixon', '89 Jefferson Way Suite 2', 'Portland', '97201', 'USA')
# ('THECR', 'The Cracker Box', 'Liu Wong', '55 Grizzly Peak Rd.', 'Butte', '59801', 'USA')
# ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Luisenstr. 48', 'Münster', '44087', 'Germany')
# ('TORTU', 'Tortuga Restaurante', 'Miguel Angel Paolino', 'Avda. Azteca 123', 'México D.F.', '05033', 'Mexico')
# ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 'Av. Inês de Castro 414', 'Sao Paulo', '05634-030', 'Brazil')
# ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', '722 DaVinci Blvd.', 'Kirkland', '98034', 'USA')
# ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 'Smagsloget 45', 'Århus', '8200', 'Denmark')
# ('VICTE', 'Victuailles en stock', 'Mary Saveley', '2 rue du Commerce', 'Lyon', '69004', 'France')
# ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', "59 rue de l'Abbaye", 'Reims', '51100', 'France')
# ('WANDK', 'Die Wandernde Kuh', 'Rita Müller', 'Adenauerallee 900', 'Stuttgart', '70563', 'Germany')
# ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Torikatu 38', 'Oulu', '90110', 'Finland')
# ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Rua do Mercado 12', 'Resende', '08737-363', 'Brazil')
# ('WHITC', 'White Clover Markets', 'Karl Jablonski', '305 - 14th Ave. S. Suite 3B', 'Seattle', '98128', 'USA')
# ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Keskuskatu 45', 'Helsinki', '21240', 'Finland')
# ('WOLZA', 'Wolski  Zajazd', 'Zbyszek Piestrzeniewicz', 'ul. Filtrowa 68', 'Warszawa', '01-012', 'Poland')

# %%
run_query("SQL Insert Into", "INSERT INTO Customers (CustomerName, ContactName, Address, City, PostalCode, Country) VALUES ('Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway');")

run_query("SQL Insert Into / Insert Data Only in Specified Columns", "INSERT INTO Customers (CustomerName, City, Country) VALUES ('Cardinal', 'Stavanger', 'Norway');")

run_query("SQL Insert Into / Insert Multiple Rows", "INSERT INTO Customers (CustomerName, ContactName, Address, City, PostalCode, Country) VALUES ('Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway'), ('Greasy Burger', 'Per Olsen', 'Gateveien 15', 'Sandnes', '4306', 'Norway'), ('Tasty Tee', 'Finn Egan', 'Streetroad 19B', 'Liverpool', 'L1 0AA', 'UK');")
# Out:
#  SQL Insert Into
# SQL : INSERT INTO Customers (CustomerName, ContactName, Address, City, PostalCode, Country) VALUES ('Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway');
#
#  SQL Insert Into / Insert Data Only in Specified Columns
# SQL : INSERT INTO Customers (CustomerName, City, Country) VALUES ('Cardinal', 'Stavanger', 'Norway');
#
#  SQL Insert Into / Insert Multiple Rows
# SQL : INSERT INTO Customers (CustomerName, ContactName, Address, City, PostalCode, Country) VALUES ('Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway'), ('Greasy Burger', 'Per Olsen', 'Gateveien 15', 'Sandnes', '4306', 'Norway'), ('Tasty Tee', 'Finn Egan', 'Streetroad 19B', 'Liverpool', 'L1 0AA', 'UK');

# %%
run_query("SQL Null Values / The IS NULL Operator", "SELECT CustomerName, ContactName, Address FROM Customers WHERE Address IS NULL;")

run_query("SQL Null Values / The IS NOT NULL Operator", "SELECT CustomerName, ContactName, Address FROM Customers WHERE Address IS NOT NULL;")
# Out:
#  SQL Null Values / The IS NULL Operator
# SQL : SELECT CustomerName, ContactName, Address FROM Customers WHERE Address IS NULL;
# ('Cardinal', None, None)
#
#  SQL Null Values / The IS NOT NULL Operator
# SQL : SELECT CustomerName, ContactName, Address FROM Customers WHERE Address IS NOT NULL;
# ('Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57')
# ('Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222')
# ('Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos  2312')
# ('Around the Horn', 'Thomas Hardy', '120 Hanover Sq.')
# ('Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen  8')
# ('Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57')
# ('Blondesddsl père et fils', 'Frédérique Citeaux', '24 place Kléber')
# ('Bólido Comidas preparadas', 'Martín Sommer', '67C Araquil')
# ("Bon app'", 'Laurence Lebihan', '12 rue des Bouchers')
# ('Bottom-Dollar Markets', 'Elizabeth Lincoln', '23 Tsawassen Blvd.')
# ("B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus')
# ('Cactus Comidas para llevar', 'Patricio Simpson', 'Cerrito 333')
# ('Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993')
# ('Chop-suey Chinese', 'Yang Wang', 'Hauptstr. 29')
# ('Comércio Mineiro', 'Pedro Afonso', '23 Av. dos Lusíadas')
# ('Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12  Brewery')
# ('Drachenblut Delikatessen', 'Sven Ottlieb', 'Walserweg 21')
# ('Du monde entier', 'Janine Labrune', '67 rue des Cinquante Otages')
# ('Eastern Connection', 'Ann Devon', '35 King George')
# ('Ernst Handel', 'Roland Mendel', 'Kirchgasse 6')
# ('Familia Arquibaldo', 'Aria Cruz', 'Rua Orós 92')
# ('FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'C/ Moralzarzal 86')
# ('Folies gourmandes', 'Martine Rancé', '184 chaussée de Tournai')
# ('Folk och fä HB', 'Maria Larsson', 'Åkergatan 24')
# ('Frankenversand', 'Peter Franken', 'Berliner Platz 43')
# ('France restauration', 'Carine Schmitt', '54 rue Royale')
# ('Franchi S.p.A.', 'Paolo Accorti', 'Via Monte Bianco 34')
# ('Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez', 'Jardim das rosas n. 32')
# ('Galería del gastrónomo', 'Eduardo Saavedra', 'Rambla de Cataluña 23')
# ('Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero 33')
# ('Gourmet Lanchonetes', 'André Fonseca', 'Av. Brasil 442')
# ('Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.')
# ('GROSELLA-Restaurante', 'Manuel Pereira', '5ª Ave. Los Palos Grandes')
# ('Hanari Carnes', 'Mario Pontes', 'Rua do Paço 67')
# ('HILARION-Abastos', 'Carlos Hernández', 'Carrera 22 con Ave. Carlos Soublette #8-35')
# ('Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.')
# ('Hungry Owl All-Night Grocers', 'Patricia McKenna', '8 Johnstown Road')
# ('Island Trading', 'Helen Bennett', 'Garden House Crowther Way')
# ('Königlich Essen', 'Philip Cramer', 'Maubelstr. 90')
# ("La corne d'abondance", 'Daniel Tonini', "67 avenue de l'Europe")
# ("La maison d'Asie", 'Annette Roulet', '1 rue Alsace-Lorraine')
# ('Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', '1900 Oak St.')
# ('Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace')
# ('Lehmanns Marktstand', 'Renate Messner', 'Magazinweg 7')
# ("Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5')
# ('LILA-Supermercado', 'Carlos González', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo')
# ('LINO-Delicateses', 'Felipe Izquierdo', 'Ave. 5 de Mayo Porlamar')
# ('Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.')
# ('Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 'Via Ludovico il Moro 22')
# ('Maison Dewey', 'Catherine Dewey', 'Rue Joseph-Bens 532')
# ('Mère Paillarde', 'Jean Fresnière', '43 rue St. Laurent')
# ('Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22')
# ('North/South', 'Simon Crowther', 'South House 300 Queensbridge')
# ('Océano Atlántico Ltda.', 'Yvonne Moncada', 'Ing. Gustavo Moncada 8585 Piso 20-A')
# ('Old World Delicatessen', 'Rene Phillips', '2743 Bering St.')
# ('Ottilies Käseladen', 'Henriette Pfalzheim', 'Mehrheimerstr. 369')
# ('Paris spécialités', 'Marie Bertrand', '265 boulevard Charonne')
# ('Pericles Comidas clásicas', 'Guillermo Fernández', 'Calle Dr. Jorge Cash 321')
# ('Piccolo und mehr', 'Georg Pipps', 'Geislweg 14')
# ('Princesa Isabel Vinhos', 'Isabel de Castro', 'Estrada da saúde n. 58')
# ('Que Delícia', 'Bernardo Batista', 'Rua da Panificadora')
# ('Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios 891')
# ('QUICK-Stop', 'Horst Kloss', 'Taucherstraße 10')
# ('Rancho grande', 'Sergio Gutiérrez', 'Av. del Libertador 900')
# ('Rattlesnake Canyon Grocery', 'Paula Wilson', '2817 Milton Dr.')
# ('Reggiani Caseifici', 'Maurizio Moroni', 'Strada Provinciale 124')
# ('Ricardo Adocicados', 'Janete Limeira', 'Av. Copacabana 267')
# ('Richter Supermarkt', 'Michael Holz', 'Grenzacherweg 237')
# ('Romero y tomillo', 'Alejandra Camino', 'Gran Vía 1')
# ('Santé Gourmet', 'Jonas Bergulfsen', 'Erling Skakkes gate 78')
# ('Save-a-lot Markets', 'Jose Pavarotti', '187 Suffolk Ln.')
# ('Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.')
# ('Simons bistro', 'Jytte Petersen', 'Vinbæltet 34')
# ('Spécialités du monde', 'Dominique Perrier', '25 rue Lauriston')
# ('Split Rail Beer & Ale', 'Art Braunschweiger', 'P.O. Box 555')
# ('Suprêmes délices', 'Pascale Cartrain', 'Boulevard Tirou 255')
# ('The Big Cheese', 'Liz Nixon', '89 Jefferson Way Suite 2')
# ('The Cracker Box', 'Liu Wong', '55 Grizzly Peak Rd.')
# ('Toms Spezialitäten', 'Karin Josephs', 'Luisenstr. 48')
# ('Tortuga Restaurante', 'Miguel Angel Paolino', 'Avda. Azteca 123')
# ('Tradição Hipermercados', 'Anabela Domingues', 'Av. Inês de Castro 414')
# ("Trail's Head Gourmet Provisioners", 'Helvetius Nagy', '722 DaVinci Blvd.')
# ('Vaffeljernet', 'Palle Ibsen', 'Smagsloget 45')
# ('Victuailles en stock', 'Mary Saveley', '2 rue du Commerce')
# ('Vins et alcools Chevalier', 'Paul Henriot', "59 rue de l'Abbaye")
# ('Die Wandernde Kuh', 'Rita Müller', 'Adenauerallee 900')
# ('Wartian Herkku', 'Pirkko Koskitalo', 'Torikatu 38')
# ('Wellington Importadora', 'Paula Parente', 'Rua do Mercado 12')
# ('White Clover Markets', 'Karl Jablonski', '305 - 14th Ave. S. Suite 3B')
# ('Wilman Kala', 'Matti Karttunen', 'Keskuskatu 45')
# ('Wolski  Zajazd', 'Zbyszek Piestrzeniewicz', 'ul. Filtrowa 68')
# ('Cardinal', 'Tom B. Erichsen', 'Skagen 21')
# ('Cardinal', 'Tom B. Erichsen', 'Skagen 21')
# ('Greasy Burger', 'Per Olsen', 'Gateveien 15')
# ('Tasty Tee', 'Finn Egan', 'Streetroad 19B')

# %%
run_query("SQL Update", "UPDATE Customers SET ContactName = 'Alfred Schmidt', City = 'Frankfurt' WHERE CustomerID = 1;")

run_query("SQL Update / UPDATE Multiple Records", "UPDATE Customers SET ContactName = 'Juan' WHERE Country = 'Mexico';")

# run_query("SQL Update / Update Warning!", "UPDATE Customers SET ContactName = 'Juan';")
# Out:
#  SQL Update
# SQL : UPDATE Customers SET ContactName = 'Alfred Schmidt', City = 'Frankfurt' WHERE CustomerID = 1;
#
#  SQL Update / UPDATE Multiple Records
# SQL : UPDATE Customers SET ContactName = 'Juan' WHERE Country = 'Mexico';

# %%
run_query("SQL Delete", "DELETE FROM Customers WHERE CustomerName = 'Alfreds Futterkiste';")

# run_query("SQL Delete / Delete All Records", "DELETE FROM Customers;")

# run_query("SQL Delete / Delete a Table", "DROP TABLE Customers;")
# Out:
#  SQL Delete
# SQL : DELETE FROM Customers WHERE CustomerName = 'Alfreds Futterkiste';

# %%
# run_query("SQL Select Top", "SELECT TOP 3 * FROM Customers;") SQLite에서는 SELECT TOP을 지원하지 않아서 'LIMIT'절을 사용해야 된다.

run_query("SQL Select Top / LIMIT", "SELECT * FROM Customers LIMIT 3;")

# run_query("SQL Select Top / FETCH FIRST", "SELECT * FROM Customers FETCH FIRST 3 ROWS ONLY;") SQLite에서 FIRST 함수도 지원하지 않는다.

# run_query("SQL Select Top / SQL TOP PERCENT", "SELECT * FROM Customers FETCH FIRST 50 PERCENT ROWS ONLY;")

run_query("SQL Select Top / ADD a WHERE CLAUSE", "SELECT * FROM Customers WHERE Country = 'Germany' LIMIT 3;")

# run_query("SQL Select Top / ADD a WHERE CLAUSE", "SELECT * FROM Customers WHERE Country = 'Germany' FETCH FIRST 3 ROWS ONLY;")

run_query("SQL Select Top / ADD the ORDER BY Keyword", "SELECT * FROM Customers ORDER BY CustomerName DESC LIMIT 3;")

# run_query("SQL Select Top / ADD the ORDER BY Keyword", "SELECT * FROM Customers ORDER BY CustomerName DESC FETCH FIRST 3 ROWS ONLY;")
# Out:
#  SQL Select Top / LIMIT
# SQL : SELECT * FROM Customers LIMIT 3;
# ('ANATR', 'Ana Trujillo Emparedados y helados', 'Juan', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# ('ANTON', 'Antonio Moreno Taquería', 'Juan', 'Mataderos  2312', 'México D.F.', '05023', 'Mexico')
# ('AROUT', 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
#
#  SQL Select Top / ADD a WHERE CLAUSE
# SQL : SELECT * FROM Customers WHERE Country = 'Germany' LIMIT 3;
# ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany')
# ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Walserweg 21', 'Aachen', '52066', 'Germany')
# ('FRANK', 'Frankenversand', 'Peter Franken', 'Berliner Platz 43', 'München', '80805', 'Germany')
#
#  SQL Select Top / ADD the ORDER BY Keyword
# SQL : SELECT * FROM Customers ORDER BY CustomerName DESC LIMIT 3;
# ('WOLZA', 'Wolski  Zajazd', 'Zbyszek Piestrzeniewicz', 'ul. Filtrowa 68', 'Warszawa', '01-012', 'Poland')
# ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Keskuskatu 45', 'Helsinki', '21240', 'Finland')
# ('WHITC', 'White Clover Markets', 'Karl Jablonski', '305 - 14th Ave. S. Suite 3B', 'Seattle', '98128', 'USA')

# %%
run_query("SQL Min and Max", "SELECT MIN(unitPrice) FROM Products;")

run_query("SQL Min and Max", "SELECT MAX(unitPrice) FROM Products;")

run_query("SQL Min and Max / Set Column Name (Alias)", "SELECT MIN(unitPrice) AS SmallestPrice FROM Products;")

run_query("SQL Min and Max / Use MIN() with GROUP BY", "SELECT MIN(unitPrice) AS SmallestPrice, CategoryID FROM Products GROUP BY CategoryID;")
# Out:
#  SQL Min and Max
# SQL : SELECT MIN(unitPrice) FROM Products;
# (2.5,)
#
#  SQL Min and Max
# SQL : SELECT MAX(unitPrice) FROM Products;
# (263.5,)
#
#  SQL Min and Max / Set Column Name (Alias)
# SQL : SELECT MIN(unitPrice) AS SmallestPrice FROM Products;
# (2.5,)
#
#  SQL Min and Max / Use MIN() with GROUP BY
# SQL : SELECT MIN(unitPrice) AS SmallestPrice, CategoryID FROM Products GROUP BY CategoryID;
# (4.5, 1)
# (10.0, 2)
# (9.2, 3)
# (2.5, 4)
# (7.0, 5)
# (7.45, 6)
# (10.0, 7)
# (6.0, 8)

# %%
run_query("SQL Count", "SELECT COUNT(*) FROM Products;")

run_query("SQL Count / Specify Column", "SELECT COUNT(ProductName) FROM Products;")

run_query("SQL Count / Add a WHERE Clause", "SELECT COUNT(ProductID) FROM Products WHERE unitPrice > 20;")

run_query("SQL Count / Ignore Duplicates", "SELECT COUNT(DISTINCT unitPrice) FROM Products;")

run_query("SQL Count / Use and Alias", "SELECT COUNT(*) AS [Number of records] FROM Products;")

run_query("SQL Count / use COUNT() with GROUP BY", "SELECT COUNT(*) AS [Number of records], CategoryID FROM Products GROUP BY CategoryID;")
# Out:
#  SQL Count
# SQL : SELECT COUNT(*) FROM Products;
# (77,)
#
#  SQL Count / Specify Column
# SQL : SELECT COUNT(ProductName) FROM Products;
# (77,)
#
#  SQL Count / Add a WHERE Clause
# SQL : SELECT COUNT(ProductID) FROM Products WHERE unitPrice > 20;
# (37,)
#
#  SQL Count / Ignore Duplicates
# SQL : SELECT COUNT(DISTINCT unitPrice) FROM Products;
# (62,)
#
#  SQL Count / Use and Alias
# SQL : SELECT COUNT(*) AS [Number of records] FROM Products;
# (77,)
#
#  SQL Count / use COUNT() with GROUP BY
# SQL : SELECT COUNT(*) AS [Number of records], CategoryID FROM Products GROUP BY CategoryID;
# (12, 1)
# (12, 2)
# (13, 3)
# (10, 4)
# (7, 5)
# (6, 6)
# (5, 7)
# (12, 8)

# %%
run_query("SQL Sum", "SELECT SUM(Quantity) FROM Order_details;")

run_query("SQL Sum / Add a WHERE Clause", "SELECT SUM(Quantity) FROM Order_details WHERE ProductID = 11;")

run_query("SQL Sum / Use an Alias", "SELECT SUM(Quantity) AS total FROM Order_details;")

run_query("SQL Sum / Use SUM() with GROUP BY", "SELECT OrderID, SUM(Quantity) AS [Total Quantity] FROM Order_details GROUP BY OrderID;")

run_query("SQL Sum / SUM() with an Expression", "SELECT SUM(Quantity * 10) FROM Order_details;")
# Out:
#  SQL Sum
# SQL : SELECT SUM(Quantity) FROM Order_details;
# (51317,)
#
#  SQL Sum / Add a WHERE Clause
# SQL : SELECT SUM(Quantity) FROM Order_details WHERE ProductID = 11;
# (706,)
#
#  SQL Sum / Use an Alias
# SQL : SELECT SUM(Quantity) AS total FROM Order_details;
# (51317,)
#
#  SQL Sum / Use SUM() with GROUP BY
# SQL : SELECT OrderID, SUM(Quantity) AS [Total Quantity] FROM Order_details GROUP BY OrderID;
# (10248, 27)
# (10249, 49)
# (10250, 60)
# (10251, 41)
# (10252, 105)
# (10253, 102)
# (10254, 57)
# (10255, 110)
# (10256, 27)
# (10257, 46)
# (10258, 121)
# (10259, 11)
# (10260, 102)
# (10261, 40)
# (10262, 29)
# (10263, 184)
# (10264, 60)
# (10265, 50)
# (10266, 12)
# (10267, 135)
# (10268, 14)
# (10269, 80)
# (10270, 55)
# (10271, 24)
# (10272, 70)
# (10273, 152)
# (10274, 27)
# (10275, 18)
# (10276, 25)
# (10277, 32)
# (10278, 64)
# (10279, 15)
# (10280, 62)
# (10281, 11)
# (10282, 8)
# (10283, 76)
# (10284, 61)
# (10285, 121)
# (10286, 140)
# (10287, 75)
# (10288, 13)
# (10289, 39)
# (10290, 60)
# (10291, 46)
# (10292, 20)
# (10293, 33)
# (10294, 75)
# (10295, 4)
# (10296, 57)
# (10297, 80)
# (10298, 125)
# (10299, 35)
# (10300, 50)
# (10301, 30)
# (10302, 80)
# (10303, 85)
# (10304, 42)
# (10305, 80)
# (10306, 25)
# (10307, 13)
# (10308, 6)
# (10309, 75)
# (10310, 15)
# (10311, 13)
# (10312, 58)
# (10313, 12)
# (10314, 95)
# (10315, 44)
# (10316, 80)
# (10317, 20)
# (10318, 26)
# (10319, 52)
# (10320, 30)
# (10321, 10)
# (10322, 20)
# (10323, 13)
# (10324, 241)
# (10325, 71)
# (10326, 90)
# (10327, 140)
# (10328, 59)
# (10329, 50)
# (10330, 75)
# (10331, 15)
# (10332, 66)
# (10333, 60)
# (10334, 18)
# (10335, 86)
# (10336, 18)
# (10337, 137)
# (10338, 35)
# (10339, 108)
# (10340, 72)
# (10341, 17)
# (10342, 160)
# (10343, 69)
# (10344, 105)
# (10345, 159)
# (10346, 56)
# (10347, 70)
# (10348, 40)
# (10349, 24)
# (10350, 33)
# (10351, 120)
# (10352, 30)
# (10353, 62)
# (10354, 16)
# (10355, 50)
# (10356, 62)
# (10357, 54)
# (10358, 40)
# (10359, 206)
# (10360, 138)
# (10361, 109)
# (10362, 94)
# (10363, 44)
# (10364, 35)
# (10365, 24)
# (10366, 10)
# (10367, 76)
# (10368, 78)
# (10369, 38)
# (10370, 65)
# (10371, 6)
# (10372, 164)
# (10373, 130)
# (10374, 45)
# (10375, 25)
# (10376, 42)
# (10377, 40)
# (10378, 6)
# (10379, 44)
# (10380, 74)
# (10381, 14)
# (10382, 165)
# (10383, 55)
# (10384, 43)
# (10385, 38)
# (10386, 25)
# (10387, 48)
# (10388, 75)
# (10389, 81)
# (10390, 169)
# (10391, 18)
# (10392, 50)
# (10393, 176)
# (10394, 20)
# (10395, 106)
# (10396, 121)
# (10397, 28)
# (10398, 150)
# (10399, 139)
# (10400, 86)
# (10401, 168)
# (10402, 125)
# (10403, 91)
# (10404, 100)
# (10405, 50)
# (10406, 89)
# (10407, 60)
# (10408, 51)
# (10409, 24)
# (10410, 65)
# (10411, 74)
# (10412, 20)
# (10413, 78)
# (10414, 68)
# (10415, 22)
# (10416, 50)
# (10417, 123)
# (10418, 146)
# (10419, 80)
# (10420, 50)
# (10421, 59)
# (10422, 2)
# (10423, 34)
# (10424, 139)
# (10425, 30)
# (10426, 12)
# (10427, 35)
# (10428, 20)
# (10429, 75)
# (10430, 195)
# (10431, 130)
# (10432, 50)
# (10433, 28)
# (10434, 24)
# (10435, 32)
# (10436, 99)
# (10437, 15)
# (10438, 50)
# (10439, 67)
# (10440, 208)
# (10441, 50)
# (10442, 170)
# (10443, 18)
# (10444, 63)
# (10445, 21)
# (10446, 50)
# (10447, 77)
# (10448, 26)
# (10449, 69)
# (10450, 26)
# (10451, 238)
# (10452, 115)
# (10453, 40)
# (10454, 50)
# (10455, 125)
# (10456, 61)
# (10457, 36)
# (10458, 145)
# (10459, 76)
# (10460, 25)
# (10461, 128)
# (10462, 22)
# (10463, 71)
# (10464, 69)
# (10465, 118)
# (10466, 15)
# (10467, 40)
# (10468, 23)
# (10469, 77)
# (10470, 53)
# (10471, 50)
# (10472, 98)
# (10473, 24)
# (10474, 61)
# (10475, 137)
# (10476, 14)
# (10477, 56)
# (10478, 20)
# (10479, 148)
# (10480, 42)
# (10481, 64)
# (10482, 10)
# (10483, 65)
# (10484, 27)
# (10485, 130)
# (10486, 46)
# (10487, 59)
# (10488, 50)
# (10489, 33)
# (10490, 126)
# (10491, 22)
# (10492, 80)
# (10493, 35)
# (10494, 30)
# (10495, 35)
# (10496, 20)
# (10497, 64)
# (10498, 49)
# (10499, 45)
# (10500, 20)
# (10501, 20)
# (10502, 57)
# (10503, 90)
# (10504, 59)
# (10505, 3)
# (10506, 32)
# (10507, 30)
# (10508, 20)
# (10509, 3)
# (10510, 72)
# (10511, 110)
# (10512, 37)
# (10513, 105)
# (10514, 233)
# (10515, 286)
# (10516, 125)
# (10517, 16)
# (10518, 29)
# (10519, 66)
# (10520, 13)
# (10521, 19)
# (10522, 109)
# (10523, 64)
# (10524, 87)
# (10525, 45)
# (10526, 48)
# (10527, 80)
# (10528, 20)
# (10529, 44)
# (10530, 135)
# (10531, 2)
# (10532, 39)
# (10533, 98)
# (10534, 30)
# (10535, 80)
# (10536, 100)
# (10537, 86)
# (10538, 8)
# (10539, 44)
# (10540, 165)
# (10541, 84)
# (10542, 39)
# (10543, 100)
# (10544, 14)
# (10545, 10)
# (10546, 80)
# (10547, 84)
# (10548, 24)
# (10549, 203)
# (10550, 34)
# (10551, 100)
# (10552, 48)
# (10553, 89)
# (10554, 80)
# (10555, 143)
# (10556, 24)
# (10557, 50)
# (10558, 96)
# (10559, 30)
# (10560, 35)
# (10561, 60)
# (10562, 30)
# (10563, 95)
# (10564, 47)
# (10565, 43)
# (10566, 63)
# (10567, 103)
# (10568, 5)
# (10569, 65)
# (10570, 75)
# (10571, 39)
# (10572, 87)
# (10573, 83)
# (10574, 32)
# (10575, 58)
# (10576, 51)
# (10577, 48)
# (10578, 26)
# (10579, 31)
# (10580, 54)
# (10581, 50)
# (10582, 18)
# (10583, 44)
# (10584, 50)
# (10585, 15)
# (10586, 4)
# (10587, 46)
# (10588, 140)
# (10589, 4)
# (10590, 80)
# (10591, 74)
# (10592, 30)
# (10593, 45)
# (10594, 54)
# (10595, 215)
# (10596, 59)
# (10597, 67)
# (10598, 59)
# (10599, 10)
# (10600, 34)
# (10601, 95)
# (10602, 5)
# (10603, 73)
# (10604, 16)
# (10605, 135)
# (10606, 50)
# (10607, 213)
# (10608, 28)
# (10609, 19)
# (10610, 21)
# (10611, 31)
# (10612, 263)
# (10613, 48)
# (10614, 27)
# (10615, 5)
# (10616, 59)
# (10617, 30)
# (10618, 105)
# (10619, 82)
# (10620, 10)
# (10621, 50)
# (10622, 38)
# (10623, 94)
# (10624, 26)
# (10625, 18)
# (10626, 52)
# (10627, 50)
# (10628, 25)
# (10629, 29)
# (10630, 47)
# (10631, 8)
# (10632, 50)
# (10633, 164)
# (10634, 102)
# (10635, 65)
# (10636, 31)
# (10637, 95)
# (10638, 101)
# (10639, 8)
# (10640, 35)
# (10641, 110)
# (10642, 50)
# (10643, 38)
# (10644, 45)
# (10645, 35)
# (10646, 98)
# (10647, 50)
# (10648, 30)
# (10649, 35)
# (10650, 85)
# (10651, 32)
# (10652, 22)
# (10653, 50)
# (10654, 38)
# (10655, 20)
# (10656, 37)
# (10657, 204)
# (10658, 255)
# (10659, 84)
# (10660, 21)
# (10661, 52)
# (10662, 10)
# (10663, 80)
# (10664, 51)
# (10665, 31)
# (10666, 46)
# (10667, 59)
# (10668, 27)
# (10669, 30)
# (10670, 192)
# (10671, 32)
# (10672, 27)
# (10673, 15)
# (10674, 5)
# (10675, 70)
# (10676, 30)
# (10677, 38)
# (10678, 280)
# (10679, 12)
# (10680, 110)
# (10681, 70)
# (10682, 64)
# (10683, 9)
# (10684, 90)
# (10685, 39)
# (10686, 45)
# (10687, 66)
# (10688, 92)
# (10689, 35)
# (10690, 50)
# (10691, 182)
# (10692, 20)
# (10693, 111)
# (10694, 165)
# (10695, 34)
# (10696, 38)
# (10697, 76)
# (10698, 108)
# (10699, 12)
# (10700, 117)
# (10701, 97)
# (10702, 21)
# (10703, 75)
# (10704, 65)
# (10705, 24)
# (10706, 52)
# (10707, 89)
# (10708, 9)
# (10709, 78)
# (10710, 10)
# (10711, 174)
# (10712, 33)
# (10713, 182)
# (10714, 137)
# (10715, 51)
# (10716, 22)
# (10717, 72)
# (10718, 116)
# (10719, 55)
# (10720, 29)
# (10721, 50)
# (10722, 140)
# (10723, 15)
# (10724, 21)
# (10725, 22)
# (10726, 30)
# (10727, 40)
# (10728, 48)
# (10729, 120)
# (10730, 28)
# (10731, 70)
# (10732, 20)
# (10733, 61)
# (10734, 65)
# (10735, 22)
# (10736, 60)
# (10737, 16)
# (10738, 3)
# (10739, 24)
# (10740, 94)
# (10741, 15)
# (10742, 105)
# (10743, 28)
# (10744, 50)
# (10745, 92)
# (10746, 83)
# (10747, 82)
# (10748, 112)
# (10749, 31)
# (10750, 70)
# (10751, 77)
# (10752, 11)
# (10753, 9)
# (10754, 3)
# (10755, 99)
# (10756, 67)
# (10757, 91)
# (10758, 120)
# (10759, 10)
# (10760, 82)
# (10761, 53)
# (10762, 134)
# (10763, 66)
# (10764, 150)
# (10765, 80)
# (10766, 115)
# (10767, 2)
# (10768, 81)
# (10769, 80)
# (10770, 15)
# (10771, 16)
# (10772, 43)
# (10773, 110)
# (10774, 52)
# (10775, 9)
# (10776, 175)
# (10777, 20)
# (10778, 10)
# (10779, 40)
# (10780, 50)
# (10781, 58)
# (10782, 1)
# (10783, 15)
# (10784, 62)
# (10785, 20)
# (10786, 87)
# (10787, 35)
# (10788, 90)
# (10789, 93)
# (10790, 23)
# (10791, 34)
# (10792, 28)
# (10793, 22)
# (10794, 21)
# (10795, 100)
# (10796, 90)
# (10797, 20)
# (10798, 12)
# (10799, 65)
# (10800, 67)
# (10801, 60)
# (10802, 120)
# (10803, 54)
# (10804, 64)
# (10805, 20)
# (10806, 37)
# (10807, 1)
# (10808, 70)
# (10809, 20)
# (10810, 17)
# (10811, 63)
# (10812, 76)
# (10813, 47)
# (10814, 78)
# (10815, 16)
# (10816, 50)
# (10817, 155)
# (10818, 40)
# (10819, 27)
# (10820, 30)
# (10821, 26)
# (10822, 9)
# (10823, 90)
# (10824, 21)
# (10825, 32)
# (10826, 50)
# (10827, 36)
# (10828, 7)
# (10829, 61)
# (10830, 88)
# (10831, 27)
# (10832, 32)
# (10833, 38)
# (10834, 28)
# (10835, 17)
# (10836, 172)
# (10837, 92)
# (10838, 79)
# (10839, 45)
# (10840, 16)
# (10841, 111)
# (10842, 52)
# (10843, 4)
# (10844, 35)
# (10845, 245)
# (10846, 71)
# (10847, 288)
# (10848, 33)
# (10849, 67)
# (10850, 54)
# (10851, 67)
# (10852, 71)
# (10853, 10)
# (10854, 165)
# (10855, 103)
# (10856, 40)
# (10857, 75)
# (10858, 19)
# (10859, 105)
# (10860, 23)
# (10861, 140)
# (10862, 33)
# (10863, 32)
# (10864, 19)
# (10865, 140)
# (10866, 67)
# (10867, 3)
# (10868, 92)
# (10869, 120)
# (10870, 5)
# (10871, 78)
# (10872, 66)
# (10873, 23)
# (10874, 10)
# (10875, 61)
# (10876, 41)
# (10877, 55)
# (10878, 20)
# (10879, 32)
# (10880, 110)
# (10881, 10)
# (10882, 77)
# (10883, 8)
# (10884, 73)
# (10885, 87)
# (10886, 145)
# (10887, 5)
# (10888, 38)
# (10889, 80)
# (10890, 39)
# (10891, 15)
# (10892, 40)
# (10893, 119)
# (10894, 198)
# (10895, 346)
# (10896, 31)
# (10897, 116)
# (10898, 5)
# (10899, 8)
# (10900, 3)
# (10901, 60)
# (10902, 36)
# (10903, 81)
# (10904, 50)
# (10905, 20)
# (10906, 15)
# (10907, 14)
# (10908, 34)
# (10909, 32)
# (10910, 27)
# (10911, 37)
# (10912, 100)
# (10913, 85)
# (10914, 25)
# (10915, 50)
# (10916, 32)
# (10917, 11)
# (10918, 85)
# (10919, 68)
# (10920, 24)
# (10921, 50)
# (10922, 50)
# (10923, 44)
# (10924, 56)
# (10925, 37)
# (10926, 29)
# (10927, 30)
# (10928, 10)
# (10929, 124)
# (10930, 116)
# (10931, 72)
# (10932, 80)
# (10933, 32)
# (10934, 20)
# (10935, 33)
# (10936, 30)
# (10937, 28)
# (10938, 128)
# (10939, 50)
# (10940, 28)
# (10941, 204)
# (10942, 28)
# (10943, 51)
# (10944, 41)
# (10945, 30)
# (10946, 90)
# (10947, 4)
# (10948, 53)
# (10949, 108)
# (10950, 5)
# (10951, 71)
# (10952, 18)
# (10953, 100)
# (10954, 107)
# (10955, 12)
# (10956, 34)
# (10957, 78)
# (10958, 31)
# (10959, 20)
# (10960, 34)
# (10961, 66)
# (10962, 195)
# (10963, 2)
# (10964, 21)
# (10965, 16)
# (10966, 32)
# (10967, 52)
# (10968, 64)
# (10969, 9)
# (10970, 40)
# (10971, 14)
# (10972, 13)
# (10973, 21)
# (10974, 10)
# (10975, 26)
# (10976, 20)
# (10977, 90)
# (10978, 76)
# (10979, 207)
# (10980, 40)
# (10981, 60)
# (10982, 29)
# (10983, 99)
# (10984, 115)
# (10985, 79)
# (10986, 70)
# (10987, 86)
# (10988, 100)
# (10989, 59)
# (10990, 256)
# (10991, 160)
# (10992, 2)
# (10993, 85)
# (10994, 18)
# (10995, 24)
# (10996, 40)
# (10997, 90)
# (10998, 69)
# (10999, 56)
# (11000, 85)
# (11001, 116)
# (11002, 135)
# (11003, 24)
# (11004, 12)
# (11005, 12)
# (11006, 10)
# (11007, 54)
# (11008, 181)
# (11009, 39)
# (11010, 30)
# (11011, 60)
# (11012, 146)
# (11013, 36)
# (11014, 28)
# (11015, 33)
# (11016, 31)
# (11017, 165)
# (11018, 35)
# (11019, 5)
# (11020, 24)
# (11021, 168)
# (11022, 65)
# (11023, 34)
# (11024, 113)
# (11025, 30)
# (11026, 18)
# (11027, 51)
# (11028, 59)
# (11029, 32)
# (11030, 330)
# (11031, 182)
# (11032, 90)
# (11033, 106)
# (11034, 33)
# (11035, 110)
# (11036, 37)
# (11037, 4)
# (11038, 37)
# (11039, 132)
# (11040, 20)
# (11041, 60)
# (11042, 19)
# (11043, 10)
# (11044, 12)
# (11045, 39)
# (11046, 53)
# (11047, 55)
# (11048, 42)
# (11049, 14)
# (11050, 50)
# (11051, 10)
# (11052, 40)
# (11053, 80)
# (11054, 30)
# (11055, 70)
# (11056, 125)
# (11057, 3)
# (11058, 28)
# (11059, 77)
# (11060, 14)
# (11061, 15)
# (11062, 22)
# (11063, 100)
# (11064, 173)
# (11065, 24)
# (11066, 80)
# (11067, 9)
# (11068, 72)
# (11069, 20)
# (11070, 110)
# (11071, 25)
# (11072, 200)
# (11073, 30)
# (11074, 14)
# (11075, 42)
# (11076, 50)
# (11077, 72)
#
#  SQL Sum / SUM() with an Expression
# SQL : SELECT SUM(Quantity * 10) FROM Order_details;
# (513170,)

# %%
run_query("SQL Avg", "SELECT AVG(unitPrice) FROM Products;")

run_query("SQL Avg / Add a WHERE Clause", "SELECT AVG(unitPrice) FROM Products WHERE CategoryID = 1;")

run_query("SQL Avg / Use an Alias", "SELECT AVG(unitPrice) AS [average price] FROM Products;")

run_query("SQL Avg / Higher than Average", "SELECT * FROM Products WHERE unitprice > (SELECT AVG(unitprice) FROM Products);")

run_query("SQL Avg / Use AVG() with GROUP BY", "SELECT AVG(unitPrice) AS AveragePrice, CategoryID FROM Products GROUP BY CategoryID;")
# Out:
#  SQL Avg
# SQL : SELECT AVG(unitPrice) FROM Products;
# (28.866363636363637,)
#
#  SQL Avg / Add a WHERE Clause
# SQL : SELECT AVG(unitPrice) FROM Products WHERE CategoryID = 1;
# (37.979166666666664,)
#
#  SQL Avg / Use an Alias
# SQL : SELECT AVG(unitPrice) AS [average price] FROM Products;
# (28.866363636363637,)
#
#  SQL Avg / Higher than Average
# SQL : SELECT * FROM Products WHERE unitprice > (SELECT AVG(unitprice) FROM Products);
# (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30.0, 15, 0, 10, 0)
# (8, 'Northwoods Cranberry Sauce', 3, 2, '12 - 12 oz jars', 40.0, 6, 0, 0, 0)
# (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97.0, 29, 0, 0, 1)
# (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31.0, 31, 0, 0, 0)
# (12, 'Queso Manchego La Pastora', 5, 4, '10 - 500 g pkgs.', 38.0, 86, 0, 0, 0)
# (17, 'Alice Mutton', 7, 6, '20 - 1 kg tins', 39.0, 0, 0, 0, 1)
# (18, 'Carnarvon Tigers', 7, 8, '16 kg pkg.', 62.5, 42, 0, 0, 0)
# (20, "Sir Rodney's Marmalade", 8, 3, '30 gift boxes', 81.0, 40, 0, 0, 0)
# (26, 'Gumbär Gummibärchen', 11, 3, '100 - 250 g bags', 31.23, 15, 0, 0, 0)
# (27, 'Schoggi Schokolade', 11, 3, '100 - 100 g pieces', 43.9, 49, 0, 30, 0)
# (28, 'Rössle Sauerkraut', 12, 7, '25 - 825 g cans', 45.6, 26, 0, 0, 1)
# (29, 'Thüringer Rostbratwurst', 12, 6, '50 bags x 30 sausgs.', 123.79, 0, 0, 0, 1)
# (32, 'Mascarpone Fabioli', 14, 4, '24 - 200 g pkgs.', 32.0, 9, 40, 25, 0)
# (38, 'Côte de Blaye', 18, 1, '12 - 75 cl bottles', 263.5, 17, 0, 15, 0)
# (43, 'Ipoh Coffee', 20, 1, '16 - 500 g tins', 46.0, 17, 10, 25, 0)
# (51, 'Manjimup Dried Apples', 24, 7, '50 - 300 g pkgs.', 53.0, 20, 0, 10, 0)
# (53, 'Perth Pasties', 24, 6, '48 pieces', 32.8, 0, 0, 0, 1)
# (56, 'Gnocchi di nonna Alice', 26, 5, '24 - 250 g pkgs.', 38.0, 21, 10, 30, 0)
# (59, 'Raclette Courdavault', 28, 4, '5 kg pkg.', 55.0, 79, 0, 0, 0)
# (60, 'Camembert Pierrot', 28, 4, '15 - 300 g rounds', 34.0, 19, 0, 0, 0)
# (62, 'Tarte au sucre', 29, 3, '48 pies', 49.3, 17, 0, 0, 0)
# (63, 'Vegie-spread', 7, 2, '15 - 625 g jars', 43.9, 24, 0, 5, 0)
# (64, 'Wimmers gute Semmelknödel', 12, 5, '20 bags x 4 pieces', 33.25, 22, 80, 30, 0)
# (69, 'Gudbrandsdalsost', 15, 4, '10 kg pkg.', 36.0, 26, 0, 15, 0)
# (72, 'Mozzarella di Giovanni', 14, 4, '24 - 200 g pkgs.', 34.8, 14, 0, 0, 0)
#
#  SQL Avg / Use AVG() with GROUP BY
# SQL : SELECT AVG(unitPrice) AS AveragePrice, CategoryID FROM Products GROUP BY CategoryID;
# (37.979166666666664, 1)
# (23.0625, 2)
# (25.16, 3)
# (28.73, 4)
# (20.25, 5)
# (54.00666666666667, 6)
# (32.37, 7)
# (20.6825, 8)

# %%
run_query("SQL Like", "SELECT * FROM Customers WHERE CustomerName LIKE 'a%';")

run_query("SQL Like / The _ Wildcard", "SELECT * FROM Customers WHERE city LIKE 'L_nd__';")

run_query("SQL Like / The % Wildcard", "SELECT * FROM Customers WHERE City LIKE '%L%';")

run_query("SQL Like / Starts With", "SELECT * FROM Customers WHERE CustomerName LIKE 'La%';")

run_query("SQL Like / Ends With", "SELECT * FROM Customers WHERE CustomerName LIKE '%a';")

run_query("SQL Like / Starts With, Ends With", "SELECT * FROM Customers WHERE CustomerName LIKE 'b%s';")

run_query("SQL Like / Contains", "SELECT * FROM Customers WHERE CustomerName LIKE '%or%';")

run_query("SQL Like / Combine Wildcards", "SELECT * FROM Customers WHERE CustomerName LIKE 'a__%';")

run_query("SQL Like / Without Wildcard", "SELECT * FROM Customers WHERE Country LIKE 'Spain';")
# Out:
#  SQL Like
# SQL : SELECT * FROM Customers WHERE CustomerName LIKE 'a%';
# ('ANATR', 'Ana Trujillo Emparedados y helados', 'Juan', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# ('ANTON', 'Antonio Moreno Taquería', 'Juan', 'Mataderos  2312', 'México D.F.', '05023', 'Mexico')
# ('AROUT', 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
#
#  SQL Like / The _ Wildcard
# SQL : SELECT * FROM Customers WHERE city LIKE 'L_nd__';
# ('AROUT', 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK')
# ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12  Brewery', 'London', 'WX1 6LT', 'UK')
# ('EASTC', 'Eastern Connection', 'Ann Devon', '35 King George', 'London', 'WX3 6FW', 'UK')
# ('NORTS', 'North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK')
# ('SEVES', 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK')
# ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'P.O. Box 555', 'Lander', '82520', 'USA')
#
#  SQL Like / The % Wildcard
# SQL : SELECT * FROM Customers WHERE City LIKE '%L%';
# ('AROUT', 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen  8', 'Luleå', 'S-958 22', 'Sweden')
# ('BONAP', "Bon app'", 'Laurence Lebihan', '12 rue des Bouchers', 'Marseille', '13008', 'France')
# ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK')
# ('COMMI', 'Comércio Mineiro', 'Pedro Afonso', '23 Av. dos Lusíadas', 'Sao Paulo', '05432-043', 'Brazil')
# ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12  Brewery', 'London', 'WX1 6LT', 'UK')
# ('EASTC', 'Eastern Connection', 'Ann Devon', '35 King George', 'London', 'WX3 6FW', 'UK')
# ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 'Rua Orós 92', 'Sao Paulo', '05442-030', 'Brazil')
# ('FOLIG', 'Folies gourmandes', 'Martine Rancé', '184 chaussée de Tournai', 'Lille', '59000', 'France')
# ('FURIB', 'Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez', 'Jardim das rosas n. 32', 'Lisboa', '1675', 'Portugal')
# ('GALED', 'Galería del gastrónomo', 'Eduardo Saavedra', 'Rambla de Cataluña 23', 'Barcelona', '08022', 'Spain')
# ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero 33', 'Sevilla', '41101', 'Spain')
# ('HILAA', 'HILARION-Abastos', 'Carlos Hernández', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristóbal', '5022', 'Venezuela')
# ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA')
# ('LACOR', "La corne d'abondance", 'Daniel Tonini', "67 avenue de l'Europe", 'Versailles', '78000', 'France')
# ('LAMAI', "La maison d'Asie", 'Annette Roulet', '1 rue Alsace-Lorraine', 'Toulouse', '31000', 'France')
# ('LAZYK', 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA')
# ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA')
# ('MAISD', 'Maison Dewey', 'Catherine Dewey', 'Rue Joseph-Bens 532', 'Bruxelles', 'B-1180', 'Belgium')
# ('MEREP', 'Mère Paillarde', 'Jean Fresnière', '43 rue St. Laurent', 'Montréal', 'H1J 1C3', 'Canada')
# ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '04179', 'Germany')
# ('NORTS', 'North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK')
# ('OTTIK', 'Ottilies Käseladen', 'Henriette Pfalzheim', 'Mehrheimerstr. 369', 'Köln', '50739', 'Germany')
# ('PICCO', 'Piccolo und mehr', 'Georg Pipps', 'Geislweg 14', 'Salzburg', '5020', 'Austria')
# ('PRINI', 'Princesa Isabel Vinhos', 'Isabel de Castro', 'Estrada da saúde n. 58', 'Lisboa', '1756', 'Portugal')
# ('QUEEN', 'Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios 891', 'Sao Paulo', '05487-020', 'Brazil')
# ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Taucherstraße 10', 'Cunewalde', '01307', 'Germany')
# ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', '2817 Milton Dr.', 'Albuquerque', '87110', 'USA')
# ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Strada Provinciale 124', 'Reggio Emilia', '42100', 'Italy')
# ('SEVES', 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK')
# ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'P.O. Box 555', 'Lander', '82520', 'USA')
# ('SUPRD', 'Suprêmes délices', 'Pascale Cartrain', 'Boulevard Tirou 255', 'Charleroi', 'B-6000', 'Belgium')
# ('THEBI', 'The Big Cheese', 'Liz Nixon', '89 Jefferson Way Suite 2', 'Portland', '97201', 'USA')
# ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 'Av. Inês de Castro 414', 'Sao Paulo', '05634-030', 'Brazil')
# ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', '722 DaVinci Blvd.', 'Kirkland', '98034', 'USA')
# ('VICTE', 'Victuailles en stock', 'Mary Saveley', '2 rue du Commerce', 'Lyon', '69004', 'France')
# ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Torikatu 38', 'Oulu', '90110', 'Finland')
# ('WHITC', 'White Clover Markets', 'Karl Jablonski', '305 - 14th Ave. S. Suite 3B', 'Seattle', '98128', 'USA')
# ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Keskuskatu 45', 'Helsinki', '21240', 'Finland')
# (None, 'Tasty Tee', 'Finn Egan', 'Streetroad 19B', 'Liverpool', 'L1 0AA', 'UK')
#
#  SQL Like / Starts With
# SQL : SELECT * FROM Customers WHERE CustomerName LIKE 'La%';
# ('LACOR', "La corne d'abondance", 'Daniel Tonini', "67 avenue de l'Europe", 'Versailles', '78000', 'France')
# ('LAMAI', "La maison d'Asie", 'Annette Roulet', '1 rue Alsace-Lorraine', 'Toulouse', '31000', 'France')
# ('LAUGB', 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', '1900 Oak St.', 'Vancouver', 'V3F 2K1', 'Canada')
# ('LAZYK', 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA')
#
#  SQL Like / Ends With
# SQL : SELECT * FROM Customers WHERE CustomerName LIKE '%a';
# ('ANTON', 'Antonio Moreno Taquería', 'Juan', 'Mataderos  2312', 'México D.F.', '05023', 'Mexico')
# ('CENTC', 'Centro comercial Moctezuma', 'Juan', 'Sierras de Granada 9993', 'México D.F.', '05022', 'Mexico')
# ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero 33', 'Sevilla', '41101', 'Spain')
# ('QUEDE', 'Que Delícia', 'Bernardo Batista', 'Rua da Panificadora', ' 12Rio de Janeiro', '02389-673', 'Brazil')
# ('QUEEN', 'Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios 891', 'Sao Paulo', '05487-020', 'Brazil')
# ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Rua do Mercado 12', 'Resende', '08737-363', 'Brazil')
# ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Keskuskatu 45', 'Helsinki', '21240', 'Finland')
#
#  SQL Like / Starts With, Ends With
# SQL : SELECT * FROM Customers WHERE CustomerName LIKE 'b%s';
# ('BLONP', 'Blondesddsl père et fils', 'Frédérique Citeaux', '24 place Kléber', 'Strasbourg', '67000', 'France')
# ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', '67C Araquil', 'Madrid', '28023', 'Spain')
# ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada')
# ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK')
#
#  SQL Like / Contains
# SQL : SELECT * FROM Customers WHERE CustomerName LIKE '%or%';
# ('ANTON', 'Antonio Moreno Taquería', 'Juan', 'Mataderos  2312', 'México D.F.', '05023', 'Mexico')
# ('AROUT', 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA')
# ('LACOR', "La corne d'abondance", 'Daniel Tonini', "67 avenue de l'Europe", 'Versailles', '78000', 'France')
# ('LAZYK', 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA')
# ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '04179', 'Germany')
# ('NORTS', 'North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK')
# ('OLDWO', 'Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA')
# ('SEVES', 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK')
# ('TORTU', 'Tortuga Restaurante', 'Juan', 'Avda. Azteca 123', 'México D.F.', '05033', 'Mexico')
# ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Rua do Mercado 12', 'Resende', '08737-363', 'Brazil')
#
#  SQL Like / Combine Wildcards
# SQL : SELECT * FROM Customers WHERE CustomerName LIKE 'a__%';
# ('ANATR', 'Ana Trujillo Emparedados y helados', 'Juan', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# ('ANTON', 'Antonio Moreno Taquería', 'Juan', 'Mataderos  2312', 'México D.F.', '05023', 'Mexico')
# ('AROUT', 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
#
#  SQL Like / Without Wildcard
# SQL : SELECT * FROM Customers WHERE Country LIKE 'Spain';
# ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', '67C Araquil', 'Madrid', '28023', 'Spain')
# ('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'C/ Moralzarzal 86', 'Madrid', '28034', 'Spain')
# ('GALED', 'Galería del gastrónomo', 'Eduardo Saavedra', 'Rambla de Cataluña 23', 'Barcelona', '08022', 'Spain')
# ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero 33', 'Sevilla', '41101', 'Spain')
# ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Gran Vía 1', 'Madrid', '28001', 'Spain')

# %%
run_query("SQL Wildcards", "SELECT * FROM Customers WHERE CustomerName LIKE 'a%';")

run_query("SQL Wildcards / Using the % Wildcard", "SELECT * FROM Customers WHERE CustomerName LIKE '%es';")

run_query("SQL Wildcards / Using the _ Wildcard", "SELECT * FROM Customers WHERE City LIKE '_ondon';")

run_query("SQL Wildcards / Using the [] Wildcard", "SELECT * FROM Customers WHERE CustomerName LIKE '[bsp]%';")

run_query("SQL Wildcards / Using the - Wildcard", "SELECT * FROM Customers WHERE CustomerName LIKE '[a-f]%';")

run_query("SQL Wildcards / Combine Wildcards", "SELECT * FROM Customers WHERE CustomerName LIKE 'a__%';")

run_query("SQL Wildcards / Without Wildcard", "SELECT * FROM Customers WHERE Country LIKE 'Spain';")
# Out:
#  SQL Wildcards
# SQL : SELECT * FROM Customers WHERE CustomerName LIKE 'a%';
# ('ANATR', 'Ana Trujillo Emparedados y helados', 'Juan', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# ('ANTON', 'Antonio Moreno Taquería', 'Juan', 'Mataderos  2312', 'México D.F.', '05023', 'Mexico')
# ('AROUT', 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
#
#  SQL Wildcards / Using the % Wildcard
# SQL : SELECT * FROM Customers WHERE CustomerName LIKE '%es';
# ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK')
# ('FOLIG', 'Folies gourmandes', 'Martine Rancé', '184 chaussée de Tournai', 'Lille', '59000', 'France')
# ('GOURL', 'Gourmet Lanchonetes', 'André Fonseca', 'Av. Brasil 442', 'Campinas', '04876-786', 'Brazil')
# ('HANAR', 'Hanari Carnes', 'Mario Pontes', 'Rua do Paço 67', 'Rio de Janeiro', '05454-876', 'Brazil')
# ('LINOD', 'LINO-Delicateses', 'Felipe Izquierdo', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita', '4980', 'Venezuela')
# ('SUPRD', 'Suprêmes délices', 'Pascale Cartrain', 'Boulevard Tirou 255', 'Charleroi', 'B-6000', 'Belgium')
#
#  SQL Wildcards / Using the _ Wildcard
# SQL : SELECT * FROM Customers WHERE City LIKE '_ondon';
# ('AROUT', 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK')
# ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12  Brewery', 'London', 'WX1 6LT', 'UK')
# ('EASTC', 'Eastern Connection', 'Ann Devon', '35 King George', 'London', 'WX3 6FW', 'UK')
# ('NORTS', 'North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK')
# ('SEVES', 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK')
#
#  SQL Wildcards / Using the [] Wildcard
# SQL : SELECT * FROM Customers WHERE CustomerName LIKE '[bsp]%';
#
#  SQL Wildcards / Using the - Wildcard
# SQL : SELECT * FROM Customers WHERE CustomerName LIKE '[a-f]%';
#
#  SQL Wildcards / Combine Wildcards
# SQL : SELECT * FROM Customers WHERE CustomerName LIKE 'a__%';
# ('ANATR', 'Ana Trujillo Emparedados y helados', 'Juan', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# ('ANTON', 'Antonio Moreno Taquería', 'Juan', 'Mataderos  2312', 'México D.F.', '05023', 'Mexico')
# ('AROUT', 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
#
#  SQL Wildcards / Without Wildcard
# SQL : SELECT * FROM Customers WHERE Country LIKE 'Spain';
# ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', '67C Araquil', 'Madrid', '28023', 'Spain')
# ('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'C/ Moralzarzal 86', 'Madrid', '28034', 'Spain')
# ('GALED', 'Galería del gastrónomo', 'Eduardo Saavedra', 'Rambla de Cataluña 23', 'Barcelona', '08022', 'Spain')
# ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero 33', 'Sevilla', '41101', 'Spain')
# ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Gran Vía 1', 'Madrid', '28001', 'Spain')

# %%
run_query("SQL In", "SELECT * FROM Customers WHERE Country IN ('Germany', 'France', 'UK');")

run_query("SQL In / NOT IN", "SELECT * FROM Customers WHERE Country NOT IN ('Germany', 'France', 'UK');")

run_query("SQL In / IN (SELECT)", "SELECT * FROM Customers WHERE CustomerID IN (SELECT CustomerID FROM Orders);")

run_query("SQL In / NOT IN (SELECT)", "SELECT * FROM Customers WHERE CustomerID NOT IN (SELECT CustomerID FROM Orders);")
# Out:
#  SQL In
# SQL : SELECT * FROM Customers WHERE Country IN ('Germany', 'France', 'UK');
# ('AROUT', 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany')
# ('BLONP', 'Blondesddsl père et fils', 'Frédérique Citeaux', '24 place Kléber', 'Strasbourg', '67000', 'France')
# ('BONAP', "Bon app'", 'Laurence Lebihan', '12 rue des Bouchers', 'Marseille', '13008', 'France')
# ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK')
# ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12  Brewery', 'London', 'WX1 6LT', 'UK')
# ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Walserweg 21', 'Aachen', '52066', 'Germany')
# ('DUMON', 'Du monde entier', 'Janine Labrune', '67 rue des Cinquante Otages', 'Nantes', '44000', 'France')
# ('EASTC', 'Eastern Connection', 'Ann Devon', '35 King George', 'London', 'WX3 6FW', 'UK')
# ('FOLIG', 'Folies gourmandes', 'Martine Rancé', '184 chaussée de Tournai', 'Lille', '59000', 'France')
# ('FRANK', 'Frankenversand', 'Peter Franken', 'Berliner Platz 43', 'München', '80805', 'Germany')
# ('FRANR', 'France restauration', 'Carine Schmitt', '54 rue Royale', 'Nantes', '44000', 'France')
# ('ISLAT', 'Island Trading', 'Helen Bennett', 'Garden House Crowther Way', 'Cowes', 'PO31 7PJ', 'UK')
# ('KOENE', 'Königlich Essen', 'Philip Cramer', 'Maubelstr. 90', 'Brandenburg', '14776', 'Germany')
# ('LACOR', "La corne d'abondance", 'Daniel Tonini', "67 avenue de l'Europe", 'Versailles', '78000', 'France')
# ('LAMAI', "La maison d'Asie", 'Annette Roulet', '1 rue Alsace-Lorraine', 'Toulouse', '31000', 'France')
# ('LEHMS', 'Lehmanns Marktstand', 'Renate Messner', 'Magazinweg 7', 'Frankfurt a.M.', '60528', 'Germany')
# ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '04179', 'Germany')
# ('NORTS', 'North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK')
# ('OTTIK', 'Ottilies Käseladen', 'Henriette Pfalzheim', 'Mehrheimerstr. 369', 'Köln', '50739', 'Germany')
# ('PARIS', 'Paris spécialités', 'Marie Bertrand', '265 boulevard Charonne', 'Paris', '75012', 'France')
# ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Taucherstraße 10', 'Cunewalde', '01307', 'Germany')
# ('SEVES', 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK')
# ('SPECD', 'Spécialités du monde', 'Dominique Perrier', '25 rue Lauriston', 'Paris', '75016', 'France')
# ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Luisenstr. 48', 'Münster', '44087', 'Germany')
# ('VICTE', 'Victuailles en stock', 'Mary Saveley', '2 rue du Commerce', 'Lyon', '69004', 'France')
# ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', "59 rue de l'Abbaye", 'Reims', '51100', 'France')
# ('WANDK', 'Die Wandernde Kuh', 'Rita Müller', 'Adenauerallee 900', 'Stuttgart', '70563', 'Germany')
# (None, 'Tasty Tee', 'Finn Egan', 'Streetroad 19B', 'Liverpool', 'L1 0AA', 'UK')
#
#  SQL In / NOT IN
# SQL : SELECT * FROM Customers WHERE Country NOT IN ('Germany', 'France', 'UK');
# ('ANATR', 'Ana Trujillo Emparedados y helados', 'Juan', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# ('ANTON', 'Antonio Moreno Taquería', 'Juan', 'Mataderos  2312', 'México D.F.', '05023', 'Mexico')
# ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen  8', 'Luleå', 'S-958 22', 'Sweden')
# ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', '67C Araquil', 'Madrid', '28023', 'Spain')
# ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada')
# ('CACTU', 'Cactus Comidas para llevar', 'Patricio Simpson', 'Cerrito 333', 'Buenos Aires', '1010', 'Argentina')
# ('CENTC', 'Centro comercial Moctezuma', 'Juan', 'Sierras de Granada 9993', 'México D.F.', '05022', 'Mexico')
# ('CHOPS', 'Chop-suey Chinese', 'Yang Wang', 'Hauptstr. 29', 'Bern', '3012', 'Switzerland')
# ('COMMI', 'Comércio Mineiro', 'Pedro Afonso', '23 Av. dos Lusíadas', 'Sao Paulo', '05432-043', 'Brazil')
# ('ERNSH', 'Ernst Handel', 'Roland Mendel', 'Kirchgasse 6', 'Graz', '8010', 'Austria')
# ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 'Rua Orós 92', 'Sao Paulo', '05442-030', 'Brazil')
# ('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'C/ Moralzarzal 86', 'Madrid', '28034', 'Spain')
# ('FOLKO', 'Folk och fä HB', 'Maria Larsson', 'Åkergatan 24', 'Bräcke', 'S-844 67', 'Sweden')
# ('FRANS', 'Franchi S.p.A.', 'Paolo Accorti', 'Via Monte Bianco 34', 'Torino', '10100', 'Italy')
# ('FURIB', 'Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez', 'Jardim das rosas n. 32', 'Lisboa', '1675', 'Portugal')
# ('GALED', 'Galería del gastrónomo', 'Eduardo Saavedra', 'Rambla de Cataluña 23', 'Barcelona', '08022', 'Spain')
# ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero 33', 'Sevilla', '41101', 'Spain')
# ('GOURL', 'Gourmet Lanchonetes', 'André Fonseca', 'Av. Brasil 442', 'Campinas', '04876-786', 'Brazil')
# ('GREAL', 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA')
# ('GROSR', 'GROSELLA-Restaurante', 'Manuel Pereira', '5ª Ave. Los Palos Grandes', 'Caracas', '1081', 'Venezuela')
# ('HANAR', 'Hanari Carnes', 'Mario Pontes', 'Rua do Paço 67', 'Rio de Janeiro', '05454-876', 'Brazil')
# ('HILAA', 'HILARION-Abastos', 'Carlos Hernández', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristóbal', '5022', 'Venezuela')
# ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA')
# ('HUNGO', 'Hungry Owl All-Night Grocers', 'Patricia McKenna', '8 Johnstown Road', 'Cork', 'NULL', 'Ireland')
# ('LAUGB', 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', '1900 Oak St.', 'Vancouver', 'V3F 2K1', 'Canada')
# ('LAZYK', 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA')
# ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA')
# ('LILAS', 'LILA-Supermercado', 'Carlos González', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', '3508', 'Venezuela')
# ('LINOD', 'LINO-Delicateses', 'Felipe Izquierdo', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita', '4980', 'Venezuela')
# ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA')
# ('MAGAA', 'Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 'Via Ludovico il Moro 22', 'Bergamo', '24100', 'Italy')
# ('MAISD', 'Maison Dewey', 'Catherine Dewey', 'Rue Joseph-Bens 532', 'Bruxelles', 'B-1180', 'Belgium')
# ('MEREP', 'Mère Paillarde', 'Jean Fresnière', '43 rue St. Laurent', 'Montréal', 'H1J 1C3', 'Canada')
# ('OCEAN', 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', '1010', 'Argentina')
# ('OLDWO', 'Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA')
# ('PERIC', 'Pericles Comidas clásicas', 'Juan', 'Calle Dr. Jorge Cash 321', 'México D.F.', '05033', 'Mexico')
# ('PICCO', 'Piccolo und mehr', 'Georg Pipps', 'Geislweg 14', 'Salzburg', '5020', 'Austria')
# ('PRINI', 'Princesa Isabel Vinhos', 'Isabel de Castro', 'Estrada da saúde n. 58', 'Lisboa', '1756', 'Portugal')
# ('QUEDE', 'Que Delícia', 'Bernardo Batista', 'Rua da Panificadora', ' 12Rio de Janeiro', '02389-673', 'Brazil')
# ('QUEEN', 'Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios 891', 'Sao Paulo', '05487-020', 'Brazil')
# ('RANCH', 'Rancho grande', 'Sergio Gutiérrez', 'Av. del Libertador 900', 'Buenos Aires', '1010', 'Argentina')
# ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', '2817 Milton Dr.', 'Albuquerque', '87110', 'USA')
# ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Strada Provinciale 124', 'Reggio Emilia', '42100', 'Italy')
# ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Av. Copacabana 267', 'Rio de Janeiro', '02389-890', 'Brazil')
# ('RICSU', 'Richter Supermarkt', 'Michael Holz', 'Grenzacherweg 237', 'Genève', '1203', 'Switzerland')
# ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Gran Vía 1', 'Madrid', '28001', 'Spain')
# ('SANTG', 'Santé Gourmet', 'Jonas Bergulfsen', 'Erling Skakkes gate 78', 'Stavern', '4110', 'Norway')
# ('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', '187 Suffolk Ln.', 'Boise', '83720', 'USA')
# ('SIMOB', 'Simons bistro', 'Jytte Petersen', 'Vinbæltet 34', 'Kobenhavn', '1734', 'Denmark')
# ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'P.O. Box 555', 'Lander', '82520', 'USA')
# ('SUPRD', 'Suprêmes délices', 'Pascale Cartrain', 'Boulevard Tirou 255', 'Charleroi', 'B-6000', 'Belgium')
# ('THEBI', 'The Big Cheese', 'Liz Nixon', '89 Jefferson Way Suite 2', 'Portland', '97201', 'USA')
# ('THECR', 'The Cracker Box', 'Liu Wong', '55 Grizzly Peak Rd.', 'Butte', '59801', 'USA')
# ('TORTU', 'Tortuga Restaurante', 'Juan', 'Avda. Azteca 123', 'México D.F.', '05033', 'Mexico')
# ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 'Av. Inês de Castro 414', 'Sao Paulo', '05634-030', 'Brazil')
# ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', '722 DaVinci Blvd.', 'Kirkland', '98034', 'USA')
# ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 'Smagsloget 45', 'Århus', '8200', 'Denmark')
# ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Torikatu 38', 'Oulu', '90110', 'Finland')
# ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Rua do Mercado 12', 'Resende', '08737-363', 'Brazil')
# ('WHITC', 'White Clover Markets', 'Karl Jablonski', '305 - 14th Ave. S. Suite 3B', 'Seattle', '98128', 'USA')
# ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Keskuskatu 45', 'Helsinki', '21240', 'Finland')
# ('WOLZA', 'Wolski  Zajazd', 'Zbyszek Piestrzeniewicz', 'ul. Filtrowa 68', 'Warszawa', '01-012', 'Poland')
# (None, 'Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway')
# (None, 'Cardinal', None, None, 'Stavanger', None, 'Norway')
# (None, 'Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway')
# (None, 'Greasy Burger', 'Per Olsen', 'Gateveien 15', 'Sandnes', '4306', 'Norway')
#
#  SQL In / IN (SELECT)
# SQL : SELECT * FROM Customers WHERE CustomerID IN (SELECT CustomerID FROM Orders);
# ('ANATR', 'Ana Trujillo Emparedados y helados', 'Juan', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# ('ANTON', 'Antonio Moreno Taquería', 'Juan', 'Mataderos  2312', 'México D.F.', '05023', 'Mexico')
# ('AROUT', 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen  8', 'Luleå', 'S-958 22', 'Sweden')
# ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany')
# ('BLONP', 'Blondesddsl père et fils', 'Frédérique Citeaux', '24 place Kléber', 'Strasbourg', '67000', 'France')
# ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', '67C Araquil', 'Madrid', '28023', 'Spain')
# ('BONAP', "Bon app'", 'Laurence Lebihan', '12 rue des Bouchers', 'Marseille', '13008', 'France')
# ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada')
# ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK')
# ('CACTU', 'Cactus Comidas para llevar', 'Patricio Simpson', 'Cerrito 333', 'Buenos Aires', '1010', 'Argentina')
# ('CENTC', 'Centro comercial Moctezuma', 'Juan', 'Sierras de Granada 9993', 'México D.F.', '05022', 'Mexico')
# ('CHOPS', 'Chop-suey Chinese', 'Yang Wang', 'Hauptstr. 29', 'Bern', '3012', 'Switzerland')
# ('COMMI', 'Comércio Mineiro', 'Pedro Afonso', '23 Av. dos Lusíadas', 'Sao Paulo', '05432-043', 'Brazil')
# ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12  Brewery', 'London', 'WX1 6LT', 'UK')
# ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Walserweg 21', 'Aachen', '52066', 'Germany')
# ('DUMON', 'Du monde entier', 'Janine Labrune', '67 rue des Cinquante Otages', 'Nantes', '44000', 'France')
# ('EASTC', 'Eastern Connection', 'Ann Devon', '35 King George', 'London', 'WX3 6FW', 'UK')
# ('ERNSH', 'Ernst Handel', 'Roland Mendel', 'Kirchgasse 6', 'Graz', '8010', 'Austria')
# ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 'Rua Orós 92', 'Sao Paulo', '05442-030', 'Brazil')
# ('FOLIG', 'Folies gourmandes', 'Martine Rancé', '184 chaussée de Tournai', 'Lille', '59000', 'France')
# ('FOLKO', 'Folk och fä HB', 'Maria Larsson', 'Åkergatan 24', 'Bräcke', 'S-844 67', 'Sweden')
# ('FRANK', 'Frankenversand', 'Peter Franken', 'Berliner Platz 43', 'München', '80805', 'Germany')
# ('FRANR', 'France restauration', 'Carine Schmitt', '54 rue Royale', 'Nantes', '44000', 'France')
# ('FRANS', 'Franchi S.p.A.', 'Paolo Accorti', 'Via Monte Bianco 34', 'Torino', '10100', 'Italy')
# ('FURIB', 'Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez', 'Jardim das rosas n. 32', 'Lisboa', '1675', 'Portugal')
# ('GALED', 'Galería del gastrónomo', 'Eduardo Saavedra', 'Rambla de Cataluña 23', 'Barcelona', '08022', 'Spain')
# ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero 33', 'Sevilla', '41101', 'Spain')
# ('GOURL', 'Gourmet Lanchonetes', 'André Fonseca', 'Av. Brasil 442', 'Campinas', '04876-786', 'Brazil')
# ('GREAL', 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA')
# ('GROSR', 'GROSELLA-Restaurante', 'Manuel Pereira', '5ª Ave. Los Palos Grandes', 'Caracas', '1081', 'Venezuela')
# ('HANAR', 'Hanari Carnes', 'Mario Pontes', 'Rua do Paço 67', 'Rio de Janeiro', '05454-876', 'Brazil')
# ('HILAA', 'HILARION-Abastos', 'Carlos Hernández', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristóbal', '5022', 'Venezuela')
# ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA')
# ('HUNGO', 'Hungry Owl All-Night Grocers', 'Patricia McKenna', '8 Johnstown Road', 'Cork', 'NULL', 'Ireland')
# ('ISLAT', 'Island Trading', 'Helen Bennett', 'Garden House Crowther Way', 'Cowes', 'PO31 7PJ', 'UK')
# ('KOENE', 'Königlich Essen', 'Philip Cramer', 'Maubelstr. 90', 'Brandenburg', '14776', 'Germany')
# ('LACOR', "La corne d'abondance", 'Daniel Tonini', "67 avenue de l'Europe", 'Versailles', '78000', 'France')
# ('LAMAI', "La maison d'Asie", 'Annette Roulet', '1 rue Alsace-Lorraine', 'Toulouse', '31000', 'France')
# ('LAUGB', 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', '1900 Oak St.', 'Vancouver', 'V3F 2K1', 'Canada')
# ('LAZYK', 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA')
# ('LEHMS', 'Lehmanns Marktstand', 'Renate Messner', 'Magazinweg 7', 'Frankfurt a.M.', '60528', 'Germany')
# ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA')
# ('LILAS', 'LILA-Supermercado', 'Carlos González', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', '3508', 'Venezuela')
# ('LINOD', 'LINO-Delicateses', 'Felipe Izquierdo', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita', '4980', 'Venezuela')
# ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA')
# ('MAGAA', 'Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 'Via Ludovico il Moro 22', 'Bergamo', '24100', 'Italy')
# ('MAISD', 'Maison Dewey', 'Catherine Dewey', 'Rue Joseph-Bens 532', 'Bruxelles', 'B-1180', 'Belgium')
# ('MEREP', 'Mère Paillarde', 'Jean Fresnière', '43 rue St. Laurent', 'Montréal', 'H1J 1C3', 'Canada')
# ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '04179', 'Germany')
# ('NORTS', 'North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK')
# ('OCEAN', 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', '1010', 'Argentina')
# ('OLDWO', 'Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA')
# ('OTTIK', 'Ottilies Käseladen', 'Henriette Pfalzheim', 'Mehrheimerstr. 369', 'Köln', '50739', 'Germany')
# ('PERIC', 'Pericles Comidas clásicas', 'Juan', 'Calle Dr. Jorge Cash 321', 'México D.F.', '05033', 'Mexico')
# ('PICCO', 'Piccolo und mehr', 'Georg Pipps', 'Geislweg 14', 'Salzburg', '5020', 'Austria')
# ('PRINI', 'Princesa Isabel Vinhos', 'Isabel de Castro', 'Estrada da saúde n. 58', 'Lisboa', '1756', 'Portugal')
# ('QUEDE', 'Que Delícia', 'Bernardo Batista', 'Rua da Panificadora', ' 12Rio de Janeiro', '02389-673', 'Brazil')
# ('QUEEN', 'Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios 891', 'Sao Paulo', '05487-020', 'Brazil')
# ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Taucherstraße 10', 'Cunewalde', '01307', 'Germany')
# ('RANCH', 'Rancho grande', 'Sergio Gutiérrez', 'Av. del Libertador 900', 'Buenos Aires', '1010', 'Argentina')
# ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', '2817 Milton Dr.', 'Albuquerque', '87110', 'USA')
# ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Strada Provinciale 124', 'Reggio Emilia', '42100', 'Italy')
# ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Av. Copacabana 267', 'Rio de Janeiro', '02389-890', 'Brazil')
# ('RICSU', 'Richter Supermarkt', 'Michael Holz', 'Grenzacherweg 237', 'Genève', '1203', 'Switzerland')
# ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Gran Vía 1', 'Madrid', '28001', 'Spain')
# ('SANTG', 'Santé Gourmet', 'Jonas Bergulfsen', 'Erling Skakkes gate 78', 'Stavern', '4110', 'Norway')
# ('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', '187 Suffolk Ln.', 'Boise', '83720', 'USA')
# ('SEVES', 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK')
# ('SIMOB', 'Simons bistro', 'Jytte Petersen', 'Vinbæltet 34', 'Kobenhavn', '1734', 'Denmark')
# ('SPECD', 'Spécialités du monde', 'Dominique Perrier', '25 rue Lauriston', 'Paris', '75016', 'France')
# ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'P.O. Box 555', 'Lander', '82520', 'USA')
# ('SUPRD', 'Suprêmes délices', 'Pascale Cartrain', 'Boulevard Tirou 255', 'Charleroi', 'B-6000', 'Belgium')
# ('THEBI', 'The Big Cheese', 'Liz Nixon', '89 Jefferson Way Suite 2', 'Portland', '97201', 'USA')
# ('THECR', 'The Cracker Box', 'Liu Wong', '55 Grizzly Peak Rd.', 'Butte', '59801', 'USA')
# ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Luisenstr. 48', 'Münster', '44087', 'Germany')
# ('TORTU', 'Tortuga Restaurante', 'Juan', 'Avda. Azteca 123', 'México D.F.', '05033', 'Mexico')
# ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 'Av. Inês de Castro 414', 'Sao Paulo', '05634-030', 'Brazil')
# ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', '722 DaVinci Blvd.', 'Kirkland', '98034', 'USA')
# ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 'Smagsloget 45', 'Århus', '8200', 'Denmark')
# ('VICTE', 'Victuailles en stock', 'Mary Saveley', '2 rue du Commerce', 'Lyon', '69004', 'France')
# ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', "59 rue de l'Abbaye", 'Reims', '51100', 'France')
# ('WANDK', 'Die Wandernde Kuh', 'Rita Müller', 'Adenauerallee 900', 'Stuttgart', '70563', 'Germany')
# ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Torikatu 38', 'Oulu', '90110', 'Finland')
# ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Rua do Mercado 12', 'Resende', '08737-363', 'Brazil')
# ('WHITC', 'White Clover Markets', 'Karl Jablonski', '305 - 14th Ave. S. Suite 3B', 'Seattle', '98128', 'USA')
# ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Keskuskatu 45', 'Helsinki', '21240', 'Finland')
# ('WOLZA', 'Wolski  Zajazd', 'Zbyszek Piestrzeniewicz', 'ul. Filtrowa 68', 'Warszawa', '01-012', 'Poland')
#
#  SQL In / NOT IN (SELECT)
# SQL : SELECT * FROM Customers WHERE CustomerID NOT IN (SELECT CustomerID FROM Orders);
# ('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'C/ Moralzarzal 86', 'Madrid', '28034', 'Spain')
# ('PARIS', 'Paris spécialités', 'Marie Bertrand', '265 boulevard Charonne', 'Paris', '75012', 'France')

# %%
run_query("SQL Between", "SELECT * FROM Products WHERE unitPrice BETWEEN 10 AND 20;")

run_query("SQL Between / NOT BETWEEN", "SELECT * FROM Products WHERE unitPrice NOT BETWEEN 10 AND 20;")

run_query("SQL Between / BETWEEN with IN", "SELECT * FROM Products WHERE unitPrice BETWEEN 10 AND 20 AND CategoryID IN (1,2,3);")

run_query("SQL Between / BETWEEN Text Values", "SELECT * FROM Products WHERE ProductName BETWEEN 'Carnarvon Tigers' AND 'Mozzarella di Giovanni' ORDER BY ProductName;")

run_query("SQL Between / NOT BETWEEN Text Values", "SELECT * FROM Products WHERE ProductName NOT BETWEEN 'Carnarvon Tigers' AND 'Mozzarella di Giovanni' ORDER BY ProductName;")

run_query("SQL Between / BETWEEN Dates", "SELECT * FROM Orders WHERE OrderDate BETWEEN '1996-07-01' AND '1996-07-31';")
# Out:
#  SQL Between
# SQL : SELECT * FROM Products WHERE unitPrice BETWEEN 10 AND 20;
# (1, 'Chai', 1, 1, '10 boxes x 20 bags', 18.0, 39, 0, 10, 0)
# (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19.0, 17, 40, 25, 0)
# (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10.0, 13, 70, 25, 0)
# (15, 'Genen Shouyu', 6, 2, '24 - 250 ml bottles', 15.5, 39, 0, 5, 0)
# (16, 'Pavlova', 7, 3, '32 - 500 g boxes', 17.45, 29, 0, 10, 0)
# (21, "Sir Rodney's Scones", 8, 3, '24 pkgs. x 4 pieces', 10.0, 3, 40, 5, 0)
# (25, 'NuNuCa Nuß-Nougat-Creme', 11, 3, '20 - 450 g glasses', 14.0, 76, 0, 30, 0)
# (31, 'Gorgonzola Telino', 14, 4, '12 - 100 g pkgs', 12.5, 0, 70, 20, 0)
# (34, 'Sasquatch Ale', 16, 1, '24 - 12 oz bottles', 14.0, 111, 0, 15, 0)
# (35, 'Steeleye Stout', 16, 1, '24 - 12 oz bottles', 18.0, 20, 0, 15, 0)
# (36, 'Inlagd Sill', 17, 8, '24 - 250 g  jars', 19.0, 112, 0, 20, 0)
# (39, 'Chartreuse verte', 18, 1, '750 cc per bottle', 18.0, 69, 0, 5, 0)
# (40, 'Boston Crab Meat', 19, 8, '24 - 4 oz tins', 18.4, 123, 0, 30, 0)
# (42, 'Singaporean Hokkien Fried Mee', 20, 5, '32 - 1 kg pkgs.', 14.0, 26, 0, 0, 1)
# (44, 'Gula Malacca', 20, 2, '20 - 2 kg bags', 19.45, 27, 0, 15, 0)
# (46, 'Spegesild', 21, 8, '4 - 450 g glasses', 12.0, 95, 0, 0, 0)
# (48, 'Chocolade', 22, 3, '10 pkgs.', 12.75, 15, 70, 25, 0)
# (49, 'Maxilaku', 23, 3, '24 - 50 g pkgs.', 20.0, 10, 60, 15, 0)
# (50, 'Valkoinen suklaa', 23, 3, '12 - 100 g bars', 16.25, 65, 0, 30, 0)
# (57, 'Ravioli Angelo', 26, 5, '24 - 250 g pkgs.', 19.5, 36, 0, 20, 0)
# (58, 'Escargots de Bourgogne', 27, 8, '24 pieces', 13.25, 62, 0, 20, 0)
# (66, 'Louisiana Hot Spiced Okra', 2, 2, '24 - 8 oz jars', 17.0, 4, 100, 20, 0)
# (67, 'Laughing Lumberjack Lager', 16, 1, '24 - 12 oz bottles', 14.0, 52, 0, 10, 0)
# (68, 'Scottish Longbreads', 8, 3, '10 boxes x 8 pieces', 12.5, 6, 10, 15, 0)
# (70, 'Outback Lager', 7, 1, '24 - 355 ml bottles', 15.0, 15, 10, 30, 0)
# (73, 'Röd Kaviar', 17, 8, '24 - 150 g jars', 15.0, 101, 0, 5, 0)
# (74, 'Longlife Tofu', 4, 7, '5 kg pkg.', 10.0, 4, 20, 5, 0)
# (76, 'Lakkalikööri', 23, 1, '500 ml', 18.0, 57, 0, 20, 0)
# (77, 'Original Frankfurter grüne Soße', 12, 2, '12 boxes', 13.0, 32, 0, 15, 0)
#
#  SQL Between / NOT BETWEEN
# SQL : SELECT * FROM Products WHERE unitPrice NOT BETWEEN 10 AND 20;
# (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22.0, 53, 0, 0, 0)
# (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21.35, 0, 0, 0, 1)
# (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25.0, 120, 0, 25, 0)
# (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30.0, 15, 0, 10, 0)
# (8, 'Northwoods Cranberry Sauce', 3, 2, '12 - 12 oz jars', 40.0, 6, 0, 0, 0)
# (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97.0, 29, 0, 0, 1)
# (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31.0, 31, 0, 0, 0)
# (11, 'Queso Cabrales', 5, 4, '1 kg pkg.', 21.0, 22, 30, 30, 0)
# (12, 'Queso Manchego La Pastora', 5, 4, '10 - 500 g pkgs.', 38.0, 86, 0, 0, 0)
# (13, 'Konbu', 6, 8, '2 kg box', 6.0, 24, 0, 5, 0)
# (14, 'Tofu', 6, 7, '40 - 100 g pkgs.', 23.25, 35, 0, 0, 0)
# (17, 'Alice Mutton', 7, 6, '20 - 1 kg tins', 39.0, 0, 0, 0, 1)
# (18, 'Carnarvon Tigers', 7, 8, '16 kg pkg.', 62.5, 42, 0, 0, 0)
# (19, 'Teatime Chocolate Biscuits', 8, 3, '10 boxes x 12 pieces', 9.2, 25, 0, 5, 0)
# (20, "Sir Rodney's Marmalade", 8, 3, '30 gift boxes', 81.0, 40, 0, 0, 0)
# (22, "Gustaf's Knäckebröd", 9, 5, '24 - 500 g pkgs.', 21.0, 104, 0, 25, 0)
# (23, 'Tunnbröd', 9, 5, '12 - 250 g pkgs.', 9.0, 61, 0, 25, 0)
# (24, 'Guaraná Fantástica', 10, 1, '12 - 355 ml cans', 4.5, 20, 0, 0, 1)
# (26, 'Gumbär Gummibärchen', 11, 3, '100 - 250 g bags', 31.23, 15, 0, 0, 0)
# (27, 'Schoggi Schokolade', 11, 3, '100 - 100 g pieces', 43.9, 49, 0, 30, 0)
# (28, 'Rössle Sauerkraut', 12, 7, '25 - 825 g cans', 45.6, 26, 0, 0, 1)
# (29, 'Thüringer Rostbratwurst', 12, 6, '50 bags x 30 sausgs.', 123.79, 0, 0, 0, 1)
# (30, 'Nord-Ost Matjeshering', 13, 8, '10 - 200 g glasses', 25.89, 10, 0, 15, 0)
# (32, 'Mascarpone Fabioli', 14, 4, '24 - 200 g pkgs.', 32.0, 9, 40, 25, 0)
# (33, 'Geitost', 15, 4, '500 g', 2.5, 112, 0, 20, 0)
# (37, 'Gravad lax', 17, 8, '12 - 500 g pkgs.', 26.0, 11, 50, 25, 0)
# (38, 'Côte de Blaye', 18, 1, '12 - 75 cl bottles', 263.5, 17, 0, 15, 0)
# (41, "Jack's New England Clam Chowder", 19, 8, '12 - 12 oz cans', 9.65, 85, 0, 10, 0)
# (43, 'Ipoh Coffee', 20, 1, '16 - 500 g tins', 46.0, 17, 10, 25, 0)
# (45, 'Rogede sild', 21, 8, '1k pkg.', 9.5, 5, 70, 15, 0)
# (47, 'Zaanse koeken', 22, 3, '10 - 4 oz boxes', 9.5, 36, 0, 0, 0)
# (51, 'Manjimup Dried Apples', 24, 7, '50 - 300 g pkgs.', 53.0, 20, 0, 10, 0)
# (52, 'Filo Mix', 24, 5, '16 - 2 kg boxes', 7.0, 38, 0, 25, 0)
# (53, 'Perth Pasties', 24, 6, '48 pieces', 32.8, 0, 0, 0, 1)
# (54, 'Tourtière', 25, 6, '16 pies', 7.45, 21, 0, 10, 0)
# (55, 'Pâté chinois', 25, 6, '24 boxes x 2 pies', 24.0, 115, 0, 20, 0)
# (56, 'Gnocchi di nonna Alice', 26, 5, '24 - 250 g pkgs.', 38.0, 21, 10, 30, 0)
# (59, 'Raclette Courdavault', 28, 4, '5 kg pkg.', 55.0, 79, 0, 0, 0)
# (60, 'Camembert Pierrot', 28, 4, '15 - 300 g rounds', 34.0, 19, 0, 0, 0)
# (61, "Sirop d'érable", 29, 2, '24 - 500 ml bottles', 28.5, 113, 0, 25, 0)
# (62, 'Tarte au sucre', 29, 3, '48 pies', 49.3, 17, 0, 0, 0)
# (63, 'Vegie-spread', 7, 2, '15 - 625 g jars', 43.9, 24, 0, 5, 0)
# (64, 'Wimmers gute Semmelknödel', 12, 5, '20 bags x 4 pieces', 33.25, 22, 80, 30, 0)
# (65, 'Louisiana Fiery Hot Pepper Sauce', 2, 2, '32 - 8 oz bottles', 21.05, 76, 0, 0, 0)
# (69, 'Gudbrandsdalsost', 15, 4, '10 kg pkg.', 36.0, 26, 0, 15, 0)
# (71, 'Flotemysost', 15, 4, '10 - 500 g pkgs.', 21.5, 26, 0, 0, 0)
# (72, 'Mozzarella di Giovanni', 14, 4, '24 - 200 g pkgs.', 34.8, 14, 0, 0, 0)
# (75, 'Rhönbräu Klosterbier', 12, 1, '24 - 0.5 l bottles', 7.75, 125, 0, 25, 0)
#
#  SQL Between / BETWEEN with IN
# SQL : SELECT * FROM Products WHERE unitPrice BETWEEN 10 AND 20 AND CategoryID IN (1,2,3);
# (1, 'Chai', 1, 1, '10 boxes x 20 bags', 18.0, 39, 0, 10, 0)
# (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19.0, 17, 40, 25, 0)
# (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10.0, 13, 70, 25, 0)
# (15, 'Genen Shouyu', 6, 2, '24 - 250 ml bottles', 15.5, 39, 0, 5, 0)
# (16, 'Pavlova', 7, 3, '32 - 500 g boxes', 17.45, 29, 0, 10, 0)
# (21, "Sir Rodney's Scones", 8, 3, '24 pkgs. x 4 pieces', 10.0, 3, 40, 5, 0)
# (25, 'NuNuCa Nuß-Nougat-Creme', 11, 3, '20 - 450 g glasses', 14.0, 76, 0, 30, 0)
# (34, 'Sasquatch Ale', 16, 1, '24 - 12 oz bottles', 14.0, 111, 0, 15, 0)
# (35, 'Steeleye Stout', 16, 1, '24 - 12 oz bottles', 18.0, 20, 0, 15, 0)
# (39, 'Chartreuse verte', 18, 1, '750 cc per bottle', 18.0, 69, 0, 5, 0)
# (44, 'Gula Malacca', 20, 2, '20 - 2 kg bags', 19.45, 27, 0, 15, 0)
# (48, 'Chocolade', 22, 3, '10 pkgs.', 12.75, 15, 70, 25, 0)
# (49, 'Maxilaku', 23, 3, '24 - 50 g pkgs.', 20.0, 10, 60, 15, 0)
# (50, 'Valkoinen suklaa', 23, 3, '12 - 100 g bars', 16.25, 65, 0, 30, 0)
# (66, 'Louisiana Hot Spiced Okra', 2, 2, '24 - 8 oz jars', 17.0, 4, 100, 20, 0)
# (67, 'Laughing Lumberjack Lager', 16, 1, '24 - 12 oz bottles', 14.0, 52, 0, 10, 0)
# (68, 'Scottish Longbreads', 8, 3, '10 boxes x 8 pieces', 12.5, 6, 10, 15, 0)
# (70, 'Outback Lager', 7, 1, '24 - 355 ml bottles', 15.0, 15, 10, 30, 0)
# (76, 'Lakkalikööri', 23, 1, '500 ml', 18.0, 57, 0, 20, 0)
# (77, 'Original Frankfurter grüne Soße', 12, 2, '12 boxes', 13.0, 32, 0, 15, 0)
#
#  SQL Between / BETWEEN Text Values
# SQL : SELECT * FROM Products WHERE ProductName BETWEEN 'Carnarvon Tigers' AND 'Mozzarella di Giovanni' ORDER BY ProductName;
# (18, 'Carnarvon Tigers', 7, 8, '16 kg pkg.', 62.5, 42, 0, 0, 0)
# (1, 'Chai', 1, 1, '10 boxes x 20 bags', 18.0, 39, 0, 10, 0)
# (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19.0, 17, 40, 25, 0)
# (39, 'Chartreuse verte', 18, 1, '750 cc per bottle', 18.0, 69, 0, 5, 0)
# (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22.0, 53, 0, 0, 0)
# (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21.35, 0, 0, 0, 1)
# (48, 'Chocolade', 22, 3, '10 pkgs.', 12.75, 15, 70, 25, 0)
# (38, 'Côte de Blaye', 18, 1, '12 - 75 cl bottles', 263.5, 17, 0, 15, 0)
# (58, 'Escargots de Bourgogne', 27, 8, '24 pieces', 13.25, 62, 0, 20, 0)
# (52, 'Filo Mix', 24, 5, '16 - 2 kg boxes', 7.0, 38, 0, 25, 0)
# (71, 'Flotemysost', 15, 4, '10 - 500 g pkgs.', 21.5, 26, 0, 0, 0)
# (33, 'Geitost', 15, 4, '500 g', 2.5, 112, 0, 20, 0)
# (15, 'Genen Shouyu', 6, 2, '24 - 250 ml bottles', 15.5, 39, 0, 5, 0)
# (56, 'Gnocchi di nonna Alice', 26, 5, '24 - 250 g pkgs.', 38.0, 21, 10, 30, 0)
# (31, 'Gorgonzola Telino', 14, 4, '12 - 100 g pkgs', 12.5, 0, 70, 20, 0)
# (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25.0, 120, 0, 25, 0)
# (37, 'Gravad lax', 17, 8, '12 - 500 g pkgs.', 26.0, 11, 50, 25, 0)
# (24, 'Guaraná Fantástica', 10, 1, '12 - 355 ml cans', 4.5, 20, 0, 0, 1)
# (69, 'Gudbrandsdalsost', 15, 4, '10 kg pkg.', 36.0, 26, 0, 15, 0)
# (44, 'Gula Malacca', 20, 2, '20 - 2 kg bags', 19.45, 27, 0, 15, 0)
# (26, 'Gumbär Gummibärchen', 11, 3, '100 - 250 g bags', 31.23, 15, 0, 0, 0)
# (22, "Gustaf's Knäckebröd", 9, 5, '24 - 500 g pkgs.', 21.0, 104, 0, 25, 0)
# (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31.0, 31, 0, 0, 0)
# (36, 'Inlagd Sill', 17, 8, '24 - 250 g  jars', 19.0, 112, 0, 20, 0)
# (43, 'Ipoh Coffee', 20, 1, '16 - 500 g tins', 46.0, 17, 10, 25, 0)
# (41, "Jack's New England Clam Chowder", 19, 8, '12 - 12 oz cans', 9.65, 85, 0, 10, 0)
# (13, 'Konbu', 6, 8, '2 kg box', 6.0, 24, 0, 5, 0)
# (76, 'Lakkalikööri', 23, 1, '500 ml', 18.0, 57, 0, 20, 0)
# (67, 'Laughing Lumberjack Lager', 16, 1, '24 - 12 oz bottles', 14.0, 52, 0, 10, 0)
# (74, 'Longlife Tofu', 4, 7, '5 kg pkg.', 10.0, 4, 20, 5, 0)
# (65, 'Louisiana Fiery Hot Pepper Sauce', 2, 2, '32 - 8 oz bottles', 21.05, 76, 0, 0, 0)
# (66, 'Louisiana Hot Spiced Okra', 2, 2, '24 - 8 oz jars', 17.0, 4, 100, 20, 0)
# (51, 'Manjimup Dried Apples', 24, 7, '50 - 300 g pkgs.', 53.0, 20, 0, 10, 0)
# (32, 'Mascarpone Fabioli', 14, 4, '24 - 200 g pkgs.', 32.0, 9, 40, 25, 0)
# (49, 'Maxilaku', 23, 3, '24 - 50 g pkgs.', 20.0, 10, 60, 15, 0)
# (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97.0, 29, 0, 0, 1)
# (72, 'Mozzarella di Giovanni', 14, 4, '24 - 200 g pkgs.', 34.8, 14, 0, 0, 0)
#
#  SQL Between / NOT BETWEEN Text Values
# SQL : SELECT * FROM Products WHERE ProductName NOT BETWEEN 'Carnarvon Tigers' AND 'Mozzarella di Giovanni' ORDER BY ProductName;
# (17, 'Alice Mutton', 7, 6, '20 - 1 kg tins', 39.0, 0, 0, 0, 1)
# (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10.0, 13, 70, 25, 0)
# (40, 'Boston Crab Meat', 19, 8, '24 - 4 oz tins', 18.4, 123, 0, 30, 0)
# (60, 'Camembert Pierrot', 28, 4, '15 - 300 g rounds', 34.0, 19, 0, 0, 0)
# (30, 'Nord-Ost Matjeshering', 13, 8, '10 - 200 g glasses', 25.89, 10, 0, 15, 0)
# (8, 'Northwoods Cranberry Sauce', 3, 2, '12 - 12 oz jars', 40.0, 6, 0, 0, 0)
# (25, 'NuNuCa Nuß-Nougat-Creme', 11, 3, '20 - 450 g glasses', 14.0, 76, 0, 30, 0)
# (77, 'Original Frankfurter grüne Soße', 12, 2, '12 boxes', 13.0, 32, 0, 15, 0)
# (70, 'Outback Lager', 7, 1, '24 - 355 ml bottles', 15.0, 15, 10, 30, 0)
# (16, 'Pavlova', 7, 3, '32 - 500 g boxes', 17.45, 29, 0, 10, 0)
# (53, 'Perth Pasties', 24, 6, '48 pieces', 32.8, 0, 0, 0, 1)
# (55, 'Pâté chinois', 25, 6, '24 boxes x 2 pies', 24.0, 115, 0, 20, 0)
# (11, 'Queso Cabrales', 5, 4, '1 kg pkg.', 21.0, 22, 30, 30, 0)
# (12, 'Queso Manchego La Pastora', 5, 4, '10 - 500 g pkgs.', 38.0, 86, 0, 0, 0)
# (59, 'Raclette Courdavault', 28, 4, '5 kg pkg.', 55.0, 79, 0, 0, 0)
# (57, 'Ravioli Angelo', 26, 5, '24 - 250 g pkgs.', 19.5, 36, 0, 20, 0)
# (75, 'Rhönbräu Klosterbier', 12, 1, '24 - 0.5 l bottles', 7.75, 125, 0, 25, 0)
# (45, 'Rogede sild', 21, 8, '1k pkg.', 9.5, 5, 70, 15, 0)
# (73, 'Röd Kaviar', 17, 8, '24 - 150 g jars', 15.0, 101, 0, 5, 0)
# (28, 'Rössle Sauerkraut', 12, 7, '25 - 825 g cans', 45.6, 26, 0, 0, 1)
# (34, 'Sasquatch Ale', 16, 1, '24 - 12 oz bottles', 14.0, 111, 0, 15, 0)
# (27, 'Schoggi Schokolade', 11, 3, '100 - 100 g pieces', 43.9, 49, 0, 30, 0)
# (68, 'Scottish Longbreads', 8, 3, '10 boxes x 8 pieces', 12.5, 6, 10, 15, 0)
# (42, 'Singaporean Hokkien Fried Mee', 20, 5, '32 - 1 kg pkgs.', 14.0, 26, 0, 0, 1)
# (20, "Sir Rodney's Marmalade", 8, 3, '30 gift boxes', 81.0, 40, 0, 0, 0)
# (21, "Sir Rodney's Scones", 8, 3, '24 pkgs. x 4 pieces', 10.0, 3, 40, 5, 0)
# (61, "Sirop d'érable", 29, 2, '24 - 500 ml bottles', 28.5, 113, 0, 25, 0)
# (46, 'Spegesild', 21, 8, '4 - 450 g glasses', 12.0, 95, 0, 0, 0)
# (35, 'Steeleye Stout', 16, 1, '24 - 12 oz bottles', 18.0, 20, 0, 15, 0)
# (62, 'Tarte au sucre', 29, 3, '48 pies', 49.3, 17, 0, 0, 0)
# (19, 'Teatime Chocolate Biscuits', 8, 3, '10 boxes x 12 pieces', 9.2, 25, 0, 5, 0)
# (29, 'Thüringer Rostbratwurst', 12, 6, '50 bags x 30 sausgs.', 123.79, 0, 0, 0, 1)
# (14, 'Tofu', 6, 7, '40 - 100 g pkgs.', 23.25, 35, 0, 0, 0)
# (54, 'Tourtière', 25, 6, '16 pies', 7.45, 21, 0, 10, 0)
# (23, 'Tunnbröd', 9, 5, '12 - 250 g pkgs.', 9.0, 61, 0, 25, 0)
# (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30.0, 15, 0, 10, 0)
# (50, 'Valkoinen suklaa', 23, 3, '12 - 100 g bars', 16.25, 65, 0, 30, 0)
# (63, 'Vegie-spread', 7, 2, '15 - 625 g jars', 43.9, 24, 0, 5, 0)
# (64, 'Wimmers gute Semmelknödel', 12, 5, '20 bags x 4 pieces', 33.25, 22, 80, 30, 0)
# (47, 'Zaanse koeken', 22, 3, '10 - 4 oz boxes', 9.5, 36, 0, 0, 0)
#
#  SQL Between / BETWEEN Dates
# SQL : SELECT * FROM Orders WHERE OrderDate BETWEEN '1996-07-01' AND '1996-07-31';
# (10248, 'VINET', 5, '1996-07-04 00:00:00.000', '1996-08-01 00:00:00.000', '1996-07-16 00:00:00.000', 3, 32.38, 'Vins et alcools Chevalier', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France')
# (10249, 'TOMSP', 6, '1996-07-05 00:00:00.000', '1996-08-16 00:00:00.000', '1996-07-10 00:00:00.000', 1, 11.61, 'Toms Spezialitäten', 'Luisenstr. 48', 'Münster', None, '44087', 'Germany')
# (10250, 'HANAR', 4, '1996-07-08 00:00:00.000', '1996-08-05 00:00:00.000', '1996-07-12 00:00:00.000', 2, 65.83, 'Hanari Carnes', 'Rua do Paço 67', 'Rio de Janeiro', 'RJ', '05454-876', 'Brazil')
# (10251, 'VICTE', 3, '1996-07-08 00:00:00.000', '1996-08-05 00:00:00.000', '1996-07-15 00:00:00.000', 1, 41.34, 'Victuailles en stock', '2 rue du Commerce', 'Lyon', None, '69004', 'France')
# (10252, 'SUPRD', 4, '1996-07-09 00:00:00.000', '1996-08-06 00:00:00.000', '1996-07-11 00:00:00.000', 2, 51.3, 'Suprêmes délices', 'Boulevard Tirou 255', 'Charleroi', None, 'B-6000', 'Belgium')
# (10253, 'HANAR', 3, '1996-07-10 00:00:00.000', '1996-07-24 00:00:00.000', '1996-07-16 00:00:00.000', 2, 58.17, 'Hanari Carnes', 'Rua do Paço 67', 'Rio de Janeiro', 'RJ', '05454-876', 'Brazil')
# (10254, 'CHOPS', 5, '1996-07-11 00:00:00.000', '1996-08-08 00:00:00.000', '1996-07-23 00:00:00.000', 2, 22.98, 'Chop-suey Chinese', 'Hauptstr. 31', 'Bern', None, '3012', 'Switzerland')
# (10255, 'RICSU', 9, '1996-07-12 00:00:00.000', '1996-08-09 00:00:00.000', '1996-07-15 00:00:00.000', 3, 148.33, 'Richter Supermarkt', 'Starenweg 5', 'Genève', None, '1204', 'Switzerland')
# (10256, 'WELLI', 3, '1996-07-15 00:00:00.000', '1996-08-12 00:00:00.000', '1996-07-17 00:00:00.000', 2, 13.97, 'Wellington Importadora', 'Rua do Mercado 12', 'Resende', 'SP', '08737-363', 'Brazil')
# (10257, 'HILAA', 4, '1996-07-16 00:00:00.000', '1996-08-13 00:00:00.000', '1996-07-22 00:00:00.000', 3, 81.91, 'HILARION-Abastos', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristóbal', 'Táchira', '5022', 'Venezuela')
# (10258, 'ERNSH', 1, '1996-07-17 00:00:00.000', '1996-08-14 00:00:00.000', '1996-07-23 00:00:00.000', 1, 140.51, 'Ernst Handel', 'Kirchgasse 6', 'Graz', None, '8010', 'Austria')
# (10259, 'CENTC', 4, '1996-07-18 00:00:00.000', '1996-08-15 00:00:00.000', '1996-07-25 00:00:00.000', 3, 3.25, 'Centro comercial Moctezuma', 'Sierras de Granada 9993', 'México D.F.', None, '05022', 'Mexico')
# (10260, 'OTTIK', 4, '1996-07-19 00:00:00.000', '1996-08-16 00:00:00.000', '1996-07-29 00:00:00.000', 1, 55.09, 'Ottilies Käseladen', 'Mehrheimerstr. 369', 'Köln', None, '50739', 'Germany')
# (10261, 'QUEDE', 4, '1996-07-19 00:00:00.000', '1996-08-16 00:00:00.000', '1996-07-30 00:00:00.000', 2, 3.05, 'Que Delícia', 'Rua da Panificadora 12', 'Rio de Janeiro', 'RJ', '02389-673', 'Brazil')
# (10262, 'RATTC', 8, '1996-07-22 00:00:00.000', '1996-08-19 00:00:00.000', '1996-07-25 00:00:00.000', 3, 48.29, 'Rattlesnake Canyon Grocery', '2817 Milton Dr.', 'Albuquerque', 'NM', '87110', 'USA')
# (10263, 'ERNSH', 9, '1996-07-23 00:00:00.000', '1996-08-20 00:00:00.000', '1996-07-31 00:00:00.000', 3, 146.06, 'Ernst Handel', 'Kirchgasse 6', 'Graz', None, '8010', 'Austria')
# (10264, 'FOLKO', 6, '1996-07-24 00:00:00.000', '1996-08-21 00:00:00.000', '1996-08-23 00:00:00.000', 3, 3.67, 'Folk och fä HB', 'Åkergatan 24', 'Bräcke', None, 'S-844 67', 'Sweden')
# (10265, 'BLONP', 2, '1996-07-25 00:00:00.000', '1996-08-22 00:00:00.000', '1996-08-12 00:00:00.000', 1, 55.28, 'Blondel père et fils', '24 place Kléber', 'Strasbourg', None, '67000', 'France')
# (10266, 'WARTH', 3, '1996-07-26 00:00:00.000', '1996-09-06 00:00:00.000', '1996-07-31 00:00:00.000', 3, 25.73, 'Wartian Herkku', 'Torikatu 38', 'Oulu', None, '90110', 'Finland')
# (10267, 'FRANK', 4, '1996-07-29 00:00:00.000', '1996-08-26 00:00:00.000', '1996-08-06 00:00:00.000', 1, 208.58, 'Frankenversand', 'Berliner Platz 43', 'München', None, '80805', 'Germany')
# (10268, 'GROSR', 8, '1996-07-30 00:00:00.000', '1996-08-27 00:00:00.000', '1996-08-02 00:00:00.000', 3, 66.29, 'GROSELLA-Restaurante', '5ª Ave. Los Palos Grandes', 'Caracas', 'DF', '1081', 'Venezuela')

# %%
run_query("SQL Aliases", "SELECT CustomerID AS ID FROM Customers;")
# Out:
#  SQL Aliases
# SQL : SELECT CustomerID AS ID FROM Customers;
# (None,)
# (None,)
# (None,)
# (None,)
# (None,)
# ('ANATR',)
# ('ANTON',)
# ('AROUT',)
# ('BERGS',)
# ('BLAUS',)
# ('BLONP',)
# ('BOLID',)
# ('BONAP',)
# ('BOTTM',)
# ('BSBEV',)
# ('CACTU',)
# ('CENTC',)
# ('CHOPS',)
# ('COMMI',)
# ('CONSH',)
# ('DRACD',)
# ('DUMON',)
# ('EASTC',)
# ('ERNSH',)
# ('FAMIA',)
# ('FISSA',)
# ('FOLIG',)
# ('FOLKO',)
# ('FRANK',)
# ('FRANR',)
# ('FRANS',)
# ('FURIB',)
# ('GALED',)
# ('GODOS',)
# ('GOURL',)
# ('GREAL',)
# ('GROSR',)
# ('HANAR',)
# ('HILAA',)
# ('HUNGC',)
# ('HUNGO',)
# ('ISLAT',)
# ('KOENE',)
# ('LACOR',)
# ('LAMAI',)
# ('LAUGB',)
# ('LAZYK',)
# ('LEHMS',)
# ('LETSS',)
# ('LILAS',)
# ('LINOD',)
# ('LONEP',)
# ('MAGAA',)
# ('MAISD',)
# ('MEREP',)
# ('MORGK',)
# ('NORTS',)
# ('OCEAN',)
# ('OLDWO',)
# ('OTTIK',)
# ('PARIS',)
# ('PERIC',)
# ('PICCO',)
# ('PRINI',)
# ('QUEDE',)
# ('QUEEN',)
# ('QUICK',)
# ('RANCH',)
# ('RATTC',)
# ('REGGC',)
# ('RICAR',)
# ('RICSU',)
# ('ROMEY',)
# ('SANTG',)
# ('SAVEA',)
# ('SEVES',)
# ('SIMOB',)
# ('SPECD',)
# ('SPLIR',)
# ('SUPRD',)
# ('THEBI',)
# ('THECR',)
# ('TOMSP',)
# ('TORTU',)
# ('TRADH',)
# ('TRAIH',)
# ('VAFFE',)
# ('VICTE',)
# ('VINET',)
# ('WANDK',)
# ('WARTH',)
# ('WELLI',)
# ('WHITC',)
# ('WILMK',)
# ('WOLZA',)

# %%
run_query("SQL Joins", "SELECT Orders.OrderID, Customers.CustomerName, Orders.OrderDate FROM Orders INNER JOIN Customers ON Orders.CustomerID=Customers.CustomerID;")
# Out:
#  SQL Joins
# SQL : SELECT Orders.OrderID, Customers.CustomerName, Orders.OrderDate FROM Orders INNER JOIN Customers ON Orders.CustomerID=Customers.CustomerID;
# (10248, 'Vins et alcools Chevalier', '1996-07-04 00:00:00.000')
# (10249, 'Toms Spezialitäten', '1996-07-05 00:00:00.000')
# (10250, 'Hanari Carnes', '1996-07-08 00:00:00.000')
# (10251, 'Victuailles en stock', '1996-07-08 00:00:00.000')
# (10252, 'Suprêmes délices', '1996-07-09 00:00:00.000')
# (10253, 'Hanari Carnes', '1996-07-10 00:00:00.000')
# (10254, 'Chop-suey Chinese', '1996-07-11 00:00:00.000')
# (10255, 'Richter Supermarkt', '1996-07-12 00:00:00.000')
# (10256, 'Wellington Importadora', '1996-07-15 00:00:00.000')
# (10257, 'HILARION-Abastos', '1996-07-16 00:00:00.000')
# (10258, 'Ernst Handel', '1996-07-17 00:00:00.000')
# (10259, 'Centro comercial Moctezuma', '1996-07-18 00:00:00.000')
# (10260, 'Ottilies Käseladen', '1996-07-19 00:00:00.000')
# (10261, 'Que Delícia', '1996-07-19 00:00:00.000')
# (10262, 'Rattlesnake Canyon Grocery', '1996-07-22 00:00:00.000')
# (10263, 'Ernst Handel', '1996-07-23 00:00:00.000')
# (10264, 'Folk och fä HB', '1996-07-24 00:00:00.000')
# (10265, 'Blondesddsl père et fils', '1996-07-25 00:00:00.000')
# (10266, 'Wartian Herkku', '1996-07-26 00:00:00.000')
# (10267, 'Frankenversand', '1996-07-29 00:00:00.000')
# (10268, 'GROSELLA-Restaurante', '1996-07-30 00:00:00.000')
# (10269, 'White Clover Markets', '1996-07-31 00:00:00.000')
# (10270, 'Wartian Herkku', '1996-08-01 00:00:00.000')
# (10271, 'Split Rail Beer & Ale', '1996-08-01 00:00:00.000')
# (10272, 'Rattlesnake Canyon Grocery', '1996-08-02 00:00:00.000')
# (10273, 'QUICK-Stop', '1996-08-05 00:00:00.000')
# (10274, 'Vins et alcools Chevalier', '1996-08-06 00:00:00.000')
# (10275, 'Magazzini Alimentari Riuniti', '1996-08-07 00:00:00.000')
# (10276, 'Tortuga Restaurante', '1996-08-08 00:00:00.000')
# (10277, 'Morgenstern Gesundkost', '1996-08-09 00:00:00.000')
# (10278, 'Berglunds snabbköp', '1996-08-12 00:00:00.000')
# (10279, 'Lehmanns Marktstand', '1996-08-13 00:00:00.000')
# (10280, 'Berglunds snabbköp', '1996-08-14 00:00:00.000')
# (10281, 'Romero y tomillo', '1996-08-14 00:00:00.000')
# (10282, 'Romero y tomillo', '1996-08-15 00:00:00.000')
# (10283, 'LILA-Supermercado', '1996-08-16 00:00:00.000')
# (10284, 'Lehmanns Marktstand', '1996-08-19 00:00:00.000')
# (10285, 'QUICK-Stop', '1996-08-20 00:00:00.000')
# (10286, 'QUICK-Stop', '1996-08-21 00:00:00.000')
# (10287, 'Ricardo Adocicados', '1996-08-22 00:00:00.000')
# (10288, 'Reggiani Caseifici', '1996-08-23 00:00:00.000')
# (10289, "B's Beverages", '1996-08-26 00:00:00.000')
# (10290, 'Comércio Mineiro', '1996-08-27 00:00:00.000')
# (10291, 'Que Delícia', '1996-08-27 00:00:00.000')
# (10292, 'Tradição Hipermercados', '1996-08-28 00:00:00.000')
# (10293, 'Tortuga Restaurante', '1996-08-29 00:00:00.000')
# (10294, 'Rattlesnake Canyon Grocery', '1996-08-30 00:00:00.000')
# (10295, 'Vins et alcools Chevalier', '1996-09-02 00:00:00.000')
# (10296, 'LILA-Supermercado', '1996-09-03 00:00:00.000')
# (10297, 'Blondesddsl père et fils', '1996-09-04 00:00:00.000')
# (10298, 'Hungry Owl All-Night Grocers', '1996-09-05 00:00:00.000')
# (10299, 'Ricardo Adocicados', '1996-09-06 00:00:00.000')
# (10300, 'Magazzini Alimentari Riuniti', '1996-09-09 00:00:00.000')
# (10301, 'Die Wandernde Kuh', '1996-09-09 00:00:00.000')
# (10302, 'Suprêmes délices', '1996-09-10 00:00:00.000')
# (10303, 'Godos Cocina Típica', '1996-09-11 00:00:00.000')
# (10304, 'Tortuga Restaurante', '1996-09-12 00:00:00.000')
# (10305, 'Old World Delicatessen', '1996-09-13 00:00:00.000')
# (10306, 'Romero y tomillo', '1996-09-16 00:00:00.000')
# (10307, 'Lonesome Pine Restaurant', '1996-09-17 00:00:00.000')
# (10308, 'Ana Trujillo Emparedados y helados', '1996-09-18 00:00:00.000')
# (10309, 'Hungry Owl All-Night Grocers', '1996-09-19 00:00:00.000')
# (10310, 'The Big Cheese', '1996-09-20 00:00:00.000')
# (10311, 'Du monde entier', '1996-09-20 00:00:00.000')
# (10312, 'Die Wandernde Kuh', '1996-09-23 00:00:00.000')
# (10313, 'QUICK-Stop', '1996-09-24 00:00:00.000')
# (10314, 'Rattlesnake Canyon Grocery', '1996-09-25 00:00:00.000')
# (10315, 'Island Trading', '1996-09-26 00:00:00.000')
# (10316, 'Rattlesnake Canyon Grocery', '1996-09-27 00:00:00.000')
# (10317, 'Lonesome Pine Restaurant', '1996-09-30 00:00:00.000')
# (10318, 'Island Trading', '1996-10-01 00:00:00.000')
# (10319, 'Tortuga Restaurante', '1996-10-02 00:00:00.000')
# (10320, 'Wartian Herkku', '1996-10-03 00:00:00.000')
# (10321, 'Island Trading', '1996-10-03 00:00:00.000')
# (10322, 'Pericles Comidas clásicas', '1996-10-04 00:00:00.000')
# (10323, 'Königlich Essen', '1996-10-07 00:00:00.000')
# (10324, 'Save-a-lot Markets', '1996-10-08 00:00:00.000')
# (10325, 'Königlich Essen', '1996-10-09 00:00:00.000')
# (10326, 'Bólido Comidas preparadas', '1996-10-10 00:00:00.000')
# (10327, 'Folk och fä HB', '1996-10-11 00:00:00.000')
# (10328, 'Furia Bacalhau e Frutos do Mar', '1996-10-14 00:00:00.000')
# (10329, 'Split Rail Beer & Ale', '1996-10-15 00:00:00.000')
# (10330, 'LILA-Supermercado', '1996-10-16 00:00:00.000')
# (10331, "Bon app'", '1996-10-16 00:00:00.000')
# (10332, 'Mère Paillarde', '1996-10-17 00:00:00.000')
# (10333, 'Wartian Herkku', '1996-10-18 00:00:00.000')
# (10334, 'Victuailles en stock', '1996-10-21 00:00:00.000')
# (10335, 'Hungry Owl All-Night Grocers', '1996-10-22 00:00:00.000')
# (10336, 'Princesa Isabel Vinhos', '1996-10-23 00:00:00.000')
# (10337, 'Frankenversand', '1996-10-24 00:00:00.000')
# (10338, 'Old World Delicatessen', '1996-10-25 00:00:00.000')
# (10339, 'Mère Paillarde', '1996-10-28 00:00:00.000')
# (10340, "Bon app'", '1996-10-29 00:00:00.000')
# (10341, 'Simons bistro', '1996-10-29 00:00:00.000')
# (10342, 'Frankenversand', '1996-10-30 00:00:00.000')
# (10343, 'Lehmanns Marktstand', '1996-10-31 00:00:00.000')
# (10344, 'White Clover Markets', '1996-11-01 00:00:00.000')
# (10345, 'QUICK-Stop', '1996-11-04 00:00:00.000')
# (10346, 'Rattlesnake Canyon Grocery', '1996-11-05 00:00:00.000')
# (10347, 'Familia Arquibaldo', '1996-11-06 00:00:00.000')
# (10348, 'Die Wandernde Kuh', '1996-11-07 00:00:00.000')
# (10349, 'Split Rail Beer & Ale', '1996-11-08 00:00:00.000')
# (10350, "La maison d'Asie", '1996-11-11 00:00:00.000')
# (10351, 'Ernst Handel', '1996-11-11 00:00:00.000')
# (10352, 'Furia Bacalhau e Frutos do Mar', '1996-11-12 00:00:00.000')
# (10353, 'Piccolo und mehr', '1996-11-13 00:00:00.000')
# (10354, 'Pericles Comidas clásicas', '1996-11-14 00:00:00.000')
# (10355, 'Around the Horn', '1996-11-15 00:00:00.000')
# (10356, 'Die Wandernde Kuh', '1996-11-18 00:00:00.000')
# (10357, 'LILA-Supermercado', '1996-11-19 00:00:00.000')
# (10358, "La maison d'Asie", '1996-11-20 00:00:00.000')
# (10359, 'Seven Seas Imports', '1996-11-21 00:00:00.000')
# (10360, 'Blondesddsl père et fils', '1996-11-22 00:00:00.000')
# (10361, 'QUICK-Stop', '1996-11-22 00:00:00.000')
# (10362, "Bon app'", '1996-11-25 00:00:00.000')
# (10363, 'Drachenblut Delikatessen', '1996-11-26 00:00:00.000')
# (10364, 'Eastern Connection', '1996-11-26 00:00:00.000')
# (10365, 'Antonio Moreno Taquería', '1996-11-27 00:00:00.000')
# (10366, 'Galería del gastrónomo', '1996-11-28 00:00:00.000')
# (10367, 'Vaffeljernet', '1996-11-28 00:00:00.000')
# (10368, 'Ernst Handel', '1996-11-29 00:00:00.000')
# (10369, 'Split Rail Beer & Ale', '1996-12-02 00:00:00.000')
# (10370, 'Chop-suey Chinese', '1996-12-03 00:00:00.000')
# (10371, "La maison d'Asie", '1996-12-03 00:00:00.000')
# (10372, 'Queen Cozinha', '1996-12-04 00:00:00.000')
# (10373, 'Hungry Owl All-Night Grocers', '1996-12-05 00:00:00.000')
# (10374, 'Wolski  Zajazd', '1996-12-05 00:00:00.000')
# (10375, 'Hungry Coyote Import Store', '1996-12-06 00:00:00.000')
# (10376, 'Mère Paillarde', '1996-12-09 00:00:00.000')
# (10377, 'Seven Seas Imports', '1996-12-09 00:00:00.000')
# (10378, 'Folk och fä HB', '1996-12-10 00:00:00.000')
# (10379, 'Que Delícia', '1996-12-11 00:00:00.000')
# (10380, 'Hungry Owl All-Night Grocers', '1996-12-12 00:00:00.000')
# (10381, 'LILA-Supermercado', '1996-12-12 00:00:00.000')
# (10382, 'Ernst Handel', '1996-12-13 00:00:00.000')
# (10383, 'Around the Horn', '1996-12-16 00:00:00.000')
# (10384, 'Berglunds snabbköp', '1996-12-16 00:00:00.000')
# (10385, 'Split Rail Beer & Ale', '1996-12-17 00:00:00.000')
# (10386, 'Familia Arquibaldo', '1996-12-18 00:00:00.000')
# (10387, 'Santé Gourmet', '1996-12-18 00:00:00.000')
# (10388, 'Seven Seas Imports', '1996-12-19 00:00:00.000')
# (10389, 'Bottom-Dollar Markets', '1996-12-20 00:00:00.000')
# (10390, 'Ernst Handel', '1996-12-23 00:00:00.000')
# (10391, 'Drachenblut Delikatessen', '1996-12-23 00:00:00.000')
# (10392, 'Piccolo und mehr', '1996-12-24 00:00:00.000')
# (10393, 'Save-a-lot Markets', '1996-12-25 00:00:00.000')
# (10394, 'Hungry Coyote Import Store', '1996-12-25 00:00:00.000')
# (10395, 'HILARION-Abastos', '1996-12-26 00:00:00.000')
# (10396, 'Frankenversand', '1996-12-27 00:00:00.000')
# (10397, 'Princesa Isabel Vinhos', '1996-12-27 00:00:00.000')
# (10398, 'Save-a-lot Markets', '1996-12-30 00:00:00.000')
# (10399, 'Vaffeljernet', '1996-12-31 00:00:00.000')
# (10400, 'Eastern Connection', '1997-01-01 00:00:00.000')
# (10401, 'Rattlesnake Canyon Grocery', '1997-01-01 00:00:00.000')
# (10402, 'Ernst Handel', '1997-01-02 00:00:00.000')
# (10403, 'Ernst Handel', '1997-01-03 00:00:00.000')
# (10404, 'Magazzini Alimentari Riuniti', '1997-01-03 00:00:00.000')
# (10405, 'LINO-Delicateses', '1997-01-06 00:00:00.000')
# (10406, 'Queen Cozinha', '1997-01-07 00:00:00.000')
# (10407, 'Ottilies Käseladen', '1997-01-07 00:00:00.000')
# (10408, 'Folies gourmandes', '1997-01-08 00:00:00.000')
# (10409, 'Océano Atlántico Ltda.', '1997-01-09 00:00:00.000')
# (10410, 'Bottom-Dollar Markets', '1997-01-10 00:00:00.000')
# (10411, 'Bottom-Dollar Markets', '1997-01-10 00:00:00.000')
# (10412, 'Wartian Herkku', '1997-01-13 00:00:00.000')
# (10413, "La maison d'Asie", '1997-01-14 00:00:00.000')
# (10414, 'Familia Arquibaldo', '1997-01-14 00:00:00.000')
# (10415, 'Hungry Coyote Import Store', '1997-01-15 00:00:00.000')
# (10416, 'Wartian Herkku', '1997-01-16 00:00:00.000')
# (10417, 'Simons bistro', '1997-01-16 00:00:00.000')
# (10418, 'QUICK-Stop', '1997-01-17 00:00:00.000')
# (10419, 'Richter Supermarkt', '1997-01-20 00:00:00.000')
# (10420, 'Wellington Importadora', '1997-01-21 00:00:00.000')
# (10421, 'Que Delícia', '1997-01-21 00:00:00.000')
# (10422, 'Franchi S.p.A.', '1997-01-22 00:00:00.000')
# (10423, 'Gourmet Lanchonetes', '1997-01-23 00:00:00.000')
# (10424, 'Mère Paillarde', '1997-01-23 00:00:00.000')
# (10425, "La maison d'Asie", '1997-01-24 00:00:00.000')
# (10426, 'Galería del gastrónomo', '1997-01-27 00:00:00.000')
# (10427, 'Piccolo und mehr', '1997-01-27 00:00:00.000')
# (10428, 'Reggiani Caseifici', '1997-01-28 00:00:00.000')
# (10429, 'Hungry Owl All-Night Grocers', '1997-01-29 00:00:00.000')
# (10430, 'Ernst Handel', '1997-01-30 00:00:00.000')
# (10431, 'Bottom-Dollar Markets', '1997-01-30 00:00:00.000')
# (10432, 'Split Rail Beer & Ale', '1997-01-31 00:00:00.000')
# (10433, 'Princesa Isabel Vinhos', '1997-02-03 00:00:00.000')
# (10434, 'Folk och fä HB', '1997-02-03 00:00:00.000')
# (10435, 'Consolidated Holdings', '1997-02-04 00:00:00.000')
# (10436, 'Blondesddsl père et fils', '1997-02-05 00:00:00.000')
# (10437, 'Wartian Herkku', '1997-02-05 00:00:00.000')
# (10438, 'Toms Spezialitäten', '1997-02-06 00:00:00.000')
# (10439, 'Mère Paillarde', '1997-02-07 00:00:00.000')
# (10440, 'Save-a-lot Markets', '1997-02-10 00:00:00.000')
# (10441, 'Old World Delicatessen', '1997-02-10 00:00:00.000')
# (10442, 'Ernst Handel', '1997-02-11 00:00:00.000')
# (10443, 'Reggiani Caseifici', '1997-02-12 00:00:00.000')
# (10444, 'Berglunds snabbköp', '1997-02-12 00:00:00.000')
# (10445, 'Berglunds snabbköp', '1997-02-13 00:00:00.000')
# (10446, 'Toms Spezialitäten', '1997-02-14 00:00:00.000')
# (10447, 'Ricardo Adocicados', '1997-02-14 00:00:00.000')
# (10448, 'Rancho grande', '1997-02-17 00:00:00.000')
# (10449, 'Blondesddsl père et fils', '1997-02-18 00:00:00.000')
# (10450, 'Victuailles en stock', '1997-02-19 00:00:00.000')
# (10451, 'QUICK-Stop', '1997-02-19 00:00:00.000')
# (10452, 'Save-a-lot Markets', '1997-02-20 00:00:00.000')
# (10453, 'Around the Horn', '1997-02-21 00:00:00.000')
# (10454, "La maison d'Asie", '1997-02-21 00:00:00.000')
# (10455, 'Wartian Herkku', '1997-02-24 00:00:00.000')
# (10456, 'Königlich Essen', '1997-02-25 00:00:00.000')
# (10457, 'Königlich Essen', '1997-02-25 00:00:00.000')
# (10458, 'Suprêmes délices', '1997-02-26 00:00:00.000')
# (10459, 'Victuailles en stock', '1997-02-27 00:00:00.000')
# (10460, 'Folk och fä HB', '1997-02-28 00:00:00.000')
# (10461, 'LILA-Supermercado', '1997-02-28 00:00:00.000')
# (10462, 'Consolidated Holdings', '1997-03-03 00:00:00.000')
# (10463, 'Suprêmes délices', '1997-03-04 00:00:00.000')
# (10464, 'Furia Bacalhau e Frutos do Mar', '1997-03-04 00:00:00.000')
# (10465, 'Vaffeljernet', '1997-03-05 00:00:00.000')
# (10466, 'Comércio Mineiro', '1997-03-06 00:00:00.000')
# (10467, 'Magazzini Alimentari Riuniti', '1997-03-06 00:00:00.000')
# (10468, 'Königlich Essen', '1997-03-07 00:00:00.000')
# (10469, 'White Clover Markets', '1997-03-10 00:00:00.000')
# (10470, "Bon app'", '1997-03-11 00:00:00.000')
# (10471, "B's Beverages", '1997-03-11 00:00:00.000')
# (10472, 'Seven Seas Imports', '1997-03-12 00:00:00.000')
# (10473, 'Island Trading', '1997-03-13 00:00:00.000')
# (10474, 'Pericles Comidas clásicas', '1997-03-13 00:00:00.000')
# (10475, 'Suprêmes délices', '1997-03-14 00:00:00.000')
# (10476, 'HILARION-Abastos', '1997-03-17 00:00:00.000')
# (10477, 'Princesa Isabel Vinhos', '1997-03-17 00:00:00.000')
# (10478, 'Victuailles en stock', '1997-03-18 00:00:00.000')
# (10479, 'Rattlesnake Canyon Grocery', '1997-03-19 00:00:00.000')
# (10480, 'Folies gourmandes', '1997-03-20 00:00:00.000')
# (10481, 'Ricardo Adocicados', '1997-03-20 00:00:00.000')
# (10482, 'Lazy K Kountry Store', '1997-03-21 00:00:00.000')
# (10483, 'White Clover Markets', '1997-03-24 00:00:00.000')
# (10484, "B's Beverages", '1997-03-24 00:00:00.000')
# (10485, 'LINO-Delicateses', '1997-03-25 00:00:00.000')
# (10486, 'HILARION-Abastos', '1997-03-26 00:00:00.000')
# (10487, 'Queen Cozinha', '1997-03-26 00:00:00.000')
# (10488, 'Frankenversand', '1997-03-27 00:00:00.000')
# (10489, 'Piccolo und mehr', '1997-03-28 00:00:00.000')
# (10490, 'HILARION-Abastos', '1997-03-31 00:00:00.000')
# (10491, 'Furia Bacalhau e Frutos do Mar', '1997-03-31 00:00:00.000')
# (10492, 'Bottom-Dollar Markets', '1997-04-01 00:00:00.000')
# (10493, "La maison d'Asie", '1997-04-02 00:00:00.000')
# (10494, 'Comércio Mineiro', '1997-04-02 00:00:00.000')
# (10495, 'Laughing Bacchus Wine Cellars', '1997-04-03 00:00:00.000')
# (10496, 'Tradição Hipermercados', '1997-04-04 00:00:00.000')
# (10497, 'Lehmanns Marktstand', '1997-04-04 00:00:00.000')
# (10498, 'HILARION-Abastos', '1997-04-07 00:00:00.000')
# (10499, 'LILA-Supermercado', '1997-04-08 00:00:00.000')
# (10500, "La maison d'Asie", '1997-04-09 00:00:00.000')
# (10501, 'Blauer See Delikatessen', '1997-04-09 00:00:00.000')
# (10502, 'Pericles Comidas clásicas', '1997-04-10 00:00:00.000')
# (10503, 'Hungry Owl All-Night Grocers', '1997-04-11 00:00:00.000')
# (10504, 'White Clover Markets', '1997-04-11 00:00:00.000')
# (10505, 'Mère Paillarde', '1997-04-14 00:00:00.000')
# (10506, 'Königlich Essen', '1997-04-15 00:00:00.000')
# (10507, 'Antonio Moreno Taquería', '1997-04-15 00:00:00.000')
# (10508, 'Ottilies Käseladen', '1997-04-16 00:00:00.000')
# (10509, 'Blauer See Delikatessen', '1997-04-17 00:00:00.000')
# (10510, 'Save-a-lot Markets', '1997-04-18 00:00:00.000')
# (10511, "Bon app'", '1997-04-18 00:00:00.000')
# (10512, 'Familia Arquibaldo', '1997-04-21 00:00:00.000')
# (10513, 'Die Wandernde Kuh', '1997-04-22 00:00:00.000')
# (10514, 'Ernst Handel', '1997-04-22 00:00:00.000')
# (10515, 'QUICK-Stop', '1997-04-23 00:00:00.000')
# (10516, 'Hungry Owl All-Night Grocers', '1997-04-24 00:00:00.000')
# (10517, 'North/South', '1997-04-24 00:00:00.000')
# (10518, 'Tortuga Restaurante', '1997-04-25 00:00:00.000')
# (10519, 'Chop-suey Chinese', '1997-04-28 00:00:00.000')
# (10520, 'Santé Gourmet', '1997-04-29 00:00:00.000')
# (10521, 'Cactus Comidas para llevar', '1997-04-29 00:00:00.000')
# (10522, 'Lehmanns Marktstand', '1997-04-30 00:00:00.000')
# (10523, 'Seven Seas Imports', '1997-05-01 00:00:00.000')
# (10524, 'Berglunds snabbköp', '1997-05-01 00:00:00.000')
# (10525, "Bon app'", '1997-05-02 00:00:00.000')
# (10526, 'Wartian Herkku', '1997-05-05 00:00:00.000')
# (10527, 'QUICK-Stop', '1997-05-05 00:00:00.000')
# (10528, 'Great Lakes Food Market', '1997-05-06 00:00:00.000')
# (10529, 'Maison Dewey', '1997-05-07 00:00:00.000')
# (10530, 'Piccolo und mehr', '1997-05-08 00:00:00.000')
# (10531, 'Océano Atlántico Ltda.', '1997-05-08 00:00:00.000')
# (10532, 'Eastern Connection', '1997-05-09 00:00:00.000')
# (10533, 'Folk och fä HB', '1997-05-12 00:00:00.000')
# (10534, 'Lehmanns Marktstand', '1997-05-12 00:00:00.000')
# (10535, 'Antonio Moreno Taquería', '1997-05-13 00:00:00.000')
# (10536, 'Lehmanns Marktstand', '1997-05-14 00:00:00.000')
# (10537, 'Richter Supermarkt', '1997-05-14 00:00:00.000')
# (10538, "B's Beverages", '1997-05-15 00:00:00.000')
# (10539, "B's Beverages", '1997-05-16 00:00:00.000')
# (10540, 'QUICK-Stop', '1997-05-19 00:00:00.000')
# (10541, 'Hanari Carnes', '1997-05-19 00:00:00.000')
# (10542, 'Königlich Essen', '1997-05-20 00:00:00.000')
# (10543, 'LILA-Supermercado', '1997-05-21 00:00:00.000')
# (10544, 'Lonesome Pine Restaurant', '1997-05-21 00:00:00.000')
# (10545, 'Lazy K Kountry Store', '1997-05-22 00:00:00.000')
# (10546, 'Victuailles en stock', '1997-05-23 00:00:00.000')
# (10547, 'Seven Seas Imports', '1997-05-23 00:00:00.000')
# (10548, 'Toms Spezialitäten', '1997-05-26 00:00:00.000')
# (10549, 'QUICK-Stop', '1997-05-27 00:00:00.000')
# (10550, 'Godos Cocina Típica', '1997-05-28 00:00:00.000')
# (10551, 'Furia Bacalhau e Frutos do Mar', '1997-05-28 00:00:00.000')
# (10552, 'HILARION-Abastos', '1997-05-29 00:00:00.000')
# (10553, 'Wartian Herkku', '1997-05-30 00:00:00.000')
# (10554, 'Ottilies Käseladen', '1997-05-30 00:00:00.000')
# (10555, 'Save-a-lot Markets', '1997-06-02 00:00:00.000')
# (10556, 'Simons bistro', '1997-06-03 00:00:00.000')
# (10557, 'Lehmanns Marktstand', '1997-06-03 00:00:00.000')
# (10558, 'Around the Horn', '1997-06-04 00:00:00.000')
# (10559, 'Blondesddsl père et fils', '1997-06-05 00:00:00.000')
# (10560, 'Frankenversand', '1997-06-06 00:00:00.000')
# (10561, 'Folk och fä HB', '1997-06-06 00:00:00.000')
# (10562, 'Reggiani Caseifici', '1997-06-09 00:00:00.000')
# (10563, 'Ricardo Adocicados', '1997-06-10 00:00:00.000')
# (10564, 'Rattlesnake Canyon Grocery', '1997-06-10 00:00:00.000')
# (10565, 'Mère Paillarde', '1997-06-11 00:00:00.000')
# (10566, 'Blondesddsl père et fils', '1997-06-12 00:00:00.000')
# (10567, 'Hungry Owl All-Night Grocers', '1997-06-12 00:00:00.000')
# (10568, 'Galería del gastrónomo', '1997-06-13 00:00:00.000')
# (10569, 'Rattlesnake Canyon Grocery', '1997-06-16 00:00:00.000')
# (10570, 'Mère Paillarde', '1997-06-17 00:00:00.000')
# (10571, 'Ernst Handel', '1997-06-17 00:00:00.000')
# (10572, 'Berglunds snabbköp', '1997-06-18 00:00:00.000')
# (10573, 'Antonio Moreno Taquería', '1997-06-19 00:00:00.000')
# (10574, "Trail's Head Gourmet Provisioners", '1997-06-19 00:00:00.000')
# (10575, 'Morgenstern Gesundkost', '1997-06-20 00:00:00.000')
# (10576, 'Tortuga Restaurante', '1997-06-23 00:00:00.000')
# (10577, "Trail's Head Gourmet Provisioners", '1997-06-23 00:00:00.000')
# (10578, "B's Beverages", '1997-06-24 00:00:00.000')
# (10579, "Let's Stop N Shop", '1997-06-25 00:00:00.000')
# (10580, 'Ottilies Käseladen', '1997-06-26 00:00:00.000')
# (10581, 'Familia Arquibaldo', '1997-06-26 00:00:00.000')
# (10582, 'Blauer See Delikatessen', '1997-06-27 00:00:00.000')
# (10583, 'Wartian Herkku', '1997-06-30 00:00:00.000')
# (10584, 'Blondesddsl père et fils', '1997-06-30 00:00:00.000')
# (10585, 'Wellington Importadora', '1997-07-01 00:00:00.000')
# (10586, 'Reggiani Caseifici', '1997-07-02 00:00:00.000')
# (10587, 'Que Delícia', '1997-07-02 00:00:00.000')
# (10588, 'QUICK-Stop', '1997-07-03 00:00:00.000')
# (10589, 'Great Lakes Food Market', '1997-07-04 00:00:00.000')
# (10590, 'Mère Paillarde', '1997-07-07 00:00:00.000')
# (10591, 'Vaffeljernet', '1997-07-07 00:00:00.000')
# (10592, 'Lehmanns Marktstand', '1997-07-08 00:00:00.000')
# (10593, 'Lehmanns Marktstand', '1997-07-09 00:00:00.000')
# (10594, 'Old World Delicatessen', '1997-07-09 00:00:00.000')
# (10595, 'Ernst Handel', '1997-07-10 00:00:00.000')
# (10596, 'White Clover Markets', '1997-07-11 00:00:00.000')
# (10597, 'Piccolo und mehr', '1997-07-11 00:00:00.000')
# (10598, 'Rattlesnake Canyon Grocery', '1997-07-14 00:00:00.000')
# (10599, "B's Beverages", '1997-07-15 00:00:00.000')
# (10600, 'Hungry Coyote Import Store', '1997-07-16 00:00:00.000')
# (10601, 'HILARION-Abastos', '1997-07-16 00:00:00.000')
# (10602, 'Vaffeljernet', '1997-07-17 00:00:00.000')
# (10603, 'Save-a-lot Markets', '1997-07-18 00:00:00.000')
# (10604, 'Furia Bacalhau e Frutos do Mar', '1997-07-18 00:00:00.000')
# (10605, 'Mère Paillarde', '1997-07-21 00:00:00.000')
# (10606, 'Tradição Hipermercados', '1997-07-22 00:00:00.000')
# (10607, 'Save-a-lot Markets', '1997-07-22 00:00:00.000')
# (10608, 'Toms Spezialitäten', '1997-07-23 00:00:00.000')
# (10609, 'Du monde entier', '1997-07-24 00:00:00.000')
# (10610, "La maison d'Asie", '1997-07-25 00:00:00.000')
# (10611, 'Wolski  Zajazd', '1997-07-25 00:00:00.000')
# (10612, 'Save-a-lot Markets', '1997-07-28 00:00:00.000')
# (10613, 'HILARION-Abastos', '1997-07-29 00:00:00.000')
# (10614, 'Blauer See Delikatessen', '1997-07-29 00:00:00.000')
# (10615, 'Wilman Kala', '1997-07-30 00:00:00.000')
# (10616, 'Great Lakes Food Market', '1997-07-31 00:00:00.000')
# (10617, 'Great Lakes Food Market', '1997-07-31 00:00:00.000')
# (10618, 'Mère Paillarde', '1997-08-01 00:00:00.000')
# (10619, 'Mère Paillarde', '1997-08-04 00:00:00.000')
# (10620, 'Laughing Bacchus Wine Cellars', '1997-08-05 00:00:00.000')
# (10621, 'Island Trading', '1997-08-05 00:00:00.000')
# (10622, 'Ricardo Adocicados', '1997-08-06 00:00:00.000')
# (10623, 'Frankenversand', '1997-08-07 00:00:00.000')
# (10624, 'The Cracker Box', '1997-08-07 00:00:00.000')
# (10625, 'Ana Trujillo Emparedados y helados', '1997-08-08 00:00:00.000')
# (10626, 'Berglunds snabbköp', '1997-08-11 00:00:00.000')
# (10627, 'Save-a-lot Markets', '1997-08-11 00:00:00.000')
# (10628, 'Blondesddsl père et fils', '1997-08-12 00:00:00.000')
# (10629, 'Godos Cocina Típica', '1997-08-12 00:00:00.000')
# (10630, 'Königlich Essen', '1997-08-13 00:00:00.000')
# (10631, "La maison d'Asie", '1997-08-14 00:00:00.000')
# (10632, 'Die Wandernde Kuh', '1997-08-14 00:00:00.000')
# (10633, 'Ernst Handel', '1997-08-15 00:00:00.000')
# (10634, 'Folies gourmandes', '1997-08-15 00:00:00.000')
# (10635, 'Magazzini Alimentari Riuniti', '1997-08-18 00:00:00.000')
# (10636, 'Wartian Herkku', '1997-08-19 00:00:00.000')
# (10637, 'Queen Cozinha', '1997-08-19 00:00:00.000')
# (10638, 'LINO-Delicateses', '1997-08-20 00:00:00.000')
# (10639, 'Santé Gourmet', '1997-08-20 00:00:00.000')
# (10640, 'Die Wandernde Kuh', '1997-08-21 00:00:00.000')
# (10641, 'HILARION-Abastos', '1997-08-22 00:00:00.000')
# (10642, 'Simons bistro', '1997-08-22 00:00:00.000')
# (10644, 'Wellington Importadora', '1997-08-25 00:00:00.000')
# (10645, 'Hanari Carnes', '1997-08-26 00:00:00.000')
# (10646, 'Hungry Owl All-Night Grocers', '1997-08-27 00:00:00.000')
# (10647, 'Que Delícia', '1997-08-27 00:00:00.000')
# (10648, 'Ricardo Adocicados', '1997-08-28 00:00:00.000')
# (10649, 'Maison Dewey', '1997-08-28 00:00:00.000')
# (10650, 'Familia Arquibaldo', '1997-08-29 00:00:00.000')
# (10651, 'Die Wandernde Kuh', '1997-09-01 00:00:00.000')
# (10652, 'Gourmet Lanchonetes', '1997-09-01 00:00:00.000')
# (10653, 'Frankenversand', '1997-09-02 00:00:00.000')
# (10654, 'Berglunds snabbköp', '1997-09-02 00:00:00.000')
# (10655, 'Reggiani Caseifici', '1997-09-03 00:00:00.000')
# (10656, 'Great Lakes Food Market', '1997-09-04 00:00:00.000')
# (10657, 'Save-a-lot Markets', '1997-09-04 00:00:00.000')
# (10658, 'QUICK-Stop', '1997-09-05 00:00:00.000')
# (10659, 'Queen Cozinha', '1997-09-05 00:00:00.000')
# (10660, 'Hungry Coyote Import Store', '1997-09-08 00:00:00.000')
# (10661, 'Hungry Owl All-Night Grocers', '1997-09-09 00:00:00.000')
# (10662, 'Lonesome Pine Restaurant', '1997-09-09 00:00:00.000')
# (10663, "Bon app'", '1997-09-10 00:00:00.000')
# (10664, 'Furia Bacalhau e Frutos do Mar', '1997-09-10 00:00:00.000')
# (10665, 'Lonesome Pine Restaurant', '1997-09-11 00:00:00.000')
# (10666, 'Richter Supermarkt', '1997-09-12 00:00:00.000')
# (10667, 'Ernst Handel', '1997-09-12 00:00:00.000')
# (10668, 'Die Wandernde Kuh', '1997-09-15 00:00:00.000')
# (10669, 'Simons bistro', '1997-09-15 00:00:00.000')
# (10670, 'Frankenversand', '1997-09-16 00:00:00.000')
# (10671, 'France restauration', '1997-09-17 00:00:00.000')
# (10672, 'Berglunds snabbköp', '1997-09-17 00:00:00.000')
# (10673, 'Wilman Kala', '1997-09-18 00:00:00.000')
# (10674, 'Island Trading', '1997-09-18 00:00:00.000')
# (10675, 'Frankenversand', '1997-09-19 00:00:00.000')
# (10676, 'Tortuga Restaurante', '1997-09-22 00:00:00.000')
# (10677, 'Antonio Moreno Taquería', '1997-09-22 00:00:00.000')
# (10678, 'Save-a-lot Markets', '1997-09-23 00:00:00.000')
# (10679, 'Blondesddsl père et fils', '1997-09-23 00:00:00.000')
# (10680, 'Old World Delicatessen', '1997-09-24 00:00:00.000')
# (10681, 'Great Lakes Food Market', '1997-09-25 00:00:00.000')
# (10682, 'Antonio Moreno Taquería', '1997-09-25 00:00:00.000')
# (10683, 'Du monde entier', '1997-09-26 00:00:00.000')
# (10684, 'Ottilies Käseladen', '1997-09-26 00:00:00.000')
# (10685, 'Gourmet Lanchonetes', '1997-09-29 00:00:00.000')
# (10686, 'Piccolo und mehr', '1997-09-30 00:00:00.000')
# (10687, 'Hungry Owl All-Night Grocers', '1997-09-30 00:00:00.000')
# (10688, 'Vaffeljernet', '1997-10-01 00:00:00.000')
# (10689, 'Berglunds snabbköp', '1997-10-01 00:00:00.000')
# (10690, 'Hanari Carnes', '1997-10-02 00:00:00.000')
# (10691, 'QUICK-Stop', '1997-10-03 00:00:00.000')
# (10693, 'White Clover Markets', '1997-10-06 00:00:00.000')
# (10694, 'QUICK-Stop', '1997-10-06 00:00:00.000')
# (10695, 'Wilman Kala', '1997-10-07 00:00:00.000')
# (10696, 'White Clover Markets', '1997-10-08 00:00:00.000')
# (10697, 'LINO-Delicateses', '1997-10-08 00:00:00.000')
# (10698, 'Ernst Handel', '1997-10-09 00:00:00.000')
# (10699, 'Morgenstern Gesundkost', '1997-10-09 00:00:00.000')
# (10700, 'Save-a-lot Markets', '1997-10-10 00:00:00.000')
# (10701, 'Hungry Owl All-Night Grocers', '1997-10-13 00:00:00.000')
# (10703, 'Folk och fä HB', '1997-10-14 00:00:00.000')
# (10704, 'Queen Cozinha', '1997-10-14 00:00:00.000')
# (10705, 'HILARION-Abastos', '1997-10-15 00:00:00.000')
# (10706, 'Old World Delicatessen', '1997-10-16 00:00:00.000')
# (10707, 'Around the Horn', '1997-10-16 00:00:00.000')
# (10708, 'The Big Cheese', '1997-10-17 00:00:00.000')
# (10709, 'Gourmet Lanchonetes', '1997-10-17 00:00:00.000')
# (10710, 'Franchi S.p.A.', '1997-10-20 00:00:00.000')
# (10711, 'Save-a-lot Markets', '1997-10-21 00:00:00.000')
# (10712, 'Hungry Owl All-Night Grocers', '1997-10-21 00:00:00.000')
# (10713, 'Save-a-lot Markets', '1997-10-22 00:00:00.000')
# (10714, 'Save-a-lot Markets', '1997-10-22 00:00:00.000')
# (10715, "Bon app'", '1997-10-23 00:00:00.000')
# (10716, 'Rancho grande', '1997-10-24 00:00:00.000')
# (10717, 'Frankenversand', '1997-10-24 00:00:00.000')
# (10718, 'Königlich Essen', '1997-10-27 00:00:00.000')
# (10719, "Let's Stop N Shop", '1997-10-27 00:00:00.000')
# (10720, 'Que Delícia', '1997-10-28 00:00:00.000')
# (10721, 'QUICK-Stop', '1997-10-29 00:00:00.000')
# (10722, 'Save-a-lot Markets', '1997-10-29 00:00:00.000')
# (10723, 'White Clover Markets', '1997-10-30 00:00:00.000')
# (10724, 'Mère Paillarde', '1997-10-30 00:00:00.000')
# (10725, 'Familia Arquibaldo', '1997-10-31 00:00:00.000')
# (10726, 'Eastern Connection', '1997-11-03 00:00:00.000')
# (10727, 'Reggiani Caseifici', '1997-11-03 00:00:00.000')
# (10728, 'Queen Cozinha', '1997-11-04 00:00:00.000')
# (10729, 'LINO-Delicateses', '1997-11-04 00:00:00.000')
# (10730, "Bon app'", '1997-11-05 00:00:00.000')
# (10731, 'Chop-suey Chinese', '1997-11-06 00:00:00.000')
# (10732, "Bon app'", '1997-11-06 00:00:00.000')
# (10733, 'Berglunds snabbköp', '1997-11-07 00:00:00.000')
# (10734, 'Gourmet Lanchonetes', '1997-11-07 00:00:00.000')
# (10735, "Let's Stop N Shop", '1997-11-10 00:00:00.000')
# (10736, 'Hungry Owl All-Night Grocers', '1997-11-11 00:00:00.000')
# (10737, 'Vins et alcools Chevalier', '1997-11-11 00:00:00.000')
# (10738, 'Spécialités du monde', '1997-11-12 00:00:00.000')
# (10739, 'Vins et alcools Chevalier', '1997-11-12 00:00:00.000')
# (10740, 'White Clover Markets', '1997-11-13 00:00:00.000')
# (10741, 'Around the Horn', '1997-11-14 00:00:00.000')
# (10742, 'Bottom-Dollar Markets', '1997-11-14 00:00:00.000')
# (10743, 'Around the Horn', '1997-11-17 00:00:00.000')
# (10744, 'Vaffeljernet', '1997-11-17 00:00:00.000')
# (10745, 'QUICK-Stop', '1997-11-18 00:00:00.000')
# (10746, 'Chop-suey Chinese', '1997-11-19 00:00:00.000')
# (10747, 'Piccolo und mehr', '1997-11-19 00:00:00.000')
# (10748, 'Save-a-lot Markets', '1997-11-20 00:00:00.000')
# (10749, 'Island Trading', '1997-11-20 00:00:00.000')
# (10750, 'Wartian Herkku', '1997-11-21 00:00:00.000')
# (10751, 'Richter Supermarkt', '1997-11-24 00:00:00.000')
# (10752, 'North/South', '1997-11-24 00:00:00.000')
# (10753, 'Franchi S.p.A.', '1997-11-25 00:00:00.000')
# (10754, 'Magazzini Alimentari Riuniti', '1997-11-25 00:00:00.000')
# (10755, "Bon app'", '1997-11-26 00:00:00.000')
# (10756, 'Split Rail Beer & Ale', '1997-11-27 00:00:00.000')
# (10757, 'Save-a-lot Markets', '1997-11-27 00:00:00.000')
# (10758, 'Richter Supermarkt', '1997-11-28 00:00:00.000')
# (10759, 'Ana Trujillo Emparedados y helados', '1997-11-28 00:00:00.000')
# (10760, 'Maison Dewey', '1997-12-01 00:00:00.000')
# (10761, 'Rattlesnake Canyon Grocery', '1997-12-02 00:00:00.000')
# (10762, 'Folk och fä HB', '1997-12-02 00:00:00.000')
# (10763, 'Folies gourmandes', '1997-12-03 00:00:00.000')
# (10764, 'Ernst Handel', '1997-12-03 00:00:00.000')
# (10765, 'QUICK-Stop', '1997-12-04 00:00:00.000')
# (10766, 'Ottilies Käseladen', '1997-12-05 00:00:00.000')
# (10767, 'Suprêmes délices', '1997-12-05 00:00:00.000')
# (10768, 'Around the Horn', '1997-12-08 00:00:00.000')
# (10769, 'Vaffeljernet', '1997-12-08 00:00:00.000')
# (10770, 'Hanari Carnes', '1997-12-09 00:00:00.000')
# (10771, 'Ernst Handel', '1997-12-10 00:00:00.000')
# (10772, 'Lehmanns Marktstand', '1997-12-10 00:00:00.000')
# (10773, 'Ernst Handel', '1997-12-11 00:00:00.000')
# (10774, 'Folk och fä HB', '1997-12-11 00:00:00.000')
# (10775, 'The Cracker Box', '1997-12-12 00:00:00.000')
# (10776, 'Ernst Handel', '1997-12-15 00:00:00.000')
# (10777, 'Gourmet Lanchonetes', '1997-12-15 00:00:00.000')
# (10778, 'Berglunds snabbköp', '1997-12-16 00:00:00.000')
# (10779, 'Morgenstern Gesundkost', '1997-12-16 00:00:00.000')
# (10780, 'LILA-Supermercado', '1997-12-16 00:00:00.000')
# (10781, 'Wartian Herkku', '1997-12-17 00:00:00.000')
# (10782, 'Cactus Comidas para llevar', '1997-12-17 00:00:00.000')
# (10783, 'Hanari Carnes', '1997-12-18 00:00:00.000')
# (10784, 'Magazzini Alimentari Riuniti', '1997-12-18 00:00:00.000')
# (10785, 'GROSELLA-Restaurante', '1997-12-18 00:00:00.000')
# (10786, 'Queen Cozinha', '1997-12-19 00:00:00.000')
# (10787, "La maison d'Asie", '1997-12-19 00:00:00.000')
# (10788, 'QUICK-Stop', '1997-12-22 00:00:00.000')
# (10789, 'Folies gourmandes', '1997-12-22 00:00:00.000')
# (10790, 'Gourmet Lanchonetes', '1997-12-22 00:00:00.000')
# (10791, 'Frankenversand', '1997-12-23 00:00:00.000')
# (10792, 'Wolski  Zajazd', '1997-12-23 00:00:00.000')
# (10793, 'Around the Horn', '1997-12-24 00:00:00.000')
# (10794, 'Que Delícia', '1997-12-24 00:00:00.000')
# (10795, 'Ernst Handel', '1997-12-24 00:00:00.000')
# (10796, 'HILARION-Abastos', '1997-12-25 00:00:00.000')
# (10797, 'Drachenblut Delikatessen', '1997-12-25 00:00:00.000')
# (10798, 'Island Trading', '1997-12-26 00:00:00.000')
# (10799, 'Königlich Essen', '1997-12-26 00:00:00.000')
# (10800, 'Seven Seas Imports', '1997-12-26 00:00:00.000')
# (10801, 'Bólido Comidas preparadas', '1997-12-29 00:00:00.000')
# (10802, 'Simons bistro', '1997-12-29 00:00:00.000')
# (10803, 'Wellington Importadora', '1997-12-30 00:00:00.000')
# (10804, 'Seven Seas Imports', '1997-12-30 00:00:00.000')
# (10805, 'The Big Cheese', '1997-12-30 00:00:00.000')
# (10806, 'Victuailles en stock', '1997-12-31 00:00:00.000')
# (10807, 'Franchi S.p.A.', '1997-12-31 00:00:00.000')
# (10808, 'Old World Delicatessen', '1998-01-01 00:00:00.000')
# (10809, 'Wellington Importadora', '1998-01-01 00:00:00.000')
# (10810, 'Laughing Bacchus Wine Cellars', '1998-01-01 00:00:00.000')
# (10811, 'LINO-Delicateses', '1998-01-02 00:00:00.000')
# (10812, 'Reggiani Caseifici', '1998-01-02 00:00:00.000')
# (10813, 'Ricardo Adocicados', '1998-01-05 00:00:00.000')
# (10814, 'Victuailles en stock', '1998-01-05 00:00:00.000')
# (10815, 'Save-a-lot Markets', '1998-01-05 00:00:00.000')
# (10816, 'Great Lakes Food Market', '1998-01-06 00:00:00.000')
# (10817, 'Königlich Essen', '1998-01-06 00:00:00.000')
# (10818, 'Magazzini Alimentari Riuniti', '1998-01-07 00:00:00.000')
# (10819, 'Cactus Comidas para llevar', '1998-01-07 00:00:00.000')
# (10820, 'Rattlesnake Canyon Grocery', '1998-01-07 00:00:00.000')
# (10821, 'Split Rail Beer & Ale', '1998-01-08 00:00:00.000')
# (10822, "Trail's Head Gourmet Provisioners", '1998-01-08 00:00:00.000')
# (10823, 'LILA-Supermercado', '1998-01-09 00:00:00.000')
# (10824, 'Folk och fä HB', '1998-01-09 00:00:00.000')
# (10825, 'Drachenblut Delikatessen', '1998-01-09 00:00:00.000')
# (10826, 'Blondesddsl père et fils', '1998-01-12 00:00:00.000')
# (10827, "Bon app'", '1998-01-12 00:00:00.000')
# (10828, 'Rancho grande', '1998-01-13 00:00:00.000')
# (10829, 'Island Trading', '1998-01-13 00:00:00.000')
# (10830, 'Tradição Hipermercados', '1998-01-13 00:00:00.000')
# (10831, 'Santé Gourmet', '1998-01-14 00:00:00.000')
# (10832, "La maison d'Asie", '1998-01-14 00:00:00.000')
# (10833, 'Ottilies Käseladen', '1998-01-15 00:00:00.000')
# (10834, 'Tradição Hipermercados', '1998-01-15 00:00:00.000')
# (10836, 'Ernst Handel', '1998-01-16 00:00:00.000')
# (10837, 'Berglunds snabbköp', '1998-01-16 00:00:00.000')
# (10838, 'LINO-Delicateses', '1998-01-19 00:00:00.000')
# (10839, 'Tradição Hipermercados', '1998-01-19 00:00:00.000')
# (10840, 'LINO-Delicateses', '1998-01-19 00:00:00.000')
# (10841, 'Suprêmes délices', '1998-01-20 00:00:00.000')
# (10842, 'Tortuga Restaurante', '1998-01-20 00:00:00.000')
# (10843, 'Victuailles en stock', '1998-01-21 00:00:00.000')
# (10844, 'Piccolo und mehr', '1998-01-21 00:00:00.000')
# (10845, 'QUICK-Stop', '1998-01-21 00:00:00.000')
# (10846, 'Suprêmes délices', '1998-01-22 00:00:00.000')
# (10847, 'Save-a-lot Markets', '1998-01-22 00:00:00.000')
# (10848, 'Consolidated Holdings', '1998-01-23 00:00:00.000')
# (10849, 'Königlich Essen', '1998-01-23 00:00:00.000')
# (10850, 'Victuailles en stock', '1998-01-23 00:00:00.000')
# (10851, 'Ricardo Adocicados', '1998-01-26 00:00:00.000')
# (10852, 'Rattlesnake Canyon Grocery', '1998-01-26 00:00:00.000')
# (10853, 'Blauer See Delikatessen', '1998-01-27 00:00:00.000')
# (10854, 'Ernst Handel', '1998-01-27 00:00:00.000')
# (10855, 'Old World Delicatessen', '1998-01-27 00:00:00.000')
# (10856, 'Antonio Moreno Taquería', '1998-01-28 00:00:00.000')
# (10857, 'Berglunds snabbköp', '1998-01-28 00:00:00.000')
# (10858, "La corne d'abondance", '1998-01-29 00:00:00.000')
# (10859, 'Frankenversand', '1998-01-29 00:00:00.000')
# (10860, 'France restauration', '1998-01-29 00:00:00.000')
# (10861, 'White Clover Markets', '1998-01-30 00:00:00.000')
# (10862, 'Lehmanns Marktstand', '1998-01-30 00:00:00.000')
# (10863, 'HILARION-Abastos', '1998-02-02 00:00:00.000')
# (10864, 'Around the Horn', '1998-02-02 00:00:00.000')
# (10865, 'QUICK-Stop', '1998-02-02 00:00:00.000')
# (10866, 'Berglunds snabbköp', '1998-02-03 00:00:00.000')
# (10867, 'Lonesome Pine Restaurant', '1998-02-03 00:00:00.000')
# (10868, 'Queen Cozinha', '1998-02-04 00:00:00.000')
# (10869, 'Seven Seas Imports', '1998-02-04 00:00:00.000')
# (10870, 'Wolski  Zajazd', '1998-02-04 00:00:00.000')
# (10871, "Bon app'", '1998-02-05 00:00:00.000')
# (10872, 'Godos Cocina Típica', '1998-02-05 00:00:00.000')
# (10873, 'Wilman Kala', '1998-02-06 00:00:00.000')
# (10874, 'Godos Cocina Típica', '1998-02-06 00:00:00.000')
# (10875, 'Berglunds snabbköp', '1998-02-06 00:00:00.000')
# (10876, "Bon app'", '1998-02-09 00:00:00.000')
# (10877, 'Ricardo Adocicados', '1998-02-09 00:00:00.000')
# (10878, 'QUICK-Stop', '1998-02-10 00:00:00.000')
# (10879, 'Wilman Kala', '1998-02-10 00:00:00.000')
# (10880, 'Folk och fä HB', '1998-02-10 00:00:00.000')
# (10881, 'Cactus Comidas para llevar', '1998-02-11 00:00:00.000')
# (10882, 'Save-a-lot Markets', '1998-02-11 00:00:00.000')
# (10883, 'Lonesome Pine Restaurant', '1998-02-12 00:00:00.000')
# (10884, "Let's Stop N Shop", '1998-02-12 00:00:00.000')
# (10885, 'Suprêmes délices', '1998-02-12 00:00:00.000')
# (10886, 'Hanari Carnes', '1998-02-13 00:00:00.000')
# (10887, 'Galería del gastrónomo', '1998-02-13 00:00:00.000')
# (10888, 'Godos Cocina Típica', '1998-02-16 00:00:00.000')
# (10889, 'Rattlesnake Canyon Grocery', '1998-02-16 00:00:00.000')
# (10890, 'Du monde entier', '1998-02-16 00:00:00.000')
# (10891, 'Lehmanns Marktstand', '1998-02-17 00:00:00.000')
# (10892, 'Maison Dewey', '1998-02-17 00:00:00.000')
# (10893, 'Königlich Essen', '1998-02-18 00:00:00.000')
# (10894, 'Save-a-lot Markets', '1998-02-18 00:00:00.000')
# (10895, 'Ernst Handel', '1998-02-18 00:00:00.000')
# (10896, 'Maison Dewey', '1998-02-19 00:00:00.000')
# (10897, 'Hungry Owl All-Night Grocers', '1998-02-19 00:00:00.000')
# (10898, 'Océano Atlántico Ltda.', '1998-02-20 00:00:00.000')
# (10899, 'LILA-Supermercado', '1998-02-20 00:00:00.000')
# (10900, 'Wellington Importadora', '1998-02-20 00:00:00.000')
# (10901, 'HILARION-Abastos', '1998-02-23 00:00:00.000')
# (10902, 'Folk och fä HB', '1998-02-23 00:00:00.000')
# (10903, 'Hanari Carnes', '1998-02-24 00:00:00.000')
# (10904, 'White Clover Markets', '1998-02-24 00:00:00.000')
# (10905, 'Wellington Importadora', '1998-02-24 00:00:00.000')
# (10906, 'Wolski  Zajazd', '1998-02-25 00:00:00.000')
# (10907, 'Spécialités du monde', '1998-02-25 00:00:00.000')
# (10908, 'Reggiani Caseifici', '1998-02-26 00:00:00.000')
# (10909, 'Santé Gourmet', '1998-02-26 00:00:00.000')
# (10910, 'Wilman Kala', '1998-02-26 00:00:00.000')
# (10911, 'Godos Cocina Típica', '1998-02-26 00:00:00.000')
# (10912, 'Hungry Owl All-Night Grocers', '1998-02-26 00:00:00.000')
# (10913, 'Queen Cozinha', '1998-02-26 00:00:00.000')
# (10914, 'Queen Cozinha', '1998-02-27 00:00:00.000')
# (10915, 'Tortuga Restaurante', '1998-02-27 00:00:00.000')
# (10916, 'Rancho grande', '1998-02-27 00:00:00.000')
# (10917, 'Romero y tomillo', '1998-03-02 00:00:00.000')
# (10918, 'Bottom-Dollar Markets', '1998-03-02 00:00:00.000')
# (10919, 'LINO-Delicateses', '1998-03-02 00:00:00.000')
# (10920, 'Around the Horn', '1998-03-03 00:00:00.000')
# (10921, 'Vaffeljernet', '1998-03-03 00:00:00.000')
# (10922, 'Hanari Carnes', '1998-03-03 00:00:00.000')
# (10923, "La maison d'Asie", '1998-03-03 00:00:00.000')
# (10924, 'Berglunds snabbköp', '1998-03-04 00:00:00.000')
# (10925, 'Hanari Carnes', '1998-03-04 00:00:00.000')
# (10926, 'Ana Trujillo Emparedados y helados', '1998-03-04 00:00:00.000')
# (10927, "La corne d'abondance", '1998-03-05 00:00:00.000')
# (10928, 'Galería del gastrónomo', '1998-03-05 00:00:00.000')
# (10929, 'Frankenversand', '1998-03-05 00:00:00.000')
# (10930, 'Suprêmes délices', '1998-03-06 00:00:00.000')
# (10931, 'Richter Supermarkt', '1998-03-06 00:00:00.000')
# (10932, "Bon app'", '1998-03-06 00:00:00.000')
# (10933, 'Island Trading', '1998-03-06 00:00:00.000')
# (10934, 'Lehmanns Marktstand', '1998-03-09 00:00:00.000')
# (10935, 'Wellington Importadora', '1998-03-09 00:00:00.000')
# (10936, 'Great Lakes Food Market', '1998-03-09 00:00:00.000')
# (10937, 'Cactus Comidas para llevar', '1998-03-10 00:00:00.000')
# (10938, 'QUICK-Stop', '1998-03-10 00:00:00.000')
# (10939, 'Magazzini Alimentari Riuniti', '1998-03-10 00:00:00.000')
# (10940, "Bon app'", '1998-03-11 00:00:00.000')
# (10941, 'Save-a-lot Markets', '1998-03-11 00:00:00.000')
# (10942, 'Reggiani Caseifici', '1998-03-11 00:00:00.000')
# (10943, "B's Beverages", '1998-03-11 00:00:00.000')
# (10944, 'Bottom-Dollar Markets', '1998-03-12 00:00:00.000')
# (10945, 'Morgenstern Gesundkost', '1998-03-12 00:00:00.000')
# (10946, 'Vaffeljernet', '1998-03-12 00:00:00.000')
# (10947, "B's Beverages", '1998-03-13 00:00:00.000')
# (10948, 'Godos Cocina Típica', '1998-03-13 00:00:00.000')
# (10949, 'Bottom-Dollar Markets', '1998-03-13 00:00:00.000')
# (10950, 'Magazzini Alimentari Riuniti', '1998-03-16 00:00:00.000')
# (10951, 'Richter Supermarkt', '1998-03-16 00:00:00.000')
# (10953, 'Around the Horn', '1998-03-16 00:00:00.000')
# (10954, 'LINO-Delicateses', '1998-03-17 00:00:00.000')
# (10955, 'Folk och fä HB', '1998-03-17 00:00:00.000')
# (10956, 'Blauer See Delikatessen', '1998-03-17 00:00:00.000')
# (10957, 'HILARION-Abastos', '1998-03-18 00:00:00.000')
# (10958, 'Océano Atlántico Ltda.', '1998-03-18 00:00:00.000')
# (10959, 'Gourmet Lanchonetes', '1998-03-18 00:00:00.000')
# (10960, 'HILARION-Abastos', '1998-03-19 00:00:00.000')
# (10961, 'Queen Cozinha', '1998-03-19 00:00:00.000')
# (10962, 'QUICK-Stop', '1998-03-19 00:00:00.000')
# (10963, 'Furia Bacalhau e Frutos do Mar', '1998-03-19 00:00:00.000')
# (10964, 'Spécialités du monde', '1998-03-20 00:00:00.000')
# (10965, 'Old World Delicatessen', '1998-03-20 00:00:00.000')
# (10966, 'Chop-suey Chinese', '1998-03-20 00:00:00.000')
# (10967, 'Toms Spezialitäten', '1998-03-23 00:00:00.000')
# (10968, 'Ernst Handel', '1998-03-23 00:00:00.000')
# (10969, 'Comércio Mineiro', '1998-03-23 00:00:00.000')
# (10970, 'Bólido Comidas preparadas', '1998-03-24 00:00:00.000')
# (10971, 'France restauration', '1998-03-24 00:00:00.000')
# (10972, "La corne d'abondance", '1998-03-24 00:00:00.000')
# (10973, "La corne d'abondance", '1998-03-24 00:00:00.000')
# (10974, 'Split Rail Beer & Ale', '1998-03-25 00:00:00.000')
# (10975, 'Bottom-Dollar Markets', '1998-03-25 00:00:00.000')
# (10976, 'HILARION-Abastos', '1998-03-25 00:00:00.000')
# (10977, 'Folk och fä HB', '1998-03-26 00:00:00.000')
# (10978, 'Maison Dewey', '1998-03-26 00:00:00.000')
# (10979, 'Ernst Handel', '1998-03-26 00:00:00.000')
# (10980, 'Folk och fä HB', '1998-03-27 00:00:00.000')
# (10981, 'Hanari Carnes', '1998-03-27 00:00:00.000')
# (10982, 'Bottom-Dollar Markets', '1998-03-27 00:00:00.000')
# (10983, 'Save-a-lot Markets', '1998-03-27 00:00:00.000')
# (10984, 'Save-a-lot Markets', '1998-03-30 00:00:00.000')
# (10985, 'Hungry Owl All-Night Grocers', '1998-03-30 00:00:00.000')
# (10986, 'Océano Atlántico Ltda.', '1998-03-30 00:00:00.000')
# (10987, 'Eastern Connection', '1998-03-31 00:00:00.000')
# (10988, 'Rattlesnake Canyon Grocery', '1998-03-31 00:00:00.000')
# (10989, 'Que Delícia', '1998-03-31 00:00:00.000')
# (10990, 'Ernst Handel', '1998-04-01 00:00:00.000')
# (10991, 'QUICK-Stop', '1998-04-01 00:00:00.000')
# (10992, 'The Big Cheese', '1998-04-01 00:00:00.000')
# (10993, 'Folk och fä HB', '1998-04-01 00:00:00.000')
# (10994, 'Vaffeljernet', '1998-04-02 00:00:00.000')
# (10995, 'Pericles Comidas clásicas', '1998-04-02 00:00:00.000')
# (10996, 'QUICK-Stop', '1998-04-02 00:00:00.000')
# (10997, 'LILA-Supermercado', '1998-04-03 00:00:00.000')
# (10998, 'Wolski  Zajazd', '1998-04-03 00:00:00.000')
# (10999, 'Ottilies Käseladen', '1998-04-03 00:00:00.000')
# (11000, 'Rattlesnake Canyon Grocery', '1998-04-06 00:00:00.000')
# (11001, 'Folk och fä HB', '1998-04-06 00:00:00.000')
# (11002, 'Save-a-lot Markets', '1998-04-06 00:00:00.000')
# (11003, 'The Cracker Box', '1998-04-06 00:00:00.000')
# (11004, 'Maison Dewey', '1998-04-07 00:00:00.000')
# (11005, 'Wilman Kala', '1998-04-07 00:00:00.000')
# (11006, 'Great Lakes Food Market', '1998-04-07 00:00:00.000')
# (11007, 'Princesa Isabel Vinhos', '1998-04-08 00:00:00.000')
# (11008, 'Ernst Handel', '1998-04-08 00:00:00.000')
# (11009, 'Godos Cocina Típica', '1998-04-08 00:00:00.000')
# (11010, 'Reggiani Caseifici', '1998-04-09 00:00:00.000')
# (11012, 'Frankenversand', '1998-04-09 00:00:00.000')
# (11013, 'Romero y tomillo', '1998-04-09 00:00:00.000')
# (11014, 'LINO-Delicateses', '1998-04-10 00:00:00.000')
# (11015, 'Santé Gourmet', '1998-04-10 00:00:00.000')
# (11016, 'Around the Horn', '1998-04-10 00:00:00.000')
# (11017, 'Ernst Handel', '1998-04-13 00:00:00.000')
# (11018, 'Lonesome Pine Restaurant', '1998-04-13 00:00:00.000')
# (11019, 'Rancho grande', '1998-04-13 00:00:00.000')
# (11020, 'Ottilies Käseladen', '1998-04-14 00:00:00.000')
# (11021, 'QUICK-Stop', '1998-04-14 00:00:00.000')
# (11022, 'Hanari Carnes', '1998-04-14 00:00:00.000')
# (11023, "B's Beverages", '1998-04-14 00:00:00.000')
# (11024, 'Eastern Connection', '1998-04-15 00:00:00.000')
# (11025, 'Wartian Herkku', '1998-04-15 00:00:00.000')
# (11026, 'Franchi S.p.A.', '1998-04-15 00:00:00.000')
# (11027, 'Bottom-Dollar Markets', '1998-04-16 00:00:00.000')
# (11028, 'Königlich Essen', '1998-04-16 00:00:00.000')
# (11029, 'Chop-suey Chinese', '1998-04-16 00:00:00.000')
# (11030, 'Save-a-lot Markets', '1998-04-17 00:00:00.000')
# (11031, 'Save-a-lot Markets', '1998-04-17 00:00:00.000')
# (11032, 'White Clover Markets', '1998-04-17 00:00:00.000')
# (11033, 'Richter Supermarkt', '1998-04-17 00:00:00.000')
# (11034, 'Old World Delicatessen', '1998-04-20 00:00:00.000')
# (11035, 'Suprêmes délices', '1998-04-20 00:00:00.000')
# (11036, 'Drachenblut Delikatessen', '1998-04-20 00:00:00.000')
# (11037, 'Godos Cocina Típica', '1998-04-21 00:00:00.000')
# (11038, 'Suprêmes délices', '1998-04-21 00:00:00.000')
# (11039, 'LINO-Delicateses', '1998-04-21 00:00:00.000')
# (11040, 'Great Lakes Food Market', '1998-04-22 00:00:00.000')
# (11041, 'Chop-suey Chinese', '1998-04-22 00:00:00.000')
# (11042, 'Comércio Mineiro', '1998-04-22 00:00:00.000')
# (11043, 'Spécialités du monde', '1998-04-22 00:00:00.000')
# (11044, 'Wolski  Zajazd', '1998-04-23 00:00:00.000')
# (11045, 'Bottom-Dollar Markets', '1998-04-23 00:00:00.000')
# (11046, 'Die Wandernde Kuh', '1998-04-23 00:00:00.000')
# (11047, 'Eastern Connection', '1998-04-24 00:00:00.000')
# (11048, 'Bottom-Dollar Markets', '1998-04-24 00:00:00.000')
# (11049, 'Gourmet Lanchonetes', '1998-04-24 00:00:00.000')
# (11050, 'Folk och fä HB', '1998-04-27 00:00:00.000')
# (11051, "La maison d'Asie", '1998-04-27 00:00:00.000')
# (11052, 'Hanari Carnes', '1998-04-27 00:00:00.000')
# (11053, 'Piccolo und mehr', '1998-04-27 00:00:00.000')
# (11054, 'Cactus Comidas para llevar', '1998-04-28 00:00:00.000')
# (11055, 'HILARION-Abastos', '1998-04-28 00:00:00.000')
# (11056, 'Eastern Connection', '1998-04-28 00:00:00.000')
# (11057, 'North/South', '1998-04-29 00:00:00.000')
# (11058, 'Blauer See Delikatessen', '1998-04-29 00:00:00.000')
# (11059, 'Ricardo Adocicados', '1998-04-29 00:00:00.000')
# (11060, 'Franchi S.p.A.', '1998-04-30 00:00:00.000')
# (11061, 'Great Lakes Food Market', '1998-04-30 00:00:00.000')
# (11062, 'Reggiani Caseifici', '1998-04-30 00:00:00.000')
# (11063, 'Hungry Owl All-Night Grocers', '1998-04-30 00:00:00.000')
# (11064, 'Save-a-lot Markets', '1998-05-01 00:00:00.000')
# (11065, 'LILA-Supermercado', '1998-05-01 00:00:00.000')
# (11066, 'White Clover Markets', '1998-05-01 00:00:00.000')
# (11067, 'Drachenblut Delikatessen', '1998-05-04 00:00:00.000')
# (11068, 'Queen Cozinha', '1998-05-04 00:00:00.000')
# (11069, 'Tortuga Restaurante', '1998-05-04 00:00:00.000')
# (11070, 'Lehmanns Marktstand', '1998-05-05 00:00:00.000')
# (11071, 'LILA-Supermercado', '1998-05-05 00:00:00.000')
# (11072, 'Ernst Handel', '1998-05-05 00:00:00.000')
# (11073, 'Pericles Comidas clásicas', '1998-05-05 00:00:00.000')
# (11074, 'Simons bistro', '1998-05-06 00:00:00.000')
# (11075, 'Richter Supermarkt', '1998-05-06 00:00:00.000')
# (11076, "Bon app'", '1998-05-06 00:00:00.000')
# (11077, 'Rattlesnake Canyon Grocery', '1998-05-06 00:00:00.000')

# %%
run_query("SQL Inner Join", "SELECT ProductID, ProductName, CategoryName FROM Products INNER JOIN Categories ON Products.CategoryID = Categories.CategoryID;")
# Out:
#  SQL Inner Join
# SQL : SELECT ProductID, ProductName, CategoryName FROM Products INNER JOIN Categories ON Products.CategoryID = Categories.CategoryID;
# (1, 'Chai', 'Beverages')
# (2, 'Chang', 'Beverages')
# (3, 'Aniseed Syrup', 'Condiments')
# (4, "Chef Anton's Cajun Seasoning", 'Condiments')
# (5, "Chef Anton's Gumbo Mix", 'Condiments')
# (6, "Grandma's Boysenberry Spread", 'Condiments')
# (7, "Uncle Bob's Organic Dried Pears", 'Produce')
# (8, 'Northwoods Cranberry Sauce', 'Condiments')
# (9, 'Mishi Kobe Niku', 'Meat/Poultry')
# (10, 'Ikura', 'Seafood')
# (11, 'Queso Cabrales', 'Dairy Products')
# (12, 'Queso Manchego La Pastora', 'Dairy Products')
# (13, 'Konbu', 'Seafood')
# (14, 'Tofu', 'Produce')
# (15, 'Genen Shouyu', 'Condiments')
# (16, 'Pavlova', 'Confections')
# (17, 'Alice Mutton', 'Meat/Poultry')
# (18, 'Carnarvon Tigers', 'Seafood')
# (19, 'Teatime Chocolate Biscuits', 'Confections')
# (20, "Sir Rodney's Marmalade", 'Confections')
# (21, "Sir Rodney's Scones", 'Confections')
# (22, "Gustaf's Knäckebröd", 'Grains/Cereals')
# (23, 'Tunnbröd', 'Grains/Cereals')
# (24, 'Guaraná Fantástica', 'Beverages')
# (25, 'NuNuCa Nuß-Nougat-Creme', 'Confections')
# (26, 'Gumbär Gummibärchen', 'Confections')
# (27, 'Schoggi Schokolade', 'Confections')
# (28, 'Rössle Sauerkraut', 'Produce')
# (29, 'Thüringer Rostbratwurst', 'Meat/Poultry')
# (30, 'Nord-Ost Matjeshering', 'Seafood')
# (31, 'Gorgonzola Telino', 'Dairy Products')
# (32, 'Mascarpone Fabioli', 'Dairy Products')
# (33, 'Geitost', 'Dairy Products')
# (34, 'Sasquatch Ale', 'Beverages')
# (35, 'Steeleye Stout', 'Beverages')
# (36, 'Inlagd Sill', 'Seafood')
# (37, 'Gravad lax', 'Seafood')
# (38, 'Côte de Blaye', 'Beverages')
# (39, 'Chartreuse verte', 'Beverages')
# (40, 'Boston Crab Meat', 'Seafood')
# (41, "Jack's New England Clam Chowder", 'Seafood')
# (42, 'Singaporean Hokkien Fried Mee', 'Grains/Cereals')
# (43, 'Ipoh Coffee', 'Beverages')
# (44, 'Gula Malacca', 'Condiments')
# (45, 'Rogede sild', 'Seafood')
# (46, 'Spegesild', 'Seafood')
# (47, 'Zaanse koeken', 'Confections')
# (48, 'Chocolade', 'Confections')
# (49, 'Maxilaku', 'Confections')
# (50, 'Valkoinen suklaa', 'Confections')
# (51, 'Manjimup Dried Apples', 'Produce')
# (52, 'Filo Mix', 'Grains/Cereals')
# (53, 'Perth Pasties', 'Meat/Poultry')
# (54, 'Tourtière', 'Meat/Poultry')
# (55, 'Pâté chinois', 'Meat/Poultry')
# (56, 'Gnocchi di nonna Alice', 'Grains/Cereals')
# (57, 'Ravioli Angelo', 'Grains/Cereals')
# (58, 'Escargots de Bourgogne', 'Seafood')
# (59, 'Raclette Courdavault', 'Dairy Products')
# (60, 'Camembert Pierrot', 'Dairy Products')
# (61, "Sirop d'érable", 'Condiments')
# (62, 'Tarte au sucre', 'Confections')
# (63, 'Vegie-spread', 'Condiments')
# (64, 'Wimmers gute Semmelknödel', 'Grains/Cereals')
# (65, 'Louisiana Fiery Hot Pepper Sauce', 'Condiments')
# (66, 'Louisiana Hot Spiced Okra', 'Condiments')
# (67, 'Laughing Lumberjack Lager', 'Beverages')
# (68, 'Scottish Longbreads', 'Confections')
# (69, 'Gudbrandsdalsost', 'Dairy Products')
# (70, 'Outback Lager', 'Beverages')
# (71, 'Flotemysost', 'Dairy Products')
# (72, 'Mozzarella di Giovanni', 'Dairy Products')
# (73, 'Röd Kaviar', 'Seafood')
# (74, 'Longlife Tofu', 'Produce')
# (75, 'Rhönbräu Klosterbier', 'Beverages')
# (76, 'Lakkalikööri', 'Beverages')
# (77, 'Original Frankfurter grüne Soße', 'Condiments')

# %%
run_query("SQL Left Join", "SELECT Customers.CustomerName, Orders.OrderID FROM Customers LEFT JOIN Orders ON Customers.CustomerID = Orders.CustomerID ORDER BY Customers.CustomerName;")
# Out:
#  SQL Left Join
# SQL : SELECT Customers.CustomerName, Orders.OrderID FROM Customers LEFT JOIN Orders ON Customers.CustomerID = Orders.CustomerID ORDER BY Customers.CustomerName;
# ('Ana Trujillo Emparedados y helados', 10308)
# ('Ana Trujillo Emparedados y helados', 10625)
# ('Ana Trujillo Emparedados y helados', 10759)
# ('Ana Trujillo Emparedados y helados', 10926)
# ('Antonio Moreno Taquería', 10365)
# ('Antonio Moreno Taquería', 10507)
# ('Antonio Moreno Taquería', 10535)
# ('Antonio Moreno Taquería', 10573)
# ('Antonio Moreno Taquería', 10677)
# ('Antonio Moreno Taquería', 10682)
# ('Antonio Moreno Taquería', 10856)
# ('Around the Horn', 10355)
# ('Around the Horn', 10383)
# ('Around the Horn', 10453)
# ('Around the Horn', 10558)
# ('Around the Horn', 10707)
# ('Around the Horn', 10741)
# ('Around the Horn', 10743)
# ('Around the Horn', 10768)
# ('Around the Horn', 10793)
# ('Around the Horn', 10864)
# ('Around the Horn', 10920)
# ('Around the Horn', 10953)
# ('Around the Horn', 11016)
# ("B's Beverages", 10289)
# ("B's Beverages", 10471)
# ("B's Beverages", 10484)
# ("B's Beverages", 10538)
# ("B's Beverages", 10539)
# ("B's Beverages", 10578)
# ("B's Beverages", 10599)
# ("B's Beverages", 10943)
# ("B's Beverages", 10947)
# ("B's Beverages", 11023)
# ('Berglunds snabbköp', 10278)
# ('Berglunds snabbköp', 10280)
# ('Berglunds snabbköp', 10384)
# ('Berglunds snabbköp', 10444)
# ('Berglunds snabbköp', 10445)
# ('Berglunds snabbköp', 10524)
# ('Berglunds snabbköp', 10572)
# ('Berglunds snabbköp', 10626)
# ('Berglunds snabbköp', 10654)
# ('Berglunds snabbköp', 10672)
# ('Berglunds snabbköp', 10689)
# ('Berglunds snabbköp', 10733)
# ('Berglunds snabbköp', 10778)
# ('Berglunds snabbköp', 10837)
# ('Berglunds snabbköp', 10857)
# ('Berglunds snabbköp', 10866)
# ('Berglunds snabbköp', 10875)
# ('Berglunds snabbköp', 10924)
# ('Blauer See Delikatessen', 10501)
# ('Blauer See Delikatessen', 10509)
# ('Blauer See Delikatessen', 10582)
# ('Blauer See Delikatessen', 10614)
# ('Blauer See Delikatessen', 10853)
# ('Blauer See Delikatessen', 10956)
# ('Blauer See Delikatessen', 11058)
# ('Blondesddsl père et fils', 10265)
# ('Blondesddsl père et fils', 10297)
# ('Blondesddsl père et fils', 10360)
# ('Blondesddsl père et fils', 10436)
# ('Blondesddsl père et fils', 10449)
# ('Blondesddsl père et fils', 10559)
# ('Blondesddsl père et fils', 10566)
# ('Blondesddsl père et fils', 10584)
# ('Blondesddsl père et fils', 10628)
# ('Blondesddsl père et fils', 10679)
# ('Blondesddsl père et fils', 10826)
# ("Bon app'", 10331)
# ("Bon app'", 10340)
# ("Bon app'", 10362)
# ("Bon app'", 10470)
# ("Bon app'", 10511)
# ("Bon app'", 10525)
# ("Bon app'", 10663)
# ("Bon app'", 10715)
# ("Bon app'", 10730)
# ("Bon app'", 10732)
# ("Bon app'", 10755)
# ("Bon app'", 10827)
# ("Bon app'", 10871)
# ("Bon app'", 10876)
# ("Bon app'", 10932)
# ("Bon app'", 10940)
# ("Bon app'", 11076)
# ('Bottom-Dollar Markets', 10389)
# ('Bottom-Dollar Markets', 10410)
# ('Bottom-Dollar Markets', 10411)
# ('Bottom-Dollar Markets', 10431)
# ('Bottom-Dollar Markets', 10492)
# ('Bottom-Dollar Markets', 10742)
# ('Bottom-Dollar Markets', 10918)
# ('Bottom-Dollar Markets', 10944)
# ('Bottom-Dollar Markets', 10949)
# ('Bottom-Dollar Markets', 10975)
# ('Bottom-Dollar Markets', 10982)
# ('Bottom-Dollar Markets', 11027)
# ('Bottom-Dollar Markets', 11045)
# ('Bottom-Dollar Markets', 11048)
# ('Bólido Comidas preparadas', 10326)
# ('Bólido Comidas preparadas', 10801)
# ('Bólido Comidas preparadas', 10970)
# ('Cactus Comidas para llevar', 10521)
# ('Cactus Comidas para llevar', 10782)
# ('Cactus Comidas para llevar', 10819)
# ('Cactus Comidas para llevar', 10881)
# ('Cactus Comidas para llevar', 10937)
# ('Cactus Comidas para llevar', 11054)
# ('Cardinal', None)
# ('Cardinal', None)
# ('Cardinal', None)
# ('Centro comercial Moctezuma', 10259)
# ('Chop-suey Chinese', 10254)
# ('Chop-suey Chinese', 10370)
# ('Chop-suey Chinese', 10519)
# ('Chop-suey Chinese', 10731)
# ('Chop-suey Chinese', 10746)
# ('Chop-suey Chinese', 10966)
# ('Chop-suey Chinese', 11029)
# ('Chop-suey Chinese', 11041)
# ('Comércio Mineiro', 10290)
# ('Comércio Mineiro', 10466)
# ('Comércio Mineiro', 10494)
# ('Comércio Mineiro', 10969)
# ('Comércio Mineiro', 11042)
# ('Consolidated Holdings', 10435)
# ('Consolidated Holdings', 10462)
# ('Consolidated Holdings', 10848)
# ('Die Wandernde Kuh', 10301)
# ('Die Wandernde Kuh', 10312)
# ('Die Wandernde Kuh', 10348)
# ('Die Wandernde Kuh', 10356)
# ('Die Wandernde Kuh', 10513)
# ('Die Wandernde Kuh', 10632)
# ('Die Wandernde Kuh', 10640)
# ('Die Wandernde Kuh', 10651)
# ('Die Wandernde Kuh', 10668)
# ('Die Wandernde Kuh', 11046)
# ('Drachenblut Delikatessen', 10363)
# ('Drachenblut Delikatessen', 10391)
# ('Drachenblut Delikatessen', 10797)
# ('Drachenblut Delikatessen', 10825)
# ('Drachenblut Delikatessen', 11036)
# ('Drachenblut Delikatessen', 11067)
# ('Du monde entier', 10311)
# ('Du monde entier', 10609)
# ('Du monde entier', 10683)
# ('Du monde entier', 10890)
# ('Eastern Connection', 10364)
# ('Eastern Connection', 10400)
# ('Eastern Connection', 10532)
# ('Eastern Connection', 10726)
# ('Eastern Connection', 10987)
# ('Eastern Connection', 11024)
# ('Eastern Connection', 11047)
# ('Eastern Connection', 11056)
# ('Ernst Handel', 10258)
# ('Ernst Handel', 10263)
# ('Ernst Handel', 10351)
# ('Ernst Handel', 10368)
# ('Ernst Handel', 10382)
# ('Ernst Handel', 10390)
# ('Ernst Handel', 10402)
# ('Ernst Handel', 10403)
# ('Ernst Handel', 10430)
# ('Ernst Handel', 10442)
# ('Ernst Handel', 10514)
# ('Ernst Handel', 10571)
# ('Ernst Handel', 10595)
# ('Ernst Handel', 10633)
# ('Ernst Handel', 10667)
# ('Ernst Handel', 10698)
# ('Ernst Handel', 10764)
# ('Ernst Handel', 10771)
# ('Ernst Handel', 10773)
# ('Ernst Handel', 10776)
# ('Ernst Handel', 10795)
# ('Ernst Handel', 10836)
# ('Ernst Handel', 10854)
# ('Ernst Handel', 10895)
# ('Ernst Handel', 10968)
# ('Ernst Handel', 10979)
# ('Ernst Handel', 10990)
# ('Ernst Handel', 11008)
# ('Ernst Handel', 11017)
# ('Ernst Handel', 11072)
# ('FISSA Fabrica Inter. Salchichas S.A.', None)
# ('Familia Arquibaldo', 10347)
# ('Familia Arquibaldo', 10386)
# ('Familia Arquibaldo', 10414)
# ('Familia Arquibaldo', 10512)
# ('Familia Arquibaldo', 10581)
# ('Familia Arquibaldo', 10650)
# ('Familia Arquibaldo', 10725)
# ('Folies gourmandes', 10408)
# ('Folies gourmandes', 10480)
# ('Folies gourmandes', 10634)
# ('Folies gourmandes', 10763)
# ('Folies gourmandes', 10789)
# ('Folk och fä HB', 10264)
# ('Folk och fä HB', 10327)
# ('Folk och fä HB', 10378)
# ('Folk och fä HB', 10434)
# ('Folk och fä HB', 10460)
# ('Folk och fä HB', 10533)
# ('Folk och fä HB', 10561)
# ('Folk och fä HB', 10703)
# ('Folk och fä HB', 10762)
# ('Folk och fä HB', 10774)
# ('Folk och fä HB', 10824)
# ('Folk och fä HB', 10880)
# ('Folk och fä HB', 10902)
# ('Folk och fä HB', 10955)
# ('Folk och fä HB', 10977)
# ('Folk och fä HB', 10980)
# ('Folk och fä HB', 10993)
# ('Folk och fä HB', 11001)
# ('Folk och fä HB', 11050)
# ('France restauration', 10671)
# ('France restauration', 10860)
# ('France restauration', 10971)
# ('Franchi S.p.A.', 10422)
# ('Franchi S.p.A.', 10710)
# ('Franchi S.p.A.', 10753)
# ('Franchi S.p.A.', 10807)
# ('Franchi S.p.A.', 11026)
# ('Franchi S.p.A.', 11060)
# ('Frankenversand', 10267)
# ('Frankenversand', 10337)
# ('Frankenversand', 10342)
# ('Frankenversand', 10396)
# ('Frankenversand', 10488)
# ('Frankenversand', 10560)
# ('Frankenversand', 10623)
# ('Frankenversand', 10653)
# ('Frankenversand', 10670)
# ('Frankenversand', 10675)
# ('Frankenversand', 10717)
# ('Frankenversand', 10791)
# ('Frankenversand', 10859)
# ('Frankenversand', 10929)
# ('Frankenversand', 11012)
# ('Furia Bacalhau e Frutos do Mar', 10328)
# ('Furia Bacalhau e Frutos do Mar', 10352)
# ('Furia Bacalhau e Frutos do Mar', 10464)
# ('Furia Bacalhau e Frutos do Mar', 10491)
# ('Furia Bacalhau e Frutos do Mar', 10551)
# ('Furia Bacalhau e Frutos do Mar', 10604)
# ('Furia Bacalhau e Frutos do Mar', 10664)
# ('Furia Bacalhau e Frutos do Mar', 10963)
# ('GROSELLA-Restaurante', 10268)
# ('GROSELLA-Restaurante', 10785)
# ('Galería del gastrónomo', 10366)
# ('Galería del gastrónomo', 10426)
# ('Galería del gastrónomo', 10568)
# ('Galería del gastrónomo', 10887)
# ('Galería del gastrónomo', 10928)
# ('Godos Cocina Típica', 10303)
# ('Godos Cocina Típica', 10550)
# ('Godos Cocina Típica', 10629)
# ('Godos Cocina Típica', 10872)
# ('Godos Cocina Típica', 10874)
# ('Godos Cocina Típica', 10888)
# ('Godos Cocina Típica', 10911)
# ('Godos Cocina Típica', 10948)
# ('Godos Cocina Típica', 11009)
# ('Godos Cocina Típica', 11037)
# ('Gourmet Lanchonetes', 10423)
# ('Gourmet Lanchonetes', 10652)
# ('Gourmet Lanchonetes', 10685)
# ('Gourmet Lanchonetes', 10709)
# ('Gourmet Lanchonetes', 10734)
# ('Gourmet Lanchonetes', 10777)
# ('Gourmet Lanchonetes', 10790)
# ('Gourmet Lanchonetes', 10959)
# ('Gourmet Lanchonetes', 11049)
# ('Greasy Burger', None)
# ('Great Lakes Food Market', 10528)
# ('Great Lakes Food Market', 10589)
# ('Great Lakes Food Market', 10616)
# ('Great Lakes Food Market', 10617)
# ('Great Lakes Food Market', 10656)
# ('Great Lakes Food Market', 10681)
# ('Great Lakes Food Market', 10816)
# ('Great Lakes Food Market', 10936)
# ('Great Lakes Food Market', 11006)
# ('Great Lakes Food Market', 11040)
# ('Great Lakes Food Market', 11061)
# ('HILARION-Abastos', 10257)
# ('HILARION-Abastos', 10395)
# ('HILARION-Abastos', 10476)
# ('HILARION-Abastos', 10486)
# ('HILARION-Abastos', 10490)
# ('HILARION-Abastos', 10498)
# ('HILARION-Abastos', 10552)
# ('HILARION-Abastos', 10601)
# ('HILARION-Abastos', 10613)
# ('HILARION-Abastos', 10641)
# ('HILARION-Abastos', 10705)
# ('HILARION-Abastos', 10796)
# ('HILARION-Abastos', 10863)
# ('HILARION-Abastos', 10901)
# ('HILARION-Abastos', 10957)
# ('HILARION-Abastos', 10960)
# ('HILARION-Abastos', 10976)
# ('HILARION-Abastos', 11055)
# ('Hanari Carnes', 10250)
# ('Hanari Carnes', 10253)
# ('Hanari Carnes', 10541)
# ('Hanari Carnes', 10645)
# ('Hanari Carnes', 10690)
# ('Hanari Carnes', 10770)
# ('Hanari Carnes', 10783)
# ('Hanari Carnes', 10886)
# ('Hanari Carnes', 10903)
# ('Hanari Carnes', 10922)
# ('Hanari Carnes', 10925)
# ('Hanari Carnes', 10981)
# ('Hanari Carnes', 11022)
# ('Hanari Carnes', 11052)
# ('Hungry Coyote Import Store', 10375)
# ('Hungry Coyote Import Store', 10394)
# ('Hungry Coyote Import Store', 10415)
# ('Hungry Coyote Import Store', 10600)
# ('Hungry Coyote Import Store', 10660)
# ('Hungry Owl All-Night Grocers', 10298)
# ('Hungry Owl All-Night Grocers', 10309)
# ('Hungry Owl All-Night Grocers', 10335)
# ('Hungry Owl All-Night Grocers', 10373)
# ('Hungry Owl All-Night Grocers', 10380)
# ('Hungry Owl All-Night Grocers', 10429)
# ('Hungry Owl All-Night Grocers', 10503)
# ('Hungry Owl All-Night Grocers', 10516)
# ('Hungry Owl All-Night Grocers', 10567)
# ('Hungry Owl All-Night Grocers', 10646)
# ('Hungry Owl All-Night Grocers', 10661)
# ('Hungry Owl All-Night Grocers', 10687)
# ('Hungry Owl All-Night Grocers', 10701)
# ('Hungry Owl All-Night Grocers', 10712)
# ('Hungry Owl All-Night Grocers', 10736)
# ('Hungry Owl All-Night Grocers', 10897)
# ('Hungry Owl All-Night Grocers', 10912)
# ('Hungry Owl All-Night Grocers', 10985)
# ('Hungry Owl All-Night Grocers', 11063)
# ('Island Trading', 10315)
# ('Island Trading', 10318)
# ('Island Trading', 10321)
# ('Island Trading', 10473)
# ('Island Trading', 10621)
# ('Island Trading', 10674)
# ('Island Trading', 10749)
# ('Island Trading', 10798)
# ('Island Trading', 10829)
# ('Island Trading', 10933)
# ('Königlich Essen', 10323)
# ('Königlich Essen', 10325)
# ('Königlich Essen', 10456)
# ('Königlich Essen', 10457)
# ('Königlich Essen', 10468)
# ('Königlich Essen', 10506)
# ('Königlich Essen', 10542)
# ('Königlich Essen', 10630)
# ('Königlich Essen', 10718)
# ('Königlich Essen', 10799)
# ('Königlich Essen', 10817)
# ('Königlich Essen', 10849)
# ('Königlich Essen', 10893)
# ('Königlich Essen', 11028)
# ('LILA-Supermercado', 10283)
# ('LILA-Supermercado', 10296)
# ('LILA-Supermercado', 10330)
# ('LILA-Supermercado', 10357)
# ('LILA-Supermercado', 10381)
# ('LILA-Supermercado', 10461)
# ('LILA-Supermercado', 10499)
# ('LILA-Supermercado', 10543)
# ('LILA-Supermercado', 10780)
# ('LILA-Supermercado', 10823)
# ('LILA-Supermercado', 10899)
# ('LILA-Supermercado', 10997)
# ('LILA-Supermercado', 11065)
# ('LILA-Supermercado', 11071)
# ('LINO-Delicateses', 10405)
# ('LINO-Delicateses', 10485)
# ('LINO-Delicateses', 10638)
# ('LINO-Delicateses', 10697)
# ('LINO-Delicateses', 10729)
# ('LINO-Delicateses', 10811)
# ('LINO-Delicateses', 10838)
# ('LINO-Delicateses', 10840)
# ('LINO-Delicateses', 10919)
# ('LINO-Delicateses', 10954)
# ('LINO-Delicateses', 11014)
# ('LINO-Delicateses', 11039)
# ("La corne d'abondance", 10858)
# ("La corne d'abondance", 10927)
# ("La corne d'abondance", 10972)
# ("La corne d'abondance", 10973)
# ("La maison d'Asie", 10350)
# ("La maison d'Asie", 10358)
# ("La maison d'Asie", 10371)
# ("La maison d'Asie", 10413)
# ("La maison d'Asie", 10425)
# ("La maison d'Asie", 10454)
# ("La maison d'Asie", 10493)
# ("La maison d'Asie", 10500)
# ("La maison d'Asie", 10610)
# ("La maison d'Asie", 10631)
# ("La maison d'Asie", 10787)
# ("La maison d'Asie", 10832)
# ("La maison d'Asie", 10923)
# ("La maison d'Asie", 11051)
# ('Laughing Bacchus Wine Cellars', 10495)
# ('Laughing Bacchus Wine Cellars', 10620)
# ('Laughing Bacchus Wine Cellars', 10810)
# ('Lazy K Kountry Store', 10482)
# ('Lazy K Kountry Store', 10545)
# ('Lehmanns Marktstand', 10279)
# ('Lehmanns Marktstand', 10284)
# ('Lehmanns Marktstand', 10343)
# ('Lehmanns Marktstand', 10497)
# ('Lehmanns Marktstand', 10522)
# ('Lehmanns Marktstand', 10534)
# ('Lehmanns Marktstand', 10536)
# ('Lehmanns Marktstand', 10557)
# ('Lehmanns Marktstand', 10592)
# ('Lehmanns Marktstand', 10593)
# ('Lehmanns Marktstand', 10772)
# ('Lehmanns Marktstand', 10862)
# ('Lehmanns Marktstand', 10891)
# ('Lehmanns Marktstand', 10934)
# ('Lehmanns Marktstand', 11070)
# ("Let's Stop N Shop", 10579)
# ("Let's Stop N Shop", 10719)
# ("Let's Stop N Shop", 10735)
# ("Let's Stop N Shop", 10884)
# ('Lonesome Pine Restaurant', 10307)
# ('Lonesome Pine Restaurant', 10317)
# ('Lonesome Pine Restaurant', 10544)
# ('Lonesome Pine Restaurant', 10662)
# ('Lonesome Pine Restaurant', 10665)
# ('Lonesome Pine Restaurant', 10867)
# ('Lonesome Pine Restaurant', 10883)
# ('Lonesome Pine Restaurant', 11018)
# ('Magazzini Alimentari Riuniti', 10275)
# ('Magazzini Alimentari Riuniti', 10300)
# ('Magazzini Alimentari Riuniti', 10404)
# ('Magazzini Alimentari Riuniti', 10467)
# ('Magazzini Alimentari Riuniti', 10635)
# ('Magazzini Alimentari Riuniti', 10754)
# ('Magazzini Alimentari Riuniti', 10784)
# ('Magazzini Alimentari Riuniti', 10818)
# ('Magazzini Alimentari Riuniti', 10939)
# ('Magazzini Alimentari Riuniti', 10950)
# ('Maison Dewey', 10529)
# ('Maison Dewey', 10649)
# ('Maison Dewey', 10760)
# ('Maison Dewey', 10892)
# ('Maison Dewey', 10896)
# ('Maison Dewey', 10978)
# ('Maison Dewey', 11004)
# ('Morgenstern Gesundkost', 10277)
# ('Morgenstern Gesundkost', 10575)
# ('Morgenstern Gesundkost', 10699)
# ('Morgenstern Gesundkost', 10779)
# ('Morgenstern Gesundkost', 10945)
# ('Mère Paillarde', 10332)
# ('Mère Paillarde', 10339)
# ('Mère Paillarde', 10376)
# ('Mère Paillarde', 10424)
# ('Mère Paillarde', 10439)
# ('Mère Paillarde', 10505)
# ('Mère Paillarde', 10565)
# ('Mère Paillarde', 10570)
# ('Mère Paillarde', 10590)
# ('Mère Paillarde', 10605)
# ('Mère Paillarde', 10618)
# ('Mère Paillarde', 10619)
# ('Mère Paillarde', 10724)
# ('North/South', 10517)
# ('North/South', 10752)
# ('North/South', 11057)
# ('Océano Atlántico Ltda.', 10409)
# ('Océano Atlántico Ltda.', 10531)
# ('Océano Atlántico Ltda.', 10898)
# ('Océano Atlántico Ltda.', 10958)
# ('Océano Atlántico Ltda.', 10986)
# ('Old World Delicatessen', 10305)
# ('Old World Delicatessen', 10338)
# ('Old World Delicatessen', 10441)
# ('Old World Delicatessen', 10594)
# ('Old World Delicatessen', 10680)
# ('Old World Delicatessen', 10706)
# ('Old World Delicatessen', 10808)
# ('Old World Delicatessen', 10855)
# ('Old World Delicatessen', 10965)
# ('Old World Delicatessen', 11034)
# ('Ottilies Käseladen', 10260)
# ('Ottilies Käseladen', 10407)
# ('Ottilies Käseladen', 10508)
# ('Ottilies Käseladen', 10554)
# ('Ottilies Käseladen', 10580)
# ('Ottilies Käseladen', 10684)
# ('Ottilies Käseladen', 10766)
# ('Ottilies Käseladen', 10833)
# ('Ottilies Käseladen', 10999)
# ('Ottilies Käseladen', 11020)
# ('Paris spécialités', None)
# ('Pericles Comidas clásicas', 10322)
# ('Pericles Comidas clásicas', 10354)
# ('Pericles Comidas clásicas', 10474)
# ('Pericles Comidas clásicas', 10502)
# ('Pericles Comidas clásicas', 10995)
# ('Pericles Comidas clásicas', 11073)
# ('Piccolo und mehr', 10353)
# ('Piccolo und mehr', 10392)
# ('Piccolo und mehr', 10427)
# ('Piccolo und mehr', 10489)
# ('Piccolo und mehr', 10530)
# ('Piccolo und mehr', 10597)
# ('Piccolo und mehr', 10686)
# ('Piccolo und mehr', 10747)
# ('Piccolo und mehr', 10844)
# ('Piccolo und mehr', 11053)
# ('Princesa Isabel Vinhos', 10336)
# ('Princesa Isabel Vinhos', 10397)
# ('Princesa Isabel Vinhos', 10433)
# ('Princesa Isabel Vinhos', 10477)
# ('Princesa Isabel Vinhos', 11007)
# ('QUICK-Stop', 10273)
# ('QUICK-Stop', 10285)
# ('QUICK-Stop', 10286)
# ('QUICK-Stop', 10313)
# ('QUICK-Stop', 10345)
# ('QUICK-Stop', 10361)
# ('QUICK-Stop', 10418)
# ('QUICK-Stop', 10451)
# ('QUICK-Stop', 10515)
# ('QUICK-Stop', 10527)
# ('QUICK-Stop', 10540)
# ('QUICK-Stop', 10549)
# ('QUICK-Stop', 10588)
# ('QUICK-Stop', 10658)
# ('QUICK-Stop', 10691)
# ('QUICK-Stop', 10694)
# ('QUICK-Stop', 10721)
# ('QUICK-Stop', 10745)
# ('QUICK-Stop', 10765)
# ('QUICK-Stop', 10788)
# ('QUICK-Stop', 10845)
# ('QUICK-Stop', 10865)
# ('QUICK-Stop', 10878)
# ('QUICK-Stop', 10938)
# ('QUICK-Stop', 10962)
# ('QUICK-Stop', 10991)
# ('QUICK-Stop', 10996)
# ('QUICK-Stop', 11021)
# ('Que Delícia', 10261)
# ('Que Delícia', 10291)
# ('Que Delícia', 10379)
# ('Que Delícia', 10421)
# ('Que Delícia', 10587)
# ('Que Delícia', 10647)
# ('Que Delícia', 10720)
# ('Que Delícia', 10794)
# ('Que Delícia', 10989)
# ('Queen Cozinha', 10372)
# ('Queen Cozinha', 10406)
# ('Queen Cozinha', 10487)
# ('Queen Cozinha', 10637)
# ('Queen Cozinha', 10659)
# ('Queen Cozinha', 10704)
# ('Queen Cozinha', 10728)
# ('Queen Cozinha', 10786)
# ('Queen Cozinha', 10868)
# ('Queen Cozinha', 10913)
# ('Queen Cozinha', 10914)
# ('Queen Cozinha', 10961)
# ('Queen Cozinha', 11068)
# ('Rancho grande', 10448)
# ('Rancho grande', 10716)
# ('Rancho grande', 10828)
# ('Rancho grande', 10916)
# ('Rancho grande', 11019)
# ('Rattlesnake Canyon Grocery', 10262)
# ('Rattlesnake Canyon Grocery', 10272)
# ('Rattlesnake Canyon Grocery', 10294)
# ('Rattlesnake Canyon Grocery', 10314)
# ('Rattlesnake Canyon Grocery', 10316)
# ('Rattlesnake Canyon Grocery', 10346)
# ('Rattlesnake Canyon Grocery', 10401)
# ('Rattlesnake Canyon Grocery', 10479)
# ('Rattlesnake Canyon Grocery', 10564)
# ('Rattlesnake Canyon Grocery', 10569)
# ('Rattlesnake Canyon Grocery', 10598)
# ('Rattlesnake Canyon Grocery', 10761)
# ('Rattlesnake Canyon Grocery', 10820)
# ('Rattlesnake Canyon Grocery', 10852)
# ('Rattlesnake Canyon Grocery', 10889)
# ('Rattlesnake Canyon Grocery', 10988)
# ('Rattlesnake Canyon Grocery', 11000)
# ('Rattlesnake Canyon Grocery', 11077)
# ('Reggiani Caseifici', 10288)
# ('Reggiani Caseifici', 10428)
# ('Reggiani Caseifici', 10443)
# ('Reggiani Caseifici', 10562)
# ('Reggiani Caseifici', 10586)
# ('Reggiani Caseifici', 10655)
# ('Reggiani Caseifici', 10727)
# ('Reggiani Caseifici', 10812)
# ('Reggiani Caseifici', 10908)
# ('Reggiani Caseifici', 10942)
# ('Reggiani Caseifici', 11010)
# ('Reggiani Caseifici', 11062)
# ('Ricardo Adocicados', 10287)
# ('Ricardo Adocicados', 10299)
# ('Ricardo Adocicados', 10447)
# ('Ricardo Adocicados', 10481)
# ('Ricardo Adocicados', 10563)
# ('Ricardo Adocicados', 10622)
# ('Ricardo Adocicados', 10648)
# ('Ricardo Adocicados', 10813)
# ('Ricardo Adocicados', 10851)
# ('Ricardo Adocicados', 10877)
# ('Ricardo Adocicados', 11059)
# ('Richter Supermarkt', 10255)
# ('Richter Supermarkt', 10419)
# ('Richter Supermarkt', 10537)
# ('Richter Supermarkt', 10666)
# ('Richter Supermarkt', 10751)
# ('Richter Supermarkt', 10758)
# ('Richter Supermarkt', 10931)
# ('Richter Supermarkt', 10951)
# ('Richter Supermarkt', 11033)
# ('Richter Supermarkt', 11075)
# ('Romero y tomillo', 10281)
# ('Romero y tomillo', 10282)
# ('Romero y tomillo', 10306)
# ('Romero y tomillo', 10917)
# ('Romero y tomillo', 11013)
# ('Santé Gourmet', 10387)
# ('Santé Gourmet', 10520)
# ('Santé Gourmet', 10639)
# ('Santé Gourmet', 10831)
# ('Santé Gourmet', 10909)
# ('Santé Gourmet', 11015)
# ('Save-a-lot Markets', 10324)
# ('Save-a-lot Markets', 10393)
# ('Save-a-lot Markets', 10398)
# ('Save-a-lot Markets', 10440)
# ('Save-a-lot Markets', 10452)
# ('Save-a-lot Markets', 10510)
# ('Save-a-lot Markets', 10555)
# ('Save-a-lot Markets', 10603)
# ('Save-a-lot Markets', 10607)
# ('Save-a-lot Markets', 10612)
# ('Save-a-lot Markets', 10627)
# ('Save-a-lot Markets', 10657)
# ('Save-a-lot Markets', 10678)
# ('Save-a-lot Markets', 10700)
# ('Save-a-lot Markets', 10711)
# ('Save-a-lot Markets', 10713)
# ('Save-a-lot Markets', 10714)
# ('Save-a-lot Markets', 10722)
# ('Save-a-lot Markets', 10748)
# ('Save-a-lot Markets', 10757)
# ('Save-a-lot Markets', 10815)
# ('Save-a-lot Markets', 10847)
# ('Save-a-lot Markets', 10882)
# ('Save-a-lot Markets', 10894)
# ('Save-a-lot Markets', 10941)
# ('Save-a-lot Markets', 10983)
# ('Save-a-lot Markets', 10984)
# ('Save-a-lot Markets', 11002)
# ('Save-a-lot Markets', 11030)
# ('Save-a-lot Markets', 11031)
# ('Save-a-lot Markets', 11064)
# ('Seven Seas Imports', 10359)
# ('Seven Seas Imports', 10377)
# ('Seven Seas Imports', 10388)
# ('Seven Seas Imports', 10472)
# ('Seven Seas Imports', 10523)
# ('Seven Seas Imports', 10547)
# ('Seven Seas Imports', 10800)
# ('Seven Seas Imports', 10804)
# ('Seven Seas Imports', 10869)
# ('Simons bistro', 10341)
# ('Simons bistro', 10417)
# ('Simons bistro', 10556)
# ('Simons bistro', 10642)
# ('Simons bistro', 10669)
# ('Simons bistro', 10802)
# ('Simons bistro', 11074)
# ('Split Rail Beer & Ale', 10271)
# ('Split Rail Beer & Ale', 10329)
# ('Split Rail Beer & Ale', 10349)
# ('Split Rail Beer & Ale', 10369)
# ('Split Rail Beer & Ale', 10385)
# ('Split Rail Beer & Ale', 10432)
# ('Split Rail Beer & Ale', 10756)
# ('Split Rail Beer & Ale', 10821)
# ('Split Rail Beer & Ale', 10974)
# ('Spécialités du monde', 10738)
# ('Spécialités du monde', 10907)
# ('Spécialités du monde', 10964)
# ('Spécialités du monde', 11043)
# ('Suprêmes délices', 10252)
# ('Suprêmes délices', 10302)
# ('Suprêmes délices', 10458)
# ('Suprêmes délices', 10463)
# ('Suprêmes délices', 10475)
# ('Suprêmes délices', 10767)
# ('Suprêmes délices', 10841)
# ('Suprêmes délices', 10846)
# ('Suprêmes délices', 10885)
# ('Suprêmes délices', 10930)
# ('Suprêmes délices', 11035)
# ('Suprêmes délices', 11038)
# ('Tasty Tee', None)
# ('The Big Cheese', 10310)
# ('The Big Cheese', 10708)
# ('The Big Cheese', 10805)
# ('The Big Cheese', 10992)
# ('The Cracker Box', 10624)
# ('The Cracker Box', 10775)
# ('The Cracker Box', 11003)
# ('Toms Spezialitäten', 10249)
# ('Toms Spezialitäten', 10438)
# ('Toms Spezialitäten', 10446)
# ('Toms Spezialitäten', 10548)
# ('Toms Spezialitäten', 10608)
# ('Toms Spezialitäten', 10967)
# ('Tortuga Restaurante', 10276)
# ('Tortuga Restaurante', 10293)
# ('Tortuga Restaurante', 10304)
# ('Tortuga Restaurante', 10319)
# ('Tortuga Restaurante', 10518)
# ('Tortuga Restaurante', 10576)
# ('Tortuga Restaurante', 10676)
# ('Tortuga Restaurante', 10842)
# ('Tortuga Restaurante', 10915)
# ('Tortuga Restaurante', 11069)
# ('Tradição Hipermercados', 10292)
# ('Tradição Hipermercados', 10496)
# ('Tradição Hipermercados', 10606)
# ('Tradição Hipermercados', 10830)
# ('Tradição Hipermercados', 10834)
# ('Tradição Hipermercados', 10839)
# ("Trail's Head Gourmet Provisioners", 10574)
# ("Trail's Head Gourmet Provisioners", 10577)
# ("Trail's Head Gourmet Provisioners", 10822)
# ('Vaffeljernet', 10367)
# ('Vaffeljernet', 10399)
# ('Vaffeljernet', 10465)
# ('Vaffeljernet', 10591)
# ('Vaffeljernet', 10602)
# ('Vaffeljernet', 10688)
# ('Vaffeljernet', 10744)
# ('Vaffeljernet', 10769)
# ('Vaffeljernet', 10921)
# ('Vaffeljernet', 10946)
# ('Vaffeljernet', 10994)
# ('Victuailles en stock', 10251)
# ('Victuailles en stock', 10334)
# ('Victuailles en stock', 10450)
# ('Victuailles en stock', 10459)
# ('Victuailles en stock', 10478)
# ('Victuailles en stock', 10546)
# ('Victuailles en stock', 10806)
# ('Victuailles en stock', 10814)
# ('Victuailles en stock', 10843)
# ('Victuailles en stock', 10850)
# ('Vins et alcools Chevalier', 10248)
# ('Vins et alcools Chevalier', 10274)
# ('Vins et alcools Chevalier', 10295)
# ('Vins et alcools Chevalier', 10737)
# ('Vins et alcools Chevalier', 10739)
# ('Wartian Herkku', 10266)
# ('Wartian Herkku', 10270)
# ('Wartian Herkku', 10320)
# ('Wartian Herkku', 10333)
# ('Wartian Herkku', 10412)
# ('Wartian Herkku', 10416)
# ('Wartian Herkku', 10437)
# ('Wartian Herkku', 10455)
# ('Wartian Herkku', 10526)
# ('Wartian Herkku', 10553)
# ('Wartian Herkku', 10583)
# ('Wartian Herkku', 10636)
# ('Wartian Herkku', 10750)
# ('Wartian Herkku', 10781)
# ('Wartian Herkku', 11025)
# ('Wellington Importadora', 10256)
# ('Wellington Importadora', 10420)
# ('Wellington Importadora', 10585)
# ('Wellington Importadora', 10644)
# ('Wellington Importadora', 10803)
# ('Wellington Importadora', 10809)
# ('Wellington Importadora', 10900)
# ('Wellington Importadora', 10905)
# ('Wellington Importadora', 10935)
# ('White Clover Markets', 10269)
# ('White Clover Markets', 10344)
# ('White Clover Markets', 10469)
# ('White Clover Markets', 10483)
# ('White Clover Markets', 10504)
# ('White Clover Markets', 10596)
# ('White Clover Markets', 10693)
# ('White Clover Markets', 10696)
# ('White Clover Markets', 10723)
# ('White Clover Markets', 10740)
# ('White Clover Markets', 10861)
# ('White Clover Markets', 10904)
# ('White Clover Markets', 11032)
# ('White Clover Markets', 11066)
# ('Wilman Kala', 10615)
# ('Wilman Kala', 10673)
# ('Wilman Kala', 10695)
# ('Wilman Kala', 10873)
# ('Wilman Kala', 10879)
# ('Wilman Kala', 10910)
# ('Wilman Kala', 11005)
# ('Wolski  Zajazd', 10374)
# ('Wolski  Zajazd', 10611)
# ('Wolski  Zajazd', 10792)
# ('Wolski  Zajazd', 10870)
# ('Wolski  Zajazd', 10906)
# ('Wolski  Zajazd', 10998)
# ('Wolski  Zajazd', 11044)

# %%
run_query("SQL Right Join", "SELECT Orders.OrderID, Employees.LastName, Employees.FirstName FROM Orders RIGHT JOIN Employees ON Orders.EmployeeID = Employees.EmployeeID ORDER BY Orders.OrderID;")
# Out:
#  SQL Right Join
# SQL : SELECT Orders.OrderID, Employees.LastName, Employees.FirstName FROM Orders RIGHT JOIN Employees ON Orders.EmployeeID = Employees.EmployeeID ORDER BY Orders.OrderID;
# (10248, 'Buchanan', 'Steven')
# (10249, 'Suyama', 'Michael')
# (10250, 'Peacock', 'Margaret')
# (10251, 'Leverling', 'Janet')
# (10252, 'Peacock', 'Margaret')
# (10253, 'Leverling', 'Janet')
# (10254, 'Buchanan', 'Steven')
# (10255, 'Dodsworth', 'Anne')
# (10256, 'Leverling', 'Janet')
# (10257, 'Peacock', 'Margaret')
# (10258, 'Davolio', 'Nancy')
# (10259, 'Peacock', 'Margaret')
# (10260, 'Peacock', 'Margaret')
# (10261, 'Peacock', 'Margaret')
# (10262, 'Callahan', 'Laura')
# (10263, 'Dodsworth', 'Anne')
# (10264, 'Suyama', 'Michael')
# (10265, 'Fuller', 'Andrew')
# (10266, 'Leverling', 'Janet')
# (10267, 'Peacock', 'Margaret')
# (10268, 'Callahan', 'Laura')
# (10269, 'Buchanan', 'Steven')
# (10270, 'Davolio', 'Nancy')
# (10271, 'Suyama', 'Michael')
# (10272, 'Suyama', 'Michael')
# (10273, 'Leverling', 'Janet')
# (10274, 'Suyama', 'Michael')
# (10275, 'Davolio', 'Nancy')
# (10276, 'Callahan', 'Laura')
# (10277, 'Fuller', 'Andrew')
# (10278, 'Callahan', 'Laura')
# (10279, 'Callahan', 'Laura')
# (10280, 'Fuller', 'Andrew')
# (10281, 'Peacock', 'Margaret')
# (10282, 'Peacock', 'Margaret')
# (10283, 'Leverling', 'Janet')
# (10284, 'Peacock', 'Margaret')
# (10285, 'Davolio', 'Nancy')
# (10286, 'Callahan', 'Laura')
# (10287, 'Callahan', 'Laura')
# (10288, 'Peacock', 'Margaret')
# (10289, 'King', 'Robert')
# (10290, 'Callahan', 'Laura')
# (10291, 'Suyama', 'Michael')
# (10292, 'Davolio', 'Nancy')
# (10293, 'Davolio', 'Nancy')
# (10294, 'Peacock', 'Margaret')
# (10295, 'Fuller', 'Andrew')
# (10296, 'Suyama', 'Michael')
# (10297, 'Buchanan', 'Steven')
# (10298, 'Suyama', 'Michael')
# (10299, 'Peacock', 'Margaret')
# (10300, 'Fuller', 'Andrew')
# (10301, 'Callahan', 'Laura')
# (10302, 'Peacock', 'Margaret')
# (10303, 'King', 'Robert')
# (10304, 'Davolio', 'Nancy')
# (10305, 'Callahan', 'Laura')
# (10306, 'Davolio', 'Nancy')
# (10307, 'Fuller', 'Andrew')
# (10308, 'King', 'Robert')
# (10309, 'Leverling', 'Janet')
# (10310, 'Callahan', 'Laura')
# (10311, 'Davolio', 'Nancy')
# (10312, 'Fuller', 'Andrew')
# (10313, 'Fuller', 'Andrew')
# (10314, 'Davolio', 'Nancy')
# (10315, 'Peacock', 'Margaret')
# (10316, 'Davolio', 'Nancy')
# (10317, 'Suyama', 'Michael')
# (10318, 'Callahan', 'Laura')
# (10319, 'King', 'Robert')
# (10320, 'Buchanan', 'Steven')
# (10321, 'Leverling', 'Janet')
# (10322, 'King', 'Robert')
# (10323, 'Peacock', 'Margaret')
# (10324, 'Dodsworth', 'Anne')
# (10325, 'Davolio', 'Nancy')
# (10326, 'Peacock', 'Margaret')
# (10327, 'Fuller', 'Andrew')
# (10328, 'Peacock', 'Margaret')
# (10329, 'Peacock', 'Margaret')
# (10330, 'Leverling', 'Janet')
# (10331, 'Dodsworth', 'Anne')
# (10332, 'Leverling', 'Janet')
# (10333, 'Buchanan', 'Steven')
# (10334, 'Callahan', 'Laura')
# (10335, 'King', 'Robert')
# (10336, 'King', 'Robert')
# (10337, 'Peacock', 'Margaret')
# (10338, 'Peacock', 'Margaret')
# (10339, 'Fuller', 'Andrew')
# (10340, 'Davolio', 'Nancy')
# (10341, 'King', 'Robert')
# (10342, 'Peacock', 'Margaret')
# (10343, 'Peacock', 'Margaret')
# (10344, 'Peacock', 'Margaret')
# (10345, 'Fuller', 'Andrew')
# (10346, 'Leverling', 'Janet')
# (10347, 'Peacock', 'Margaret')
# (10348, 'Peacock', 'Margaret')
# (10349, 'King', 'Robert')
# (10350, 'Suyama', 'Michael')
# (10351, 'Davolio', 'Nancy')
# (10352, 'Leverling', 'Janet')
# (10353, 'King', 'Robert')
# (10354, 'Callahan', 'Laura')
# (10355, 'Suyama', 'Michael')
# (10356, 'Suyama', 'Michael')
# (10357, 'Davolio', 'Nancy')
# (10358, 'Buchanan', 'Steven')
# (10359, 'Buchanan', 'Steven')
# (10360, 'Peacock', 'Margaret')
# (10361, 'Davolio', 'Nancy')
# (10362, 'Leverling', 'Janet')
# (10363, 'Peacock', 'Margaret')
# (10364, 'Davolio', 'Nancy')
# (10365, 'Leverling', 'Janet')
# (10366, 'Callahan', 'Laura')
# (10367, 'King', 'Robert')
# (10368, 'Fuller', 'Andrew')
# (10369, 'Callahan', 'Laura')
# (10370, 'Suyama', 'Michael')
# (10371, 'Davolio', 'Nancy')
# (10372, 'Buchanan', 'Steven')
# (10373, 'Peacock', 'Margaret')
# (10374, 'Davolio', 'Nancy')
# (10375, 'Leverling', 'Janet')
# (10376, 'Davolio', 'Nancy')
# (10377, 'Davolio', 'Nancy')
# (10378, 'Buchanan', 'Steven')
# (10379, 'Fuller', 'Andrew')
# (10380, 'Callahan', 'Laura')
# (10381, 'Leverling', 'Janet')
# (10382, 'Peacock', 'Margaret')
# (10383, 'Callahan', 'Laura')
# (10384, 'Leverling', 'Janet')
# (10385, 'Davolio', 'Nancy')
# (10386, 'Dodsworth', 'Anne')
# (10387, 'Davolio', 'Nancy')
# (10388, 'Fuller', 'Andrew')
# (10389, 'Peacock', 'Margaret')
# (10390, 'Suyama', 'Michael')
# (10391, 'Leverling', 'Janet')
# (10392, 'Fuller', 'Andrew')
# (10393, 'Davolio', 'Nancy')
# (10394, 'Davolio', 'Nancy')
# (10395, 'Suyama', 'Michael')
# (10396, 'Davolio', 'Nancy')
# (10397, 'Buchanan', 'Steven')
# (10398, 'Fuller', 'Andrew')
# (10399, 'Callahan', 'Laura')
# (10400, 'Davolio', 'Nancy')
# (10401, 'Davolio', 'Nancy')
# (10402, 'Callahan', 'Laura')
# (10403, 'Peacock', 'Margaret')
# (10404, 'Fuller', 'Andrew')
# (10405, 'Davolio', 'Nancy')
# (10406, 'King', 'Robert')
# (10407, 'Fuller', 'Andrew')
# (10408, 'Callahan', 'Laura')
# (10409, 'Leverling', 'Janet')
# (10410, 'Leverling', 'Janet')
# (10411, 'Dodsworth', 'Anne')
# (10412, 'Callahan', 'Laura')
# (10413, 'Leverling', 'Janet')
# (10414, 'Fuller', 'Andrew')
# (10415, 'Leverling', 'Janet')
# (10416, 'Callahan', 'Laura')
# (10417, 'Peacock', 'Margaret')
# (10418, 'Peacock', 'Margaret')
# (10419, 'Peacock', 'Margaret')
# (10420, 'Leverling', 'Janet')
# (10421, 'Callahan', 'Laura')
# (10422, 'Fuller', 'Andrew')
# (10423, 'Suyama', 'Michael')
# (10424, 'King', 'Robert')
# (10425, 'Suyama', 'Michael')
# (10426, 'Peacock', 'Margaret')
# (10427, 'Peacock', 'Margaret')
# (10428, 'King', 'Robert')
# (10429, 'Leverling', 'Janet')
# (10430, 'Peacock', 'Margaret')
# (10431, 'Peacock', 'Margaret')
# (10432, 'Leverling', 'Janet')
# (10433, 'Leverling', 'Janet')
# (10434, 'Leverling', 'Janet')
# (10435, 'Callahan', 'Laura')
# (10436, 'Leverling', 'Janet')
# (10437, 'Callahan', 'Laura')
# (10438, 'Leverling', 'Janet')
# (10439, 'Suyama', 'Michael')
# (10440, 'Peacock', 'Margaret')
# (10441, 'Leverling', 'Janet')
# (10442, 'Leverling', 'Janet')
# (10443, 'Callahan', 'Laura')
# (10444, 'Leverling', 'Janet')
# (10445, 'Leverling', 'Janet')
# (10446, 'Suyama', 'Michael')
# (10447, 'Peacock', 'Margaret')
# (10448, 'Peacock', 'Margaret')
# (10449, 'Leverling', 'Janet')
# (10450, 'Callahan', 'Laura')
# (10451, 'Peacock', 'Margaret')
# (10452, 'Callahan', 'Laura')
# (10453, 'Davolio', 'Nancy')
# (10454, 'Peacock', 'Margaret')
# (10455, 'Callahan', 'Laura')
# (10456, 'Callahan', 'Laura')
# (10457, 'Fuller', 'Andrew')
# (10458, 'King', 'Robert')
# (10459, 'Peacock', 'Margaret')
# (10460, 'Callahan', 'Laura')
# (10461, 'Davolio', 'Nancy')
# (10462, 'Fuller', 'Andrew')
# (10463, 'Buchanan', 'Steven')
# (10464, 'Peacock', 'Margaret')
# (10465, 'Davolio', 'Nancy')
# (10466, 'Peacock', 'Margaret')
# (10467, 'Callahan', 'Laura')
# (10468, 'Leverling', 'Janet')
# (10469, 'Davolio', 'Nancy')
# (10470, 'Peacock', 'Margaret')
# (10471, 'Fuller', 'Andrew')
# (10472, 'Callahan', 'Laura')
# (10473, 'Davolio', 'Nancy')
# (10474, 'Buchanan', 'Steven')
# (10475, 'Dodsworth', 'Anne')
# (10476, 'Callahan', 'Laura')
# (10477, 'Buchanan', 'Steven')
# (10478, 'Fuller', 'Andrew')
# (10479, 'Leverling', 'Janet')
# (10480, 'Suyama', 'Michael')
# (10481, 'Callahan', 'Laura')
# (10482, 'Davolio', 'Nancy')
# (10483, 'King', 'Robert')
# (10484, 'Leverling', 'Janet')
# (10485, 'Peacock', 'Margaret')
# (10486, 'Davolio', 'Nancy')
# (10487, 'Fuller', 'Andrew')
# (10488, 'Callahan', 'Laura')
# (10489, 'Suyama', 'Michael')
# (10490, 'King', 'Robert')
# (10491, 'Callahan', 'Laura')
# (10492, 'Leverling', 'Janet')
# (10493, 'Peacock', 'Margaret')
# (10494, 'Peacock', 'Margaret')
# (10495, 'Leverling', 'Janet')
# (10496, 'King', 'Robert')
# (10497, 'King', 'Robert')
# (10498, 'Callahan', 'Laura')
# (10499, 'Peacock', 'Margaret')
# (10500, 'Suyama', 'Michael')
# (10501, 'Dodsworth', 'Anne')
# (10502, 'Fuller', 'Andrew')
# (10503, 'Suyama', 'Michael')
# (10504, 'Peacock', 'Margaret')
# (10505, 'Leverling', 'Janet')
# (10506, 'Dodsworth', 'Anne')
# (10507, 'King', 'Robert')
# (10508, 'Davolio', 'Nancy')
# (10509, 'Peacock', 'Margaret')
# (10510, 'Suyama', 'Michael')
# (10511, 'Peacock', 'Margaret')
# (10512, 'King', 'Robert')
# (10513, 'King', 'Robert')
# (10514, 'Leverling', 'Janet')
# (10515, 'Fuller', 'Andrew')
# (10516, 'Fuller', 'Andrew')
# (10517, 'Leverling', 'Janet')
# (10518, 'Peacock', 'Margaret')
# (10519, 'Suyama', 'Michael')
# (10520, 'King', 'Robert')
# (10521, 'Callahan', 'Laura')
# (10522, 'Peacock', 'Margaret')
# (10523, 'King', 'Robert')
# (10524, 'Davolio', 'Nancy')
# (10525, 'Davolio', 'Nancy')
# (10526, 'Peacock', 'Margaret')
# (10527, 'King', 'Robert')
# (10528, 'Suyama', 'Michael')
# (10529, 'Buchanan', 'Steven')
# (10530, 'Leverling', 'Janet')
# (10531, 'King', 'Robert')
# (10532, 'King', 'Robert')
# (10533, 'Callahan', 'Laura')
# (10534, 'Callahan', 'Laura')
# (10535, 'Peacock', 'Margaret')
# (10536, 'Leverling', 'Janet')
# (10537, 'Davolio', 'Nancy')
# (10538, 'Dodsworth', 'Anne')
# (10539, 'Suyama', 'Michael')
# (10540, 'Leverling', 'Janet')
# (10541, 'Fuller', 'Andrew')
# (10542, 'Davolio', 'Nancy')
# (10543, 'Callahan', 'Laura')
# (10544, 'Peacock', 'Margaret')
# (10545, 'Callahan', 'Laura')
# (10546, 'Davolio', 'Nancy')
# (10547, 'Leverling', 'Janet')
# (10548, 'Leverling', 'Janet')
# (10549, 'Buchanan', 'Steven')
# (10550, 'King', 'Robert')
# (10551, 'Peacock', 'Margaret')
# (10552, 'Fuller', 'Andrew')
# (10553, 'Fuller', 'Andrew')
# (10554, 'Peacock', 'Margaret')
# (10555, 'Suyama', 'Michael')
# (10556, 'Fuller', 'Andrew')
# (10557, 'Dodsworth', 'Anne')
# (10558, 'Davolio', 'Nancy')
# (10559, 'Suyama', 'Michael')
# (10560, 'Callahan', 'Laura')
# (10561, 'Fuller', 'Andrew')
# (10562, 'Davolio', 'Nancy')
# (10563, 'Fuller', 'Andrew')
# (10564, 'Peacock', 'Margaret')
# (10565, 'Callahan', 'Laura')
# (10566, 'Dodsworth', 'Anne')
# (10567, 'Davolio', 'Nancy')
# (10568, 'Leverling', 'Janet')
# (10569, 'Buchanan', 'Steven')
# (10570, 'Leverling', 'Janet')
# (10571, 'Callahan', 'Laura')
# (10572, 'Leverling', 'Janet')
# (10573, 'King', 'Robert')
# (10574, 'Peacock', 'Margaret')
# (10575, 'Buchanan', 'Steven')
# (10576, 'Leverling', 'Janet')
# (10577, 'Dodsworth', 'Anne')
# (10578, 'Peacock', 'Margaret')
# (10579, 'Davolio', 'Nancy')
# (10580, 'Peacock', 'Margaret')
# (10581, 'Leverling', 'Janet')
# (10582, 'Leverling', 'Janet')
# (10583, 'Fuller', 'Andrew')
# (10584, 'Peacock', 'Margaret')
# (10585, 'King', 'Robert')
# (10586, 'Dodsworth', 'Anne')
# (10587, 'Davolio', 'Nancy')
# (10588, 'Fuller', 'Andrew')
# (10589, 'Callahan', 'Laura')
# (10590, 'Peacock', 'Margaret')
# (10591, 'Davolio', 'Nancy')
# (10592, 'Leverling', 'Janet')
# (10593, 'King', 'Robert')
# (10594, 'Leverling', 'Janet')
# (10595, 'Fuller', 'Andrew')
# (10596, 'Callahan', 'Laura')
# (10597, 'King', 'Robert')
# (10598, 'Davolio', 'Nancy')
# (10599, 'Suyama', 'Michael')
# (10600, 'Peacock', 'Margaret')
# (10601, 'King', 'Robert')
# (10602, 'Callahan', 'Laura')
# (10603, 'Callahan', 'Laura')
# (10604, 'Davolio', 'Nancy')
# (10605, 'Davolio', 'Nancy')
# (10606, 'Peacock', 'Margaret')
# (10607, 'Buchanan', 'Steven')
# (10608, 'Peacock', 'Margaret')
# (10609, 'King', 'Robert')
# (10610, 'Callahan', 'Laura')
# (10611, 'Suyama', 'Michael')
# (10612, 'Davolio', 'Nancy')
# (10613, 'Peacock', 'Margaret')
# (10614, 'Callahan', 'Laura')
# (10615, 'Fuller', 'Andrew')
# (10616, 'Davolio', 'Nancy')
# (10617, 'Peacock', 'Margaret')
# (10618, 'Davolio', 'Nancy')
# (10619, 'Leverling', 'Janet')
# (10620, 'Fuller', 'Andrew')
# (10621, 'Peacock', 'Margaret')
# (10622, 'Peacock', 'Margaret')
# (10623, 'Callahan', 'Laura')
# (10624, 'Peacock', 'Margaret')
# (10625, 'Leverling', 'Janet')
# (10626, 'Davolio', 'Nancy')
# (10627, 'Callahan', 'Laura')
# (10628, 'Peacock', 'Margaret')
# (10629, 'Peacock', 'Margaret')
# (10630, 'Davolio', 'Nancy')
# (10631, 'Callahan', 'Laura')
# (10632, 'Callahan', 'Laura')
# (10633, 'King', 'Robert')
# (10634, 'Peacock', 'Margaret')
# (10635, 'Callahan', 'Laura')
# (10636, 'Peacock', 'Margaret')
# (10637, 'Suyama', 'Michael')
# (10638, 'Leverling', 'Janet')
# (10639, 'King', 'Robert')
# (10640, 'Peacock', 'Margaret')
# (10641, 'Peacock', 'Margaret')
# (10642, 'King', 'Robert')
# (10643, 'Suyama', 'Michael')
# (10644, 'Leverling', 'Janet')
# (10645, 'Peacock', 'Margaret')
# (10646, 'Dodsworth', 'Anne')
# (10647, 'Peacock', 'Margaret')
# (10648, 'Buchanan', 'Steven')
# (10649, 'Buchanan', 'Steven')
# (10650, 'Buchanan', 'Steven')
# (10651, 'Callahan', 'Laura')
# (10652, 'Peacock', 'Margaret')
# (10653, 'Davolio', 'Nancy')
# (10654, 'Buchanan', 'Steven')
# (10655, 'Davolio', 'Nancy')
# (10656, 'Suyama', 'Michael')
# (10657, 'Fuller', 'Andrew')
# (10658, 'Peacock', 'Margaret')
# (10659, 'King', 'Robert')
# (10660, 'Callahan', 'Laura')
# (10661, 'King', 'Robert')
# (10662, 'Leverling', 'Janet')
# (10663, 'Fuller', 'Andrew')
# (10664, 'Davolio', 'Nancy')
# (10665, 'Davolio', 'Nancy')
# (10666, 'King', 'Robert')
# (10667, 'King', 'Robert')
# (10668, 'Davolio', 'Nancy')
# (10669, 'Fuller', 'Andrew')
# (10670, 'Peacock', 'Margaret')
# (10671, 'Davolio', 'Nancy')
# (10672, 'Dodsworth', 'Anne')
# (10673, 'Fuller', 'Andrew')
# (10674, 'Peacock', 'Margaret')
# (10675, 'Buchanan', 'Steven')
# (10676, 'Fuller', 'Andrew')
# (10677, 'Davolio', 'Nancy')
# (10678, 'King', 'Robert')
# (10679, 'Callahan', 'Laura')
# (10680, 'Davolio', 'Nancy')
# (10681, 'Leverling', 'Janet')
# (10682, 'Leverling', 'Janet')
# (10683, 'Fuller', 'Andrew')
# (10684, 'Leverling', 'Janet')
# (10685, 'Peacock', 'Margaret')
# (10686, 'Fuller', 'Andrew')
# (10687, 'Dodsworth', 'Anne')
# (10688, 'Peacock', 'Margaret')
# (10689, 'Davolio', 'Nancy')
# (10690, 'Davolio', 'Nancy')
# (10691, 'Fuller', 'Andrew')
# (10692, 'Peacock', 'Margaret')
# (10693, 'Leverling', 'Janet')
# (10694, 'Callahan', 'Laura')
# (10695, 'King', 'Robert')
# (10696, 'Callahan', 'Laura')
# (10697, 'Leverling', 'Janet')
# (10698, 'Peacock', 'Margaret')
# (10699, 'Leverling', 'Janet')
# (10700, 'Leverling', 'Janet')
# (10701, 'Suyama', 'Michael')
# (10702, 'Peacock', 'Margaret')
# (10703, 'Suyama', 'Michael')
# (10704, 'Suyama', 'Michael')
# (10705, 'Dodsworth', 'Anne')
# (10706, 'Callahan', 'Laura')
# (10707, 'Peacock', 'Margaret')
# (10708, 'Suyama', 'Michael')
# (10709, 'Davolio', 'Nancy')
# (10710, 'Davolio', 'Nancy')
# (10711, 'Buchanan', 'Steven')
# (10712, 'Leverling', 'Janet')
# (10713, 'Davolio', 'Nancy')
# (10714, 'Buchanan', 'Steven')
# (10715, 'Leverling', 'Janet')
# (10716, 'Peacock', 'Margaret')
# (10717, 'Davolio', 'Nancy')
# (10718, 'Davolio', 'Nancy')
# (10719, 'Callahan', 'Laura')
# (10720, 'Callahan', 'Laura')
# (10721, 'Buchanan', 'Steven')
# (10722, 'Callahan', 'Laura')
# (10723, 'Leverling', 'Janet')
# (10724, 'Callahan', 'Laura')
# (10725, 'Peacock', 'Margaret')
# (10726, 'Peacock', 'Margaret')
# (10727, 'Fuller', 'Andrew')
# (10728, 'Peacock', 'Margaret')
# (10729, 'Callahan', 'Laura')
# (10730, 'Buchanan', 'Steven')
# (10731, 'King', 'Robert')
# (10732, 'Leverling', 'Janet')
# (10733, 'Davolio', 'Nancy')
# (10734, 'Fuller', 'Andrew')
# (10735, 'Suyama', 'Michael')
# (10736, 'Dodsworth', 'Anne')
# (10737, 'Fuller', 'Andrew')
# (10738, 'Fuller', 'Andrew')
# (10739, 'Leverling', 'Janet')
# (10740, 'Peacock', 'Margaret')
# (10741, 'Peacock', 'Margaret')
# (10742, 'Leverling', 'Janet')
# (10743, 'Davolio', 'Nancy')
# (10744, 'Suyama', 'Michael')
# (10745, 'Dodsworth', 'Anne')
# (10746, 'Davolio', 'Nancy')
# (10747, 'Suyama', 'Michael')
# (10748, 'Leverling', 'Janet')
# (10749, 'Peacock', 'Margaret')
# (10750, 'Dodsworth', 'Anne')
# (10751, 'Leverling', 'Janet')
# (10752, 'Fuller', 'Andrew')
# (10753, 'Leverling', 'Janet')
# (10754, 'Suyama', 'Michael')
# (10755, 'Peacock', 'Margaret')
# (10756, 'Callahan', 'Laura')
# (10757, 'Suyama', 'Michael')
# (10758, 'Leverling', 'Janet')
# (10759, 'Leverling', 'Janet')
# (10760, 'Peacock', 'Margaret')
# (10761, 'Buchanan', 'Steven')
# (10762, 'Leverling', 'Janet')
# (10763, 'Leverling', 'Janet')
# (10764, 'Suyama', 'Michael')
# (10765, 'Leverling', 'Janet')
# (10766, 'Peacock', 'Margaret')
# (10767, 'Peacock', 'Margaret')
# (10768, 'Leverling', 'Janet')
# (10769, 'Leverling', 'Janet')
# (10770, 'Callahan', 'Laura')
# (10771, 'Dodsworth', 'Anne')
# (10772, 'Leverling', 'Janet')
# (10773, 'Davolio', 'Nancy')
# (10774, 'Peacock', 'Margaret')
# (10775, 'King', 'Robert')
# (10776, 'Davolio', 'Nancy')
# (10777, 'King', 'Robert')
# (10778, 'Leverling', 'Janet')
# (10779, 'Leverling', 'Janet')
# (10780, 'Fuller', 'Andrew')
# (10781, 'Fuller', 'Andrew')
# (10782, 'Dodsworth', 'Anne')
# (10783, 'Peacock', 'Margaret')
# (10784, 'Peacock', 'Margaret')
# (10785, 'Davolio', 'Nancy')
# (10786, 'Callahan', 'Laura')
# (10787, 'Fuller', 'Andrew')
# (10788, 'Davolio', 'Nancy')
# (10789, 'Davolio', 'Nancy')
# (10790, 'Suyama', 'Michael')
# (10791, 'Suyama', 'Michael')
# (10792, 'Davolio', 'Nancy')
# (10793, 'Leverling', 'Janet')
# (10794, 'Suyama', 'Michael')
# (10795, 'Callahan', 'Laura')
# (10796, 'Leverling', 'Janet')
# (10797, 'King', 'Robert')
# (10798, 'Fuller', 'Andrew')
# (10799, 'Dodsworth', 'Anne')
# (10800, 'Davolio', 'Nancy')
# (10801, 'Peacock', 'Margaret')
# (10802, 'Peacock', 'Margaret')
# (10803, 'Peacock', 'Margaret')
# (10804, 'Suyama', 'Michael')
# (10805, 'Fuller', 'Andrew')
# (10806, 'Leverling', 'Janet')
# (10807, 'Peacock', 'Margaret')
# (10808, 'Fuller', 'Andrew')
# (10809, 'King', 'Robert')
# (10810, 'Fuller', 'Andrew')
# (10811, 'Callahan', 'Laura')
# (10812, 'Buchanan', 'Steven')
# (10813, 'Davolio', 'Nancy')
# (10814, 'Leverling', 'Janet')
# (10815, 'Fuller', 'Andrew')
# (10816, 'Peacock', 'Margaret')
# (10817, 'Leverling', 'Janet')
# (10818, 'King', 'Robert')
# (10819, 'Fuller', 'Andrew')
# (10820, 'Leverling', 'Janet')
# (10821, 'Davolio', 'Nancy')
# (10822, 'Suyama', 'Michael')
# (10823, 'Buchanan', 'Steven')
# (10824, 'Callahan', 'Laura')
# (10825, 'Davolio', 'Nancy')
# (10826, 'Suyama', 'Michael')
# (10827, 'Davolio', 'Nancy')
# (10828, 'Dodsworth', 'Anne')
# (10829, 'Dodsworth', 'Anne')
# (10830, 'Peacock', 'Margaret')
# (10831, 'Leverling', 'Janet')
# (10832, 'Fuller', 'Andrew')
# (10833, 'Suyama', 'Michael')
# (10834, 'Davolio', 'Nancy')
# (10835, 'Davolio', 'Nancy')
# (10836, 'King', 'Robert')
# (10837, 'Dodsworth', 'Anne')
# (10838, 'Leverling', 'Janet')
# (10839, 'Leverling', 'Janet')
# (10840, 'Peacock', 'Margaret')
# (10841, 'Buchanan', 'Steven')
# (10842, 'Davolio', 'Nancy')
# (10843, 'Peacock', 'Margaret')
# (10844, 'Callahan', 'Laura')
# (10845, 'Callahan', 'Laura')
# (10846, 'Fuller', 'Andrew')
# (10847, 'Peacock', 'Margaret')
# (10848, 'King', 'Robert')
# (10849, 'Dodsworth', 'Anne')
# (10850, 'Davolio', 'Nancy')
# (10851, 'Buchanan', 'Steven')
# (10852, 'Callahan', 'Laura')
# (10853, 'Dodsworth', 'Anne')
# (10854, 'Leverling', 'Janet')
# (10855, 'Leverling', 'Janet')
# (10856, 'Leverling', 'Janet')
# (10857, 'Callahan', 'Laura')
# (10858, 'Fuller', 'Andrew')
# (10859, 'Davolio', 'Nancy')
# (10860, 'Leverling', 'Janet')
# (10861, 'Peacock', 'Margaret')
# (10862, 'Callahan', 'Laura')
# (10863, 'Peacock', 'Margaret')
# (10864, 'Peacock', 'Margaret')
# (10865, 'Fuller', 'Andrew')
# (10866, 'Buchanan', 'Steven')
# (10867, 'Suyama', 'Michael')
# (10868, 'King', 'Robert')
# (10869, 'Buchanan', 'Steven')
# (10870, 'Buchanan', 'Steven')
# (10871, 'Dodsworth', 'Anne')
# (10872, 'Buchanan', 'Steven')
# (10873, 'Peacock', 'Margaret')
# (10874, 'Buchanan', 'Steven')
# (10875, 'Peacock', 'Margaret')
# (10876, 'King', 'Robert')
# (10877, 'Davolio', 'Nancy')
# (10878, 'Peacock', 'Margaret')
# (10879, 'Leverling', 'Janet')
# (10880, 'King', 'Robert')
# (10881, 'Peacock', 'Margaret')
# (10882, 'Peacock', 'Margaret')
# (10883, 'Callahan', 'Laura')
# (10884, 'Peacock', 'Margaret')
# (10885, 'Suyama', 'Michael')
# (10886, 'Davolio', 'Nancy')
# (10887, 'Callahan', 'Laura')
# (10888, 'Davolio', 'Nancy')
# (10889, 'Dodsworth', 'Anne')
# (10890, 'King', 'Robert')
# (10891, 'King', 'Robert')
# (10892, 'Peacock', 'Margaret')
# (10893, 'Dodsworth', 'Anne')
# (10894, 'Davolio', 'Nancy')
# (10895, 'Leverling', 'Janet')
# (10896, 'King', 'Robert')
# (10897, 'Leverling', 'Janet')
# (10898, 'Peacock', 'Margaret')
# (10899, 'Buchanan', 'Steven')
# (10900, 'Davolio', 'Nancy')
# (10901, 'Peacock', 'Margaret')
# (10902, 'Davolio', 'Nancy')
# (10903, 'Leverling', 'Janet')
# (10904, 'Leverling', 'Janet')
# (10905, 'Dodsworth', 'Anne')
# (10906, 'Peacock', 'Margaret')
# (10907, 'Suyama', 'Michael')
# (10908, 'Peacock', 'Margaret')
# (10909, 'Davolio', 'Nancy')
# (10910, 'Davolio', 'Nancy')
# (10911, 'Leverling', 'Janet')
# (10912, 'Fuller', 'Andrew')
# (10913, 'Peacock', 'Margaret')
# (10914, 'Suyama', 'Michael')
# (10915, 'Fuller', 'Andrew')
# (10916, 'Davolio', 'Nancy')
# (10917, 'Peacock', 'Margaret')
# (10918, 'Leverling', 'Janet')
# (10919, 'Fuller', 'Andrew')
# (10920, 'Peacock', 'Margaret')
# (10921, 'Davolio', 'Nancy')
# (10922, 'Buchanan', 'Steven')
# (10923, 'King', 'Robert')
# (10924, 'Leverling', 'Janet')
# (10925, 'Leverling', 'Janet')
# (10926, 'Peacock', 'Margaret')
# (10927, 'Peacock', 'Margaret')
# (10928, 'Davolio', 'Nancy')
# (10929, 'Suyama', 'Michael')
# (10930, 'Peacock', 'Margaret')
# (10931, 'Peacock', 'Margaret')
# (10932, 'Callahan', 'Laura')
# (10933, 'Suyama', 'Michael')
# (10934, 'Leverling', 'Janet')
# (10935, 'Peacock', 'Margaret')
# (10936, 'Leverling', 'Janet')
# (10937, 'King', 'Robert')
# (10938, 'Leverling', 'Janet')
# (10939, 'Fuller', 'Andrew')
# (10940, 'Callahan', 'Laura')
# (10941, 'King', 'Robert')
# (10942, 'Dodsworth', 'Anne')
# (10943, 'Peacock', 'Margaret')
# (10944, 'Suyama', 'Michael')
# (10945, 'Peacock', 'Margaret')
# (10946, 'Davolio', 'Nancy')
# (10947, 'Leverling', 'Janet')
# (10948, 'Leverling', 'Janet')
# (10949, 'Fuller', 'Andrew')
# (10950, 'Davolio', 'Nancy')
# (10951, 'Dodsworth', 'Anne')
# (10952, 'Davolio', 'Nancy')
# (10953, 'Dodsworth', 'Anne')
# (10954, 'Buchanan', 'Steven')
# (10955, 'Callahan', 'Laura')
# (10956, 'Suyama', 'Michael')
# (10957, 'Callahan', 'Laura')
# (10958, 'King', 'Robert')
# (10959, 'Suyama', 'Michael')
# (10960, 'Leverling', 'Janet')
# (10961, 'Callahan', 'Laura')
# (10962, 'Callahan', 'Laura')
# (10963, 'Dodsworth', 'Anne')
# (10964, 'Leverling', 'Janet')
# (10965, 'Suyama', 'Michael')
# (10966, 'Peacock', 'Margaret')
# (10967, 'Fuller', 'Andrew')
# (10968, 'Davolio', 'Nancy')
# (10969, 'Davolio', 'Nancy')
# (10970, 'Dodsworth', 'Anne')
# (10971, 'Fuller', 'Andrew')
# (10972, 'Peacock', 'Margaret')
# (10973, 'Suyama', 'Michael')
# (10974, 'Leverling', 'Janet')
# (10975, 'Davolio', 'Nancy')
# (10976, 'Davolio', 'Nancy')
# (10977, 'Callahan', 'Laura')
# (10978, 'Dodsworth', 'Anne')
# (10979, 'Callahan', 'Laura')
# (10980, 'Peacock', 'Margaret')
# (10981, 'Davolio', 'Nancy')
# (10982, 'Fuller', 'Andrew')
# (10983, 'Fuller', 'Andrew')
# (10984, 'Davolio', 'Nancy')
# (10985, 'Fuller', 'Andrew')
# (10986, 'Callahan', 'Laura')
# (10987, 'Callahan', 'Laura')
# (10988, 'Leverling', 'Janet')
# (10989, 'Fuller', 'Andrew')
# (10990, 'Fuller', 'Andrew')
# (10991, 'Davolio', 'Nancy')
# (10992, 'Davolio', 'Nancy')
# (10993, 'King', 'Robert')
# (10994, 'Fuller', 'Andrew')
# (10995, 'Davolio', 'Nancy')
# (10996, 'Peacock', 'Margaret')
# (10997, 'Callahan', 'Laura')
# (10998, 'Callahan', 'Laura')
# (10999, 'Suyama', 'Michael')
# (11000, 'Fuller', 'Andrew')
# (11001, 'Fuller', 'Andrew')
# (11002, 'Peacock', 'Margaret')
# (11003, 'Leverling', 'Janet')
# (11004, 'Leverling', 'Janet')
# (11005, 'Fuller', 'Andrew')
# (11006, 'Leverling', 'Janet')
# (11007, 'Callahan', 'Laura')
# (11008, 'King', 'Robert')
# (11009, 'Fuller', 'Andrew')
# (11010, 'Fuller', 'Andrew')
# (11011, 'Leverling', 'Janet')
# (11012, 'Davolio', 'Nancy')
# (11013, 'Fuller', 'Andrew')
# (11014, 'Fuller', 'Andrew')
# (11015, 'Fuller', 'Andrew')
# (11016, 'Dodsworth', 'Anne')
# (11017, 'Dodsworth', 'Anne')
# (11018, 'Peacock', 'Margaret')
# (11019, 'Suyama', 'Michael')
# (11020, 'Fuller', 'Andrew')
# (11021, 'Leverling', 'Janet')
# (11022, 'Dodsworth', 'Anne')
# (11023, 'Davolio', 'Nancy')
# (11024, 'Peacock', 'Margaret')
# (11025, 'Suyama', 'Michael')
# (11026, 'Peacock', 'Margaret')
# (11027, 'Davolio', 'Nancy')
# (11028, 'Fuller', 'Andrew')
# (11029, 'Peacock', 'Margaret')
# (11030, 'King', 'Robert')
# (11031, 'Suyama', 'Michael')
# (11032, 'Fuller', 'Andrew')
# (11033, 'King', 'Robert')
# (11034, 'Callahan', 'Laura')
# (11035, 'Fuller', 'Andrew')
# (11036, 'Callahan', 'Laura')
# (11037, 'King', 'Robert')
# (11038, 'Davolio', 'Nancy')
# (11039, 'Davolio', 'Nancy')
# (11040, 'Peacock', 'Margaret')
# (11041, 'Leverling', 'Janet')
# (11042, 'Fuller', 'Andrew')
# (11043, 'Buchanan', 'Steven')
# (11044, 'Peacock', 'Margaret')
# (11045, 'Suyama', 'Michael')
# (11046, 'Callahan', 'Laura')
# (11047, 'King', 'Robert')
# (11048, 'King', 'Robert')
# (11049, 'Leverling', 'Janet')
# (11050, 'Callahan', 'Laura')
# (11051, 'King', 'Robert')
# (11052, 'Leverling', 'Janet')
# (11053, 'Fuller', 'Andrew')
# (11054, 'Callahan', 'Laura')
# (11055, 'King', 'Robert')
# (11056, 'Callahan', 'Laura')
# (11057, 'Leverling', 'Janet')
# (11058, 'Dodsworth', 'Anne')
# (11059, 'Fuller', 'Andrew')
# (11060, 'Fuller', 'Andrew')
# (11061, 'Peacock', 'Margaret')
# (11062, 'Peacock', 'Margaret')
# (11063, 'Leverling', 'Janet')
# (11064, 'Davolio', 'Nancy')
# (11065, 'Callahan', 'Laura')
# (11066, 'King', 'Robert')
# (11067, 'Davolio', 'Nancy')
# (11068, 'Callahan', 'Laura')
# (11069, 'Davolio', 'Nancy')
# (11070, 'Fuller', 'Andrew')
# (11071, 'Davolio', 'Nancy')
# (11072, 'Peacock', 'Margaret')
# (11073, 'Fuller', 'Andrew')
# (11074, 'King', 'Robert')
# (11075, 'Callahan', 'Laura')
# (11076, 'Peacock', 'Margaret')
# (11077, 'Davolio', 'Nancy')

# %%
run_query("SQL Full Join", "SELECT Customers.CustomerName, Orders.OrderID FROM Customers FULL OUTER JOIN Orders ON Customers.CustomerID=Orders.CustomerID ORDER BY Customers.CustomerName;")
# Out:
#  SQL Full Join
# SQL : SELECT Customers.CustomerName, Orders.OrderID FROM Customers FULL OUTER JOIN Orders ON Customers.CustomerID=Orders.CustomerID ORDER BY Customers.CustomerName;
# (None, 10643)
# (None, 10692)
# (None, 10702)
# (None, 10835)
# (None, 10952)
# (None, 11011)
# ('Ana Trujillo Emparedados y helados', 10308)
# ('Ana Trujillo Emparedados y helados', 10625)
# ('Ana Trujillo Emparedados y helados', 10759)
# ('Ana Trujillo Emparedados y helados', 10926)
# ('Antonio Moreno Taquería', 10365)
# ('Antonio Moreno Taquería', 10507)
# ('Antonio Moreno Taquería', 10535)
# ('Antonio Moreno Taquería', 10573)
# ('Antonio Moreno Taquería', 10677)
# ('Antonio Moreno Taquería', 10682)
# ('Antonio Moreno Taquería', 10856)
# ('Around the Horn', 10355)
# ('Around the Horn', 10383)
# ('Around the Horn', 10453)
# ('Around the Horn', 10558)
# ('Around the Horn', 10707)
# ('Around the Horn', 10741)
# ('Around the Horn', 10743)
# ('Around the Horn', 10768)
# ('Around the Horn', 10793)
# ('Around the Horn', 10864)
# ('Around the Horn', 10920)
# ('Around the Horn', 10953)
# ('Around the Horn', 11016)
# ("B's Beverages", 10289)
# ("B's Beverages", 10471)
# ("B's Beverages", 10484)
# ("B's Beverages", 10538)
# ("B's Beverages", 10539)
# ("B's Beverages", 10578)
# ("B's Beverages", 10599)
# ("B's Beverages", 10943)
# ("B's Beverages", 10947)
# ("B's Beverages", 11023)
# ('Berglunds snabbköp', 10278)
# ('Berglunds snabbköp', 10280)
# ('Berglunds snabbköp', 10384)
# ('Berglunds snabbköp', 10444)
# ('Berglunds snabbköp', 10445)
# ('Berglunds snabbköp', 10524)
# ('Berglunds snabbköp', 10572)
# ('Berglunds snabbköp', 10626)
# ('Berglunds snabbköp', 10654)
# ('Berglunds snabbköp', 10672)
# ('Berglunds snabbköp', 10689)
# ('Berglunds snabbköp', 10733)
# ('Berglunds snabbköp', 10778)
# ('Berglunds snabbköp', 10837)
# ('Berglunds snabbköp', 10857)
# ('Berglunds snabbköp', 10866)
# ('Berglunds snabbköp', 10875)
# ('Berglunds snabbköp', 10924)
# ('Blauer See Delikatessen', 10501)
# ('Blauer See Delikatessen', 10509)
# ('Blauer See Delikatessen', 10582)
# ('Blauer See Delikatessen', 10614)
# ('Blauer See Delikatessen', 10853)
# ('Blauer See Delikatessen', 10956)
# ('Blauer See Delikatessen', 11058)
# ('Blondesddsl père et fils', 10265)
# ('Blondesddsl père et fils', 10297)
# ('Blondesddsl père et fils', 10360)
# ('Blondesddsl père et fils', 10436)
# ('Blondesddsl père et fils', 10449)
# ('Blondesddsl père et fils', 10559)
# ('Blondesddsl père et fils', 10566)
# ('Blondesddsl père et fils', 10584)
# ('Blondesddsl père et fils', 10628)
# ('Blondesddsl père et fils', 10679)
# ('Blondesddsl père et fils', 10826)
# ("Bon app'", 10331)
# ("Bon app'", 10340)
# ("Bon app'", 10362)
# ("Bon app'", 10470)
# ("Bon app'", 10511)
# ("Bon app'", 10525)
# ("Bon app'", 10663)
# ("Bon app'", 10715)
# ("Bon app'", 10730)
# ("Bon app'", 10732)
# ("Bon app'", 10755)
# ("Bon app'", 10827)
# ("Bon app'", 10871)
# ("Bon app'", 10876)
# ("Bon app'", 10932)
# ("Bon app'", 10940)
# ("Bon app'", 11076)
# ('Bottom-Dollar Markets', 10389)
# ('Bottom-Dollar Markets', 10410)
# ('Bottom-Dollar Markets', 10411)
# ('Bottom-Dollar Markets', 10431)
# ('Bottom-Dollar Markets', 10492)
# ('Bottom-Dollar Markets', 10742)
# ('Bottom-Dollar Markets', 10918)
# ('Bottom-Dollar Markets', 10944)
# ('Bottom-Dollar Markets', 10949)
# ('Bottom-Dollar Markets', 10975)
# ('Bottom-Dollar Markets', 10982)
# ('Bottom-Dollar Markets', 11027)
# ('Bottom-Dollar Markets', 11045)
# ('Bottom-Dollar Markets', 11048)
# ('Bólido Comidas preparadas', 10326)
# ('Bólido Comidas preparadas', 10801)
# ('Bólido Comidas preparadas', 10970)
# ('Cactus Comidas para llevar', 10521)
# ('Cactus Comidas para llevar', 10782)
# ('Cactus Comidas para llevar', 10819)
# ('Cactus Comidas para llevar', 10881)
# ('Cactus Comidas para llevar', 10937)
# ('Cactus Comidas para llevar', 11054)
# ('Cardinal', None)
# ('Cardinal', None)
# ('Cardinal', None)
# ('Centro comercial Moctezuma', 10259)
# ('Chop-suey Chinese', 10254)
# ('Chop-suey Chinese', 10370)
# ('Chop-suey Chinese', 10519)
# ('Chop-suey Chinese', 10731)
# ('Chop-suey Chinese', 10746)
# ('Chop-suey Chinese', 10966)
# ('Chop-suey Chinese', 11029)
# ('Chop-suey Chinese', 11041)
# ('Comércio Mineiro', 10290)
# ('Comércio Mineiro', 10466)
# ('Comércio Mineiro', 10494)
# ('Comércio Mineiro', 10969)
# ('Comércio Mineiro', 11042)
# ('Consolidated Holdings', 10435)
# ('Consolidated Holdings', 10462)
# ('Consolidated Holdings', 10848)
# ('Die Wandernde Kuh', 10301)
# ('Die Wandernde Kuh', 10312)
# ('Die Wandernde Kuh', 10348)
# ('Die Wandernde Kuh', 10356)
# ('Die Wandernde Kuh', 10513)
# ('Die Wandernde Kuh', 10632)
# ('Die Wandernde Kuh', 10640)
# ('Die Wandernde Kuh', 10651)
# ('Die Wandernde Kuh', 10668)
# ('Die Wandernde Kuh', 11046)
# ('Drachenblut Delikatessen', 10363)
# ('Drachenblut Delikatessen', 10391)
# ('Drachenblut Delikatessen', 10797)
# ('Drachenblut Delikatessen', 10825)
# ('Drachenblut Delikatessen', 11036)
# ('Drachenblut Delikatessen', 11067)
# ('Du monde entier', 10311)
# ('Du monde entier', 10609)
# ('Du monde entier', 10683)
# ('Du monde entier', 10890)
# ('Eastern Connection', 10364)
# ('Eastern Connection', 10400)
# ('Eastern Connection', 10532)
# ('Eastern Connection', 10726)
# ('Eastern Connection', 10987)
# ('Eastern Connection', 11024)
# ('Eastern Connection', 11047)
# ('Eastern Connection', 11056)
# ('Ernst Handel', 10258)
# ('Ernst Handel', 10263)
# ('Ernst Handel', 10351)
# ('Ernst Handel', 10368)
# ('Ernst Handel', 10382)
# ('Ernst Handel', 10390)
# ('Ernst Handel', 10402)
# ('Ernst Handel', 10403)
# ('Ernst Handel', 10430)
# ('Ernst Handel', 10442)
# ('Ernst Handel', 10514)
# ('Ernst Handel', 10571)
# ('Ernst Handel', 10595)
# ('Ernst Handel', 10633)
# ('Ernst Handel', 10667)
# ('Ernst Handel', 10698)
# ('Ernst Handel', 10764)
# ('Ernst Handel', 10771)
# ('Ernst Handel', 10773)
# ('Ernst Handel', 10776)
# ('Ernst Handel', 10795)
# ('Ernst Handel', 10836)
# ('Ernst Handel', 10854)
# ('Ernst Handel', 10895)
# ('Ernst Handel', 10968)
# ('Ernst Handel', 10979)
# ('Ernst Handel', 10990)
# ('Ernst Handel', 11008)
# ('Ernst Handel', 11017)
# ('Ernst Handel', 11072)
# ('FISSA Fabrica Inter. Salchichas S.A.', None)
# ('Familia Arquibaldo', 10347)
# ('Familia Arquibaldo', 10386)
# ('Familia Arquibaldo', 10414)
# ('Familia Arquibaldo', 10512)
# ('Familia Arquibaldo', 10581)
# ('Familia Arquibaldo', 10650)
# ('Familia Arquibaldo', 10725)
# ('Folies gourmandes', 10408)
# ('Folies gourmandes', 10480)
# ('Folies gourmandes', 10634)
# ('Folies gourmandes', 10763)
# ('Folies gourmandes', 10789)
# ('Folk och fä HB', 10264)
# ('Folk och fä HB', 10327)
# ('Folk och fä HB', 10378)
# ('Folk och fä HB', 10434)
# ('Folk och fä HB', 10460)
# ('Folk och fä HB', 10533)
# ('Folk och fä HB', 10561)
# ('Folk och fä HB', 10703)
# ('Folk och fä HB', 10762)
# ('Folk och fä HB', 10774)
# ('Folk och fä HB', 10824)
# ('Folk och fä HB', 10880)
# ('Folk och fä HB', 10902)
# ('Folk och fä HB', 10955)
# ('Folk och fä HB', 10977)
# ('Folk och fä HB', 10980)
# ('Folk och fä HB', 10993)
# ('Folk och fä HB', 11001)
# ('Folk och fä HB', 11050)
# ('France restauration', 10671)
# ('France restauration', 10860)
# ('France restauration', 10971)
# ('Franchi S.p.A.', 10422)
# ('Franchi S.p.A.', 10710)
# ('Franchi S.p.A.', 10753)
# ('Franchi S.p.A.', 10807)
# ('Franchi S.p.A.', 11026)
# ('Franchi S.p.A.', 11060)
# ('Frankenversand', 10267)
# ('Frankenversand', 10337)
# ('Frankenversand', 10342)
# ('Frankenversand', 10396)
# ('Frankenversand', 10488)
# ('Frankenversand', 10560)
# ('Frankenversand', 10623)
# ('Frankenversand', 10653)
# ('Frankenversand', 10670)
# ('Frankenversand', 10675)
# ('Frankenversand', 10717)
# ('Frankenversand', 10791)
# ('Frankenversand', 10859)
# ('Frankenversand', 10929)
# ('Frankenversand', 11012)
# ('Furia Bacalhau e Frutos do Mar', 10328)
# ('Furia Bacalhau e Frutos do Mar', 10352)
# ('Furia Bacalhau e Frutos do Mar', 10464)
# ('Furia Bacalhau e Frutos do Mar', 10491)
# ('Furia Bacalhau e Frutos do Mar', 10551)
# ('Furia Bacalhau e Frutos do Mar', 10604)
# ('Furia Bacalhau e Frutos do Mar', 10664)
# ('Furia Bacalhau e Frutos do Mar', 10963)
# ('GROSELLA-Restaurante', 10268)
# ('GROSELLA-Restaurante', 10785)
# ('Galería del gastrónomo', 10366)
# ('Galería del gastrónomo', 10426)
# ('Galería del gastrónomo', 10568)
# ('Galería del gastrónomo', 10887)
# ('Galería del gastrónomo', 10928)
# ('Godos Cocina Típica', 10303)
# ('Godos Cocina Típica', 10550)
# ('Godos Cocina Típica', 10629)
# ('Godos Cocina Típica', 10872)
# ('Godos Cocina Típica', 10874)
# ('Godos Cocina Típica', 10888)
# ('Godos Cocina Típica', 10911)
# ('Godos Cocina Típica', 10948)
# ('Godos Cocina Típica', 11009)
# ('Godos Cocina Típica', 11037)
# ('Gourmet Lanchonetes', 10423)
# ('Gourmet Lanchonetes', 10652)
# ('Gourmet Lanchonetes', 10685)
# ('Gourmet Lanchonetes', 10709)
# ('Gourmet Lanchonetes', 10734)
# ('Gourmet Lanchonetes', 10777)
# ('Gourmet Lanchonetes', 10790)
# ('Gourmet Lanchonetes', 10959)
# ('Gourmet Lanchonetes', 11049)
# ('Greasy Burger', None)
# ('Great Lakes Food Market', 10528)
# ('Great Lakes Food Market', 10589)
# ('Great Lakes Food Market', 10616)
# ('Great Lakes Food Market', 10617)
# ('Great Lakes Food Market', 10656)
# ('Great Lakes Food Market', 10681)
# ('Great Lakes Food Market', 10816)
# ('Great Lakes Food Market', 10936)
# ('Great Lakes Food Market', 11006)
# ('Great Lakes Food Market', 11040)
# ('Great Lakes Food Market', 11061)
# ('HILARION-Abastos', 10257)
# ('HILARION-Abastos', 10395)
# ('HILARION-Abastos', 10476)
# ('HILARION-Abastos', 10486)
# ('HILARION-Abastos', 10490)
# ('HILARION-Abastos', 10498)
# ('HILARION-Abastos', 10552)
# ('HILARION-Abastos', 10601)
# ('HILARION-Abastos', 10613)
# ('HILARION-Abastos', 10641)
# ('HILARION-Abastos', 10705)
# ('HILARION-Abastos', 10796)
# ('HILARION-Abastos', 10863)
# ('HILARION-Abastos', 10901)
# ('HILARION-Abastos', 10957)
# ('HILARION-Abastos', 10960)
# ('HILARION-Abastos', 10976)
# ('HILARION-Abastos', 11055)
# ('Hanari Carnes', 10250)
# ('Hanari Carnes', 10253)
# ('Hanari Carnes', 10541)
# ('Hanari Carnes', 10645)
# ('Hanari Carnes', 10690)
# ('Hanari Carnes', 10770)
# ('Hanari Carnes', 10783)
# ('Hanari Carnes', 10886)
# ('Hanari Carnes', 10903)
# ('Hanari Carnes', 10922)
# ('Hanari Carnes', 10925)
# ('Hanari Carnes', 10981)
# ('Hanari Carnes', 11022)
# ('Hanari Carnes', 11052)
# ('Hungry Coyote Import Store', 10375)
# ('Hungry Coyote Import Store', 10394)
# ('Hungry Coyote Import Store', 10415)
# ('Hungry Coyote Import Store', 10600)
# ('Hungry Coyote Import Store', 10660)
# ('Hungry Owl All-Night Grocers', 10298)
# ('Hungry Owl All-Night Grocers', 10309)
# ('Hungry Owl All-Night Grocers', 10335)
# ('Hungry Owl All-Night Grocers', 10373)
# ('Hungry Owl All-Night Grocers', 10380)
# ('Hungry Owl All-Night Grocers', 10429)
# ('Hungry Owl All-Night Grocers', 10503)
# ('Hungry Owl All-Night Grocers', 10516)
# ('Hungry Owl All-Night Grocers', 10567)
# ('Hungry Owl All-Night Grocers', 10646)
# ('Hungry Owl All-Night Grocers', 10661)
# ('Hungry Owl All-Night Grocers', 10687)
# ('Hungry Owl All-Night Grocers', 10701)
# ('Hungry Owl All-Night Grocers', 10712)
# ('Hungry Owl All-Night Grocers', 10736)
# ('Hungry Owl All-Night Grocers', 10897)
# ('Hungry Owl All-Night Grocers', 10912)
# ('Hungry Owl All-Night Grocers', 10985)
# ('Hungry Owl All-Night Grocers', 11063)
# ('Island Trading', 10315)
# ('Island Trading', 10318)
# ('Island Trading', 10321)
# ('Island Trading', 10473)
# ('Island Trading', 10621)
# ('Island Trading', 10674)
# ('Island Trading', 10749)
# ('Island Trading', 10798)
# ('Island Trading', 10829)
# ('Island Trading', 10933)
# ('Königlich Essen', 10323)
# ('Königlich Essen', 10325)
# ('Königlich Essen', 10456)
# ('Königlich Essen', 10457)
# ('Königlich Essen', 10468)
# ('Königlich Essen', 10506)
# ('Königlich Essen', 10542)
# ('Königlich Essen', 10630)
# ('Königlich Essen', 10718)
# ('Königlich Essen', 10799)
# ('Königlich Essen', 10817)
# ('Königlich Essen', 10849)
# ('Königlich Essen', 10893)
# ('Königlich Essen', 11028)
# ('LILA-Supermercado', 10283)
# ('LILA-Supermercado', 10296)
# ('LILA-Supermercado', 10330)
# ('LILA-Supermercado', 10357)
# ('LILA-Supermercado', 10381)
# ('LILA-Supermercado', 10461)
# ('LILA-Supermercado', 10499)
# ('LILA-Supermercado', 10543)
# ('LILA-Supermercado', 10780)
# ('LILA-Supermercado', 10823)
# ('LILA-Supermercado', 10899)
# ('LILA-Supermercado', 10997)
# ('LILA-Supermercado', 11065)
# ('LILA-Supermercado', 11071)
# ('LINO-Delicateses', 10405)
# ('LINO-Delicateses', 10485)
# ('LINO-Delicateses', 10638)
# ('LINO-Delicateses', 10697)
# ('LINO-Delicateses', 10729)
# ('LINO-Delicateses', 10811)
# ('LINO-Delicateses', 10838)
# ('LINO-Delicateses', 10840)
# ('LINO-Delicateses', 10919)
# ('LINO-Delicateses', 10954)
# ('LINO-Delicateses', 11014)
# ('LINO-Delicateses', 11039)
# ("La corne d'abondance", 10858)
# ("La corne d'abondance", 10927)
# ("La corne d'abondance", 10972)
# ("La corne d'abondance", 10973)
# ("La maison d'Asie", 10350)
# ("La maison d'Asie", 10358)
# ("La maison d'Asie", 10371)
# ("La maison d'Asie", 10413)
# ("La maison d'Asie", 10425)
# ("La maison d'Asie", 10454)
# ("La maison d'Asie", 10493)
# ("La maison d'Asie", 10500)
# ("La maison d'Asie", 10610)
# ("La maison d'Asie", 10631)
# ("La maison d'Asie", 10787)
# ("La maison d'Asie", 10832)
# ("La maison d'Asie", 10923)
# ("La maison d'Asie", 11051)
# ('Laughing Bacchus Wine Cellars', 10495)
# ('Laughing Bacchus Wine Cellars', 10620)
# ('Laughing Bacchus Wine Cellars', 10810)
# ('Lazy K Kountry Store', 10482)
# ('Lazy K Kountry Store', 10545)
# ('Lehmanns Marktstand', 10279)
# ('Lehmanns Marktstand', 10284)
# ('Lehmanns Marktstand', 10343)
# ('Lehmanns Marktstand', 10497)
# ('Lehmanns Marktstand', 10522)
# ('Lehmanns Marktstand', 10534)
# ('Lehmanns Marktstand', 10536)
# ('Lehmanns Marktstand', 10557)
# ('Lehmanns Marktstand', 10592)
# ('Lehmanns Marktstand', 10593)
# ('Lehmanns Marktstand', 10772)
# ('Lehmanns Marktstand', 10862)
# ('Lehmanns Marktstand', 10891)
# ('Lehmanns Marktstand', 10934)
# ('Lehmanns Marktstand', 11070)
# ("Let's Stop N Shop", 10579)
# ("Let's Stop N Shop", 10719)
# ("Let's Stop N Shop", 10735)
# ("Let's Stop N Shop", 10884)
# ('Lonesome Pine Restaurant', 10307)
# ('Lonesome Pine Restaurant', 10317)
# ('Lonesome Pine Restaurant', 10544)
# ('Lonesome Pine Restaurant', 10662)
# ('Lonesome Pine Restaurant', 10665)
# ('Lonesome Pine Restaurant', 10867)
# ('Lonesome Pine Restaurant', 10883)
# ('Lonesome Pine Restaurant', 11018)
# ('Magazzini Alimentari Riuniti', 10275)
# ('Magazzini Alimentari Riuniti', 10300)
# ('Magazzini Alimentari Riuniti', 10404)
# ('Magazzini Alimentari Riuniti', 10467)
# ('Magazzini Alimentari Riuniti', 10635)
# ('Magazzini Alimentari Riuniti', 10754)
# ('Magazzini Alimentari Riuniti', 10784)
# ('Magazzini Alimentari Riuniti', 10818)
# ('Magazzini Alimentari Riuniti', 10939)
# ('Magazzini Alimentari Riuniti', 10950)
# ('Maison Dewey', 10529)
# ('Maison Dewey', 10649)
# ('Maison Dewey', 10760)
# ('Maison Dewey', 10892)
# ('Maison Dewey', 10896)
# ('Maison Dewey', 10978)
# ('Maison Dewey', 11004)
# ('Morgenstern Gesundkost', 10277)
# ('Morgenstern Gesundkost', 10575)
# ('Morgenstern Gesundkost', 10699)
# ('Morgenstern Gesundkost', 10779)
# ('Morgenstern Gesundkost', 10945)
# ('Mère Paillarde', 10332)
# ('Mère Paillarde', 10339)
# ('Mère Paillarde', 10376)
# ('Mère Paillarde', 10424)
# ('Mère Paillarde', 10439)
# ('Mère Paillarde', 10505)
# ('Mère Paillarde', 10565)
# ('Mère Paillarde', 10570)
# ('Mère Paillarde', 10590)
# ('Mère Paillarde', 10605)
# ('Mère Paillarde', 10618)
# ('Mère Paillarde', 10619)
# ('Mère Paillarde', 10724)
# ('North/South', 10517)
# ('North/South', 10752)
# ('North/South', 11057)
# ('Océano Atlántico Ltda.', 10409)
# ('Océano Atlántico Ltda.', 10531)
# ('Océano Atlántico Ltda.', 10898)
# ('Océano Atlántico Ltda.', 10958)
# ('Océano Atlántico Ltda.', 10986)
# ('Old World Delicatessen', 10305)
# ('Old World Delicatessen', 10338)
# ('Old World Delicatessen', 10441)
# ('Old World Delicatessen', 10594)
# ('Old World Delicatessen', 10680)
# ('Old World Delicatessen', 10706)
# ('Old World Delicatessen', 10808)
# ('Old World Delicatessen', 10855)
# ('Old World Delicatessen', 10965)
# ('Old World Delicatessen', 11034)
# ('Ottilies Käseladen', 10260)
# ('Ottilies Käseladen', 10407)
# ('Ottilies Käseladen', 10508)
# ('Ottilies Käseladen', 10554)
# ('Ottilies Käseladen', 10580)
# ('Ottilies Käseladen', 10684)
# ('Ottilies Käseladen', 10766)
# ('Ottilies Käseladen', 10833)
# ('Ottilies Käseladen', 10999)
# ('Ottilies Käseladen', 11020)
# ('Paris spécialités', None)
# ('Pericles Comidas clásicas', 10322)
# ('Pericles Comidas clásicas', 10354)
# ('Pericles Comidas clásicas', 10474)
# ('Pericles Comidas clásicas', 10502)
# ('Pericles Comidas clásicas', 10995)
# ('Pericles Comidas clásicas', 11073)
# ('Piccolo und mehr', 10353)
# ('Piccolo und mehr', 10392)
# ('Piccolo und mehr', 10427)
# ('Piccolo und mehr', 10489)
# ('Piccolo und mehr', 10530)
# ('Piccolo und mehr', 10597)
# ('Piccolo und mehr', 10686)
# ('Piccolo und mehr', 10747)
# ('Piccolo und mehr', 10844)
# ('Piccolo und mehr', 11053)
# ('Princesa Isabel Vinhos', 10336)
# ('Princesa Isabel Vinhos', 10397)
# ('Princesa Isabel Vinhos', 10433)
# ('Princesa Isabel Vinhos', 10477)
# ('Princesa Isabel Vinhos', 11007)
# ('QUICK-Stop', 10273)
# ('QUICK-Stop', 10285)
# ('QUICK-Stop', 10286)
# ('QUICK-Stop', 10313)
# ('QUICK-Stop', 10345)
# ('QUICK-Stop', 10361)
# ('QUICK-Stop', 10418)
# ('QUICK-Stop', 10451)
# ('QUICK-Stop', 10515)
# ('QUICK-Stop', 10527)
# ('QUICK-Stop', 10540)
# ('QUICK-Stop', 10549)
# ('QUICK-Stop', 10588)
# ('QUICK-Stop', 10658)
# ('QUICK-Stop', 10691)
# ('QUICK-Stop', 10694)
# ('QUICK-Stop', 10721)
# ('QUICK-Stop', 10745)
# ('QUICK-Stop', 10765)
# ('QUICK-Stop', 10788)
# ('QUICK-Stop', 10845)
# ('QUICK-Stop', 10865)
# ('QUICK-Stop', 10878)
# ('QUICK-Stop', 10938)
# ('QUICK-Stop', 10962)
# ('QUICK-Stop', 10991)
# ('QUICK-Stop', 10996)
# ('QUICK-Stop', 11021)
# ('Que Delícia', 10261)
# ('Que Delícia', 10291)
# ('Que Delícia', 10379)
# ('Que Delícia', 10421)
# ('Que Delícia', 10587)
# ('Que Delícia', 10647)
# ('Que Delícia', 10720)
# ('Que Delícia', 10794)
# ('Que Delícia', 10989)
# ('Queen Cozinha', 10372)
# ('Queen Cozinha', 10406)
# ('Queen Cozinha', 10487)
# ('Queen Cozinha', 10637)
# ('Queen Cozinha', 10659)
# ('Queen Cozinha', 10704)
# ('Queen Cozinha', 10728)
# ('Queen Cozinha', 10786)
# ('Queen Cozinha', 10868)
# ('Queen Cozinha', 10913)
# ('Queen Cozinha', 10914)
# ('Queen Cozinha', 10961)
# ('Queen Cozinha', 11068)
# ('Rancho grande', 10448)
# ('Rancho grande', 10716)
# ('Rancho grande', 10828)
# ('Rancho grande', 10916)
# ('Rancho grande', 11019)
# ('Rattlesnake Canyon Grocery', 10262)
# ('Rattlesnake Canyon Grocery', 10272)
# ('Rattlesnake Canyon Grocery', 10294)
# ('Rattlesnake Canyon Grocery', 10314)
# ('Rattlesnake Canyon Grocery', 10316)
# ('Rattlesnake Canyon Grocery', 10346)
# ('Rattlesnake Canyon Grocery', 10401)
# ('Rattlesnake Canyon Grocery', 10479)
# ('Rattlesnake Canyon Grocery', 10564)
# ('Rattlesnake Canyon Grocery', 10569)
# ('Rattlesnake Canyon Grocery', 10598)
# ('Rattlesnake Canyon Grocery', 10761)
# ('Rattlesnake Canyon Grocery', 10820)
# ('Rattlesnake Canyon Grocery', 10852)
# ('Rattlesnake Canyon Grocery', 10889)
# ('Rattlesnake Canyon Grocery', 10988)
# ('Rattlesnake Canyon Grocery', 11000)
# ('Rattlesnake Canyon Grocery', 11077)
# ('Reggiani Caseifici', 10288)
# ('Reggiani Caseifici', 10428)
# ('Reggiani Caseifici', 10443)
# ('Reggiani Caseifici', 10562)
# ('Reggiani Caseifici', 10586)
# ('Reggiani Caseifici', 10655)
# ('Reggiani Caseifici', 10727)
# ('Reggiani Caseifici', 10812)
# ('Reggiani Caseifici', 10908)
# ('Reggiani Caseifici', 10942)
# ('Reggiani Caseifici', 11010)
# ('Reggiani Caseifici', 11062)
# ('Ricardo Adocicados', 10287)
# ('Ricardo Adocicados', 10299)
# ('Ricardo Adocicados', 10447)
# ('Ricardo Adocicados', 10481)
# ('Ricardo Adocicados', 10563)
# ('Ricardo Adocicados', 10622)
# ('Ricardo Adocicados', 10648)
# ('Ricardo Adocicados', 10813)
# ('Ricardo Adocicados', 10851)
# ('Ricardo Adocicados', 10877)
# ('Ricardo Adocicados', 11059)
# ('Richter Supermarkt', 10255)
# ('Richter Supermarkt', 10419)
# ('Richter Supermarkt', 10537)
# ('Richter Supermarkt', 10666)
# ('Richter Supermarkt', 10751)
# ('Richter Supermarkt', 10758)
# ('Richter Supermarkt', 10931)
# ('Richter Supermarkt', 10951)
# ('Richter Supermarkt', 11033)
# ('Richter Supermarkt', 11075)
# ('Romero y tomillo', 10281)
# ('Romero y tomillo', 10282)
# ('Romero y tomillo', 10306)
# ('Romero y tomillo', 10917)
# ('Romero y tomillo', 11013)
# ('Santé Gourmet', 10387)
# ('Santé Gourmet', 10520)
# ('Santé Gourmet', 10639)
# ('Santé Gourmet', 10831)
# ('Santé Gourmet', 10909)
# ('Santé Gourmet', 11015)
# ('Save-a-lot Markets', 10324)
# ('Save-a-lot Markets', 10393)
# ('Save-a-lot Markets', 10398)
# ('Save-a-lot Markets', 10440)
# ('Save-a-lot Markets', 10452)
# ('Save-a-lot Markets', 10510)
# ('Save-a-lot Markets', 10555)
# ('Save-a-lot Markets', 10603)
# ('Save-a-lot Markets', 10607)
# ('Save-a-lot Markets', 10612)
# ('Save-a-lot Markets', 10627)
# ('Save-a-lot Markets', 10657)
# ('Save-a-lot Markets', 10678)
# ('Save-a-lot Markets', 10700)
# ('Save-a-lot Markets', 10711)
# ('Save-a-lot Markets', 10713)
# ('Save-a-lot Markets', 10714)
# ('Save-a-lot Markets', 10722)
# ('Save-a-lot Markets', 10748)
# ('Save-a-lot Markets', 10757)
# ('Save-a-lot Markets', 10815)
# ('Save-a-lot Markets', 10847)
# ('Save-a-lot Markets', 10882)
# ('Save-a-lot Markets', 10894)
# ('Save-a-lot Markets', 10941)
# ('Save-a-lot Markets', 10983)
# ('Save-a-lot Markets', 10984)
# ('Save-a-lot Markets', 11002)
# ('Save-a-lot Markets', 11030)
# ('Save-a-lot Markets', 11031)
# ('Save-a-lot Markets', 11064)
# ('Seven Seas Imports', 10359)
# ('Seven Seas Imports', 10377)
# ('Seven Seas Imports', 10388)
# ('Seven Seas Imports', 10472)
# ('Seven Seas Imports', 10523)
# ('Seven Seas Imports', 10547)
# ('Seven Seas Imports', 10800)
# ('Seven Seas Imports', 10804)
# ('Seven Seas Imports', 10869)
# ('Simons bistro', 10341)
# ('Simons bistro', 10417)
# ('Simons bistro', 10556)
# ('Simons bistro', 10642)
# ('Simons bistro', 10669)
# ('Simons bistro', 10802)
# ('Simons bistro', 11074)
# ('Split Rail Beer & Ale', 10271)
# ('Split Rail Beer & Ale', 10329)
# ('Split Rail Beer & Ale', 10349)
# ('Split Rail Beer & Ale', 10369)
# ('Split Rail Beer & Ale', 10385)
# ('Split Rail Beer & Ale', 10432)
# ('Split Rail Beer & Ale', 10756)
# ('Split Rail Beer & Ale', 10821)
# ('Split Rail Beer & Ale', 10974)
# ('Spécialités du monde', 10738)
# ('Spécialités du monde', 10907)
# ('Spécialités du monde', 10964)
# ('Spécialités du monde', 11043)
# ('Suprêmes délices', 10252)
# ('Suprêmes délices', 10302)
# ('Suprêmes délices', 10458)
# ('Suprêmes délices', 10463)
# ('Suprêmes délices', 10475)
# ('Suprêmes délices', 10767)
# ('Suprêmes délices', 10841)
# ('Suprêmes délices', 10846)
# ('Suprêmes délices', 10885)
# ('Suprêmes délices', 10930)
# ('Suprêmes délices', 11035)
# ('Suprêmes délices', 11038)
# ('Tasty Tee', None)
# ('The Big Cheese', 10310)
# ('The Big Cheese', 10708)
# ('The Big Cheese', 10805)
# ('The Big Cheese', 10992)
# ('The Cracker Box', 10624)
# ('The Cracker Box', 10775)
# ('The Cracker Box', 11003)
# ('Toms Spezialitäten', 10249)
# ('Toms Spezialitäten', 10438)
# ('Toms Spezialitäten', 10446)
# ('Toms Spezialitäten', 10548)
# ('Toms Spezialitäten', 10608)
# ('Toms Spezialitäten', 10967)
# ('Tortuga Restaurante', 10276)
# ('Tortuga Restaurante', 10293)
# ('Tortuga Restaurante', 10304)
# ('Tortuga Restaurante', 10319)
# ('Tortuga Restaurante', 10518)
# ('Tortuga Restaurante', 10576)
# ('Tortuga Restaurante', 10676)
# ('Tortuga Restaurante', 10842)
# ('Tortuga Restaurante', 10915)
# ('Tortuga Restaurante', 11069)
# ('Tradição Hipermercados', 10292)
# ('Tradição Hipermercados', 10496)
# ('Tradição Hipermercados', 10606)
# ('Tradição Hipermercados', 10830)
# ('Tradição Hipermercados', 10834)
# ('Tradição Hipermercados', 10839)
# ("Trail's Head Gourmet Provisioners", 10574)
# ("Trail's Head Gourmet Provisioners", 10577)
# ("Trail's Head Gourmet Provisioners", 10822)
# ('Vaffeljernet', 10367)
# ('Vaffeljernet', 10399)
# ('Vaffeljernet', 10465)
# ('Vaffeljernet', 10591)
# ('Vaffeljernet', 10602)
# ('Vaffeljernet', 10688)
# ('Vaffeljernet', 10744)
# ('Vaffeljernet', 10769)
# ('Vaffeljernet', 10921)
# ('Vaffeljernet', 10946)
# ('Vaffeljernet', 10994)
# ('Victuailles en stock', 10251)
# ('Victuailles en stock', 10334)
# ('Victuailles en stock', 10450)
# ('Victuailles en stock', 10459)
# ('Victuailles en stock', 10478)
# ('Victuailles en stock', 10546)
# ('Victuailles en stock', 10806)
# ('Victuailles en stock', 10814)
# ('Victuailles en stock', 10843)
# ('Victuailles en stock', 10850)
# ('Vins et alcools Chevalier', 10248)
# ('Vins et alcools Chevalier', 10274)
# ('Vins et alcools Chevalier', 10295)
# ('Vins et alcools Chevalier', 10737)
# ('Vins et alcools Chevalier', 10739)
# ('Wartian Herkku', 10266)
# ('Wartian Herkku', 10270)
# ('Wartian Herkku', 10320)
# ('Wartian Herkku', 10333)
# ('Wartian Herkku', 10412)
# ('Wartian Herkku', 10416)
# ('Wartian Herkku', 10437)
# ('Wartian Herkku', 10455)
# ('Wartian Herkku', 10526)
# ('Wartian Herkku', 10553)
# ('Wartian Herkku', 10583)
# ('Wartian Herkku', 10636)
# ('Wartian Herkku', 10750)
# ('Wartian Herkku', 10781)
# ('Wartian Herkku', 11025)
# ('Wellington Importadora', 10256)
# ('Wellington Importadora', 10420)
# ('Wellington Importadora', 10585)
# ('Wellington Importadora', 10644)
# ('Wellington Importadora', 10803)
# ('Wellington Importadora', 10809)
# ('Wellington Importadora', 10900)
# ('Wellington Importadora', 10905)
# ('Wellington Importadora', 10935)
# ('White Clover Markets', 10269)
# ('White Clover Markets', 10344)
# ('White Clover Markets', 10469)
# ('White Clover Markets', 10483)
# ('White Clover Markets', 10504)
# ('White Clover Markets', 10596)
# ('White Clover Markets', 10693)
# ('White Clover Markets', 10696)
# ('White Clover Markets', 10723)
# ('White Clover Markets', 10740)
# ('White Clover Markets', 10861)
# ('White Clover Markets', 10904)
# ('White Clover Markets', 11032)
# ('White Clover Markets', 11066)
# ('Wilman Kala', 10615)
# ('Wilman Kala', 10673)
# ('Wilman Kala', 10695)
# ('Wilman Kala', 10873)
# ('Wilman Kala', 10879)
# ('Wilman Kala', 10910)
# ('Wilman Kala', 11005)
# ('Wolski  Zajazd', 10374)
# ('Wolski  Zajazd', 10611)
# ('Wolski  Zajazd', 10792)
# ('Wolski  Zajazd', 10870)
# ('Wolski  Zajazd', 10906)
# ('Wolski  Zajazd', 10998)
# ('Wolski  Zajazd', 11044)

# %%
run_query("SQL Self Join", "SELECT A.CustomerName AS CustomerName1, B.CustomerName AS CustomerName2, A.City FROM Customers A, Customers B WHERE A.CustomerID <> B.CustomerID AND A.City = B.City ORDER BY A.City;")
# Out:
#  SQL Self Join
# SQL : SELECT A.CustomerName AS CustomerName1, B.CustomerName AS CustomerName2, A.City FROM Customers A, Customers B WHERE A.CustomerID <> B.CustomerID AND A.City = B.City ORDER BY A.City;
# ('Cactus Comidas para llevar', 'Océano Atlántico Ltda.', 'Buenos Aires')
# ('Cactus Comidas para llevar', 'Rancho grande', 'Buenos Aires')
# ('Océano Atlántico Ltda.', 'Cactus Comidas para llevar', 'Buenos Aires')
# ('Océano Atlántico Ltda.', 'Rancho grande', 'Buenos Aires')
# ('Rancho grande', 'Cactus Comidas para llevar', 'Buenos Aires')
# ('Rancho grande', 'Océano Atlántico Ltda.', 'Buenos Aires')
# ('Furia Bacalhau e Frutos do Mar', 'Princesa Isabel Vinhos', 'Lisboa')
# ('Princesa Isabel Vinhos', 'Furia Bacalhau e Frutos do Mar', 'Lisboa')
# ('Around the Horn', "B's Beverages", 'London')
# ('Around the Horn', 'Consolidated Holdings', 'London')
# ('Around the Horn', 'Eastern Connection', 'London')
# ('Around the Horn', 'North/South', 'London')
# ('Around the Horn', 'Seven Seas Imports', 'London')
# ("B's Beverages", 'Around the Horn', 'London')
# ("B's Beverages", 'Consolidated Holdings', 'London')
# ("B's Beverages", 'Eastern Connection', 'London')
# ("B's Beverages", 'North/South', 'London')
# ("B's Beverages", 'Seven Seas Imports', 'London')
# ('Consolidated Holdings', 'Around the Horn', 'London')
# ('Consolidated Holdings', "B's Beverages", 'London')
# ('Consolidated Holdings', 'Eastern Connection', 'London')
# ('Consolidated Holdings', 'North/South', 'London')
# ('Consolidated Holdings', 'Seven Seas Imports', 'London')
# ('Eastern Connection', 'Around the Horn', 'London')
# ('Eastern Connection', "B's Beverages", 'London')
# ('Eastern Connection', 'Consolidated Holdings', 'London')
# ('Eastern Connection', 'North/South', 'London')
# ('Eastern Connection', 'Seven Seas Imports', 'London')
# ('North/South', 'Around the Horn', 'London')
# ('North/South', "B's Beverages", 'London')
# ('North/South', 'Consolidated Holdings', 'London')
# ('North/South', 'Eastern Connection', 'London')
# ('North/South', 'Seven Seas Imports', 'London')
# ('Seven Seas Imports', 'Around the Horn', 'London')
# ('Seven Seas Imports', "B's Beverages", 'London')
# ('Seven Seas Imports', 'Consolidated Holdings', 'London')
# ('Seven Seas Imports', 'Eastern Connection', 'London')
# ('Seven Seas Imports', 'North/South', 'London')
# ('Bólido Comidas preparadas', 'FISSA Fabrica Inter. Salchichas S.A.', 'Madrid')
# ('Bólido Comidas preparadas', 'Romero y tomillo', 'Madrid')
# ('FISSA Fabrica Inter. Salchichas S.A.', 'Bólido Comidas preparadas', 'Madrid')
# ('FISSA Fabrica Inter. Salchichas S.A.', 'Romero y tomillo', 'Madrid')
# ('Romero y tomillo', 'Bólido Comidas preparadas', 'Madrid')
# ('Romero y tomillo', 'FISSA Fabrica Inter. Salchichas S.A.', 'Madrid')
# ('Ana Trujillo Emparedados y helados', 'Antonio Moreno Taquería', 'México D.F.')
# ('Ana Trujillo Emparedados y helados', 'Centro comercial Moctezuma', 'México D.F.')
# ('Ana Trujillo Emparedados y helados', 'Pericles Comidas clásicas', 'México D.F.')
# ('Ana Trujillo Emparedados y helados', 'Tortuga Restaurante', 'México D.F.')
# ('Antonio Moreno Taquería', 'Ana Trujillo Emparedados y helados', 'México D.F.')
# ('Antonio Moreno Taquería', 'Centro comercial Moctezuma', 'México D.F.')
# ('Antonio Moreno Taquería', 'Pericles Comidas clásicas', 'México D.F.')
# ('Antonio Moreno Taquería', 'Tortuga Restaurante', 'México D.F.')
# ('Centro comercial Moctezuma', 'Ana Trujillo Emparedados y helados', 'México D.F.')
# ('Centro comercial Moctezuma', 'Antonio Moreno Taquería', 'México D.F.')
# ('Centro comercial Moctezuma', 'Pericles Comidas clásicas', 'México D.F.')
# ('Centro comercial Moctezuma', 'Tortuga Restaurante', 'México D.F.')
# ('Pericles Comidas clásicas', 'Ana Trujillo Emparedados y helados', 'México D.F.')
# ('Pericles Comidas clásicas', 'Antonio Moreno Taquería', 'México D.F.')
# ('Pericles Comidas clásicas', 'Centro comercial Moctezuma', 'México D.F.')
# ('Pericles Comidas clásicas', 'Tortuga Restaurante', 'México D.F.')
# ('Tortuga Restaurante', 'Ana Trujillo Emparedados y helados', 'México D.F.')
# ('Tortuga Restaurante', 'Antonio Moreno Taquería', 'México D.F.')
# ('Tortuga Restaurante', 'Centro comercial Moctezuma', 'México D.F.')
# ('Tortuga Restaurante', 'Pericles Comidas clásicas', 'México D.F.')
# ('Du monde entier', 'France restauration', 'Nantes')
# ('France restauration', 'Du monde entier', 'Nantes')
# ('Paris spécialités', 'Spécialités du monde', 'Paris')
# ('Spécialités du monde', 'Paris spécialités', 'Paris')
# ('Lonesome Pine Restaurant', 'The Big Cheese', 'Portland')
# ('The Big Cheese', 'Lonesome Pine Restaurant', 'Portland')
# ('Hanari Carnes', 'Ricardo Adocicados', 'Rio de Janeiro')
# ('Ricardo Adocicados', 'Hanari Carnes', 'Rio de Janeiro')
# ('Comércio Mineiro', 'Familia Arquibaldo', 'Sao Paulo')
# ('Comércio Mineiro', 'Queen Cozinha', 'Sao Paulo')
# ('Comércio Mineiro', 'Tradição Hipermercados', 'Sao Paulo')
# ('Familia Arquibaldo', 'Comércio Mineiro', 'Sao Paulo')
# ('Familia Arquibaldo', 'Queen Cozinha', 'Sao Paulo')
# ('Familia Arquibaldo', 'Tradição Hipermercados', 'Sao Paulo')
# ('Queen Cozinha', 'Comércio Mineiro', 'Sao Paulo')
# ('Queen Cozinha', 'Familia Arquibaldo', 'Sao Paulo')
# ('Queen Cozinha', 'Tradição Hipermercados', 'Sao Paulo')
# ('Tradição Hipermercados', 'Comércio Mineiro', 'Sao Paulo')
# ('Tradição Hipermercados', 'Familia Arquibaldo', 'Sao Paulo')
# ('Tradição Hipermercados', 'Queen Cozinha', 'Sao Paulo')

# %%
run_query("SQL Union", "SELECT City FROM Customers UNION SELECT City FROM Suppliers ORDER BY City;")
# Out:
#  SQL Union
# SQL : SELECT City FROM Customers UNION SELECT City FROM Suppliers ORDER BY City;
# (' 12Rio de Janeiro',)
# ('Aachen',)
# ('Albuquerque',)
# ('Anchorage',)
# ('Ann Arbor',)
# ('Annecy',)
# ('Barcelona',)
# ('Barquisimeto',)
# ('Bend',)
# ('Bergamo',)
# ('Berlin',)
# ('Bern',)
# ('Boise',)
# ('Boston',)
# ('Brandenburg',)
# ('Bruxelles',)
# ('Bräcke',)
# ('Buenos Aires',)
# ('Butte',)
# ('Campinas',)
# ('Caracas',)
# ('Charleroi',)
# ('Cork',)
# ('Cowes',)
# ('Cunewalde',)
# ('Cuxhaven',)
# ('Elgin',)
# ('Eugene',)
# ('Frankfurt',)
# ('Frankfurt a.M.',)
# ('Genève',)
# ('Graz',)
# ('Göteborg',)
# ('Helsinki',)
# ('I. de Margarita',)
# ('Kirkland',)
# ('Kobenhavn',)
# ('Köln',)
# ('Lander',)
# ('Lappeenranta',)
# ('Leipzig',)
# ('Lille',)
# ('Lisboa',)
# ('Liverpool',)
# ('London',)
# ('Luleå',)
# ('Lyngby',)
# ('Lyon',)
# ('Madrid',)
# ('Manchester',)
# ('Mannheim',)
# ('Marseille',)
# ('Melbourne',)
# ('Montceau',)
# ('Montréal',)
# ('México D.F.',)
# ('München',)
# ('Münster',)
# ('Nantes',)
# ('New Orleans',)
# ('Osaka',)
# ('Oulu',)
# ('Oviedo',)
# ('Paris',)
# ('Portland',)
# ('Ravenna',)
# ('Reggio Emilia',)
# ('Reims',)
# ('Resende',)
# ('Rio de Janeiro',)
# ('Salerno',)
# ('Salzburg',)
# ('San Cristóbal',)
# ('San Francisco',)
# ('Sandnes',)
# ('Sandvika',)
# ('Sao Paulo',)
# ('Seattle',)
# ('Sevilla',)
# ('Singapore',)
# ('Stavanger',)
# ('Stavern',)
# ('Ste-Hyacinthe',)
# ('Stockholm',)
# ('Strasbourg',)
# ('Stuttgart',)
# ('Sydney',)
# ('Tokyo',)
# ('Torino',)
# ('Toulouse',)
# ('Tsawassen',)
# ('Vancouver',)
# ('Versailles',)
# ('Walla Walla',)
# ('Warszawa',)
# ('Zaandam',)
# ('Århus',)

# %%
run_query("SQL Group By", "SELECT COUNT(CustomerID), Country FROM Customers GROUP BY Country;")
# Out:
#  SQL Group By
# SQL : SELECT COUNT(CustomerID), Country FROM Customers GROUP BY Country;
# (3, 'Argentina')
# (2, 'Austria')
# (2, 'Belgium')
# (9, 'Brazil')
# (3, 'Canada')
# (2, 'Denmark')
# (2, 'Finland')
# (11, 'France')
# (10, 'Germany')
# (1, 'Ireland')
# (3, 'Italy')
# (5, 'Mexico')
# (1, 'Norway')
# (1, 'Poland')
# (2, 'Portugal')
# (5, 'Spain')
# (2, 'Sweden')
# (2, 'Switzerland')
# (7, 'UK')
# (13, 'USA')
# (4, 'Venezuela')

# %%
run_query("SQL Having", "SELECT COUNT(CustomerID), Country FROM Customers GROUP BY Country HAVING COUNT(CustomerID) > 5;")
# Out:
#  SQL Having
# SQL : SELECT COUNT(CustomerID), Country FROM Customers GROUP BY Country HAVING COUNT(CustomerID) > 5;
# (9, 'Brazil')
# (11, 'France')
# (10, 'Germany')
# (7, 'UK')
# (13, 'USA')

# %%
run_query("SQL Exists", "SELECT CompanyName FROM Suppliers WHERE EXISTS (SELECT ProductName FROM Products WHERE Products.SupplierID = Suppliers.supplierID AND unitPrice < 20);")
# Out:
#  SQL Exists
# SQL : SELECT CompanyName FROM Suppliers WHERE EXISTS (SELECT ProductName FROM Products WHERE Products.SupplierID = Suppliers.supplierID AND unitPrice < 20);
# ('Exotic Liquids',)
# ('New Orleans Cajun Delights',)
# ('Tokyo Traders',)
# ("Mayumi's",)
# ('Pavlova Ltd.',)
# ('Specialty Biscuits Ltd.',)
# ('PB Knäckebröd AB',)
# ('Refrescos Americanas LTDA',)
# ('Heli Süßwaren GmbH & Co. KG',)
# ('Plutzer Lebensmittelgroßmärkte AG',)
# ('Formaggi Fortini s.r.l.',)
# ('Norske Meierier',)
# ('Bigfoot Breweries',)
# ('Svensk Sjöföda AB',)
# ('Aux joyeux ecclésiastiques',)
# ('New England Seafood Cannery',)
# ('Leka Trading',)
# ('Lyngbysild',)
# ('Zaanse Snoepfabriek',)
# ('Karkki Oy',)
# ("G'day Mate",)
# ('Ma Maison',)
# ('Pasta Buttini s.r.l.',)
# ('Escargots Nouveaux',)

# %%
# SQLite에서 하위 쿼리 결과와 비교할 때는 ANY나 ALL 대신 'IN', 'NOT IN'을 사용한다. >> 더 표준적이고 호환성이 높은 방법
run_query("SQL Any,All", "SELECT ProductName FROM Products WHERE ProductID IN (SELECT ProductID FROM Order_details WHERE Quantity = 10);")
# Out:
#  SQL Any,All
# SQL : SELECT ProductName FROM Products WHERE ProductID IN (SELECT ProductID FROM Order_details WHERE Quantity = 10);
# ('Chai',)
# ('Chang',)
# ("Chef Anton's Cajun Seasoning",)
# ("Uncle Bob's Organic Dried Pears",)
# ('Northwoods Cranberry Sauce',)
# ('Ikura',)
# ('Queso Cabrales',)
# ('Konbu',)
# ('Tofu',)
# ('Genen Shouyu',)
# ('Pavlova',)
# ('Alice Mutton',)
# ('Carnarvon Tigers',)
# ('Teatime Chocolate Biscuits',)
# ("Sir Rodney's Scones",)
# ('Tunnbröd',)
# ('Guaraná Fantástica',)
# ('NuNuCa Nuß-Nougat-Creme',)
# ('Gumbär Gummibärchen',)
# ('Schoggi Schokolade',)
# ('Rössle Sauerkraut',)
# ('Thüringer Rostbratwurst',)
# ('Nord-Ost Matjeshering',)
# ('Gorgonzola Telino',)
# ('Mascarpone Fabioli',)
# ('Geitost',)
# ('Sasquatch Ale',)
# ('Steeleye Stout',)
# ('Gravad lax',)
# ('Côte de Blaye',)
# ('Chartreuse verte',)
# ('Boston Crab Meat',)
# ("Jack's New England Clam Chowder",)
# ('Singaporean Hokkien Fried Mee',)
# ('Ipoh Coffee',)
# ('Gula Malacca',)
# ('Spegesild',)
# ('Zaanse koeken',)
# ('Maxilaku',)
# ('Manjimup Dried Apples',)
# ('Filo Mix',)
# ('Perth Pasties',)
# ('Tourtière',)
# ('Pâté chinois',)
# ('Gnocchi di nonna Alice',)
# ('Ravioli Angelo',)
# ('Raclette Courdavault',)
# ('Camembert Pierrot',)
# ("Sirop d'érable",)
# ('Tarte au sucre',)
# ('Vegie-spread',)
# ('Louisiana Fiery Hot Pepper Sauce',)
# ('Louisiana Hot Spiced Okra',)
# ('Scottish Longbreads',)
# ('Gudbrandsdalsost',)
# ('Mozzarella di Giovanni',)
# ('Röd Kaviar',)
# ('Rhönbräu Klosterbier',)
# ('Lakkalikööri',)
# ('Original Frankfurter grüne Soße',)

# %%
# SQLite에서는 SELECT INTO 문법을 지원하지 않는다.
# run_query("SQL Select Into", "SELECT * INTO CustomersBackup2017 FROM Customers;")

# %%
run_query("SQL Insert Into Select", "INSERT INTO Customers (CustomerName, City, Country) SELECT CompanyName, City, Country FROM Suppliers;")
# Out:
#  SQL Insert Into Select
# SQL : INSERT INTO Customers (CustomerName, City, Country) SELECT CompanyName, City, Country FROM Suppliers;

# %%
run_query("SQL Case", "SELECT CustomerName, City, Country FROM Customers ORDER BY (CASE WHEN City IS NULL THEN Country ELSE City END);")
# Out:
#  SQL Case
# SQL : SELECT CustomerName, City, Country FROM Customers ORDER BY (CASE WHEN City IS NULL THEN Country ELSE City END);
# ('Que Delícia', ' 12Rio de Janeiro', 'Brazil')
# ('Drachenblut Delikatessen', 'Aachen', 'Germany')
# ('Rattlesnake Canyon Grocery', 'Albuquerque', 'USA')
# ('Old World Delicatessen', 'Anchorage', 'USA')
# ("Grandma Kelly's Homestead", 'Ann Arbor', 'USA')
# ("Grandma Kelly's Homestead", 'Ann Arbor', 'USA')
# ('Regina Murphy', 'Ann Arbor', 'USA')
# ('Sales Representative', 'Ann Arbor', 'USA')
# ("Grandma Kelly's Homestead", 'Ann Arbor', 'USA')
# ("Grandma Kelly's Homestead", 'Ann Arbor', 'USA')
# ("Grandma Kelly's Homestead", 'Ann Arbor', 'USA')
# ("Grandma Kelly's Homestead", 'Ann Arbor', 'USA')
# ("Grandma Kelly's Homestead", 'Ann Arbor', 'USA')
# ('Gai pâturage', 'Annecy', 'France')
# ('Gai pâturage', 'Annecy', 'France')
# ('Eliane Noz', 'Annecy', 'France')
# ('Sales Representative', 'Annecy', 'France')
# ('Gai pâturage', 'Annecy', 'France')
# ('Gai pâturage', 'Annecy', 'France')
# ('Gai pâturage', 'Annecy', 'France')
# ('Gai pâturage', 'Annecy', 'France')
# ('Gai pâturage', 'Annecy', 'France')
# ('Galería del gastrónomo', 'Barcelona', 'Spain')
# ('LILA-Supermercado', 'Barquisimeto', 'Venezuela')
# ('Bigfoot Breweries', 'Bend', 'USA')
# ('Bigfoot Breweries', 'Bend', 'USA')
# ('Cheryl Saylor', 'Bend', 'USA')
# ('Regional Account Rep.', 'Bend', 'USA')
# ('Bigfoot Breweries', 'Bend', 'USA')
# ('Bigfoot Breweries', 'Bend', 'USA')
# ('Bigfoot Breweries', 'Bend', 'USA')
# ('Bigfoot Breweries', 'Bend', 'USA')
# ('Bigfoot Breweries', 'Bend', 'USA')
# ('Magazzini Alimentari Riuniti', 'Bergamo', 'Italy')
# ('Petra Winkler', 'Berlin', 'Germany')
# ('Heli Süßwaren GmbH & Co. KG', 'Berlin', 'Germany')
# ('Heli Süßwaren GmbH & Co. KG', 'Berlin', 'Germany')
# ('Heli Süßwaren GmbH & Co. KG', 'Berlin', 'Germany')
# ('Petra Winkler', 'Berlin', 'Germany')
# ('Sales Manager', 'Berlin', 'Germany')
# ('Heli Süßwaren GmbH & Co. KG', 'Berlin', 'Germany')
# ('Heli Süßwaren GmbH & Co. KG', 'Berlin', 'Germany')
# ('Heli Süßwaren GmbH & Co. KG', 'Berlin', 'Germany')
# ('Heli Süßwaren GmbH & Co. KG', 'Berlin', 'Germany')
# ('Heli Süßwaren GmbH & Co. KG', 'Berlin', 'Germany')
# ('Petra Winkler', 'Berlin', 'Germany')
# ('Heli Süßwaren GmbH & Co. KG', 'Berlin', 'Germany')
# ('Chop-suey Chinese', 'Bern', 'Switzerland')
# ('Save-a-lot Markets', 'Boise', 'USA')
# ('New England Seafood Cannery', 'Boston', 'USA')
# ('New England Seafood Cannery', 'Boston', 'USA')
# ('Robb Merchant', 'Boston', 'USA')
# ('Wholesale Account Agent', 'Boston', 'USA')
# ('New England Seafood Cannery', 'Boston', 'USA')
# ('New England Seafood Cannery', 'Boston', 'USA')
# ('New England Seafood Cannery', 'Boston', 'USA')
# ('New England Seafood Cannery', 'Boston', 'USA')
# ('New England Seafood Cannery', 'Boston', 'USA')
# ('Königlich Essen', 'Brandenburg', 'Germany')
# ('Maison Dewey', 'Bruxelles', 'Belgium')
# ('Folk och fä HB', 'Bräcke', 'Sweden')
# ('Cactus Comidas para llevar', 'Buenos Aires', 'Argentina')
# ('Océano Atlántico Ltda.', 'Buenos Aires', 'Argentina')
# ('Rancho grande', 'Buenos Aires', 'Argentina')
# ('The Cracker Box', 'Butte', 'USA')
# ('Gourmet Lanchonetes', 'Campinas', 'Brazil')
# ('GROSELLA-Restaurante', 'Caracas', 'Venezuela')
# ('Suprêmes délices', 'Charleroi', 'Belgium')
# ('Hungry Owl All-Night Grocers', 'Cork', 'Ireland')
# ('Island Trading', 'Cowes', 'UK')
# ('QUICK-Stop', 'Cunewalde', 'Germany')
# ('Sven Petersen', 'Cuxhaven', 'Germany')
# ('Nord-Ost-Fisch Handelsgesellschaft mbH', 'Cuxhaven', 'Germany')
# ('Nord-Ost-Fisch Handelsgesellschaft mbH', 'Cuxhaven', 'Germany')
# ('Nord-Ost-Fisch Handelsgesellschaft mbH', 'Cuxhaven', 'Germany')
# ('Sven Petersen', 'Cuxhaven', 'Germany')
# ('Coordinator Foreign Markets', 'Cuxhaven', 'Germany')
# ('Nord-Ost-Fisch Handelsgesellschaft mbH', 'Cuxhaven', 'Germany')
# ('Nord-Ost-Fisch Handelsgesellschaft mbH', 'Cuxhaven', 'Germany')
# ('Nord-Ost-Fisch Handelsgesellschaft mbH', 'Cuxhaven', 'Germany')
# ('Nord-Ost-Fisch Handelsgesellschaft mbH', 'Cuxhaven', 'Germany')
# ('Nord-Ost-Fisch Handelsgesellschaft mbH', 'Cuxhaven', 'Germany')
# ('Sven Petersen', 'Cuxhaven', 'Germany')
# ('Nord-Ost-Fisch Handelsgesellschaft mbH', 'Cuxhaven', 'Germany')
# ('Hungry Coyote Import Store', 'Elgin', 'USA')
# ('Great Lakes Food Market', 'Eugene', 'USA')
# ('Martin Bein', 'Frankfurt', 'Germany')
# ('Plutzer Lebensmittelgroßmärkte AG', 'Frankfurt', 'Germany')
# ('Plutzer Lebensmittelgroßmärkte AG', 'Frankfurt', 'Germany')
# ('Plutzer Lebensmittelgroßmärkte AG', 'Frankfurt', 'Germany')
# ('Martin Bein', 'Frankfurt', 'Germany')
# ('International Marketing Mgr.', 'Frankfurt', 'Germany')
# ('Plutzer Lebensmittelgroßmärkte AG', 'Frankfurt', 'Germany')
# ('Plutzer Lebensmittelgroßmärkte AG', 'Frankfurt', 'Germany')
# ('Plutzer Lebensmittelgroßmärkte AG', 'Frankfurt', 'Germany')
# ('Plutzer Lebensmittelgroßmärkte AG', 'Frankfurt', 'Germany')
# ('Plutzer Lebensmittelgroßmärkte AG', 'Frankfurt', 'Germany')
# ('Martin Bein', 'Frankfurt', 'Germany')
# ('Plutzer Lebensmittelgroßmärkte AG', 'Frankfurt', 'Germany')
# ('Lehmanns Marktstand', 'Frankfurt a.M.', 'Germany')
# ('Richter Supermarkt', 'Genève', 'Switzerland')
# ('Ernst Handel', 'Graz', 'Austria')
# ('PB Knäckebröd AB', 'Göteborg', 'Sweden')
# ('PB Knäckebröd AB', 'Göteborg', 'Sweden')
# ('Lars Peterson', 'Göteborg', 'Sweden')
# ('Sales Agent', 'Göteborg', 'Sweden')
# ('PB Knäckebröd AB', 'Göteborg', 'Sweden')
# ('PB Knäckebröd AB', 'Göteborg', 'Sweden')
# ('PB Knäckebröd AB', 'Göteborg', 'Sweden')
# ('PB Knäckebröd AB', 'Göteborg', 'Sweden')
# ('PB Knäckebröd AB', 'Göteborg', 'Sweden')
# ('Wilman Kala', 'Helsinki', 'Finland')
# ('LINO-Delicateses', 'I. de Margarita', 'Venezuela')
# ("Trail's Head Gourmet Provisioners", 'Kirkland', 'USA')
# ('Simons bistro', 'Kobenhavn', 'Denmark')
# ('Ottilies Käseladen', 'Köln', 'Germany')
# ('Split Rail Beer & Ale', 'Lander', 'USA')
# ('Karkki Oy', 'Lappeenranta', 'Finland')
# ('Karkki Oy', 'Lappeenranta', 'Finland')
# ('Anne Heikkonen', 'Lappeenranta', 'Finland')
# ('Product Manager', 'Lappeenranta', 'Finland')
# ('Karkki Oy', 'Lappeenranta', 'Finland')
# ('Karkki Oy', 'Lappeenranta', 'Finland')
# ('Karkki Oy', 'Lappeenranta', 'Finland')
# ('Karkki Oy', 'Lappeenranta', 'Finland')
# ('Karkki Oy', 'Lappeenranta', 'Finland')
# ('Morgenstern Gesundkost', 'Leipzig', 'Germany')
# ('Folies gourmandes', 'Lille', 'France')
# ('Furia Bacalhau e Frutos do Mar', 'Lisboa', 'Portugal')
# ('Princesa Isabel Vinhos', 'Lisboa', 'Portugal')
# ('Tasty Tee', 'Liverpool', 'UK')
# ('Around the Horn', 'London', 'UK')
# ("B's Beverages", 'London', 'UK')
# ('Consolidated Holdings', 'London', 'UK')
# ('Eastern Connection', 'London', 'UK')
# ('North/South', 'London', 'UK')
# ('Seven Seas Imports', 'London', 'UK')
# ('Exotic Liquids', 'London', 'UK')
# ('Exotic Liquids', 'London', 'UK')
# ('Charlotte Cooper', 'London', 'UK')
# ('Purchasing Manager', 'London', 'UK')
# ('Exotic Liquids', 'London', 'UK')
# ('Exotic Liquids', 'London', 'UK')
# ('Exotic Liquids', 'London', 'UK')
# ('Exotic Liquids', 'London', 'UK')
# ('Exotic Liquids', 'London', 'UK')
# ('Berglunds snabbköp', 'Luleå', 'Sweden')
# ('Lyngbysild', 'Lyngby', 'Denmark')
# ('Lyngbysild', 'Lyngby', 'Denmark')
# ('Niels Petersen', 'Lyngby', 'Denmark')
# ('Sales Manager', 'Lyngby', 'Denmark')
# ('Lyngbysild', 'Lyngby', 'Denmark')
# ('Lyngbysild', 'Lyngby', 'Denmark')
# ('Lyngbysild', 'Lyngby', 'Denmark')
# ('Lyngbysild', 'Lyngby', 'Denmark')
# ('Lyngbysild', 'Lyngby', 'Denmark')
# ('Victuailles en stock', 'Lyon', 'France')
# ('Bólido Comidas preparadas', 'Madrid', 'Spain')
# ('FISSA Fabrica Inter. Salchichas S.A.', 'Madrid', 'Spain')
# ('Romero y tomillo', 'Madrid', 'Spain')
# ('Specialty Biscuits Ltd.', 'Manchester', 'UK')
# ('Specialty Biscuits Ltd.', 'Manchester', 'UK')
# ('Peter Wilson', 'Manchester', 'UK')
# ('Sales Representative', 'Manchester', 'UK')
# ('Specialty Biscuits Ltd.', 'Manchester', 'UK')
# ('Specialty Biscuits Ltd.', 'Manchester', 'UK')
# ('Specialty Biscuits Ltd.', 'Manchester', 'UK')
# ('Specialty Biscuits Ltd.', 'Manchester', 'UK')
# ('Specialty Biscuits Ltd.', 'Manchester', 'UK')
# ('Blauer See Delikatessen', 'Mannheim', 'Germany')
# ("Bon app'", 'Marseille', 'France')
# ('Pavlova Ltd.', 'Melbourne', 'Australia')
# ('Pavlova Ltd.', 'Melbourne', 'Australia')
# ('Ian Devling', 'Melbourne', 'Australia')
# ('Marketing Manager', 'Melbourne', 'Australia')
# ('Pavlova Ltd.', 'Melbourne', 'Australia')
# ('Pavlova Ltd.', 'Melbourne', 'Australia')
# ('Pavlova Ltd.', 'Melbourne', 'Australia')
# ('Pavlova Ltd.', 'Melbourne', 'Australia')
# ('Pavlova Ltd.', 'Melbourne', 'Australia')
# ('Escargots Nouveaux', 'Montceau', 'France')
# ('Escargots Nouveaux', 'Montceau', 'France')
# ('Marie Delamare', 'Montceau', 'France')
# ('Sales Manager', 'Montceau', 'France')
# ('Escargots Nouveaux', 'Montceau', 'France')
# ('Escargots Nouveaux', 'Montceau', 'France')
# ('Escargots Nouveaux', 'Montceau', 'France')
# ('Escargots Nouveaux', 'Montceau', 'France')
# ('Escargots Nouveaux', 'Montceau', 'France')
# ('Mère Paillarde', 'Montréal', 'Canada')
# ('Ma Maison', 'Montréal', 'Canada')
# ('Ma Maison', 'Montréal', 'Canada')
# ('Jean-Guy Lauzon', 'Montréal', 'Canada')
# ('Marketing Manager', 'Montréal', 'Canada')
# ('Ma Maison', 'Montréal', 'Canada')
# ('Ma Maison', 'Montréal', 'Canada')
# ('Ma Maison', 'Montréal', 'Canada')
# ('Ma Maison', 'Montréal', 'Canada')
# ('Ma Maison', 'Montréal', 'Canada')
# ('Ana Trujillo Emparedados y helados', 'México D.F.', 'Mexico')
# ('Antonio Moreno Taquería', 'México D.F.', 'Mexico')
# ('Centro comercial Moctezuma', 'México D.F.', 'Mexico')
# ('Pericles Comidas clásicas', 'México D.F.', 'Mexico')
# ('Tortuga Restaurante', 'México D.F.', 'Mexico')
# ('Frankenversand', 'München', 'Germany')
# ('Toms Spezialitäten', 'Münster', 'Germany')
# ('Du monde entier', 'Nantes', 'France')
# ('France restauration', 'Nantes', 'France')
# ('New Orleans Cajun Delights', 'New Orleans', 'USA')
# ('New Orleans Cajun Delights', 'New Orleans', 'USA')
# ('Shelley Burke', 'New Orleans', 'USA')
# ('Order Administrator', 'New Orleans', 'USA')
# ('New Orleans Cajun Delights', 'New Orleans', 'USA')
# ('New Orleans Cajun Delights', 'New Orleans', 'USA')
# ('New Orleans Cajun Delights', 'New Orleans', 'USA')
# ('New Orleans Cajun Delights', 'New Orleans', 'USA')
# ('New Orleans Cajun Delights', 'New Orleans', 'USA')
# ("Mayumi's", 'Osaka', 'Japan')
# ("Mayumi's", 'Osaka', 'Japan')
# ('Mayumi Ohno', 'Osaka', 'Japan')
# ('Marketing Representative', 'Osaka', 'Japan')
# ("Mayumi's", 'Osaka', 'Japan')
# ("Mayumi's", 'Osaka', 'Japan')
# ("Mayumi's", 'Osaka', 'Japan')
# ("Mayumi's", 'Osaka', 'Japan')
# ("Mayumi's", 'Osaka', 'Japan')
# ('Wartian Herkku', 'Oulu', 'Finland')
# ("Cooperativa de Quesos 'Las Cabras'", 'Oviedo', 'Spain')
# ("Cooperativa de Quesos 'Las Cabras'", 'Oviedo', 'Spain')
# ('Antonio del Valle Saavedra', 'Oviedo', 'Spain')
# ('Export Administrator', 'Oviedo', 'Spain')
# ("Cooperativa de Quesos 'Las Cabras'", 'Oviedo', 'Spain')
# ("Cooperativa de Quesos 'Las Cabras'", 'Oviedo', 'Spain')
# ("Cooperativa de Quesos 'Las Cabras'", 'Oviedo', 'Spain')
# ("Cooperativa de Quesos 'Las Cabras'", 'Oviedo', 'Spain')
# ("Cooperativa de Quesos 'Las Cabras'", 'Oviedo', 'Spain')
# ('Paris spécialités', 'Paris', 'France')
# ('Spécialités du monde', 'Paris', 'France')
# ('Aux joyeux ecclésiastiques', 'Paris', 'France')
# ('Aux joyeux ecclésiastiques', 'Paris', 'France')
# ('Guylène Nodier', 'Paris', 'France')
# ('Sales Manager', 'Paris', 'France')
# ('Aux joyeux ecclésiastiques', 'Paris', 'France')
# ('Aux joyeux ecclésiastiques', 'Paris', 'France')
# ('Aux joyeux ecclésiastiques', 'Paris', 'France')
# ('Aux joyeux ecclésiastiques', 'Paris', 'France')
# ('Aux joyeux ecclésiastiques', 'Paris', 'France')
# ('Lonesome Pine Restaurant', 'Portland', 'USA')
# ('The Big Cheese', 'Portland', 'USA')
# ('Formaggi Fortini s.r.l.', 'Ravenna', 'Italy')
# ('Formaggi Fortini s.r.l.', 'Ravenna', 'Italy')
# ('Elio Rossi', 'Ravenna', 'Italy')
# ('Sales Representative', 'Ravenna', 'Italy')
# ('Formaggi Fortini s.r.l.', 'Ravenna', 'Italy')
# ('Formaggi Fortini s.r.l.', 'Ravenna', 'Italy')
# ('Formaggi Fortini s.r.l.', 'Ravenna', 'Italy')
# ('Formaggi Fortini s.r.l.', 'Ravenna', 'Italy')
# ('Formaggi Fortini s.r.l.', 'Ravenna', 'Italy')
# ('Reggiani Caseifici', 'Reggio Emilia', 'Italy')
# ('Vins et alcools Chevalier', 'Reims', 'France')
# ('Wellington Importadora', 'Resende', 'Brazil')
# ('Hanari Carnes', 'Rio de Janeiro', 'Brazil')
# ('Ricardo Adocicados', 'Rio de Janeiro', 'Brazil')
# ('Pasta Buttini s.r.l.', 'Salerno', 'Italy')
# ('Pasta Buttini s.r.l.', 'Salerno', 'Italy')
# ('Giovanni Giudici', 'Salerno', 'Italy')
# ('Order Administrator', 'Salerno', 'Italy')
# ('Pasta Buttini s.r.l.', 'Salerno', 'Italy')
# ('Pasta Buttini s.r.l.', 'Salerno', 'Italy')
# ('Pasta Buttini s.r.l.', 'Salerno', 'Italy')
# ('Pasta Buttini s.r.l.', 'Salerno', 'Italy')
# ('Pasta Buttini s.r.l.', 'Salerno', 'Italy')
# ('Piccolo und mehr', 'Salzburg', 'Austria')
# ('HILARION-Abastos', 'San Cristóbal', 'Venezuela')
# ("Let's Stop N Shop", 'San Francisco', 'USA')
# ('Greasy Burger', 'Sandnes', 'Norway')
# ('Norske Meierier', 'Sandvika', 'Norway')
# ('Norske Meierier', 'Sandvika', 'Norway')
# ('Beate Vileid', 'Sandvika', 'Norway')
# ('Marketing Manager', 'Sandvika', 'Norway')
# ('Norske Meierier', 'Sandvika', 'Norway')
# ('Norske Meierier', 'Sandvika', 'Norway')
# ('Norske Meierier', 'Sandvika', 'Norway')
# ('Norske Meierier', 'Sandvika', 'Norway')
# ('Norske Meierier', 'Sandvika', 'Norway')
# ('Comércio Mineiro', 'Sao Paulo', 'Brazil')
# ('Familia Arquibaldo', 'Sao Paulo', 'Brazil')
# ('Queen Cozinha', 'Sao Paulo', 'Brazil')
# ('Tradição Hipermercados', 'Sao Paulo', 'Brazil')
# ('Refrescos Americanas LTDA', 'Sao Paulo', 'Brazil')
# ('Refrescos Americanas LTDA', 'Sao Paulo', 'Brazil')
# ('Carlos Diaz', 'Sao Paulo', 'Brazil')
# ('Marketing Manager', 'Sao Paulo', 'Brazil')
# ('Refrescos Americanas LTDA', 'Sao Paulo', 'Brazil')
# ('Refrescos Americanas LTDA', 'Sao Paulo', 'Brazil')
# ('Refrescos Americanas LTDA', 'Sao Paulo', 'Brazil')
# ('Refrescos Americanas LTDA', 'Sao Paulo', 'Brazil')
# ('Refrescos Americanas LTDA', 'Sao Paulo', 'Brazil')
# ('White Clover Markets', 'Seattle', 'USA')
# ('Godos Cocina Típica', 'Sevilla', 'Spain')
# ('Leka Trading', 'Singapore', 'Singapore')
# ('Leka Trading', 'Singapore', 'Singapore')
# ('Chandra Leka', 'Singapore', 'Singapore')
# ('Owner', 'Singapore', 'Singapore')
# ('Leka Trading', 'Singapore', 'Singapore')
# ('Leka Trading', 'Singapore', 'Singapore')
# ('Leka Trading', 'Singapore', 'Singapore')
# ('Leka Trading', 'Singapore', 'Singapore')
# ('Leka Trading', 'Singapore', 'Singapore')
# ('Cardinal', 'Stavanger', 'Norway')
# ('Cardinal', 'Stavanger', 'Norway')
# ('Cardinal', 'Stavanger', 'Norway')
# ('Santé Gourmet', 'Stavern', 'Norway')
# ("Forêts d'érables", 'Ste-Hyacinthe', 'Canada')
# ("Forêts d'érables", 'Ste-Hyacinthe', 'Canada')
# ('Chantal Goulet', 'Ste-Hyacinthe', 'Canada')
# ('Accounting Manager', 'Ste-Hyacinthe', 'Canada')
# ("Forêts d'érables", 'Ste-Hyacinthe', 'Canada')
# ("Forêts d'érables", 'Ste-Hyacinthe', 'Canada')
# ("Forêts d'érables", 'Ste-Hyacinthe', 'Canada')
# ("Forêts d'érables", 'Ste-Hyacinthe', 'Canada')
# ("Forêts d'érables", 'Ste-Hyacinthe', 'Canada')
# ('Svensk Sjöföda AB', 'Stockholm', 'Sweden')
# ('Svensk Sjöföda AB', 'Stockholm', 'Sweden')
# ('Michael Björn', 'Stockholm', 'Sweden')
# ('Sales Representative', 'Stockholm', 'Sweden')
# ('Svensk Sjöföda AB', 'Stockholm', 'Sweden')
# ('Svensk Sjöföda AB', 'Stockholm', 'Sweden')
# ('Svensk Sjöföda AB', 'Stockholm', 'Sweden')
# ('Svensk Sjöföda AB', 'Stockholm', 'Sweden')
# ('Svensk Sjöföda AB', 'Stockholm', 'Sweden')
# ('Blondesddsl père et fils', 'Strasbourg', 'France')
# ('Die Wandernde Kuh', 'Stuttgart', 'Germany')
# ("G'day Mate", 'Sydney', 'Australia')
# ("G'day Mate", 'Sydney', 'Australia')
# ('Wendy Mackenzie', 'Sydney', 'Australia')
# ('Sales Representative', 'Sydney', 'Australia')
# ("G'day Mate", 'Sydney', 'Australia')
# ("G'day Mate", 'Sydney', 'Australia')
# ("G'day Mate", 'Sydney', 'Australia')
# ("G'day Mate", 'Sydney', 'Australia')
# ("G'day Mate", 'Sydney', 'Australia')
# ('Tokyo Traders', 'Tokyo', 'Japan')
# ('Tokyo Traders', 'Tokyo', 'Japan')
# ('Yoshi Nagase', 'Tokyo', 'Japan')
# ('Marketing Manager', 'Tokyo', 'Japan')
# ('Tokyo Traders', 'Tokyo', 'Japan')
# ('Tokyo Traders', 'Tokyo', 'Japan')
# ('Tokyo Traders', 'Tokyo', 'Japan')
# ('Tokyo Traders', 'Tokyo', 'Japan')
# ('Tokyo Traders', 'Tokyo', 'Japan')
# ('Franchi S.p.A.', 'Torino', 'Italy')
# ("La maison d'Asie", 'Toulouse', 'France')
# ('Bottom-Dollar Markets', 'Tsawassen', 'Canada')
# ('Laughing Bacchus Wine Cellars', 'Vancouver', 'Canada')
# ("La corne d'abondance", 'Versailles', 'France')
# ('Lazy K Kountry Store', 'Walla Walla', 'USA')
# ('Wolski  Zajazd', 'Warszawa', 'Poland')
# ('Zaanse Snoepfabriek', 'Zaandam', 'Netherlands')
# ('Zaanse Snoepfabriek', 'Zaandam', 'Netherlands')
# ('Dirk Luchte', 'Zaandam', 'Netherlands')
# ('Accounting Manager', 'Zaandam', 'Netherlands')
# ('Zaanse Snoepfabriek', 'Zaandam', 'Netherlands')
# ('Zaanse Snoepfabriek', 'Zaandam', 'Netherlands')
# ('Zaanse Snoepfabriek', 'Zaandam', 'Netherlands')
# ('Zaanse Snoepfabriek', 'Zaandam', 'Netherlands')
# ('Zaanse Snoepfabriek', 'Zaandam', 'Netherlands')
# ('Vaffeljernet', 'Århus', 'Denmark')

# %%
run_query("SQL Null Functions", "SELECT ProductName, UnitPrice * (UnitsInStock + UnitsOnOrder) FROM Products;")
# Out:
#  SQL Null Functions
# SQL : SELECT ProductName, UnitPrice * (UnitsInStock + UnitsOnOrder) FROM Products;
# ('Chai', 702.0)
# ('Chang', 1083.0)
# ('Aniseed Syrup', 830.0)
# ("Chef Anton's Cajun Seasoning", 1166.0)
# ("Chef Anton's Gumbo Mix", 0.0)
# ("Grandma's Boysenberry Spread", 3000.0)
# ("Uncle Bob's Organic Dried Pears", 450.0)
# ('Northwoods Cranberry Sauce', 240.0)
# ('Mishi Kobe Niku', 2813.0)
# ('Ikura', 961.0)
# ('Queso Cabrales', 1092.0)
# ('Queso Manchego La Pastora', 3268.0)
# ('Konbu', 144.0)
# ('Tofu', 813.75)
# ('Genen Shouyu', 604.5)
# ('Pavlova', 506.04999999999995)
# ('Alice Mutton', 0.0)
# ('Carnarvon Tigers', 2625.0)
# ('Teatime Chocolate Biscuits', 229.99999999999997)
# ("Sir Rodney's Marmalade", 3240.0)
# ("Sir Rodney's Scones", 430.0)
# ("Gustaf's Knäckebröd", 2184.0)
# ('Tunnbröd', 549.0)
# ('Guaraná Fantástica', 90.0)
# ('NuNuCa Nuß-Nougat-Creme', 1064.0)
# ('Gumbär Gummibärchen', 468.45)
# ('Schoggi Schokolade', 2151.1)
# ('Rössle Sauerkraut', 1185.6000000000001)
# ('Thüringer Rostbratwurst', 0.0)
# ('Nord-Ost Matjeshering', 258.9)
# ('Gorgonzola Telino', 875.0)
# ('Mascarpone Fabioli', 1568.0)
# ('Geitost', 280.0)
# ('Sasquatch Ale', 1554.0)
# ('Steeleye Stout', 360.0)
# ('Inlagd Sill', 2128.0)
# ('Gravad lax', 1586.0)
# ('Côte de Blaye', 4479.5)
# ('Chartreuse verte', 1242.0)
# ('Boston Crab Meat', 2263.2)
# ("Jack's New England Clam Chowder", 820.25)
# ('Singaporean Hokkien Fried Mee', 364.0)
# ('Ipoh Coffee', 1242.0)
# ('Gula Malacca', 525.15)
# ('Rogede sild', 712.5)
# ('Spegesild', 1140.0)
# ('Zaanse koeken', 342.0)
# ('Chocolade', 1083.75)
# ('Maxilaku', 1400.0)
# ('Valkoinen suklaa', 1056.25)
# ('Manjimup Dried Apples', 1060.0)
# ('Filo Mix', 266.0)
# ('Perth Pasties', 0.0)
# ('Tourtière', 156.45000000000002)
# ('Pâté chinois', 2760.0)
# ('Gnocchi di nonna Alice', 1178.0)
# ('Ravioli Angelo', 702.0)
# ('Escargots de Bourgogne', 821.5)
# ('Raclette Courdavault', 4345.0)
# ('Camembert Pierrot', 646.0)
# ("Sirop d'érable", 3220.5)
# ('Tarte au sucre', 838.0999999999999)
# ('Vegie-spread', 1053.6)
# ('Wimmers gute Semmelknödel', 3391.5)
# ('Louisiana Fiery Hot Pepper Sauce', 1599.8)
# ('Louisiana Hot Spiced Okra', 1768.0)
# ('Laughing Lumberjack Lager', 728.0)
# ('Scottish Longbreads', 200.0)
# ('Gudbrandsdalsost', 936.0)
# ('Outback Lager', 375.0)
# ('Flotemysost', 559.0)
# ('Mozzarella di Giovanni', 487.19999999999993)
# ('Röd Kaviar', 1515.0)
# ('Longlife Tofu', 240.0)
# ('Rhönbräu Klosterbier', 968.75)
# ('Lakkalikööri', 1026.0)
# ('Original Frankfurter grüne Soße', 416.0)

# %%
# SQLite에서 CREATE PROCEDURE, GO 문법을 모두 지원하지 않는다.
# run_query("SQL Stored Procedures", "CREATE PROCEDURE SelectAllCustomers AS SELECT * FROM Customers GO;")

# %%
run_query("SQL Comments", "-- Select all: SELECT * FROM Customers;")
# Out:
#  SQL Comments
# SQL : -- Select all: SELECT * FROM Customers;
